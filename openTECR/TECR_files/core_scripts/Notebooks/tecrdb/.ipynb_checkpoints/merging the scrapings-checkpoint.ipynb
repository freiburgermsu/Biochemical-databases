# %% [markdown]
# # Import the scrapings

# %% [markdown]
# ### Refining the freiburger scraping

# %%
from numpy import unique, nan 
import re 

empty = [nan, 'nan', None, ' ', '', 'NaN']


def refine_freiburger(freiburger_file):
    # strip spaces from the freiburger_file
    for column in freiburger_file:
        for index, entry in freiburger_file[column].iteritems():
            if entry is float:
                freiburger_file.at[index, column] = str(entry).strip(' ?~')
                freiburger_file.at[index, column] = float(entry)
            elif entry is int:
                freiburger_file.at[index, column] = str(entry).strip(' ?~')
                freiburger_file.at[index, column] = int(entry)
            else:
                freiburger_file.at[index, column] = str(entry).strip(' ?~')

    # extrapolate metadata to all datums
    for index, row in freiburger_file.iterrows():    
        if row['Reference ID:'] not in empty:
            reference_id = row['Reference ID:']
            reference = row['Reference:']
            methods = row['Method:']
            buffer = row['Buffer:']
            ec = row['EC Value:']
        elif row['Reference ID:'] in empty:
            freiburger_file.at[index, 'Reference ID:'] = reference_id
            freiburger_file.at[index, 'Reference:'] = reference
            freiburger_file.at[index, 'Method:'] = methods
            freiburger_file.at[index, 'Buffer:'] = buffer
            freiburger_file.at[index, 'EC Value:'] = ec
        else:
            print('ERROR: The reference has an unidentified structure.')
        
    # strip the EC values
    for index, master_ec in freiburger_file['EC Value:'].iteritems():
        if master_ec not in empty:  
            master_ec = re.search('([\d|\.|\-]+)', master_ec).group()
            freiburger_file['EC Value:'].iloc[index] = master_ec
            
    # consolidate the solutes column 
    for index, solute in freiburger_file['solutes [mol / dm^3]'].iteritems():
        if solute not in empty:  
            solute_list = solute.split(' & ')
            if len(solute_list) > 1:
                solute_list = unique(solute_list)
                if len(solute_list) > 2:
                    print('Large solute set {}'.format(solute_list))
                else:
                    freiburger_file['solutes [mol / dm^3]'].iloc[index] = ' & '.join([x for x in list(solute_list)])

            elif solute_list[0] in ['#NAME']:
                freiburger_file['solutes [mol / dm^3]'].iloc[index] = ''

    # create the additional columns
    column_nans = ['' for row in range(len(freiburger_file))]  
    freiburger_file.insert(0, 'noor_index', column_nans)  
    freiburger_file.insert(0, 'du_index', column_nans)  
    freiburger_file.insert(0, 'freiburger_index', freiburger_file.index)
    freiburger_file.insert(4, 'KEGG Reaction:', column_nans)
    freiburger_file.insert(5, 'CID Reaction:', column_nans)

    for index, value in freiburger_file[['Ionic strength [mol / dm^3]', 'Ionic strength [mol / kg]']].iterrows():
        if value['Ionic strength [mol / kg]'] in empty:
            freiburger_file.at[index, 'Ionic strength [mol / kg]'] = value['Ionic strength [mol / dm^3]']
        elif value['Ionic strength [mol / kg]'] not in empty:
            if value['Ionic strength [mol / dm^3]'] not in empty:
                if value['Ionic strength [mol / dm^3]'] != value['Ionic strength [mol / kg]']:
                    print(value['Ionic strength [mol / dm^3]'], '\t', value['Ionic strength [mol / kg]'])
                    freiburger_file.at[index, 'Ionic strength [mol / kg]'] = average(value['Ionic strength [mol / kg]'], value['Ionic strength [mol / dm^3]'])

    
    return freiburger_file

# %% [markdown]
# ### import the CSV files

# %%
import pandas

noor_dataframe = pandas.read_csv('TECRDB_Elad_Noor.csv').fillna(' ')
manual_noor_curation = pandas.read_csv('Manual curation of Noor et al., comma delimited.txt', header = 0)

du_dataframe = pandas.read_excel('mmc2.xlsx', sheet_name = 'Table S1. TECRDB Keqs')
du_dataframe.rename(columns = {'Reaction.1': 'reaction_string'}, inplace = True)
manual_du_curation = pandas.read_csv('Manual curation of Du et al., comma delimited.txt', header = 0)

freiburger_dataframe = pandas.read_csv('2021-08-04_vetted & reorganized NIST database_01.csv').fillna(' ')
freiburger_dataframe = refine_freiburger(freiburger_dataframe)
freiburger_dataframe.head()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:296: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    freiburger_index du_index noor_index                  Enzyme:  \
# 0                 0                      aspartate ammonia-lyase
# 1                 1                      aspartate ammonia-lyase
# 2                 2                           fumarate hydratase
# 3                 3                           fumarate hydratase
# 4                 4                           fumarate hydratase
#
#   KEGG Reaction: CID Reaction:                                     Reaction:  \
# 0                               L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 1                               L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 2                                     fumarate(aq) + H2O(l) = (S)-malate(aq)
# 3                                     fumarate(aq) + H2O(l) = (S)-malate(aq)
# 4                                     fumarate(aq) + H2O(l) = (S)-malate(aq)
#
#                                           Reference:   Reference ID:   T [K]  \
# 0  Quastel J.H.; Woolf B.; Biochem. J.; 20 545 (1...  26QUA/WOO_1205  310.15
# 1              Woolf B.; Biochem. J.; 23 472 (1929).      29WOO_1206  310.15
# 2  Borsook H.; Schott H.F.; J. Biol. Chem.; 92 55...  31BOR/SCH_1141  298.15
# 3  Borsook H.; Schott H.F.; J. Biol. Chem.; 92 55...  31BOR/SCH_1141  298.15
# 4       Jacobsohn K.P.; Biochem. Z.; 274 167 (1934).      34JAC_1142  278.15
#
#    ... Km                            Method:    Buffer:  \
# 0  ...                     chemical analysis  phosphate
# 1  ...     chemical analysis and polarimetry  phosphate
# 2  ...                      electrochemistry
# 3  ...                      electrochemistry
# 4  ...                           polarimetry   barbital
#
#   Experimental conditions EC Value: solutes [mol / kg] solutes [mol / dm^3]  \
# 0                           4.3.1.1
# 1                           4.3.1.1
# 2                           4.2.1.2
# 3                           4.2.1.2
# 4                           4.2.1.2
#
#   Ionic strength [mol / dm^3] Ionic strength [mol / kg] Enthalpy [kJ / mol]
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %% [markdown]
# # Merge the scrapings

# %%
# %run ../../merging_datasets.py

# merging the noor scraping
elad_enzymes = 'enzyme_name'
elad_references = 'reference'
scraping_name = 'noor'
mrgpkg = merge_package(freiburger_dataframe, noor_dataframe, scraping_name)
# mrgpkg.add_new(elad_enzymes, elad_references) #, export = True)
# mrgpkg.merge_existing()#export = True)
# mrgpkg.incorporate_manual_curation(manual_noor_curation, export = True)
# mrgpkg.confirm_merging()
noor_master_merge = mrgpkg.merge(elad_enzymes, elad_references, manual_noor_curation, export = False)

# merging the du scraping
du_enzymes = 'Reaction'
du_references = 'Reference_id'
scraping_name = 'du'
mrgpkg = merge_package(noor_master_merge, du_dataframe, scraping_name) #, first = False)
# mrgpkg.add_new(du_enzymes, du_references, export = False)
# mrgpkg.merge_existing()#export = True)
# mrgpkg.incorporate_manual_curation(manual_du_curation, export = False)
mrgpkg.merge(du_enzymes, du_references, manual_du_curation, export = True)
missing_indices = mrgpkg.confirm_merging()

if missing_indices is not None:
    print(len(missing_indices))
    for index in missing_indices:
        print(f'{index},\t\tReaction string,\t\t\t')
# final_master_file = mrgpkg.merge(du_enzymes, du_references, manual_du_curation, export = True)
# Out:
# ==============================
#
# enzymes in the master file:  425
# enzymes in the new file:  431
# Extra enzymes in the master file, versus new file:  60
# Missing enzymes in the master file, versus new file:  66
# ==============================
#
# references in the master file:  911
# references in the new file:  919
# Extra references in the master file, versus new file:  96
# Missing references in the master file, versus new file:  104
# before 4041
# after 4934
# total additions 893
# --> Failed index to match:  38 ___ hexokinase
# --> Failed index to match:  79 ___ shikimate dehydrogenase
# --> Failed index to match:  80 ___ shikimate dehydrogenase
# --> Failed index to match:  114 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  270 ___ alkaline phosphatase
# --> Failed index to match:  271 ___ alkaline phosphatase
# --> Failed index to match:  283 ___ glucose-6-phosphate 1-epimerase
# --> Failed index to match:  315 ___ adenylate kinase
# --> Failed index to match:  358 ___ creatine kinase
# --> Failed index to match:  449 ___ phosphoserine transaminase
# --> Failed index to match:  470 ___ phosphoserine transaminase
# --> Failed index to match:  518 ___ diiodophenylpyruvate reductase
# --> Failed index to match:  674 ___ penicillin amidase
# --> Failed index to match:  729 ___ UDPglucose-hexose-1-phosphate uridylyltransferase
# --> Failed index to match:  965 ___ acetate-CoA ligase
# --> Failed index to match:  1051 ___ alkaline phosphatase
# --> Failed index to match:  1052 ___ alkaline phosphatase
# --> Failed index to match:  1096 ___ adenylate kinase
# --> Failed index to match:  1097 ___ adenylate kinase
# --> Failed index to match:  1098 ___ adenylate kinase
# --> Failed index to match:  1099 ___ adenylate kinase
# --> Failed index to match:  1100 ___ adenylate kinase
# --> Failed index to match:  1101 ___ adenylate kinase
# --> Failed index to match:  1102 ___ adenylate kinase
# --> Failed index to match:  1103 ___ adenylate kinase
# --> Failed index to match:  1104 ___ adenylate kinase
# --> Failed index to match:  1105 ___ adenylate kinase
# --> Failed index to match:  1106 ___ adenylate kinase
# --> Failed index to match:  1107 ___ adenylate kinase
# --> Failed index to match:  1108 ___ adenylate kinase
# --> Failed index to match:  1109 ___ adenylate kinase
# --> Failed index to match:  1110 ___ adenylate kinase
# --> Failed index to match:  1111 ___ adenylate kinase
# --> Failed index to match:  1112 ___ adenylate kinase
# --> Failed index to match:  1113 ___ adenylate kinase
# --> Failed index to match:  1114 ___ adenylate kinase
# --> Failed index to match:  1115 ___ adenylate kinase
# --> Failed index to match:  1116 ___ adenylate kinase
# --> Failed index to match:  1117 ___ adenylate kinase
# --> Failed index to match:  1118 ___ adenylate kinase
# --> Failed index to match:  1119 ___ adenylate kinase
# --> Failed index to match:  1120 ___ adenylate kinase
# --> Failed index to match:  1121 ___ adenylate kinase
# --> Failed index to match:  1122 ___ adenylate kinase
# --> Failed index to match:  1123 ___ adenylate kinase
# --> Failed index to match:  1124 ___ adenylate kinase
# --> Failed index to match:  1125 ___ adenylate kinase
# --> Failed index to match:  1126 ___ adenylate kinase
# --> Failed index to match:  1127 ___ adenylate kinase
# --> Failed index to match:  1128 ___ adenylate kinase
# --> Failed index to match:  1129 ___ adenylate kinase
# --> Failed index to match:  1130 ___ adenylate kinase
# --> Failed index to match:  1131 ___ adenylate kinase
# --> Failed index to match:  1132 ___ adenylate kinase
# --> Failed index to match:  1133 ___ adenylate kinase
# --> Failed index to match:  1134 ___ adenylate kinase
# --> Failed index to match:  1135 ___ adenylate kinase
# --> Failed index to match:  1136 ___ adenylate kinase
# --> Failed index to match:  1137 ___ adenylate kinase
# --> Failed index to match:  1138 ___ adenylate kinase
# --> Failed index to match:  1139 ___ adenylate kinase
# --> Failed index to match:  1140 ___ adenylate kinase
# --> Failed index to match:  1141 ___ adenylate kinase
# --> Failed index to match:  1142 ___ adenylate kinase
# --> Failed index to match:  1143 ___ adenylate kinase
# --> Failed index to match:  1144 ___ adenylate kinase
# --> Failed index to match:  1145 ___ adenylate kinase
# --> Failed index to match:  1146 ___ adenylate kinase
# --> Failed index to match:  1147 ___ adenylate kinase
# --> Failed index to match:  1148 ___ adenylate kinase
# --> Failed index to match:  1149 ___ adenylate kinase
# --> Failed index to match:  1150 ___ adenylate kinase
# --> Failed index to match:  1151 ___ adenylate kinase
# --> Failed index to match:  1152 ___ adenylate kinase
# --> Failed index to match:  1153 ___ adenylate kinase
# --> Failed index to match:  1154 ___ adenylate kinase
# --> Failed index to match:  1155 ___ adenylate kinase
# --> Failed index to match:  1156 ___ adenylate kinase
# --> Failed index to match:  1157 ___ adenylate kinase
# --> Failed index to match:  1158 ___ adenylate kinase
# --> Failed index to match:  1159 ___ adenylate kinase
# --> Failed index to match:  1160 ___ adenylate kinase
# --> Failed index to match:  1161 ___ adenylate kinase
# --> Failed index to match:  1162 ___ adenylate kinase
# --> Failed index to match:  1163 ___ adenylate kinase
# --> Failed index to match:  1164 ___ adenylate kinase
# --> Failed index to match:  1165 ___ adenylate kinase
# --> Failed index to match:  1166 ___ adenylate kinase
# --> Failed index to match:  1167 ___ adenylate kinase
# --> Failed index to match:  1168 ___ adenylate kinase
# --> Failed index to match:  1169 ___ adenylate kinase
# --> Failed index to match:  1170 ___ adenylate kinase
# --> Failed index to match:  1171 ___ adenylate kinase
# --> Failed index to match:  1172 ___ adenylate kinase
# --> Failed index to match:  1173 ___ adenylate kinase
# --> Failed index to match:  1174 ___ adenylate kinase
# --> Failed index to match:  1175 ___ adenylate kinase
# --> Failed index to match:  1176 ___ adenylate kinase
# --> Failed index to match:  1177 ___ adenylate kinase
# --> Failed index to match:  1178 ___ adenylate kinase
# --> Failed index to match:  1179 ___ adenylate kinase
# --> Failed index to match:  1180 ___ adenylate kinase
# --> Failed index to match:  1181 ___ adenylate kinase
# --> Failed index to match:  1182 ___ adenylate kinase
# --> Failed index to match:  1183 ___ adenylate kinase
# --> Failed index to match:  1184 ___ adenylate kinase
# --> Failed index to match:  1185 ___ adenylate kinase
# --> Failed index to match:  1186 ___ adenylate kinase
# --> Failed index to match:  1187 ___ adenylate kinase
# --> Failed index to match:  1218 ___ galactose dehydrogenase
# --> Failed index to match:  1312 ___ adenine phosphoribosyltransferase
# --> Failed index to match:  1338 ___ urease
# --> Failed index to match:  1339 ___ urease
# --> Failed index to match:  1340 ___ urease
# --> Failed index to match:  1341 ___ urease
# --> Failed index to match:  1342 ___ urease
# --> Failed index to match:  1379 ___ triose-phosphate isomerase and fructose-bisphosphate aldolase
# --> Failed index to match:  1397 ___ _-glucosidase
# --> Failed index to match:  1478 ___ fructose-biphosphatase
# --> Failed index to match:  1479 ___ fructose-biphosphatase
# --> Failed index to match:  1512 ___ fumarate hydratase
# --> Failed index to match:  1574 ___ myosin ATPase
# --> Failed index to match:  1633 ___ hexokinase
# --> Failed index to match:  1743 ___ fumarate hydratase
# --> Failed index to match:  1764 ___ fumarate hydratase
# --> Failed index to match:  1772 ___ phosphoglucomutase
# --> Failed index to match:  1796 ___ glutamate dehydrogenase
# --> Failed index to match:  1870 ___ _-glucosidase
# --> Failed index to match:  1915 ___ alkaline phosphatase
# --> Failed index to match:  1960 ___ pyrroline-2-carboxylate reductase
# --> Failed index to match:  1961 ___ pyrroline-2-carboxylate reductase
# --> Failed index to match:  1962 ___ pyrroline-2-carboxylate reductase
# --> Failed index to match:  1963 ___ pyrroline-2-carboxylate reductase
# --> Failed index to match:  2035 ___ penicillin amidase
# --> Failed index to match:  2036 ___ penicillin amidase
# --> Failed index to match:  2037 ___ penicillin amidase
# --> Failed index to match:  2038 ___ penicillin amidase
# --> Failed index to match:  2039 ___ penicillin amidase
# --> Failed index to match:  2040 ___ penicillin amidase
# --> Failed index to match:  2041 ___ penicillin amidase
# --> Failed index to match:  2186 ___ aconitate hydratase
# --> Failed index to match:  2229 ___ prephenate dehydratase
# --> Failed index to match:  2259 ___ alkaline phosphatase
# --> Failed index to match:  2331 ___ glyceraldehyde-3-phosphate dehydrogenase
# --> Failed index to match:  2373 ___ adenosine deaminase
# --> Failed index to match:  2374 ___ adenosine deaminase
# --> Failed index to match:  2375 ___ adenosine deaminase
# --> Failed index to match:  2376 ___ adenosine deaminase
# --> Failed index to match:  2377 ___ adenosine deaminase
# --> Failed index to match:  2378 ___ adenosine deaminase
# --> Failed index to match:  2379 ___ adenosine deaminase
# --> Failed index to match:  2380 ___ adenosine deaminase
# --> Failed index to match:  2381 ___ adenosine deaminase
# --> Failed index to match:  2382 ___ adenosine deaminase
# --> Failed index to match:  2477 ___ creatine kinase
# --> Failed index to match:  2498 ___ creatine kinase
# --> Failed index to match:  2519 ___ alanine racemase
# --> Failed index to match:  2688 ___ adenylate kinase
# --> Failed index to match:  2716 ___ ornithine-oxo-acid transaminase
# --> Failed index to match:  2785 ___ succinate-CoA ligase (GDP-forming)
# --> Failed index to match:  2802 ___ nicotinamide-nucleotide adenylyltransferase
# --> Failed index to match:  2911 ___ UDPglucose-hexose-1-phosphate uridylyltransferase
# --> Failed index to match:  2912 ___ _-alanine-pyruvate transaminase
# --> Failed index to match:  2934 ___ alcohol dehydrogenase
# --> Failed index to match:  2961 ___ alkaline phosphatase
# --> Failed index to match:  2982 ___ alkaline phosphatase
# --> Failed index to match:  3025 ___ alkaline phosphatase
# --> Failed index to match:  3035 ___ alkaline phosphatase
# --> Failed index to match:  3117 ___ shikimate dehydrogenase
# --> Failed index to match:  3170 ___ phosphoserine phosphatase
# --> Failed index to match:  3191 ___ phosphoserine phosphatase
# --> Failed index to match:  3204 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  3289 ___ glycerate dehydrogenase
# --> Failed index to match:  3392 ___ valine-tRNA ligase
# --> Failed index to match:  3608 ___ myosin ATPase
# --> Failed index to match:  3609 ___ myosin ATPase
# --> Failed index to match:  3610 ___ myosin ATPase
# --> Failed index to match:  3611 ___ myosin ATPase
# --> Failed index to match:  3612 ___ myosin ATPase
# --> Failed index to match:  3613 ___ myosin ATPase
# --> Failed index to match:  3658 ___ shikimate dehydrogenase
# --> Failed index to match:  3659 ___ shikimate dehydrogenase
# --> Failed index to match:  3662 ___ alkaline phosphatase
# --> Failed index to match:  3663 ___ alkaline phosphatase
# --> Failed index to match:  3664 ___ alkaline phosphatase
# --> Failed index to match:  3665 ___ alkaline phosphatase
# --> Failed index to match:  3666 ___ alkaline phosphatase
# --> Failed index to match:  3667 ___ alkaline phosphatase
# --> Failed index to match:  3668 ___ alkaline phosphatase
# --> Failed index to match:  3669 ___ alkaline phosphatase
# --> Failed index to match:  3670 ___ alkaline phosphatase
# --> Failed index to match:  3671 ___ alkaline phosphatase
# --> Failed index to match:  3672 ___ alkaline phosphatase
# --> Failed index to match:  3673 ___ alkaline phosphatase
# --> Failed index to match:  3674 ___ alkaline phosphatase
# --> Failed index to match:  3675 ___ alkaline phosphatase
# --> Failed index to match:  3676 ___ alkaline phosphatase
# --> Failed index to match:  3677 ___ alkaline phosphatase
# --> Failed index to match:  3678 ___ alkaline phosphatase
# --> Failed index to match:  3679 ___ alkaline phosphatase
# --> Failed index to match:  3680 ___ alkaline phosphatase
# --> Failed index to match:  3681 ___ alkaline phosphatase
# --> Failed index to match:  3682 ___ alkaline phosphatase
# --> Failed index to match:  3683 ___ alkaline phosphatase
# --> Failed index to match:  3684 ___ alkaline phosphatase
# --> Failed index to match:  3685 ___ alkaline phosphatase
# --> Failed index to match:  3686 ___ alkaline phosphatase
# --> Failed index to match:  3687 ___ alkaline phosphatase
# --> Failed index to match:  3688 ___ alkaline phosphatase
# --> Failed index to match:  3689 ___ alkaline phosphatase
# --> Failed index to match:  3690 ___ alkaline phosphatase
# --> Failed index to match:  3691 ___ alkaline phosphatase
# --> Failed index to match:  3692 ___ alkaline phosphatase
# --> Failed index to match:  3693 ___ alkaline phosphatase
# --> Failed index to match:  3964 ___ alkaline phosphatase
# --> Failed index to match:  3965 ___ alkaline phosphatase
# --> Failed index to match:  3966 ___ alkaline phosphatase
# --> Failed index to match:  3967 ___ alkaline phosphatase
# --> Failed index to match:  3968 ___ alkaline phosphatase
# --> Failed index to match:  3969 ___ alkaline phosphatase
# --> Failed index to match:  3970 ___ alkaline phosphatase
# --> Failed index to match:  3971 ___ alkaline phosphatase
# --> Failed index to match:  3972 ___ alkaline phosphatase
# --> Failed index to match:  3973 ___ alkaline phosphatase
# --> Failed index to match:  3974 ___ alkaline phosphatase
# --> Failed index to match:  3975 ___ alkaline phosphatase
# --> Failed index to match:  3976 ___ alkaline phosphatase
# --> Failed index to match:  3977 ___ alkaline phosphatase
# --> Failed index to match:  3978 ___ alkaline phosphatase
# --> Failed index to match:  4039 ___ adenylosuccinate lyase
# --> Failed index to match:  4170 ___ dihydrolipoamide dehydrogenase
# --> Failed index to match:  4191 ___ dihydrolipoamide dehydrogenase
# --> Failed index to match:  4367 ___ alcohol dehydrogenase
# --> Failed index to match:  4420 ___ 1-piperidine-2-carboxylate reductase
# --> Failed index to match:  4421 ___ 1-piperidine-2-carboxylate reductase
# --> Failed index to match:  4422 ___ 1-piperidine-2-carboxylate reductase
# --> Failed index to match:  4423 ___ 1-piperidine-2-carboxylate reductase
# --> Failed index to match:  4424 ___ 1-piperidine-2-carboxylate reductase
# --> Failed index to match:  4425 ___ 1-piperidine-2-carboxylate reductase
# --> Failed index to match:  4467 ___ aconitate hydratase
# --> Failed index to match:  4493 ___ glucose-6-phosphate isomerase
# Unmatched indices:  298
# The [38] new_id is a duplicate.
# The [77] new_id is a duplicate.
# 79
# [79, 80]
# 0
# [708, 709]
# 80
# [79, 80]
# 1
# [708, 709]
# The [114] new_id is a duplicate.
# --> ERROR: Repeated noor index < 242 >
# 270
# [270]
# 0
# [1762]
# 271
# [271]
# 0
# [1763]
# 283
# [283]
# 0
# [2009]
# The [315] new_id is a duplicate.
# The [358] new_id is a duplicate.
# The [449] new_id is a duplicate.
# The [470] new_id is a duplicate.
# 518
# [518]
# 0
# [1835]
# The [674] new_id is a duplicate.
# 729
# [729]
# 0
# [2281]
# --> ERROR: Repeated noor index < 849 >
# --> ERROR: Repeated noor index < 850 >
# The [965] new_id is a duplicate.
# 1218
# [1218]
# 0
# [2278]
# 1338
# [1338, 1339, 1340, 1341, 1342]
# 0
# [2778, 2779, 2780, 2781, 2782]
# 1339
# [1338, 1339, 1340, 1341, 1342]
# 1
# [2778, 2779, 2780, 2781, 2782]
# 1340
# [1338, 1339, 1340, 1341, 1342]
# 2
# [2778, 2779, 2780, 2781, 2782]
# 1341
# [1338, 1339, 1340, 1341, 1342]
# 3
# [2778, 2779, 2780, 2781, 2782]
# 1342
# [1338, 1339, 1340, 1341, 1342]
# 4
# [2778, 2779, 2780, 2781, 2782]
# The [1379] new_id is a duplicate.
# 1397
# [1397]
# 0
# [3653]
# The [1512] new_id is a duplicate.
# 1574
# [1574]
# 0
# [1761]
# The [1633] new_id is a duplicate.
# The [1743] new_id is a duplicate.
# The [1764] new_id is a duplicate.
# The [1796] new_id is a duplicate.
# 1870
# [1870]
# 0
# [3654]
# 1915
# [1915]
# 0
# [1824]
# 1960
# [1960, 1961, 1962, 1963]
# 0
# ['3232', '3233', '3231', '3230']
# 1961
# [1960, 1961, 1962, 1963]
# 1
# ['3232', '3233', '3231', '3230']
# 1962
# [1960, 1961, 1962, 1963]
# 2
# ['3232', '3233', '3231', '3230']
# 1963
# [1960, 1961, 1962, 1963]
# 3
# ['3232', '3233', '3231', '3230']
# The [2137] new_id is already matched.
# The [2186] new_id is a duplicate.
# 2229
# [2229]
# 0
# [4030]
# The [2259] new_id is a duplicate.
# The [2331] new_id is a duplicate.
# The [2477] new_id is a duplicate.
# The [2498] new_id is a duplicate.
# The [2688] new_id is a duplicate.
# 2716
# [2716]
# 0
# [1351]
# The [2725] new_id is already matched.
# The [2785] new_id is a duplicate.
# 2802
# [2802]
# 0
# [261]
# 2911
# [2911]
# 0
# [1119]
# 2912
# [2912]
# 0
# [1211]
# The [2934] new_id is a duplicate.
# The [2961] new_id is a duplicate.
# The [2982] new_id is a duplicate.
# 3025
# [3025]
# 0
# [1821]
# 3035
# [3035]
# 0
# [1822]
# 3117
# [3117]
# 0
# [1802]
# The [3170] new_id is a duplicate.
# The [3191] new_id is a duplicate.
# The [3204] new_id is a duplicate.
# The [3289] new_id is a duplicate.
# --> ERROR: Repeated noor index < 3345 >
# 3392
# [3392]
# 0
# [1149]
# The [3489, 3490] new_id is already matched.
# The [3608, 3609, 3610, 3611, 3612, 3613] new_id is a duplicate.
# 3658
# [3658, 3659]
# 0
# [664, 665]
# 3659
# [3658, 3659]
# 1
# [664, 665]
# The [3761] new_id is a duplicate.
# 3852
# [3852, 3853, 3854, 3855, 3856, 3857]
# 0
# [3500, 3501, 3502, 3503, 3504, 3505]
# 3853
# [3852, 3853, 3854, 3855, 3856, 3857]
# 1
# [3500, 3501, 3502, 3503, 3504, 3505]
# 3854
# [3852, 3853, 3854, 3855, 3856, 3857]
# 2
# [3500, 3501, 3502, 3503, 3504, 3505]
# 3855
# [3852, 3853, 3854, 3855, 3856, 3857]
# 3
# [3500, 3501, 3502, 3503, 3504, 3505]
# 3856
# [3852, 3853, 3854, 3855, 3856, 3857]
# 4
# [3500, 3501, 3502, 3503, 3504, 3505]
# 3857
# [3852, 3853, 3854, 3855, 3856, 3857]
# 5
# [3500, 3501, 3502, 3503, 3504, 3505]
# 3932
# [3932]
# 0
# [2875]
# 4039
# [4039]
# 0
# [1051]
# The [4191] new_id is a duplicate.
# The [4367] new_id is a duplicate.
# 4420
# [4420, 4421]
# 0
# [3642, 3643]
# 4421
# [4420, 4421]
# 1
# [3642, 3643]
# 4422
# [4422]
# 0
# [3640]
# 4423
# [4423]
# 0
# [3641]
# 4424
# [4424]
# 0
# [3644]
# 4425
# [4425]
# 0
# [3639]
# The [4493] new_id is a duplicate.
# Parsing errors:  None
# missing unique indices None
# ==============================
#
# enzymes in the master file:  491
# enzymes in the new file:  413
# Extra enzymes in the master file, versus new file:  92
# Missing enzymes in the master file, versus new file:  14
# ==============================
#
# references in the master file:  1015
# references in the new file:  876
# Extra references in the master file, versus new file:  151
# Missing references in the master file, versus new file:  12
# before 5152
# after 5250
# total additions 98
# --> Failed index to match:  5 ___ ADPglucose phosphodiesterase
# --> Failed index to match:  6 ___ isochorismate synthase
# --> Failed index to match:  7 ___ isochorismate synthase
# --> Failed index to match:  8 ___ branched-chain-amino-acid transferase
# --> Failed index to match:  9 ___ branched-chain-amino-acid transferase
# --> Failed index to match:  11 ___ branched-chain-amino-acid transferase
# --> Failed index to match:  12 ___ branched-chain-amino-acid transferase
# --> Failed index to match:  13 ___ branched-chain-amino-acid transferase
# --> Failed index to match:  14 ___ enoyl-CoA hydratase
# --> Failed index to match:  15 ___ 2-dehydropantoate 2-reductase
# --> Failed index to match:  16 ___ trehalose-6-phosphate phosphorylase
# --> Failed index to match:  17 ___ trehalose-6-phosphate phosphorylase
# --> Failed index to match:  21 ___ pyruvate kinase
# --> Failed index to match:  22 ___ pyruvate kinase
# --> Failed index to match:  24 ___ pyruvate kinase
# --> Failed index to match:  25 ___ pyruvate kinase
# --> Failed index to match:  27 ___ pyruvate kinase
# --> Failed index to match:  32 ___ D-lactate dehydrogenase
# --> Failed index to match:  33 ___ D-lactate dehydrogenase
# --> Failed index to match:  37 ___ xylose isomerase
# --> Failed index to match:  43 ___ xylose isomerase
# --> Failed index to match:  57 ___ xylose isomerase
# --> Failed index to match:  58 ___ xylose isomerase
# --> Failed index to match:  59 ___ alcohol dehydrogenase
# --> Failed index to match:  60 ___ alcohol dehydrogenase
# --> Failed index to match:  61 ___ alcohol dehydrogenase
# --> Failed index to match:  62 ___ alcohol dehydrogenase
# --> Failed index to match:  63 ___ alcohol dehydrogenase
# --> Failed index to match:  64 ___ alcohol dehydrogenase
# --> Failed index to match:  65 ___ alcohol dehydrogenase
# --> Failed index to match:  66 ___ alcohol dehydrogenase
# --> Failed index to match:  67 ___ alcohol dehydrogenase
# --> Failed index to match:  68 ___ alcohol dehydrogenase
# --> Failed index to match:  69 ___ alcohol dehydrogenase
# --> Failed index to match:  70 ___ alcohol dehydrogenase
# --> Failed index to match:  71 ___ alcohol dehydrogenase
# --> Failed index to match:  72 ___ alcohol dehydrogenase
# --> Failed index to match:  73 ___ alcohol dehydrogenase
# --> Failed index to match:  74 ___ alcohol dehydrogenase
# --> Failed index to match:  75 ___ alcohol dehydrogenase
# --> Failed index to match:  76 ___ alcohol dehydrogenase
# --> Failed index to match:  77 ___ alcohol dehydrogenase
# --> Failed index to match:  78 ___ alcohol dehydrogenase
# --> Failed index to match:  79 ___ alcohol dehydrogenase
# --> Failed index to match:  80 ___ alcohol dehydrogenase
# --> Failed index to match:  81 ___ alcohol dehydrogenase
# --> Failed index to match:  82 ___ alcohol dehydrogenase
# --> Failed index to match:  83 ___ alcohol dehydrogenase
# --> Failed index to match:  84 ___ alcohol dehydrogenase
# --> Failed index to match:  85 ___ alcohol dehydrogenase
# --> Failed index to match:  86 ___ alcohol dehydrogenase
# --> Failed index to match:  87 ___ alcohol dehydrogenase
# --> Failed index to match:  88 ___ alcohol dehydrogenase
# --> Failed index to match:  89 ___ alcohol dehydrogenase
# --> Failed index to match:  90 ___ alcohol dehydrogenase
# --> Failed index to match:  91 ___ alcohol dehydrogenase
# --> Failed index to match:  92 ___ alcohol dehydrogenase
# --> Failed index to match:  93 ___ alcohol dehydrogenase
# --> Failed index to match:  94 ___ alcohol dehydrogenase
# --> Failed index to match:  95 ___ alcohol dehydrogenase
# --> Failed index to match:  96 ___ alcohol dehydrogenase
# --> Failed index to match:  97 ___ alcohol dehydrogenase
# --> Failed index to match:  98 ___ alcohol dehydrogenase
# --> Failed index to match:  99 ___ alcohol dehydrogenase
# --> Failed index to match:  100 ___ alcohol dehydrogenase
# --> Failed index to match:  101 ___ alcohol dehydrogenase
# --> Failed index to match:  102 ___ alcohol dehydrogenase
# --> Failed index to match:  103 ___ alcohol dehydrogenase
# --> Failed index to match:  104 ___ alcohol dehydrogenase
# --> Failed index to match:  105 ___ alcohol dehydrogenase
# --> Failed index to match:  106 ___ alcohol dehydrogenase
# --> Failed index to match:  107 ___ alcohol dehydrogenase
# --> Failed index to match:  108 ___ alcohol dehydrogenase
# --> Failed index to match:  109 ___ alcohol dehydrogenase
# --> Failed index to match:  110 ___ alcohol dehydrogenase
# --> Failed index to match:  111 ___ alcohol dehydrogenase
# --> Failed index to match:  112 ___ alcohol dehydrogenase
# --> Failed index to match:  113 ___ alcohol dehydrogenase
# --> Failed index to match:  114 ___ alcohol dehydrogenase
# --> Failed index to match:  115 ___ alcohol dehydrogenase
# --> Failed index to match:  116 ___ alcohol dehydrogenase
# --> Failed index to match:  117 ___ alcohol dehydrogenase
# --> Failed index to match:  118 ___ alcohol dehydrogenase
# --> Failed index to match:  120 ___ isocitrate lyase
# --> Failed index to match:  127 ___ saccharopine dehydrogenase (NAD+, L-lysine-forming)
# --> Failed index to match:  128 ___ homoisocitrate dehydrogenase
# --> Failed index to match:  129 ___ dihydropyrimidinase
# --> Failed index to match:  130 ___ dihydropyrimidinase
# --> Failed index to match:  134 ___ dihydropyrimidinase
# --> Failed index to match:  135 ___ dihydropyrimidinase
# --> Failed index to match:  136 ___ dihydropyrimidinase
# --> Failed index to match:  137 ___ dihydropyrimidinase
# --> Failed index to match:  138 ___ dihydropyrimidinase
# --> Failed index to match:  139 ___ dihydropyrimidinase
# --> Failed index to match:  200 ___ arginine kinase
# --> Failed index to match:  204 ___ _-glucosidase
# --> Failed index to match:  205 ___ _-glucosidase
# --> Failed index to match:  206 ___ _-glucosidase
# --> Failed index to match:  207 ___ _-glucosidase
# --> Failed index to match:  208 ___ _-glucosidase
# --> Failed index to match:  209 ___ _-glucosidase
# --> Failed index to match:  210 ___ _-glucosidase
# --> Failed index to match:  211 ___ _-glucosidase
# --> Failed index to match:  212 ___ _-glucosidase
# --> Failed index to match:  213 ___ _-glucosidase
# --> Failed index to match:  214 ___ _-glucosidase
# --> Failed index to match:  215 ___ _-glucosidase
# --> Failed index to match:  216 ___ _-glucosidase
# --> Failed index to match:  217 ___ _-glucosidase
# --> Failed index to match:  218 ___ _-glucosidase
# --> Failed index to match:  219 ___ _-glucosidase
# --> Failed index to match:  239 ___ L-lactate dehydrogenase
# --> Failed index to match:  281 ___ alanine transaminase
# --> Failed index to match:  282 ___ aspartate transaminase
# --> Failed index to match:  283 ___ aspartate transaminase
# --> Failed index to match:  286 ___ fructose-biphosphate aldolase
# --> Failed index to match:  288 ___ fructose-biphosphate aldolase
# --> Failed index to match:  289 ___ fructose-biphosphate aldolase
# --> Failed index to match:  295 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  296 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  297 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  298 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  299 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  302 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  303 ___ fructose-biphosphate aldolase and triose-phosphate isomerase
# --> Failed index to match:  305 ___ phosphoglucomutase
# --> Failed index to match:  306 ___ phosphoglucomutase
# --> Failed index to match:  307 ___ phosphoglucomutase
# --> Failed index to match:  318 ___ sucrose phosphorylase
# --> Failed index to match:  319 ___ sucrose phosphorylase
# --> Failed index to match:  321 ___ aconitate hydratase
# --> Failed index to match:  322 ___ aconitate hydratase
# --> Failed index to match:  323 ___ aconitate hydratase
# --> Failed index to match:  324 ___ aconitate hydratase
# --> Failed index to match:  325 ___ aconitate hydratase
# --> Failed index to match:  326 ___ aconitate hydratase
# --> Failed index to match:  337 ___ triose-phosphate isomerase
# --> Failed index to match:  340 ___ acetate kinase
# --> Failed index to match:  349 ___ acid phosphatase
# --> Failed index to match:  350 ___ acid phosphatase
# --> Failed index to match:  351 ___ acid phosphatase
# --> Failed index to match:  352 ___ acid phosphatase
# --> Failed index to match:  355 ___ glyceraldehyde-3-phosphate dehydrogenase
# --> Failed index to match:  356 ___ glyceraldehyde-3-phosphate dehydrogenase
# --> Failed index to match:  359 ___ glyceraldehyde-3-phosphate dehydrogenase
# --> Failed index to match:  361 ___ nicotinamide-nucleotide adenylyltransferase
# --> Failed index to match:  362 ___ nicotinamide-nucleotide adenylyltransferase
# --> Failed index to match:  363 ___ isocitrate dehydrogenase (NADP+)
# --> Failed index to match:  404 ___ acid phosphatase
# --> Failed index to match:  405 ___ alkaline phosphatase
# --> Failed index to match:  408 ___ pyruvate kinase
# --> Failed index to match:  409 ___ arginine kinase
# --> Failed index to match:  410 ___ arginine kinase
# --> Failed index to match:  415 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  418 ___ acetylcholinesterase
# --> Failed index to match:  420 ___ nicotinamide-nucleotide adenylyltransferase
# --> Failed index to match:  433 ___ L-iditol dehydrogenase
# --> Failed index to match:  438 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  439 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  447 ___ alcohol dehydrogenase
# --> Failed index to match:  450 ___ maltose phosphorylase
# --> Failed index to match:  452 ___ UDPglucose 4-epimerase and UDPglucose-hexose 1-phosphate uridylyltransferase
# --> Failed index to match:  453 ___ UDPglucose-hexose 1-phosphate uridylyltransferase and UDPglucose 4-epimerase
# --> Failed index to match:  471 ___ glucose dehydrogenase
# --> Failed index to match:  474 ___ fumarate hydratase
# --> Failed index to match:  499 ___ fumarate hydratase
# --> Failed index to match:  508 ___ fumarate hydratase
# --> Failed index to match:  510 ___ fumarate hydratase
# --> Failed index to match:  512 ___ fumarate hydratase
# --> Failed index to match:  523 ___ glucose dehydrogenase
# --> Failed index to match:  526 ___ phosphoglucomutase
# --> Failed index to match:  527 ___ acetaldehyde dehydrogenase (acetylating)
# --> Failed index to match:  528 ___ acetaldehyde dehydrogenase (acetylating)
# --> Failed index to match:  529 ___ acetaldehyde dehydrogenase (acetylating)
# --> Failed index to match:  544 ___ malate dehydrogenase
# --> Failed index to match:  553 ___ alcohol dehydrogenase
# --> Failed index to match:  558 ___ alcohol dehydrogenase
# --> Failed index to match:  567 ___ alcohol dehydrogenase
# --> Failed index to match:  573 ___ alcohol dehydrogenase
# --> Failed index to match:  576 ___ adenylate kinase
# --> Failed index to match:  577 ___ malate dehydrogenase (oxaloacetate-decarboxylating) (NADP+)
# --> Failed index to match:  606 ___ fumarate hydratase
# --> Failed index to match:  619 ___ xylose isomerase
# --> Failed index to match:  632 ___ acetyl-CoA C-acetyltransferase
# --> Failed index to match:  633 ___ 3-oxoacid CoA-transferase
# --> Failed index to match:  647 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  648 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  649 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  650 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  656 ___ adenylate kinase
# --> Failed index to match:  661 ___ alkaline phosphatase
# --> Failed index to match:  662 ___ alkaline phosphatase
# --> Failed index to match:  663 ___ alkaline phosphatase
# --> Failed index to match:  664 ___ alkaline phosphatase
# --> Failed index to match:  665 ___ alkaline phosphatase
# --> Failed index to match:  669 ___ UDPglucose 4-epimerase and UDPglucose-hexose 1-phosphate uridylyltransferase
# --> Failed index to match:  682 ___ creatine kinase
# --> Failed index to match:  706 ___ creatine kinase
# --> Failed index to match:  714 ___ muconate cycloisomerase
# --> Failed index to match:  727 ___ phosphoenolpyruvate carboxykinase (GTP)
# --> Failed index to match:  736 ___ L-iditol dehydrogenase
# --> Failed index to match:  738 ___ aspartate-semialdehyde dehydrogenase
# --> Failed index to match:  739 ___ aspartate-semialdehyde dehydrogenase
# --> Failed index to match:  758 ___ fructose-biphosphate aldolase
# --> Failed index to match:  761 ___ orotate phosphoribosyltransferase
# --> Failed index to match:  764 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  769 ___ glutamate-ammonia ligase
# --> Failed index to match:  785 ___ glyoxylate reductase
# --> Failed index to match:  786 ___ glyoxylate reductase
# --> Failed index to match:  790 ___ adenylate kinase
# --> Failed index to match:  791 ___ adenylate kinase
# --> Failed index to match:  792 ___ adenylate kinase
# --> Failed index to match:  793 ___ adenylate kinase
# --> Failed index to match:  794 ___ adenylate kinase
# --> Failed index to match:  795 ___ adenylate kinase
# --> Failed index to match:  796 ___ adenylate kinase
# --> Failed index to match:  797 ___ adenylate kinase
# --> Failed index to match:  798 ___ adenylate kinase
# --> Failed index to match:  803 ___ ribose-5-phosphate isomerase
# --> Failed index to match:  812 ___ retinal isomerase
# --> Failed index to match:  816 ___ alcohol dehydrogenase
# --> Failed index to match:  817 ___ alcohol dehydrogenase
# --> Failed index to match:  818 ___ alcohol dehydrogenase
# --> Failed index to match:  819 ___ alcohol dehydrogenase
# --> Failed index to match:  820 ___ alcohol dehydrogenase
# --> Failed index to match:  821 ___ alcohol dehydrogenase
# --> Failed index to match:  828 ___ myo-inositol 2-dehydrogenase
# --> Failed index to match:  836 ___ phosphoacetylglucosamine mutase
# --> Failed index to match:  860 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  861 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  862 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  863 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  864 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  865 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  866 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  877 ___ ribulose-phosphate 3-epimerase
# --> Failed index to match:  883 ___ adenine phosphoribosyltransferase
# --> Failed index to match:  923 ___ hexokinase
# --> Failed index to match:  932 ___ 3-hydroxyisobutyrate dehydrogenase
# --> Failed index to match:  940 ___ dihydrolipoamide dehydrogenase
# --> Failed index to match:  943 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  944 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  948 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1014 ___ phosphopyruvate hydratase
# --> Failed index to match:  1018 ___ phosphopyruvate hydratase
# --> Failed index to match:  1019 ___ phosphopyruvate hydratase
# --> Failed index to match:  1020 ___ phosphopyruvate hydratase
# --> Failed index to match:  1031 ___ phosphopyruvate hydratase
# --> Failed index to match:  1064 ___ ,-trehalose-phosphate synthase (UDP-forming)
# --> Failed index to match:  1065 ___ adenylosuccinate synthase
# --> Failed index to match:  1066 ___ ribitol dehydrogenase
# --> Failed index to match:  1067 ___ ribitol dehydrogenase
# --> Failed index to match:  1068 ___ ribitol dehydrogenase
# --> Failed index to match:  1072 ___ estradiol 17_-dehydrogenase
# --> Failed index to match:  1073 ___ estradiol 17_-dehydrogenase
# --> Failed index to match:  1074 ___ estradiol 17_-dehydrogenase
# --> Failed index to match:  1075 ___ estradiol 17_-dehydrogenase
# --> Failed index to match:  1082 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1083 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1084 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1085 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1088 ___ sulfate adenylyltransferase
# --> Failed index to match:  1090 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1091 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1092 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1093 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1094 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1095 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1096 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1097 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1098 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1099 ___ glycerol-3-phosphate dehydrogenase (NAD+)
# --> Failed index to match:  1100 ___ cellobiose phosphorylase
# --> Failed index to match:  1101 ___ phosphoglucomutase
# --> Failed index to match:  1105 ___ transaldolase
# --> Failed index to match:  1115 ___ gluconate 2-dehydrogenase
# --> Failed index to match:  1119 ___ gluconate 2-dehydrogenase
# --> Failed index to match:  1120 ___ gluconate 2-dehydrogenase
# --> Failed index to match:  1125 ___ dihydrolipoamide dehydrogenase
# --> Failed index to match:  1154 ___ pyruvate kinase
# --> Failed index to match:  1155 ___ pyruvate kinase
# --> Failed index to match:  1158 ___ phosphoglucomutase
# --> Failed index to match:  1166 ___ adenylosuccinate lyase
# --> Failed index to match:  1178 ___ dihydrolipoamide dehydrogenase
# --> Failed index to match:  1181 ___ UDP-N-acetylglucosamine pyrophosphorylase
# --> Failed index to match:  1183 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1184 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1185 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1186 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1188 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1190 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1192 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1194 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1196 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1198 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1200 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1202 ___ 3(or 17)_-hydroxysteroid dehydrogenase
# --> Failed index to match:  1204 ___ _-alanyl-CoA ammonia lyase
# --> Failed index to match:  1229 ___ UDPglucose-hexose-1-phosphate uridylyltransferase
# --> Failed index to match:  1230 ___ UDPglucose 4-epimerase
# --> Failed index to match:  1235 ___ alanine dehydrogenase
# --> Failed index to match:  1252 ___ cellobiose phosphorylase
# --> Failed index to match:  1255 ___ galactokinase
# --> Failed index to match:  1256 ___ galactokinase
# --> Failed index to match:  1257 ___ phosphoglucomutase
# --> Failed index to match:  1258 ___ alkaline phosphatase
# --> Failed index to match:  1259 ___ phosphoglucomutase
# --> Failed index to match:  1263 ___ maltose phosphorylase
# --> Failed index to match:  1264 ___ sucrose phosphorylase
# --> Failed index to match:  1266 ___ chymotrypsin
# --> Failed index to match:  1267 ___ 2-hydroxy-3-oxopropionate reductase
# --> Failed index to match:  1269 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1270 ___ glucose-1-phosphate thymidylyltransferase
# --> Failed index to match:  1279 ___ taurocyamine kinase
# --> Failed index to match:  1282 ___ transaldolase
# --> Failed index to match:  1285 ___ aspartate ammonia-lyase
# --> Failed index to match:  1291 ___ aspartate-semialdehyde dehydrogenase
# --> Failed index to match:  1301 ___ glucose-1-phosphate adenylyltransferase
# --> Failed index to match:  1304 ___ glycine dehydrogenase
# --> Failed index to match:  1305 ___ phosphoglycerate mutase
# --> Failed index to match:  1306 ___ propanoyl-CoA carboxylase
# --> Failed index to match:  1307 ___ _-alanine-pyruvate transaminase
# --> Failed index to match:  1308 ___ formate-tetrahydrofolate ligase
# --> Failed index to match:  1315 ___ 3-hydroxybutyrate dehydrogenase
# --> Failed index to match:  1328 ___ D-alanine 2-hydroxymethyltransferase
# --> Failed index to match:  1333 ___ alkaline phosphatase
# --> Failed index to match:  1334 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  1335 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  1339 ___ glutaminase
# --> Failed index to match:  1345 ___ chymotrypsin
# --> Failed index to match:  1347 ___ chymotrypsin
# --> Failed index to match:  1349 ___ chymotrypsin
# --> Failed index to match:  1351 ___ 4-hydroxy-2-oxoglutarate aldolase
# --> Failed index to match:  1352 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1353 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1354 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1359 ___ 21-hydroxysteroid dehydrogenase (NAD+)
# --> Failed index to match:  1360 ___ 21-hydroxysteroid dehydrogenase (NAD+)
# --> Failed index to match:  1370 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1371 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1372 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1374 ___ phosphate acetyltransferase
# --> Failed index to match:  1375 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1382 ___ oxamate carbamoyltransferase
# --> Failed index to match:  1391 ___ 2-dehydro-3-deoxyphosphogluconate aldolase
# --> Failed index to match:  1394 ___ mannose-1-phosphate guanylyltransferase
# --> Failed index to match:  1395 ___ glutathione reductase (NAD(P)H)
# --> Failed index to match:  1400 ___ mannitol-1-phosphate 5-dehydrogenase
# --> Failed index to match:  1401 ___ mannitol-1-phosphate 5-dehydrogenase
# --> Failed index to match:  1403 ___ oxaloacetate tautomerase
# --> Failed index to match:  1404 ___ pancreatic ribonuclease
# --> Failed index to match:  1405 ___ pancreatic ribonuclease
# --> Failed index to match:  1415 ___ papain
# --> Failed index to match:  1420 ___ ureidoglycolate lyase
# --> Failed index to match:  1421 ___ ureidoglycolate lyase
# --> Failed index to match:  1426 ___ propanoyl-CoA carboxylase
# --> Failed index to match:  1434 ___ ornithine-oxo-acid transaminase
# --> Failed index to match:  1454 ___ glycine formiminotransferase
# --> Failed index to match:  1459 ___ alanine dehydrogenase
# --> Failed index to match:  1460 ___ alanine dehydrogenase
# --> Failed index to match:  1461 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1488 ___ laminaribiose phosphorylase
# --> Failed index to match:  1489 ___ laminaribiose phosphorylase
# --> Failed index to match:  1490 ___ laminaribiose phosphorylase
# --> Failed index to match:  1491 ___ UTP-glucose-1-phosphate uridylyltransferase
# --> Failed index to match:  1492 ___ adenine phosphoribosyltransferase
# --> Failed index to match:  1494 ___ glucose-1-phosphate cytidylyltransferase
# --> Failed index to match:  1496 ___ CDPabequose epimerase
# --> Failed index to match:  1497 ___ dTDP-4-amino-4,6-dideoxy-D-glucose transaminase
# --> Failed index to match:  1509 ___ arginine kinase
# --> Failed index to match:  1510 ___ arginine kinase
# --> Failed index to match:  1511 ___ arginine kinase
# --> Failed index to match:  1512 ___ glucose-1-phosphate guanylyltransferase
# --> Failed index to match:  1513 ___ pyruvate carboxylase
# --> Failed index to match:  1514 ___ pyruvate carboxylase
# --> Failed index to match:  1515 ___ pyruvate carboxylase
# --> Failed index to match:  1516 ___ pyruvate carboxylase
# --> Failed index to match:  1517 ___ pyruvate carboxylase
# --> Failed index to match:  1518 ___ pyruvate carboxylase
# --> Failed index to match:  1519 ___ phosphoenolpyruvate carboxykinase (diphosphate)
# --> Failed index to match:  1526 ___ glutamate dehydrogenase
# --> Failed index to match:  1527 ___ glutamate dehydrogenase
# --> Failed index to match:  1529 ___ glutamate dehydrogenase
# --> Failed index to match:  1532 ___ glutamate dehydrogenase
# --> Failed index to match:  1534 ___ glutamate dehydrogenase
# --> Failed index to match:  1544 ___ glutamate dehydrogenase
# --> Failed index to match:  1547 ___ glutamate dehydrogenase
# --> Failed index to match:  1556 ___ glutamate dehydrogenase
# --> Failed index to match:  1560 ___ glutamate dehydrogenase
# --> Failed index to match:  1561 ___ glutamate dehydrogenase
# --> Failed index to match:  1562 ___ glutamate dehydrogenase
# --> Failed index to match:  1563 ___ glutamate dehydrogenase
# --> Failed index to match:  1564 ___ glutamate dehydrogenase
# --> Failed index to match:  1572 ___ glutamate dehydrogenase (NADP+)
# --> Failed index to match:  1581 ___ glutamate dehydrogenase (NADP+)
# --> Failed index to match:  1583 ___ glutamate dehydrogenase (NADP+)
# --> Failed index to match:  1639 ___ pyrimidine-nucleoside phosphorylase
# --> Failed index to match:  1640 ___ pyrimidine-nucleoside phosphorylase
# --> Failed index to match:  1641 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  1642 ___ purine-nucleoside phosphorylase
# --> Failed index to match:  1643 ___ sucrose phosphorylase
# --> Failed index to match:  1644 ___ amino-acid racemase
# --> Failed index to match:  1660 ___ histidine ammonia-lyase
# --> Failed index to match:  1670 ___ glutamate dehydrogenase
# --> Failed index to match:  1693 ___ pyridoxamine-pyruvate transaminase
# --> Failed index to match:  1717 ___ glucose-6-phosphate isomerase
# --> Failed index to match:  1759 ___ indolelactate dehydrogenase
# --> Failed index to match:  1767 ___ glyoxylate reductase
# --> Failed index to match:  1769 ___ glyoxylate reductase
# --> Failed index to match:  1770 ___ glyoxylate reductase
# --> Failed index to match:  1772 ___ glyoxylate reductase
# --> Failed index to match:  1774 ___ glyoxylate reductase
# --> Failed index to match:  1775 ___ glyoxylate reductase
# --> Failed index to match:  1776 ___ glyoxylate reductase
# --> Failed index to match:  1777 ___ isocitrate dehydrogenase (NADP+)
# --> Failed index to match:  1778 ___ isocitrate dehydrogenase (NADP+)
# --> Failed index to match:  1779 ___ isocitrate dehydrogenase (NADP+)
# --> Failed index to match:  1780 ___ isocitrate dehydrogenase (NADP+)
# --> Failed index to match:  1781 ___ isocitrate dehydrogenase (NADP+)
# ...
# 2
# [959, 960, 961]
# 1075
# [1075]
# 0
# [958]
# 1082
# [1082]
# 0
# [971]
# 1083
# [1083]
# 0
# [970]
# 1084
# [1084]
# 0
# [969]
# 1085
# [1085]
# 0
# [968]
# 1088
# [1088]
# 0
# [973]
# 1094
# [1094]
# 0
# [982]
# 1095
# [1095]
# 0
# [981]
# 1096
# [4002, 4003]
# 1
# [3689, 3690]
# 4004
# [4004]
# 0
# [3696]
# 4053
# [4053]
# 0
# [4352]
# 4060
# [4060]
# 0
# [3758]
# 4068
# [4068, 4069]
# 0
# [3788, 3789]
# 4069
# [4068, 4069]
# 1
# [3788, 3789]
# 4107
# [4107]
# 0
# [3866]
# 4111
# [4111]
# 0
# [4087]
# 4113
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 0
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4114
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 1
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4115
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 2
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4116
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 3
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4117
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 4
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4118
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 5
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4119
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 6
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4120
# [4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120]
# 7
# [3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897]
# 4122
# [4122]
# 0
# [3899]
# 4131
# [4131]
# 0
# [3932]
# 4132
# [4132]
# 0
# [3931]
# 4224
# [4224]
# 0
# [4532]
# 4271
# [4271]
# 0
# [2778]
# 4272
# [4272]
# 0
# [2782]
# 4273
# [4273]
# 0
# [2780]
# 4274
# [4274]
# 0
# [2779]
# 4275
# [4275]
# 0
# [2781]
# 4280
# [4280, 4281]
# 0
# [4926, 4927]
# 4281
# [4280, 4281]
# 1
# [4926, 4927]
# 4294
# [4294]
# 0
# [1417]
# Parsing errors:  None
# missing unique indices None
# missing unique indices None

# %% [markdown]
# ### Master file statistics

# %%
from datetime import date
master = pandas.read_csv(f'{date.today()}_master_TECR_3.csv')
enzymes = set(list(master['Enzyme:']))
unique_references = set()
for reference in master['Reference ID:']:
    striped_ref = re.sub('(_.+)', '', str(reference))
    unique_references.add(striped_ref)

print('Master file datums: ', len(master))
print('Master file enzymes: ', len(enzymes))
print('Master file references: ', len(unique_references))
# Out:
# Master file datums:  5813
# Master file enzymes:  505
# Master file references:  1028

# %% [markdown]
# # Contrast the scrapings

# %%
# %run ../../comparisons.py

ecoli_bigg = json.load(open('e_coli_core.json'))

comp = comparison({'freiburger':freiburger_dataframe},{'noor': noor_dataframe},{'du': du_dataframe})
enzyme_diff = comp.three_way_comparison('enzymes')
reference_diff = comp.three_way_comparison('references')
print('Enzymes')
for key, value in enzyme_diff.items():
    print(key, ': ', len(value))
print('\nReferences')
for key, value in reference_diff.items():
    print(key, ': ', len(value))  

print('\n')
master_file = pandas.read_csv(f'{date.today()}_master_TECR_3.csv')
comp.bigg_comparison(ecoli_bigg, master_file)

import pandas
print('master file')
glycolysis = pandas.read_csv('EC values of glycolysis enzymes.csv')
for index, row in glycolysis.iterrows():
    mask = master_file['EC Value:'].str.contains(row['EC'])
    if row['Enzyme'] == 'triose phosphate isomerase':
        questionable_mask = mask
    print(row['Enzyme'], '\t', row['EC'])
    print(mask.value_counts()[True])
    
print('\n\nfreiburger scraping')
glycolysis = pandas.read_csv('EC values of glycolysis enzymes.csv')
for index, row in glycolysis.iterrows():
    mask = freiburger_dataframe['EC Value:'].str.contains(row['EC'])
    if row['Enzyme'] == 'triose phosphate isomerase':
        questionable_mask = mask
    print(row['Enzyme'], '\t', row['EC'])
    print(mask.value_counts()[True])
# Out:
# Enzymes
# noor, not in du :  65
# noor, not in freiburger :  0
# du, not in noor :  47
# du, not in freiburger :  1
# freiburger, not in noor :  74
# freiburger, not in du :  93
#
# References
# noor, not in du :  122
# noor, not in freiburger :  0
# du, not in noor :  79
# du, not in freiburger :  0
# freiburger, not in noor :  109
# freiburger, not in du :  152
#
#
# Phosphofructokinase 	 ['2.7.1.11']
# 20
# Pyruvate formate lyase 	 ['2.3.1.54']
# 2
# Glucose-6-phosphate isomerase 	 ['5.3.1.9']
# 64
# Phosphoglycerate kinase 	 ['2.7.2.3']
# 80
# 6-phosphogluconolactonase 	 ['3.1.1.31']
# 6
# Acetaldehyde dehydrogenase (acetylating) 	 ['1.2.1.10']
# 7
# Phosphoglycerate mutase 	 ['5.4.2.1', '5.4.2.11', '5.4.2.12']
# 73
# Alcohol dehydrogenase (ethanol) 	 ['1.1.1.71', '1.1.1.1']
# 271
# Acetate kinase 	 ['2.7.2.15', '2.7.2.1']
# 29
# Phosphoenolpyruvate carboxylase 	 ['4.1.1.31']
# 0
# 0
# Aconitase (half-reaction A, Citrate hydro-lyase) 	 ['4.2.1.3']
# 94
# Aconitase (half-reaction B, Isocitrate hydro-lyase) 	 ['4.2.1.3']
# 94
# ATP maintenance requirement 	 ['3.6.1.5', '3.6.3.34', '3.6.3.20', '3.6.3.53', '3.6.3.8', '3.6.3.32', '3.6.4.12', '3.6.3.48', '3.6.3.40', '3.6.3.9', '3.6.3.23', '3.6.3.22', '3.6.3.54', '3.6.3.1', '3.6.1.8', '3.6.3.29', '3.6.3.17', '3.6.3.50', '3.6.3.39', '3.6.3.19', '3.6.3.4', '3.6.3.35', '3.6.3.16', '3.6.4.4', '3.6.3.37', '3.6.4.8', '3.6.3.31', '3.6.3.6', '3.6.4.5', '3.6.3.52', '3.6.3.2', '3.6.3.14', '3.6.3.51', '3.6.3.25', '3.6.3.38', '3.6.3.33', '3.6.3.43', '3.6.4.10', '3.6.4.13', '3.6.3.3', '3.6.3.10', '3.6.3.24', '3.6.3.44', '3.6.3.15', '3.6.3.5', '3.6.1.3', '3.6.1.15', '3.6.4.2', '3.6.4.3', '3.6.3.42', '3.6.3.11', '3.6.3.28', '3.6.3.30', '3.6.4.1', '3.6.4.11', '3.6.3.47', '3.6.4.6', '3.6.3.36', '3.6.3.21', '3.6.3.12', '3.6.3.18', '3.6.3.26', '3.6.3.27', '3.6.3.7', '3.6.4.9', '3.6.4.7', '3.6.3.46', '3.6.3.41', '3.6.3.49']
# 33
# Phosphoenolpyruvate carboxykinase 	 ['4.1.1.49']
# 0
# 7
# Phosphoenolpyruvate synthase 	 ['2.7.9.2']
# 1
# Adenylate kinase 	 ['2.7.4.3']
# 367
# 2-Oxogluterate dehydrogenase 	 ['1.2.1.52', '2.3.1.61', '1.8.1.4', '1.2.4.2']
# 80
# ATP synthase (four protons for one ATP) 	 ['3.6.3.14']
# 0
# 0
# Phosphotransacetylase 	 ['2.3.1.8']
# 20
# Pyruvate kinase 	 ['2.7.1.40']
# 46
# Ribulose 5-phosphate 3-epimerase 	 ['5.1.3.1']
# 9
# Citrate synthase 	 ['2.3.3.16', '2.3.3.1', '2.3.3.3']
# 0
# 0
# Ribose-5-phosphate isomerase 	 ['5.3.1.6']
# 15
# Enolase 	 ['4.2.1.11']
# 99
# Succinyl-CoA synthetase (ADP-forming) 	 ['6.2.1.5']
# 1
# Transaldolase 	 ['2.2.1.2']
# 7
# NAD(P) transhydrogenase 	 ['1.6.1.1']
# 14
# Transketolase 	 ['2.2.1.1']
# 5
# Transketolase 	 ['2.2.1.1']
# 5
# Triose-phosphate isomerase 	 ['5.3.1.1']
# 120
# Fructose-bisphosphate aldolase 	 ['4.1.2.13']
# 117
# Fructose-bisphosphatase 	 ['3.1.3.11']
# 14
# Fumarase 	 ['4.2.1.2']
# 142
# Glucose 6-phosphate dehydrogenase 	 ['1.1.1.363', '1.1.1.49']
# 11
# Glyceraldehyde-3-phosphate dehydrogenase 	 ['1.2.1.12', '1.2.1.59']
# 102
# Glutamine synthetase 	 ['6.3.1.2']
# 10
# L-glutamine transport via ABC system 	 ['3.6.3.21']
# 0
# 0
# Glutamate dehydrogenase (NADP) 	 ['1.4.1.13', '1.4.1.3', '1.4.1.4']
# 39
# Glutaminase 	 ['6.3.5.2', '4.3.3.6', '6.3.5.5', '1.4.7.1', '6.3.5.4', '3.5.1.2', '6.3.4.2', '1.4.1.13', '3.5.1.38']
# 12
# Glutamate synthase (NADPH) 	 ['1.4.1.13']
# 0
# 0
# Phosphogluconate dehydrogenase 	 ['1.1.1.44', '1.1.1.351']
# 9
# Isocitrate dehydrogenase (NADP) 	 ['1.1.1.42']
# 11
# Isocitrate lyase 	 ['4.1.3.1']
# 9
# D-lactate dehydrogenase 	 ['1.1.1.28']
# 4
# Malate synthase 	 ['2.3.3.9']
# 0
# 1
# Malate dehydrogenase 	 ['1.1.1.37', '1.1.1.299']
# 91
# Malic enzyme (NAD) 	 ['1.1.1.38', '1.1.1.39']
# 1
# Malic enzyme (NADP) 	 ['1.1.1.40']
# 9
# NADH dehydrogenase (ubiquinone-8 & 3 protons) 	 ['1.6.5.3']
# 0
# 0
# NAD transhydrogenase 	 ['1.6.1.3', '1.6.1.2', '1.6.1.1']
# 14
# Pyruvate dehydrogenase 	 ['1.2.1', '1.8.1.4', '1.2.1.51', '1.2.4.1', '2.3.1.12']
# 345
#
#
# undescribed_enzymes {'Phosphoenolpyruvate carboxylase': ['4.1.1.31'], 'ATP synthase (four protons for one ATP)': ['3.6.3.14'], 'Citrate synthase': ['2.3.3.16', '2.3.3.1', '2.3.3.3'], 'L-glutamine transport via ABC system': ['3.6.3.21'], 'Glutamate synthase (NADPH)': ['1.4.1.13'], 'NADH dehydrogenase (ubiquinone-8 & 3 protons)': ['1.6.5.3']}
#
# total_enzymes: 95
# described_enzymes: 89
# total data points: 2510
# average datums per enzyme: 49.21568627450981
# master file
# hexokinase 	 5.4.2.2
# 15
# GPI 	 5.3.1.9
# 64
# PFK 	 2.7.1.11
# 20
# aldolase 	 4.1.2.13
# 117
# triose phosphate isomerase 	 5.3.1.1
# 120
# glyceraldehyde 3-phosphate dehydrogenase 	 1.2.1.12
# 102
# phosphoglycerate kinase 	 2.7.2.3
# 80
# phosphoglycerate mutase 	 5.4.2.1
# 73
# enolase 	 4.2.1.11
# 99
# pyruvate kinase 	 2.7.1.40
# 46
#
#
# freiburger scraping
# hexokinase 	 5.4.2.2
# 15
# GPI 	 5.3.1.9
# 64
# PFK 	 2.7.1.11
# 20
# aldolase 	 4.1.2.13
# 117
# triose phosphate isomerase 	 5.3.1.1
# 120
# glyceraldehyde 3-phosphate dehydrogenase 	 1.2.1.12
# 102
# phosphoglycerate kinase 	 2.7.2.3
# 80
# phosphoglycerate mutase 	 5.4.2.1
# 73
# enolase 	 4.2.1.11
# 99
# pyruvate kinase 	 2.7.1.40
# 46

# %% [markdown]
# # Add reference mapping

# %%
# %run ../../reference_mapping.py

# import the files
mappings = pandas.read_csv('references_with_abstracts.csv')
mappings.fillna(' ')

# master_file = httpx.request("GET", "https://raw.githubusercontent.com/freiburgermsu/Biochemical-databases/main/openTECR/TECR_files/core_scripts/Notebooks/2021-09-11_master_TECR_3.csv")
# master_file = StringIO(master_file.content.decode("UTF-8"))
# master_file = pandas.read_csv(master_file)
master_file = pandas.read_csv(f'{date.today()}_master_TECR_3.csv')
master_file.fillna(' ')

# define the parameters
reference_ids_column = 'reference_code_in_online_database'
mappings_path = "https://raw.githubusercontent.com/roberts-farm-of-ideas/8/56bab7c99ef340a6c3853b595f4d777ac7288c54/materials/reference_code_mappings/reference_code_mappings.csv"
doi_column = 'doi_from_robert'
pmid_column = 'pmid'

# apply the reference mapping
refmap = reference_mapping()
mapped_master = refmap.apply_mapping(master_file, mappings, reference_ids_column, doi_column, pmid_column, export = True)
mapped_master.head()
# Out:
# References added to 3045 datums
#    freiburger_index  du_index  noor_index                  Enzyme:  \
# 0               0.0     140.0      4336.0  aspartate ammonia-lyase
# 1               1.0     141.0      2910.0  aspartate ammonia-lyase
# 2               2.0     142.0      2129.0       fumarate hydratase
# 3               3.0     143.0      2130.0       fumarate hydratase
# 4               4.0     148.0       791.0       fumarate hydratase
#
#                             KEGG Reaction: CID Reaction:      PMID  \
# 0  kegg:C00049 = kegg:C00122 + kegg:C00014           NaN  16743691
# 1  kegg:C00049 = kegg:C00122 + kegg:C00014           NaN  16744231
# 2  kegg:C00122 + kegg:C00001 = kegg:C00149           NaN
# 3  kegg:C00122 + kegg:C00001 = kegg:C00149           NaN
# 4  kegg:C00122 + kegg:C00001 = kegg:C00149           NaN
#
#                  DOI                                     Reaction:  \
# 0  10.1042/bj0200545  L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 1  10.1042/bj0230472  L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 2                           fumarate(aq) + H2O(l) = (S)-malate(aq)
# 3                           fumarate(aq) + H2O(l) = (S)-malate(aq)
# 4                           fumarate(aq) + H2O(l) = (S)-malate(aq)
#
#                                           Reference:  ...   Km  \
# 0  Quastel J.H.; Woolf B.; Biochem. J.; 20 545 (1...  ...  NaN
# 1              Woolf B.; Biochem. J.; 23 472 (1929).  ...  NaN
# 2  Borsook H.; Schott H.F.; J. Biol. Chem.; 92 55...  ...  NaN
# 3  Borsook H.; Schott H.F.; J. Biol. Chem.; 92 55...  ...  NaN
# 4       Jacobsohn K.P.; Biochem. Z.; 274 167 (1934).  ...  NaN
#
#                              Method:    Buffer: Experimental conditions  \
# 0                  chemical analysis  phosphate                     NaN
# 1  chemical analysis and polarimetry  phosphate                     NaN
# 2                   electrochemistry        NaN                     NaN
# 3                   electrochemistry        NaN                     NaN
# 4                        polarimetry   barbital                     NaN
#
#   EC Value: solutes [mol / kg] solutes [mol / dm^3]  \
# 0   4.3.1.1                NaN                  NaN
# 1   4.3.1.1                NaN                  NaN
# 2   4.2.1.2                NaN                  NaN
# 3   4.2.1.2                NaN                  NaN
# 4   4.2.1.2                NaN                  NaN
#
#   Ionic strength [mol / dm^3] Ionic strength [mol / kg] Enthalpy [kJ / mol]
# 0                         NaN                       NaN                 NaN
# 1                         NaN                       NaN                 NaN
# 2                         NaN                       NaN                 NaN
# 3                         NaN                       NaN                 NaN
# 4                         NaN                       NaN                 NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Phosphofructokinase content for Table 1

# %%
from datetime import date
master_file = pandas.read_csv(f'{date.today()}_mapped_master.csv')

pfk_content = master_file.loc[master_file['Enzyme:'] == '6-phosphofructokinase']
pandas.set_option('display.max_columns', None)
display(pfk_content)
# Out:
#       Unnamed: 0  freiburger_index  du_index  noor_index  \
# 2103        2103            2103.0    2194.0      1774.0
# 2282        2282            2282.0    2506.0      3993.0
# 2283        2283            2283.0    2509.0      3997.0
# 2284        2284            2284.0    2507.0      3994.0
# 2285        2285            2285.0    2510.0      3992.0
# 2286        2286            2286.0    2508.0      3995.0
# 2287        2287            2287.0    2511.0      3996.0
# 2288        2288            2288.0       NaN      3998.0
# 2289        2289            2289.0       NaN      4003.0
# 2290        2290            2290.0       NaN      4001.0
# 2291        2291            2291.0       NaN      4000.0
# 2292        2292            2292.0       NaN      3999.0
# 2293        2293            2293.0       NaN      4002.0
# 3033        3033            3033.0       NaN      1562.0
# 3034        3034            3034.0       NaN      1563.0
# 3035        3035            3035.0       NaN      1564.0
# 3036        3036            3036.0       NaN      1565.0
# 3376        3376            3376.0    3615.0        75.0
# 3377        3377            3377.0    3616.0        76.0
#
#                     Enzyme:  \
# 2103  6-phosphofructokinase
# 2282  6-phosphofructokinase
# 2283  6-phosphofructokinase
# 2284  6-phosphofructokinase
# 2285  6-phosphofructokinase
# 2286  6-phosphofructokinase
# 2287  6-phosphofructokinase
# 2288  6-phosphofructokinase
# 2289  6-phosphofructokinase
# 2290  6-phosphofructokinase
# 2291  6-phosphofructokinase
# 2292  6-phosphofructokinase
# 2293  6-phosphofructokinase
# 3033  6-phosphofructokinase
# 3034  6-phosphofructokinase
# 3035  6-phosphofructokinase
# 3036  6-phosphofructokinase
# 3376  6-phosphofructokinase
# 3377  6-phosphofructokinase
#
#                                          KEGG Reaction: CID Reaction:  \
# 2103  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2282  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2283  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2284  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2285  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2286  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2287  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2288  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2289  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2290  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2291  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2292  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 2293  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 3033  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 3034  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 3035  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 3036  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 3376  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
# 3377  kegg:C00002 + kegg:C00085 = kegg:C00008 + kegg...           NaN
#
#          PMID  DOI                                          Reaction:  \
# 2103  4270771  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2282   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2283   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2284   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2285   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2286   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2287   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2288   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2289   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2290   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2291   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2292   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 2293   241184  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 3033                ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 3034                ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 3035                ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 3036                ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 3376  2958459  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
# 3377  2958459  NaN  ATP(aq) + D-fructose 6-phosphate(aq) = ADP(aq)...
#
#                                              Reference: Reference ID:   T [K]  \
# 2103  Hanson R.L.; Rudolph F.B.; Lardy H.A.; J. Biol...     73HAN/RUD  303.15
# 2282  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  298.15
# 2283  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  298.15
# 2284  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  303.15
# 2285  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  303.15
# 2286  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  310.15
# 2287  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  310.15
# 2288  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  298.15
# 2289  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  298.15
# 2290  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  303.15
# 2291  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  303.15
# 2292  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  310.15
# 2293  Bvhme H.-J.; Schellenberger W.; Hofmann E.; Ac...     75BOH/SCH  310.15
# 3033  Redman-Furey N.L.; "Biochemical Thermodynamics...         82RED  298.15
# 3034  Redman-Furey N.L.; "Biochemical Thermodynamics...         82RED  298.15
# 3035  Redman-Furey N.L.; "Biochemical Thermodynamics...         82RED  298.15
# 3036  Redman-Furey N.L.; "Biochemical Thermodynamics...         82RED  298.15
# 3376  Rao G.S.J.; Harris B.G.; Cook P.F.; J. Biol. C...     87RAO/HAR  303.15
# 3377  Rao G.S.J.; Harris B.G.; Cook P.F.; J. Biol. C...     87RAO/HAR  303.15
#
#       pH    Keq   Km                                Method:  \
# 2103    8  2290  NaN     enzymatic assay; spectrophotometry
# 2282    7   800  NaN                            calorimetry
# 2283    8  2800  NaN                            calorimetry
# 2284    7  1000  NaN                            calorimetry
# 2285    8  2900  NaN                            calorimetry
# 2286    7  2700  NaN                            calorimetry
# 2287    8  4800  NaN                            calorimetry
# 2288    7   NaN  NaN                            calorimetry
# 2289    8   NaN  NaN                            calorimetry
# 2290    7   NaN  NaN                            calorimetry
# 2291    8   NaN  NaN                            calorimetry
# 2292    7   NaN  NaN                            calorimetry
# 2293    8   NaN  NaN                            calorimetry
# 3033    9   NaN  NaN                            calorimetry
# 3034    9   NaN  NaN                            calorimetry
# 3035    9   NaN  NaN                            calorimetry
# 3036    9   NaN  NaN                            calorimetry
# 3376  6.8   150  NaN  enzymatic assay and spectrophotometry
# 3377    8  2900  NaN  enzymatic assay and spectrophotometry
#
#                                                 Buffer:  \
# 2103                        Tris (0.033 mol dm-3) + HCl
# 2282                          Tris (0.1 mol dm-3) + HCl
# 2283                          Tris (0.1 mol dm-3) + HCl
# 2284                          Tris (0.1 mol dm-3) + HCl
# 2285                          Tris (0.1 mol dm-3) + HCl
# 2286                          Tris (0.1 mol dm-3) + HCl
# 2287                          Tris (0.1 mol dm-3) + HCl
# 2288                          Tris (0.1 mol dm-3) + HCl
# 2289                          Tris (0.1 mol dm-3) + HCl
# 2290                          Tris (0.1 mol dm-3) + HCl
# 2291                          Tris (0.1 mol dm-3) + HCl
# 2292                          Tris (0.1 mol dm-3) + HCl
# 2293                          Tris (0.1 mol dm-3) + HCl
# 3033  (NH3 + NH4Cl) glycylglycine Taps and Tris  +  ...
# 3034  (NH3 + NH4Cl) glycylglycine Taps and Tris  +  ...
# 3035  (NH3 + NH4Cl) glycylglycine Taps and Tris  +  ...
# 3036  (NH3 + NH4Cl) glycylglycine Taps and Tris  +  ...
# 3376  {imidazole (0.10 mol dm-3) + HCl} and {Tris (0...
# 3377  {imidazole (0.10 mol dm-3) + HCl} and {Tris (0...
#
#      Experimental conditions EC Value: solutes [mol / kg]  \
# 2103                     NaN  2.7.1.11                NaN
# 2282                     NaN  2.7.1.11                NaN
# 2283                     NaN  2.7.1.11                NaN
# 2284                     NaN  2.7.1.11                NaN
# 2285                     NaN  2.7.1.11                NaN
# 2286                     NaN  2.7.1.11                NaN
# 2287                     NaN  2.7.1.11                NaN
# 2288                     NaN  2.7.1.11                NaN
# 2289                     NaN  2.7.1.11                NaN
# 2290                     NaN  2.7.1.11                NaN
# 2291                     NaN  2.7.1.11                NaN
# 2292                     NaN  2.7.1.11                NaN
# 2293                     NaN  2.7.1.11                NaN
# 3033                     NaN  2.7.1.11                NaN
# 3034                     NaN  2.7.1.11                NaN
# 3035                     NaN  2.7.1.11                NaN
# 3036                     NaN  2.7.1.11                NaN
# 3376                     NaN  2.7.1.11                NaN
# 3377                     NaN  2.7.1.11                NaN
#
#      solutes [mol / dm^3] Ionic strength [mol / dm^3]  \
# 2103                  NaN                         NaN
# 2282                  NaN                         NaN
# 2283                  NaN                         NaN
# 2284                  NaN                         NaN
# 2285                  NaN                         NaN
# 2286                  NaN                         NaN
# 2287                  NaN                         NaN
# 2288                  NaN
# 2289                  NaN
# 2290                  NaN
# 2291                  NaN
# 2292                  NaN
# 2293                  NaN
# 3033                  NaN
# 3034                  NaN
# 3035                  NaN
# 3036                  NaN
# 3376                  NaN                         NaN
# 3377                  NaN                         NaN
#
#      Ionic strength [mol / kg] Enthalpy [kJ / mol]
# 2103                       NaN                 NaN
# 2282                       NaN                 NaN
# 2283                       NaN                 NaN
# 2284                       NaN                 NaN
# 2285                       NaN                 NaN
# 2286                       NaN                 NaN
# 2287                       NaN                 NaN
# 2288                       NaN               -84.2
# 2289                       NaN               -70.4
# 2290                       NaN               -77.4
# 2291                       NaN               -67.3
# 2292                       NaN               -72.9
# 2293                       NaN               -60.4
# 3033                       NaN                 -53
# 3034                       NaN               -61.2
# 3035                       NaN               -50.3
# 3036                       NaN               -56.7
# 3376                       NaN                 NaN
# 3377                       NaN                 NaN

# %% [markdown]
# # Convert the master file to JSONs

# %%
# %run ../../csv_to_json.py

master_file = pandas.read_csv(f'{date.today()}_mapped_master.csv')
json_template = json.load(open('tecrdb_template.json'))

tojson = to_json(master_file, json_template)
tojson.parse_to_json()
