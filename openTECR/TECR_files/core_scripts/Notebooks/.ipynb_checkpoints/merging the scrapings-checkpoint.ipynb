# %% [markdown]
# # Import the scrapings

# %% [markdown]
# ### Refining the freiburger scraping

# %%
from numpy import unique, nan 
import re 

empty = [nan, 'nan', None, ' ', '', 'NaN']


def refine_freiburger(freiburger_file):
    # strip spaces from the freiburger_file
    for column in freiburger_file:
        for index, entry in freiburger_file[column].iteritems():
            if entry is float:
                freiburger_file.at[index, column] = str(entry).strip(' ?~')
                freiburger_file.at[index, column] = float(entry)
            elif entry is int:
                freiburger_file.at[index, column] = str(entry).strip(' ?~')
                freiburger_file.at[index, column] = int(entry)
            else:
                freiburger_file.at[index, column] = str(entry).strip(' ?~')

    # extrapolate metadata to all datums
    for index, row in freiburger_file.iterrows():    
        if row['Reference ID:'] not in empty:
            reference_id = row['Reference ID:']
            reference = row['Reference:']
            methods = row['Method:']
            buffer = row['Buffer:']
            ec = row['EC Value:']
        elif row['Reference ID:'] in empty:
            freiburger_file.at[index, 'Reference ID:'] = reference_id
            freiburger_file.at[index, 'Reference:'] = reference
            freiburger_file.at[index, 'Method:'] = methods
            freiburger_file.at[index, 'Buffer:'] = buffer
            freiburger_file.at[index, 'EC Value:'] = ec
        else:
            print('ERROR: The reference has an unidentified structure.')
        
    # strip the EC values
    for index, master_ec in freiburger_file['EC Value:'].iteritems():
        if master_ec not in empty:  
            master_ec = re.search('([\d|\.|\-]+)', master_ec).group()
            freiburger_file['EC Value:'].iloc[index] = master_ec
            
    # consolidate the solutes column 
    for index, solute in freiburger_file['solutes [mol / dm^3]'].iteritems():
        if solute not in empty:  
            solute_list = solute.split(' & ')
            if len(solute_list) > 1:
                solute_list = unique(solute_list)
                if len(solute_list) > 2:
                    print('Large solute set {}'.format(solute_list))
                else:
                    freiburger_file['solutes [mol / dm^3]'].iloc[index] = ' & '.join([x for x in list(solute_list)])

            elif solute_list[0] in ['#NAME']:
                freiburger_file['solutes [mol / dm^3]'].iloc[index] = ''

    # create the additional columns
    column_nans = ['' for row in range(len(freiburger_file))]  
    freiburger_file.insert(0, 'noor_index', column_nans)  
    freiburger_file.insert(0, 'du_index', column_nans)  
    freiburger_file.insert(0, 'freiburger_index', freiburger_file.index)
    freiburger_file.insert(4, 'KEGG Reaction:', column_nans)
    freiburger_file.insert(5, 'CID Reaction:', column_nans)

    
    return freiburger_file

# %% [markdown]
# ### import the CSV files

# %%
import pandas

noor_dataframe = pandas.read_csv('TECRDB_Elad_Noor.csv').fillna(' ')
manual_noor_curation = pandas.read_csv('Manual curation of the programmatically unmatched datums, comma delimited.txt', header = 0)

du_dataframe = pandas.read_excel('mmc2.xlsx', sheet_name = 'Table S1. TECRDB Keqs')
du_dataframe.rename(columns = {'Reaction.1': 'reaction_string'}, inplace = True)
manual_du_curation = pandas.read_csv('Manual curation of Du et al., comma delimited.txt', header = 0)

freiburger_dataframe = pandas.read_csv('2021-08-04_vetted & reorganized NIST database_01.csv').fillna(' ')
freiburger_dataframe = refine_freiburger(freiburger_dataframe)
freiburger_dataframe.head()
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:296: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    freiburger_index du_index noor_index                  Enzyme:  \
# 0                 0                      aspartate ammonia-lyase
# 1                 1                      aspartate ammonia-lyase
# 2                 2                           fumarate hydratase
# 3                 3                           fumarate hydratase
# 4                 4                           fumarate hydratase
#
#   KEGG Reaction: CID Reaction:                                     Reaction:  \
# 0                               L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 1                               L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 2                                     fumarate(aq) + H2O(l) = (S)-malate(aq)
# 3                                     fumarate(aq) + H2O(l) = (S)-malate(aq)
# 4                                     fumarate(aq) + H2O(l) = (S)-malate(aq)
#
#                                           Reference:   Reference ID:   T [K]  \
# 0  Quastel J.H.; Woolf B.; Biochem. J.; 20 545 (1...  26QUA/WOO_1205  310.15
# 1              Woolf B.; Biochem. J.; 23 472 (1929).      29WOO_1206  310.15
# 2  Borsook H.; Schott H.F.; J. Biol. Chem.; 92 55...  31BOR/SCH_1141  298.15
# 3  Borsook H.; Schott H.F.; J. Biol. Chem.; 92 55...  31BOR/SCH_1141  298.15
# 4       Jacobsohn K.P.; Biochem. Z.; 274 167 (1934).      34JAC_1142  278.15
#
#    ... Km                            Method:    Buffer:  \
# 0  ...                     chemical analysis  phosphate
# 1  ...     chemical analysis and polarimetry  phosphate
# 2  ...                      electrochemistry
# 3  ...                      electrochemistry
# 4  ...                           polarimetry   barbital
#
#   Experimental conditions EC Value: solutes [mol / kg] solutes [mol / dm^3]  \
# 0                           4.3.1.1
# 1                           4.3.1.1
# 2                           4.2.1.2
# 3                           4.2.1.2
# 4                           4.2.1.2
#
#   Ionic strength [mol / dm^3] Ionic strength [mol / kg] Enthalpy [kJ / mol]
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %% [markdown]
# # Merge the scrapings

# %%
# %run ../merging_datasets.py

# merging the noor scraping
elad_enzymes = 'enzyme_name'
elad_references = 'reference'
scraping_name = 'noor'
mrgpkg = merge_package(freiburger_dataframe, noor_dataframe, scraping_name)
mrgpkg.add_new(elad_enzymes, elad_references) #, export = True)
mrgpkg.merge_existing() #export = True)
mrgpkg.incorporate_manual_curation()
# noor_master_merge = mrgpkg.merge(elad_enzymes, elad_references, manual_noor_curation, export = True)

# merging the du scraping
# du_enzymes = 'Reaction'
# du_references = 'Reference_id'
# scraping_name = 'du'
# mrgpkg = merge_package(noor_master_merge, du_dataframe, scraping_name) #, first = False)
# final_master_file = mrgpkg.merge(du_enzymes, du_references, scraping_name, manual_du_curation, export = True)
# Out:
# enzymes in the master file:  491
# enzymes in the new file:  431
# Extra enzymes in the master file, versus new file:  60
# Missing enzymes in the master file, versus new file:  0
# set()
#
# references in the master file:  1015
# references in the new file:  919
# Extra references in the master file, versus new file:  96
# Missing references in the master file, versus new file:  0
# set()
# before 4934
# after 4934
# total additions 0
#
# new_index 0
#
# matched pair:
#  ==============
# new_index 0
# master_index 4041
#
#
# new_index 1
#
# matched pair:
#  ==============
# new_index 1
# master_index 1249
#
#
# new_index 2
#
# matched pair:
#  ==============
# new_index 2
# master_index 1519
#
# 1519 	 new pmg 	 2.96 = -log[Mg+2]
#
# new_index 3
#
# matched pair:
#  ==============
# new_index 3
# master_index 1516
#
# 1516 	 new pmg 	 2.8 = -log[Mg+2]
#
# new_index 4
#
# matched pair:
#  ==============
# new_index 4
# master_index 1523
#
# 1523 	 new pmg 	 2.3 = -log[Mg+2]
#
# new_index 5
#
# matched pair:
#  ==============
# new_index 5
# master_index 1512
#
#
# new_index 6
#
# matched pair:
#  ==============
# new_index 6
# master_index 1516
#
# 1516 	 new noor_index 	 1516 & 6
#
# new_index 7
#
# matched pair:
#  ==============
# new_index 7
# master_index 1517
#
#
# new_index 8
#
# matched pair:
#  ==============
# new_index 8
# master_index 1524
#
#
# new_index 9
#
# matched pair:
#  ==============
# new_index 9
# master_index 1521
#
# 1521 	 new pmg 	 2.68 = -log[Mg+2]
#
# new_index 10
#
# matched pair:
#  ==============
# new_index 10
# master_index 1518
#
# 1518 	 new pmg 	 3.19 = -log[Mg+2]
#
# new_index 11
#
# matched pair:
#  ==============
# new_index 11
# master_index 1513
#
#
# new_index 12
#
# matched pair:
#  ==============
# new_index 12
# master_index 1515
#
#
# new_index 13
#
# matched pair:
#  ==============
# new_index 13
# master_index 1525
#
# 1525 	 new pmg 	 1.3 = -log[Mg+2]
#
# new_index 14
#
# matched pair:
#  ==============
# new_index 14
# master_index 1526
#
#
# new_index 15
#
# matched pair:
#  ==============
# new_index 15
# master_index 1514
#
#
# new_index 16
#
# matched pair:
#  ==============
# new_index 16
# master_index 1521
#
# 1521 	 new pmg 	 2.68 = -log[Mg+2] or 2.51 (-log[Mg+2])
# 1521 	 new noor_index 	 1521 & 16
#
# new_index 17
#
# matched pair:
#  ==============
# new_index 17
# master_index 884
#
# 884 	 new pmg 	 1.96 = -log[Mg+2]
#
# new_index 18
#
# matched pair:
#  ==============
# new_index 18
# master_index 876
#
# 876 	 new pmg 	 2.6 = -log[Mg+2]
#
# new_index 19
#
# matched pair:
#  ==============
# new_index 19
# master_index 878
#
# 878 	 new pmg 	 2.31 = -log[Mg+2]
#
# new_index 20
#
# matched pair:
#  ==============
# new_index 20
# master_index 873
#
# 873 	 new pmg 	 2.66 = -log[Mg+2]
#
# new_index 21
#
# matched pair:
#  ==============
# new_index 21
# master_index 896
#
# 896 	 new pmg 	 2.69 = -log[Mg+2]
#
# new_index 22
#
# matched pair:
#  ==============
# new_index 22
# master_index 891
#
# 891 	 new pmg 	 0.92 = -log[Mg+2]
#
# new_index 23
#
# matched pair:
#  ==============
# new_index 23
# master_index 884
#
# 884 	 new pmg 	 1.96 = -log[Mg+2] or 0.75 (-log[Mg+2])
# 884 	 new noor_index 	 884 & 23
#
# new_index 24
#
# matched pair:
#  ==============
# new_index 24
# master_index 899
#
# 899 	 new pmg 	 0.81 = -log[Mg+2]
#
# new_index 25
#
# matched pair:
#  ==============
# new_index 25
# master_index 875
#
# 875 	 new pmg 	 0.83 = -log[Mg+2]
#
# new_index 26
#
# matched pair:
#  ==============
# new_index 26
# master_index 871
#
# 871 	 new pmg 	 0.84 = -log[Mg+2]
#
# new_index 27
#
# matched pair:
#  ==============
# new_index 27
# master_index 885
#
# 885 	 new pmg 	 2.12 = -log[Mg+2]
#
# new_index 28
#
# matched pair:
#  ==============
# new_index 28
# master_index 879
#
# 879 	 new pmg 	 1.07 = -log[Mg+2]
#
# new_index 29
#
# matched pair:
#  ==============
# new_index 29
# master_index 880
#
# 880 	 new pmg 	 0.98 = -log[Mg+2]
#
# new_index 30
#
# matched pair:
#  ==============
# new_index 30
# master_index 883
#
# 883 	 new pmg 	 2.67 = -log[Mg+2]
#
# new_index 31
#
# matched pair:
#  ==============
# new_index 31
# master_index 897
#
# 897 	 new pmg 	 0.82 = -log[Mg+2]
#
# new_index 32
#
# matched pair:
#  ==============
# new_index 32
# master_index 874
#
# 874 	 new pmg 	 1.0 = -log[Mg+2]
#
# new_index 33
#
# matched pair:
#  ==============
# new_index 33
# master_index 878
#
# 878 	 new pmg 	 2.31 = -log[Mg+2] or 2.4 (-log[Mg+2])
# 878 	 new noor_index 	 878 & 33
#
# new_index 34
#
# matched pair:
#  ==============
# new_index 34
# master_index 882
#
# 882 	 new pmg 	 1.1 = -log[Mg+2]
#
# new_index 35
#
# matched pair:
#  ==============
# new_index 35
# master_index 877
#
# 877 	 new pmg 	 2.6 = -log[Mg+2]
#
# new_index 36
#
# matched pair:
#  ==============
# new_index 36
# master_index 879
#
# 879 	 new pmg 	 1.07 = -log[Mg+2] or 1.85 (-log[Mg+2])
# 879 	 new noor_index 	 879 & 36
#
# new_index 37
#
# matched pair:
#  ==============
# new_index 37
# master_index 872
#
# 872 	 new pmg 	 2.66 = -log[Mg+2]
#
# new_index 38
#
# matched pair:
#  ==============
# new_index 38
# master_index 872
#
# 872 	 new noor_index 	 872 & 38
#
# new_index 39
#
# matched pair:
#  ==============
# new_index 39
# master_index 892
#
# 892 	 new pmg 	 2.67 = -log[Mg+2]
#
# new_index 40
#
# matched pair:
#  ==============
# new_index 40
# master_index 898
#
# 898 	 new pmg 	 0.82 = -log[Mg+2]
#
# new_index 41
#
# matched pair:
#  ==============
# new_index 41
# master_index 889
#
# 889 	 new pmg 	 0.75 = -log[Mg+2]
#
# new_index 42
#
# matched pair:
#  ==============
# new_index 42
# master_index 890
#
# 890 	 new pmg 	 1.04 = -log[Mg+2]
#
# new_index 43
#
# matched pair:
#  ==============
# new_index 43
# master_index 895
#
# 895 	 new pmg 	 2.31 = -log[Mg+2]
#
# new_index 44
#
# matched pair:
#  ==============
# new_index 44
# master_index 893
#
# 893 	 new pmg 	 2.67 = -log[Mg+2]
#
# new_index 45
#
# matched pair:
#  ==============
# new_index 45
# master_index 887
#
# 887 	 new pmg 	 0.93 = -log[Mg+2]
#
# new_index 46
#
# matched pair:
#  ==============
# new_index 46
# master_index 893
#
# 893 	 new noor_index 	 893 & 46
#
# new_index 47
#
# matched pair:
#  ==============
# new_index 47
# master_index 1205
#
#
# new_index 48
#
# matched pair:
#  ==============
# new_index 48
# master_index 571
#
#
# new_index 49
#
# matched pair:
#  ==============
# new_index 49
# master_index 1712
#
# 1712 	 new pmg 	 2.09 = -log[Mg+2]
#
# new_index 50
#
# matched pair:
#  ==============
# new_index 50
# master_index 1715
#
# 1715 	 new pmg 	 1.19 = -log[Mg+2]
#
# new_index 51
#
# matched pair:
#  ==============
# new_index 51
# master_index 1714
#
# 1714 	 new pmg 	 1.49 = -log[Mg+2]
#
# new_index 52
#
# matched pair:
#  ==============
# new_index 52
# master_index 1713
#
# 1713 	 new pmg 	 1.8 = -log[Mg+2]
#
# new_index 53
#
# matched pair:
#  ==============
# new_index 53
# master_index 2198
#
#
# new_index 54
#
# matched pair:
#  ==============
# new_index 54
# master_index 2749
#
#
# new_index 55
#
# matched pair:
#  ==============
# new_index 55
# master_index 1327
#
#
# new_index 56
#
# matched pair:
#  ==============
# new_index 56
# master_index 1306
#
#
# new_index 57
#
# matched pair:
#  ==============
# new_index 57
# master_index 1099
#
#
# new_index 58
#
# matched pair:
#  ==============
# new_index 58
# master_index 395
#
#
# new_index 59
#
# matched pair:
#  ==============
# new_index 59
# master_index 336
#
#
# new_index 60
#
# matched pair:
#  ==============
# new_index 60
# master_index 337
#
#
# new_index 61
#
# matched pair:
#  ==============
# new_index 61
# master_index 338
#
#
# new_index 62
#
# matched pair:
#  ==============
# new_index 62
# master_index 3776
#
#
# new_index 63
#
# matched pair:
#  ==============
# new_index 63
# master_index 790
#
#
# new_index 64
#
# matched pair:
#  ==============
# new_index 64
# master_index 1955
#
#
# new_index 65
#
# matched pair:
#  ==============
# new_index 65
# master_index 1955
#
# 1955 	 new noor_index 	 1955 & 65
#
# new_index 66
#
# matched pair:
#  ==============
# new_index 66
# master_index 1958
#
#
# new_index 67
#
# matched pair:
#  ==============
# new_index 67
# master_index 1953
#
#
# new_index 68
#
# matched pair:
#  ==============
# new_index 68
# master_index 1959
#
#
# new_index 69
#
# matched pair:
#  ==============
# new_index 69
# master_index 1957
#
#
# new_index 70
#
# matched pair:
#  ==============
# new_index 70
# master_index 1953
#
# 1953 	 new noor_index 	 1953 & 70
#
# new_index 71
#
# matched pair:
#  ==============
# new_index 71
# master_index 1278
#
#
# new_index 72
#
# matched pair:
#  ==============
# new_index 72
# master_index 1280
#
#
# new_index 73
#
# matched pair:
#  ==============
# new_index 73
# master_index 1279
#
#
# new_index 74
#
# matched pair:
#  ==============
# new_index 74
# master_index 1282
#
#
# new_index 75
#
# matched pair:
#  ==============
# new_index 75
# master_index 3376
#
#
# new_index 76
#
# matched pair:
#  ==============
# new_index 76
# master_index 3377
#
#
# new_index 77
#
# matched pair:
#  ==============
# new_index 77
# master_index 4042
#
#
# new_index 78
#
# matched pair:
#  ==============
# new_index 78
# master_index 1213
#
#
# new_index 79
# --> Failed index to match:  79 ___ shikimate dehydrogenase
#
# new_index 80
# --> Failed index to match:  80 ___ shikimate dehydrogenase
#
# new_index 81
#
# matched pair:
#  ==============
# new_index 81
# master_index 3634
#
#
# new_index 82
#
# matched pair:
#  ==============
# new_index 82
# master_index 1904
#
#
# new_index 83
#
# matched pair:
#  ==============
# new_index 83
# master_index 1903
#
#
# new_index 84
#
# matched pair:
#  ==============
# new_index 84
# master_index 1905
#
#
# new_index 85
#
# matched pair:
#  ==============
# new_index 85
# master_index 1527
#
#
# new_index 86
#
# matched pair:
#  ==============
# new_index 86
# master_index 1529
#
#
# new_index 87
#
# matched pair:
#  ==============
# new_index 87
# master_index 1528
#
#
# new_index 88
#
# matched pair:
#  ==============
# new_index 88
# master_index 3695
#
# 3695 	 new pmg 	 3.0 = -log[Mg+2]
#
# new_index 89
#
# matched pair:
#  ==============
# new_index 89
# master_index 342
#
#
# new_index 90
#
# matched pair:
#  ==============
# new_index 90
# master_index 344
#
#
# new_index 91
#
# matched pair:
#  ==============
# new_index 91
# master_index 341
#
#
# new_index 92
#
# matched pair:
#  ==============
# new_index 92
# master_index 343
#
#
# new_index 93
#
# matched pair:
#  ==============
# new_index 93
# master_index 41
#
# 41 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 94
#
# matched pair:
#  ==============
# new_index 94
# master_index 61
#
# 61 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 95
#
# matched pair:
#  ==============
# new_index 95
# master_index 67
#
# 67 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 96
#
# matched pair:
#  ==============
# new_index 96
# master_index 43
#
# 43 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 97
#
# matched pair:
#  ==============
# new_index 97
# master_index 54
#
# 54 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 98
#
# matched pair:
#  ==============
# new_index 98
# master_index 55
#
# 55 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 99
#
# matched pair:
#  ==============
# new_index 99
# master_index 52
#
# 52 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 100
#
# matched pair:
#  ==============
# new_index 100
# master_index 47
#
# 47 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 101
#
# matched pair:
#  ==============
# new_index 101
# master_index 47
#
# 47 	 new EC 	 4.1.2.13 & 4.1.2.13 & 5.3.1.1 & 5.3.1.1
# 47 	 new noor_index 	 47 & 101
#
# new_index 102
#
# matched pair:
#  ==============
# new_index 102
# master_index 49
#
# 49 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 103
#
# matched pair:
#  ==============
# new_index 103
# master_index 66
#
# 66 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 104
#
# matched pair:
#  ==============
# new_index 104
# master_index 48
#
# 48 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 105
#
# matched pair:
#  ==============
# new_index 105
# master_index 45
#
# 45 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 106
#
# matched pair:
#  ==============
# new_index 106
# master_index 43
#
# 43 	 new EC 	 4.1.2.13 & 4.1.2.13 & 5.3.1.1 & 5.3.1.1
# 43 	 new noor_index 	 43 & 106
#
# new_index 107
#
# matched pair:
#  ==============
# new_index 107
# master_index 42
#
# 42 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 108
#
# matched pair:
#  ==============
# new_index 108
# master_index 59
#
# 59 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 109
#
# matched pair:
#  ==============
# new_index 109
# master_index 58
#
# 58 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 110
#
# matched pair:
#  ==============
# new_index 110
# master_index 64
#
# 64 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 111
#
# matched pair:
#  ==============
# new_index 111
# master_index 63
#
# 63 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 112
#
# matched pair:
#  ==============
# new_index 112
# master_index 60
#
# 60 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 113
#
# matched pair:
#  ==============
# new_index 113
# master_index 39
#
# 39 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 114
#
# matched pair:
#  ==============
# new_index 114
# master_index 39
#
# 39 	 new EC 	 4.1.2.13 & 4.1.2.13 & 5.3.1.1 & 5.3.1.1
# 39 	 new noor_index 	 39 & 114
#
# new_index 115
#
# matched pair:
#  ==============
# new_index 115
# master_index 62
#
# 62 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 116
#
# matched pair:
#  ==============
# new_index 116
# master_index 57
#
# 57 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 117
#
# matched pair:
#  ==============
# new_index 117
# master_index 56
#
# 56 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 118
#
# matched pair:
#  ==============
# new_index 118
# master_index 47
#
# 47 	 new EC 	 4.1.2.13 & 4.1.2.13 & 4.1.2.13 & 5.3.1.1 & 5.3.1.1 & 5.3.1.1
# 47 	 new noor_index 	 47 & 118
#
# new_index 119
#
# matched pair:
#  ==============
# new_index 119
# master_index 65
#
# 65 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 120
#
# matched pair:
#  ==============
# new_index 120
# master_index 44
#
# 44 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 121
#
# matched pair:
#  ==============
# new_index 121
# master_index 46
#
# 46 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 122
#
# matched pair:
#  ==============
# new_index 122
# master_index 40
#
# 40 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 123
#
# matched pair:
#  ==============
# new_index 123
# master_index 4043
#
#
# new_index 124
#
# matched pair:
#  ==============
# new_index 124
# master_index 4043
#
# 4043 	 new noor_index 	 4043 & 124
#
# new_index 125
# matched pair:
#  ==============
# new_index 125
# master_index 4045
#
#
# new_index 126
#
# matched pair:
#  ==============
# new_index 126
# master_index 4043
#
# 4043 	 new noor_index 	 4043 & 126
#
# new_index 127
#
# matched pair:
#  ==============
# new_index 127
# master_index 4047
#
#
# new_index 128
#
# matched pair:
#  ==============
# new_index 128
# master_index 4047
#
# 4047 	 new noor_index 	 4047 & 128
#
# new_index 129
#
# matched pair:
#  ==============
# new_index 129
# master_index 4043
#
# 4043 	 new noor_index 	 4043 & 129
#
# new_index 130
#
# matched pair:
#  ==============
# new_index 130
# master_index 217
#
#
# new_index 131
#
# matched pair:
#  ==============
# new_index 131
# master_index 1986
#
#
# new_index 132
#
# matched pair:
#  ==============
# new_index 132
# master_index 1557
#
#
# new_index 133
#
# matched pair:
#  ==============
# new_index 133
# master_index 3093
#
#
# new_index 134
#
# matched pair:
#  ==============
# new_index 134
# master_index 1376
#
#
# new_index 135
#
# matched pair:
#  ==============
# new_index 135
# master_index 2197
#
#
# new_index 136
#
# matched pair:
#  ==============
# new_index 136
# master_index 460
#
#
# new_index 137
#
# matched pair:
#  ==============
# new_index 137
# master_index 3689
#
# 3689 	 new pmg 	 3.0 = -log[Mg+2]
#
# new_index 138
#
# matched pair:
#  ==============
# new_index 138
# master_index 407
#
# 407 	 new EC 	 1.1.1.37 & 4.1.3.7
#
# new_index 139
#
# matched pair:
#  ==============
# new_index 139
# master_index 410
#
# 410 	 new EC 	 1.1.1.37 & 4.1.3.7
#
# new_index 140
#
# matched pair:
#  ==============
# new_index 140
# master_index 411
#
# 411 	 new EC 	 1.1.1.37 & 4.1.3.7
#
# new_index 141
#
# matched pair:
#  ==============
# new_index 141
# master_index 408
#
# 408 	 new EC 	 1.1.1.37 & 4.1.3.7
#
# new_index 142
#
# matched pair:
#  ==============
# new_index 142
# master_index 409
#
# 409 	 new EC 	 1.1.1.37 & 4.1.3.7
#
# new_index 143
#
# matched pair:
#  ==============
# new_index 143
# master_index 1293
#
#
# new_index 144
#
# matched pair:
#  ==============
# new_index 144
# master_index 2483
#
#
# new_index 145
#
# matched pair:
#  ==============
# new_index 145
# master_index 651
#
#
# new_index 146
#
# matched pair:
#  ==============
# new_index 146
# master_index 653
#
#
# new_index 147
#
# matched pair:
#  ==============
# new_index 147
# master_index 652
#
#
# new_index 148
#
# matched pair:
#  ==============
# new_index 148
# master_index 650
#
#
# new_index 149
#
# matched pair:
#  ==============
# new_index 149
# master_index 4050
#
#
# new_index 150
#
# matched pair:
#  ==============
# new_index 150
# master_index 4051
#
#
# new_index 151
#
# matched pair:
#  ==============
# new_index 151
# master_index 647
#
#
# new_index 152
#
# matched pair:
#  ==============
# new_index 152
# master_index 648
#
#
# new_index 153
#
# matched pair:
#  ==============
# new_index 153
# master_index 649
#
#
# new_index 154
#
# matched pair:
#  ==============
# new_index 154
# master_index 646
#
#
# new_index 155
#
# matched pair:
#  ==============
# new_index 155
# master_index 254
#
#
# new_index 156
#
# matched pair:
#  ==============
# new_index 156
# master_index 4052
#
#
# new_index 157
#
# matched pair:
#  ==============
# new_index 157
# master_index 1408
#
#
# new_index 158
#
# matched pair:
#  ==============
# new_index 158
# master_index 1345
#
#
# new_index 159
#
# matched pair:
#  ==============
# new_index 159
# master_index 1788
#
#
# new_index 160
#
# matched pair:
#  ==============
# new_index 160
# master_index 1109
#
#
# new_index 161
#
# matched pair:
#  ==============
# new_index 161
# master_index 2129
#
#
# new_index 162
#
# matched pair:
#  ==============
# new_index 162
# master_index 167
#
#
# new_index 163
#
# matched pair:
#  ==============
# new_index 163
# master_index 168
#
#
# new_index 164
#
# matched pair:
#  ==============
# new_index 164
# master_index 169
#
#
# new_index 165
#
# matched pair:
#  ==============
# new_index 165
# master_index 170
#
#
# new_index 166
#
# matched pair:
#  ==============
# new_index 166
# master_index 198
#
# 198 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 167
#
# matched pair:
#  ==============
# new_index 167
# master_index 200
#
# 200 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 168
#
# matched pair:
#  ==============
# new_index 168
# master_index 199
#
# 199 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 169
#
# matched pair:
#  ==============
# new_index 169
# master_index 530
#
#
# new_index 170
#
# matched pair:
#  ==============
# new_index 170
# master_index 2783
#
#
# new_index 171
#
# matched pair:
#  ==============
# new_index 171
# master_index 1123
#
#
# new_index 172
#
# matched pair:
#  ==============
# new_index 172
# master_index 1124
#
#
# new_index 173
#
# matched pair:
#  ==============
# new_index 173
# master_index 705
#
#
# new_index 174
#
# matched pair:
#  ==============
# new_index 174
# master_index 963
#
#
# new_index 175
#
# matched pair:
#  ==============
# new_index 175
# master_index 1987
#
#
# new_index 176
#
# matched pair:
#  ==============
# new_index 176
# master_index 1871
#
#
# new_index 177
#
# matched pair:
#  ==============
# new_index 177
# master_index 1066
#
#
# new_index 178
#
# matched pair:
#  ==============
# new_index 178
# master_index 1832
#
#
# new_index 179
#
# matched pair:
#  ==============
# new_index 179
# master_index 3632
#
#
# new_index 180
#
# matched pair:
#  ==============
# new_index 180
# master_index 215
#
#
# new_index 181
#
# matched pair:
#  ==============
# new_index 181
# master_index 216
#
#
# new_index 182
#
# matched pair:
#  ==============
# new_index 182
# master_index 1417
#
#
# new_index 183
#
# matched pair:
#  ==============
# new_index 183
# master_index 515
#
#
# new_index 184
#
# matched pair:
#  ==============
# new_index 184
# master_index 1336
#
#
# new_index 185
#
# matched pair:
#  ==============
# new_index 185
# master_index 4053
#
#
# new_index 186
#
# matched pair:
#  ==============
# new_index 186
# master_index 4054
#
#
# new_index 187
#
# matched pair:
#  ==============
# new_index 187
# master_index 4055
#
#
# new_index 188
#
# matched pair:
#  ==============
# new_index 188
# master_index 4055
#
# 4055 	 new pmg 	 2.15 = -log[Mg+2] or 2.0 (-log[Mg+2])
# 4055 	 new noor_index 	 4055 & 188
#
# new_index 189
#
# matched pair:
#  ==============
# new_index 189
# master_index 4057
#
#
# new_index 190
#
# matched pair:
#  ==============
# new_index 190
# master_index 4058
#
#
# new_index 191
#
# matched pair:
#  ==============
# new_index 191
# master_index 4059
#
#
# new_index 192
#
# matched pair:
#  ==============
# new_index 192
# master_index 4060
#
#
# new_index 193
#
# matched pair:
#  ==============
# new_index 193
# master_index 4061
#
#
# new_index 194
#
# matched pair:
#  ==============
# new_index 194
# master_index 4062
#
#
# new_index 195
#
# matched pair:
#  ==============
# new_index 195
# master_index 4062
#
# 4062 	 new noor_index 	 4062 & 195
#
# new_index 196
#
# matched pair:
#  ==============
# new_index 196
# master_index 4064
#
#
# new_index 197
#
# matched pair:
#  ==============
# new_index 197
# master_index 4065
#
#
# new_index 198
#
# matched pair:
#  ==============
# new_index 198
# master_index 4066
#
#
# new_index 199
#
# matched pair:
#  ==============
# new_index 199
# master_index 4067
#
#
# new_index 200
#
# matched pair:
#  ==============
# new_index 200
# master_index 4062
#
# 4062 	 new noor_index 	 4062 & 200
#
# new_index 201
#
# matched pair:
#  ==============
# new_index 201
# master_index 4069
#
#
# new_index 202
#
# matched pair:
#  ==============
# new_index 202
# master_index 4070
#
#
# new_index 203
#
# matched pair:
#  ==============
# new_index 203
# master_index 4071
#
#
# new_index 204
#
# matched pair:
#  ==============
# new_index 204
# master_index 4072
#
#
# new_index 205
#
# matched pair:
#  ==============
# new_index 205
# master_index 4073
#
#
# new_index 206
#
# matched pair:
#  ==============
# new_index 206
# master_index 4073
#
# 4073 	 new noor_index 	 4073 & 206
#
# new_index 207
#
# matched pair:
#  ==============
# new_index 207
# master_index 4055
#
# 4055 	 new pmg 	 2.15 = -log[Mg+2] or 2.0 (-log[Mg+2]) or 2.1 (-log[Mg+2])
# 4055 	 new noor_index 	 4055 & 207
#
# new_index 208
#
# matched pair:
#  ==============
# new_index 208
# master_index 4076
#
#
# new_index 209
#
# matched pair:
#  ==============
# new_index 209
# master_index 4077
#
#
# new_index 210
#
# matched pair:
#  ==============
# new_index 210
# master_index 4078
#
#
# new_index 211
#
# matched pair:
#  ==============
# new_index 211
# master_index 4079
#
#
# new_index 212
#
# matched pair:
#  ==============
# new_index 212
# master_index 4080
#
#
# new_index 213
#
# matched pair:
#  ==============
# new_index 213
# master_index 4081
#
#
# new_index 214
#
# matched pair:
#  ==============
# new_index 214
# master_index 4055
#
# 4055 	 new pmg 	 2.15 = -log[Mg+2] or 2.0 (-log[Mg+2]) or 2.1 (-log[Mg+2]) or 2.05 (-log[Mg+2])
# 4055 	 new noor_index 	 4055 & 214
#
# new_index 215
#
# matched pair:
#  ==============
# new_index 215
# master_index 4073
#
# 4073 	 new noor_index 	 4073 & 215
#
# new_index 216
#
# matched pair:
#  ==============
# new_index 216
# master_index 949
#
#
# new_index 217
#
# matched pair:
#  ==============
# new_index 217
# master_index 1227
#
#
# new_index 218
#
# matched pair:
#  ==============
# new_index 218
# master_index 18
#
# 18 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 219
#
# matched pair:
#  ==============
# new_index 219
# master_index 20
#
# 20 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 220
#
# matched pair:
#  ==============
# new_index 220
# master_index 21
#
# 21 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 221
#
# matched pair:
#  ==============
# new_index 221
# master_index 22
#
# 22 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 222
#
# matched pair:
#  ==============
# new_index 222
# master_index 19
#
# 19 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 223
#
# matched pair:
#  ==============
# new_index 223
# master_index 1449
#
#
# new_index 224
#
# matched pair:
#  ==============
# new_index 224
# master_index 1448
#
#
# new_index 225
#
# matched pair:
#  ==============
# new_index 225
# master_index 1447
#
#
# new_index 226
# matched pair:
#  ==============
# new_index 226
# master_index 4084
#
#
# new_index 227
#
# matched pair:
#  ==============
# new_index 227
# master_index 1450
#
#
# new_index 228
#
# matched pair:
#  ==============
# new_index 228
# master_index 392
#
#
# new_index 229
#
# matched pair:
#  ==============
# new_index 229
# master_index 1549
#
#
# new_index 230
#
# matched pair:
#  ==============
# new_index 230
# master_index 1550
#
#
# new_index 231
#
# matched pair:
#  ==============
# new_index 231
# master_index 1552
#
#
# new_index 232
#
# matched pair:
#  ==============
# new_index 232
# master_index 1551
#
#
# new_index 233
#
# matched pair:
#  ==============
# new_index 233
# master_index 1547
#
#
# new_index 234
#
# matched pair:
#  ==============
# new_index 234
# master_index 1548
#
#
# new_index 235
#
# matched pair:
#  ==============
# new_index 235
# master_index 36
#
#
# new_index 236
#
# matched pair:
#  ==============
# new_index 236
# master_index 3963
#
#
# new_index 237
#
# matched pair:
#  ==============
# new_index 237
# master_index 1189
#
#
# new_index 238
#
# matched pair:
#  ==============
# new_index 238
# master_index 3564
#
#
# new_index 239
#
# matched pair:
#  ==============
# new_index 239
# master_index 1228
#
#
# new_index 240
#
# matched pair:
#  ==============
# new_index 240
# master_index 3322
#
#
# new_index 241
#
# matched pair:
#  ==============
# new_index 241
# master_index 3563
#
#
# new_index 242
# --> Failed index to match:  242 ___ D-octopine dehydrogenase
#
# new_index 243
#
# matched pair:
#  ==============
# new_index 243
# master_index 345
#
#
# new_index 244
#
# matched pair:
#  ==============
# new_index 244
# master_index 2508
#
#
# new_index 245
#
# matched pair:
#  ==============
# new_index 245
# master_index 1206
#
#
# new_index 246
#
# matched pair:
#  ==============
# new_index 246
# master_index 1221
#
#
# new_index 247
#
# matched pair:
#  ==============
# new_index 247
# master_index 1220
#
#
# new_index 248
#
# matched pair:
#  ==============
# new_index 248
# master_index 1219
#
#
# new_index 249
#
# matched pair:
#  ==============
# new_index 249
# master_index 1218
#
#
# new_index 250
#
# matched pair:
#  ==============
# new_index 250
# master_index 1217
#
#
# new_index 251
#
# matched pair:
#  ==============
# new_index 251
# master_index 1215
#
#
# new_index 252
#
# matched pair:
#  ==============
# new_index 252
# master_index 1214
#
#
# new_index 253
#
# matched pair:
#  ==============
# new_index 253
# master_index 1216
#
#
# new_index 254
#
# matched pair:
#  ==============
# new_index 254
# master_index 1932
#
#
# new_index 255
#
# matched pair:
#  ==============
# new_index 255
# master_index 514
#
#
# new_index 256
#
# matched pair:
#  ==============
# new_index 256
# master_index 4085
#
#
# new_index 257
#
# matched pair:
#  ==============
# new_index 257
# master_index 4086
#
#
# new_index 258
#
# matched pair:
#  ==============
# new_index 258
# master_index 618
#
# 618 	 new EC 	 2.7.7.12 & 5.1.3.2
#
# new_index 259
#
# matched pair:
#  ==============
# new_index 259
# master_index 1798
#
#
# new_index 260
#
# matched pair:
#  ==============
# new_index 260
# master_index 2792
#
#
# new_index 261
#
# matched pair:
#  ==============
# new_index 261
# master_index 2793
#
#
# new_index 262
#
# matched pair:
#  ==============
# new_index 262
# master_index 2793
#
# 2793 	 new noor_index 	 2793 & 262
#
# new_index 263
#
# matched pair:
#  ==============
# new_index 263
# master_index 2795
#
#
# new_index 264
#
# matched pair:
#  ==============
# new_index 264
# master_index 2790
#
#
# new_index 265
#
# matched pair:
#  ==============
# new_index 265
# master_index 2790
#
# 2790 	 new noor_index 	 2790 & 265
#
# new_index 266
#
# matched pair:
#  ==============
# new_index 266
# master_index 4087
#
#
# new_index 267
#
# matched pair:
#  ==============
# new_index 267
# master_index 3087
#
#
# new_index 268
#
# matched pair:
#  ==============
# new_index 268
# master_index 340
#
#
# new_index 269
#
# matched pair:
#  ==============
# new_index 269
# master_index 4029
#
#
# new_index 270
# --> Failed index to match:  270 ___ alkaline phosphatase
#
# new_index 271
# --> Failed index to match:  271 ___ alkaline phosphatase
#
# new_index 272
#
# matched pair:
#  ==============
# new_index 272
# master_index 1009
#
#
# new_index 273
#
# matched pair:
#  ==============
# new_index 273
# master_index 654
#
#
# new_index 274
#
# matched pair:
#  ==============
# new_index 274
# master_index 195
#
# 195 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 275
#
# matched pair:
#  ==============
# new_index 275
# master_index 197
#
# 197 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 276
#
# matched pair:
#  ==============
# new_index 276
# master_index 196
#
# 196 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 277
#
# matched pair:
#  ==============
# new_index 277
# master_index 3338
#
#
# new_index 278
#
# matched pair:
#  ==============
# new_index 278
# master_index 3340
#
#
# new_index 279
#
# matched pair:
#  ==============
# new_index 279
# master_index 3341
#
#
# new_index 280
#
# matched pair:
#  ==============
# new_index 280
# master_index 3339
#
#
# new_index 281
#
# matched pair:
#  ==============
# new_index 281
# master_index 4088
#
#
# new_index 282
#
# matched pair:
#  ==============
# new_index 282
# master_index 853
#
#
# new_index 283
# --> Failed index to match:  283 ___ glucose-6-phosphate 1-epimerase
#
# new_index 284
#
# matched pair:
#  ==============
# new_index 284
# master_index 4089
#
#
# new_index 285
#
# matched pair:
#  ==============
# new_index 285
# master_index 795
#
#
# new_index 286
#
# matched pair:
#  ==============
# new_index 286
# master_index 3972
#
#
# new_index 287
#
# matched pair:
#  ==============
# new_index 287
# master_index 3971
#
#
# new_index 288
#
# matched pair:
#  ==============
# new_index 288
# master_index 1446
#
#
# new_index 289
#
# matched pair:
#  ==============
# new_index 289
# master_index 1445
#
#
# new_index 290
#
# matched pair:
#  ==============
# new_index 290
# master_index 796
#
#
# new_index 291
#
# matched pair:
#  ==============
# new_index 291
# master_index 813
#
#
# new_index 292
#
# matched pair:
#  ==============
# new_index 292
# master_index 2759
#
# 2759 	 new EC 	 1.1.1.37 & 2.6.1.1
#
# new_index 293
#
# matched pair:
#  ==============
# new_index 293
# master_index 724
#
#
# new_index 294
#
# matched pair:
#  ==============
# new_index 294
# master_index 2011
#
# 2011 	 new pmg 	 1.65 = -log[Mg+2] or 1.7 (-log[Mg+2])
#
# new_index 295
#
# matched pair:
#  ==============
# new_index 295
# master_index 2015
#
#
# new_index 296
#
# matched pair:
#  ==============
# new_index 296
# master_index 2016
#
#
# new_index 297
#
# matched pair:
#  ==============
# new_index 297
# master_index 2019
#
#
# new_index 298
#
# matched pair:
#  ==============
# new_index 298
# master_index 2021
#
#
# new_index 299
#
# matched pair:
#  ==============
# new_index 299
# master_index 2022
#
#
# new_index 300
#
# matched pair:
#  ==============
# new_index 300
# master_index 2023
#
#
# new_index 301
#
# matched pair:
#  ==============
# new_index 301
# master_index 2024
#
# 2024 	 new pmg 	 3.12 = -log[Mg+2] or 3.5 (-log[Mg+2])
#
# new_index 302
#
# matched pair:
#  ==============
# new_index 302
# master_index 2028
#
#
# new_index 303
#
# matched pair:
#  ==============
# new_index 303
# master_index 2030
#
#
# new_index 304
#
# matched pair:
#  ==============
# new_index 304
# master_index 2032
#
#
# new_index 305
#
# matched pair:
#  ==============
# new_index 305
# master_index 2036
#
#
# new_index 306
#
# matched pair:
#  ==============
# new_index 306
# master_index 2037
#
#
# new_index 307
#
# matched pair:
#  ==============
# new_index 307
# master_index 2040
#
#
# new_index 308
#
# matched pair:
#  ==============
# new_index 308
# master_index 2037
#
# 2037 	 new pmg 	 5.28 = -log[Mg+2] or 6.25 (-log[Mg+2])
# 2037 	 new noor_index 	 2037 & 308
#
# new_index 309
#
# matched pair:
#  ==============
# new_index 309
# master_index 2043
#
#
# new_index 310
#
# matched pair:
#  ==============
# new_index 310
# master_index 2035
#
# 2035 	 new pmg 	 5.0 = -log[Mg+2] or 6.75 (-log[Mg+2])
#
# new_index 311
#
# matched pair:
#  ==============
# new_index 311
# master_index 2043
#
# 2043 	 new pmg 	 6.4 = -log[Mg+2] or 6.8 (-log[Mg+2])
# 2043 	 new noor_index 	 2043 & 311
#
# new_index 312
#
# matched pair:
#  ==============
# new_index 312
# master_index 2049
#
#
# new_index 313
#
# matched pair:
#  ==============
# new_index 313
# master_index 2022
#
# 2022 	 new pmg 	 2.8 = -log[Mg+2] or 3.5 (-log[Mg+2])
# 2022 	 new noor_index 	 2022 & 313
#
# new_index 314
#
# matched pair:
#  ==============
# new_index 314
# master_index 2039
#
#
# new_index 315
#
# matched pair:
#  ==============
# new_index 315
# master_index 2039
#
# 2039 	 new noor_index 	 2039 & 315
#
# new_index 316
#
# matched pair:
#  ==============
# new_index 316
# master_index 2020
#
#
# new_index 317
#
# matched pair:
#  ==============
# new_index 317
# master_index 2014
#
#
# new_index 318
#
# matched pair:
#  ==============
# new_index 318
# master_index 2034
#
#
# new_index 319
#
# matched pair:
#  ==============
# new_index 319
# master_index 2043
#
# 2043 	 new pmg 	 6.4 = -log[Mg+2] or 6.8 (-log[Mg+2]) or 6.45 (-log[Mg+2])
# 2043 	 new noor_index 	 2043 & 319
#
# new_index 320
#
# matched pair:
#  ==============
# new_index 320
# master_index 2034
#
# 2034 	 new pmg 	 4.9 = -log[Mg+2] or 6.7 (-log[Mg+2])
# 2034 	 new noor_index 	 2034 & 320
#
# new_index 321
#
# matched pair:
#  ==============
# new_index 321
# master_index 2013
#
#
# new_index 322
#
# matched pair:
#  ==============
# new_index 322
# master_index 2024
#
# 2024 	 new pmg 	 3.12 = -log[Mg+2] or 3.5 (-log[Mg+2]) or 3.3 (-log[Mg+2])
# 2024 	 new noor_index 	 2024 & 322
#
# new_index 323
# matched pair:
#  ==============
# new_index 323
# master_index 2033
#
#
# new_index 324
#
# matched pair:
#  ==============
# new_index 324
# master_index 2050
#
#
# new_index 325
#
# matched pair:
#  ==============
# new_index 325
# master_index 2029
#
#
# new_index 326
#
# matched pair:
#  ==============
# new_index 326
# master_index 2029
#
# 2029 	 new pmg 	 4.0 = -log[Mg+2] or 4.15 (-log[Mg+2])
# 2029 	 new noor_index 	 2029 & 326
#
# new_index 327
#
# matched pair:
#  ==============
# new_index 327
# master_index 2024
#
# 2024 	 new pmg 	 3.12 = -log[Mg+2] or 3.5 (-log[Mg+2]) or 3.3 (-log[Mg+2]) or 3.12 (-log[Mg+2])
# 2024 	 new noor_index 	 2024 & 327
#
# new_index 328
#
# matched pair:
#  ==============
# new_index 328
# master_index 2014
#
# 2014 	 new pmg 	 1.9 = -log[Mg+2] or 2.25 (-log[Mg+2])
# 2014 	 new noor_index 	 2014 & 328
#
# new_index 329
#
# matched pair:
#  ==============
# new_index 329
# master_index 2034
#
# 2034 	 new pmg 	 4.9 = -log[Mg+2] or 6.7 (-log[Mg+2]) or 5.3 (-log[Mg+2])
# 2034 	 new noor_index 	 2034 & 329
#
# new_index 330
#
# matched pair:
#  ==============
# new_index 330
# master_index 2018
#
#
# new_index 331
#
# matched pair:
#  ==============
# new_index 331
# master_index 2037
#
# 2037 	 new pmg 	 5.28 = -log[Mg+2] or 6.25 (-log[Mg+2]) or 6.35 (-log[Mg+2])
# 2037 	 new noor_index 	 2037 & 331
#
# new_index 332
#
# matched pair:
#  ==============
# new_index 332
# master_index 2011
#
# 2011 	 new pmg 	 1.65 = -log[Mg+2] or 1.7 (-log[Mg+2]) or 1.65 (-log[Mg+2])
# 2011 	 new noor_index 	 2011 & 332
#
# new_index 333
#
# matched pair:
#  ==============
# new_index 333
# master_index 2035
#
# 2035 	 new pmg 	 5.0 = -log[Mg+2] or 6.75 (-log[Mg+2]) or 5.0 (-log[Mg+2])
# 2035 	 new noor_index 	 2035 & 333
#
# new_index 334
#
# matched pair:
#  ==============
# new_index 334
# master_index 2040
#
# 2040 	 new pmg 	 5.45 = -log[Mg+2] or 6.6 (-log[Mg+2])
# 2040 	 new noor_index 	 2040 & 334
#
# new_index 335
#
# matched pair:
#  ==============
# new_index 335
# master_index 1107
#
#
# new_index 336
#
# matched pair:
#  ==============
# new_index 336
# master_index 1107
#
# 1107 	 new noor_index 	 1107 & 336
#
# new_index 337
#
# matched pair:
#  ==============
# new_index 337
# master_index 3739
#
# 3739 	 new pmg 	 3.18 = -log[Mg+2]
#
# new_index 338
#
# matched pair:
#  ==============
# new_index 338
# master_index 3742
#
# 3742 	 new pmg 	 3.28 = -log[Mg+2]
#
# new_index 339
#
# matched pair:
#  ==============
# new_index 339
# master_index 3741
#
# 3741 	 new pmg 	 3.29 = -log[Mg+2]
#
# new_index 340
#
# matched pair:
#  ==============
# new_index 340
# master_index 3737
#
# 3737 	 new pmg 	 3.2 = -log[Mg+2]
#
# new_index 341
#
# matched pair:
#  ==============
# new_index 341
# master_index 3743
#
# 3743 	 new pmg 	 3.26 = -log[Mg+2]
#
# new_index 342
#
# matched pair:
#  ==============
# new_index 342
# master_index 3747
#
# 3747 	 new pmg 	 3.21 = -log[Mg+2]
#
# new_index 343
#
# matched pair:
#  ==============
# new_index 343
# master_index 3748
#
# 3748 	 new pmg 	 3.21 = -log[Mg+2]
#
# new_index 344
#
# matched pair:
#  ==============
# new_index 344
# master_index 3747
#
# 3747 	 new pmg 	 3.21 = -log[Mg+2] or 3.34 (-log[Mg+2])
# 3747 	 new noor_index 	 3747 & 344
#
# new_index 345
#
# matched pair:
#  ==============
# new_index 345
# master_index 3749
#
# 3749 	 new pmg 	 3.34 = -log[Mg+2]
#
# new_index 346
#
# matched pair:
#  ==============
# new_index 346
# master_index 3745
#
# 3745 	 new pmg 	 3.24 = -log[Mg+2]
#
# new_index 347
#
# matched pair:
#  ==============
# new_index 347
# master_index 3724
#
# 3724 	 new pmg 	 3.1 = -log[Mg+2]
#
# new_index 348
#
# matched pair:
#  ==============
# new_index 348
# master_index 3724
#
# 3724 	 new noor_index 	 3724 & 348
#
# new_index 349
#
# matched pair:
#  ==============
# new_index 349
# master_index 3724
#
# 3724 	 new pmg 	 3.1 = -log[Mg+2] or 3.2 (-log[Mg+2])
# 3724 	 new noor_index 	 3724 & 349
#
# new_index 350
#
# matched pair:
#  ==============
# new_index 350
# master_index 3723
#
# 3723 	 new pmg 	 3.21 = -log[Mg+2]
#
# new_index 351
#
# matched pair:
#  ==============
# new_index 351
# master_index 3721
#
# 3721 	 new pmg 	 3.13 = -log[Mg+2]
#
# new_index 352
#
# matched pair:
#  ==============
# new_index 352
# master_index 3727
#
# 3727 	 new pmg 	 3.16 = -log[Mg+2]
#
# new_index 353
#
# matched pair:
#  ==============
# new_index 353
# master_index 3734
#
# 3734 	 new pmg 	 3.13 = -log[Mg+2]
#
# new_index 354
#
# matched pair:
#  ==============
# new_index 354
# master_index 3733
#
# 3733 	 new pmg 	 3.13 = -log[Mg+2]
#
# new_index 355
#
# matched pair:
#  ==============
# new_index 355
# master_index 3731
#
# 3731 	 new pmg 	 3.25 = -log[Mg+2]
#
# new_index 356
#
# matched pair:
#  ==============
# new_index 356
# master_index 3732
#
# 3732 	 new pmg 	 3.24 = -log[Mg+2]
#
# new_index 357
#
# matched pair:
#  ==============
# new_index 357
# master_index 3730
#
# 3730 	 new pmg 	 3.15 = -log[Mg+2]
#
# new_index 358
#
# matched pair:
#  ==============
# new_index 358
# master_index 3730
#
# 3730 	 new noor_index 	 3730 & 358
#
# new_index 359
#
# matched pair:
#  ==============
# new_index 359
# master_index 3736
#
# 3736 	 new pmg 	 3.2 = -log[Mg+2]
#
# new_index 360
#
# matched pair:
#  ==============
# new_index 360
# master_index 3740
#
# 3740 	 new pmg 	 3.16 = -log[Mg+2]
#
# new_index 361
#
# matched pair:
#  ==============
# new_index 361
# master_index 3752
#
# 3752 	 new pmg 	 3.29 = -log[Mg+2]
#
# new_index 362
#
# matched pair:
#  ==============
# new_index 362
# master_index 3729
#
# 3729 	 new pmg 	 3.2 = -log[Mg+2]
#
# new_index 363
#
# matched pair:
#  ==============
# new_index 363
# master_index 3744
#
# 3744 	 new pmg 	 3.25 = -log[Mg+2]
#
# new_index 364
#
# matched pair:
#  ==============
# new_index 364
# master_index 3746
#
# 3746 	 new pmg 	 3.24 = -log[Mg+2]
#
# new_index 365
#
# matched pair:
#  ==============
# new_index 365
# master_index 3751
#
# 3751 	 new pmg 	 3.29 = -log[Mg+2]
#
# new_index 366
#
# matched pair:
#  ==============
# new_index 366
# master_index 3722
#
# 3722 	 new pmg 	 3.12 = -log[Mg+2]
#
# new_index 367
#
# matched pair:
#  ==============
# new_index 367
# master_index 3729
#
# 3729 	 new pmg 	 3.2 = -log[Mg+2] or 3.16 (-log[Mg+2])
# 3729 	 new noor_index 	 3729 & 367
#
# new_index 368
#
# matched pair:
#  ==============
# new_index 368
# master_index 3738
#
# 3738 	 new pmg 	 3.2 = -log[Mg+2]
#
# new_index 369
#
# matched pair:
#  ==============
# new_index 369
# master_index 3728
#
# 3728 	 new pmg 	 3.16 = -log[Mg+2]
#
# new_index 370
#
# matched pair:
#  ==============
# new_index 370
# master_index 804
#
#
# new_index 371
#
# matched pair:
#  ==============
# new_index 371
# master_index 661
#
#
# new_index 372
#
# matched pair:
#  ==============
# new_index 372
# master_index 1028
#
#
# new_index 373
#
# matched pair:
#  ==============
# new_index 373
# master_index 1303
#
#
# new_index 374
#
# matched pair:
#  ==============
# new_index 374
# master_index 1302
#
#
# new_index 375
#
# matched pair:
#  ==============
# new_index 375
# master_index 1301
#
#
# new_index 376
#
# matched pair:
#  ==============
# new_index 376
# master_index 15
#
# 15 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 377
#
# matched pair:
#  ==============
# new_index 377
# master_index 16
#
# 16 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 378
#
# matched pair:
#  ==============
# new_index 378
# master_index 17
#
# 17 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 379
#
# matched pair:
#  ==============
# new_index 379
# master_index 13
#
# 13 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 380
#
# matched pair:
#  ==============
# new_index 380
# master_index 14
#
# 14 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 381
#
# matched pair:
#  ==============
# new_index 381
# master_index 1928
#
#
# new_index 382
#
# matched pair:
#  ==============
# new_index 382
# master_index 1931
#
#
# new_index 383
#
# matched pair:
#  ==============
# new_index 383
# master_index 1929
#
#
# new_index 384
#
# matched pair:
#  ==============
# new_index 384
# master_index 1929
#
# 1929 	 new noor_index 	 1929 & 384
#
# new_index 385
#
# matched pair:
#  ==============
# new_index 385
# master_index 38
#
#
# new_index 386
#
# matched pair:
#  ==============
# new_index 386
# master_index 1210
#
#
# new_index 387
#
# matched pair:
#  ==============
# new_index 387
# master_index 3975
#
#
# new_index 388
#
# matched pair:
#  ==============
# new_index 388
# master_index 32
#
# 32 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 389
#
# matched pair:
#  ==============
# new_index 389
# master_index 31
#
# 31 	 new EC 	 4.1.2.13 & 5.3.1.1
#
# new_index 390
#
# matched pair:
#  ==============
# new_index 390
# master_index 3479
#
#
# new_index 391
#
# matched pair:
#  ==============
# new_index 391
# master_index 2491
#
#
# new_index 392
#
# matched pair:
#  ==============
# new_index 392
# master_index 2492
#
#
# new_index 393
#
# matched pair:
#  ==============
# new_index 393
# master_index 391
#
#
# new_index 394
#
# matched pair:
#  ==============
# new_index 394
# master_index 389
#
#
# new_index 395
#
# matched pair:
#  ==============
# new_index 395
# master_index 390
#
#
# new_index 396
#
# matched pair:
#  ==============
# new_index 396
# master_index 388
#
#
# new_index 397
#
# matched pair:
#  ==============
# new_index 397
# master_index 4090
#
#
# new_index 398
#
# matched pair:
#  ==============
# new_index 398
# master_index 4091
#
#
# new_index 399
#
# matched pair:
#  ==============
# new_index 399
# master_index 3446
#
# 3446 	 new pmg 	 2.21 = -log[Mg+2]
#
# new_index 400
#
# matched pair:
#  ==============
# new_index 400
# master_index 3449
#
# 3449 	 new pmg 	 2.96 = -log[Mg+2]
#
# new_index 401
#
# matched pair:
#  ==============
# new_index 401
# master_index 3449
#
# 3449 	 new pmg 	 2.96 = -log[Mg+2] or 2.49 (-log[Mg+2])
# 3449 	 new noor_index 	 3449 & 401
#
# new_index 402
#
# matched pair:
#  ==============
# new_index 402
# master_index 3443
#
# 3443 	 new pmg 	 3.27 = -log[Mg+2]
#
# new_index 403
#
# matched pair:
#  ==============
# new_index 403
# master_index 3443
#
# 3443 	 new noor_index 	 3443 & 403
#
# new_index 404
#
# matched pair:
#  ==============
# new_index 404
# master_index 3447
#
# 3447 	 new pmg 	 2.21 = -log[Mg+2]
#
# new_index 405
#
# matched pair:
#  ==============
# new_index 405
# master_index 3449
#
# 3449 	 new pmg 	 2.96 = -log[Mg+2] or 2.49 (-log[Mg+2]) or 3.11 (-log[Mg+2])
# 3449 	 new noor_index 	 3449 & 405
#
# new_index 406
#
# matched pair:
#  ==============
# new_index 406
# master_index 3448
#
# 3448 	 new pmg 	 2.21 = -log[Mg+2]
#
# new_index 407
#
# matched pair:
#  ==============
# new_index 407
# master_index 3449
#
# 3449 	 new pmg 	 2.96 = -log[Mg+2] or 2.49 (-log[Mg+2]) or 3.11 (-log[Mg+2]) or 2.25 (-log[Mg+2])
# 3449 	 new noor_index 	 3449 & 407
#
# new_index 408
#
# matched pair:
#  ==============
# new_index 408
# master_index 3445
#
# 3445 	 new pmg 	 2.21 = -log[Mg+2]
#
# new_index 409
#
# matched pair:
#  ==============
# new_index 409
# master_index 3455
#
# 3455 	 new pmg 	 2.21 = -log[Mg+2]
#
# new_index 410
# matched pair:
#  ==============
# new_index 410
# master_index 3449
#
# 3449 	 new pmg 	 2.96 = -log[Mg+2] or 2.49 (-log[Mg+2]) or 3.11 (-log[Mg+2]) or 2.25 (-log[Mg+2]) or 3.27 (-log[Mg+2])
# 3449 	 new noor_index 	 3449 & 410
#
# new_index 411
#
# matched pair:
#  ==============
# new_index 411
# master_index 3449
#
# 3449 	 new pmg 	 2.96 = -log[Mg+2] or 2.49 (-log[Mg+2]) or 3.11 (-log[Mg+2]) or 2.25 (-log[Mg+2]) or 3.27 (-log[Mg+2]) or 3.11 (-log[Mg+2])
# 3449 	 new noor_index 	 3449 & 411
#
# new_index 412
#
# matched pair:
#  ==============
# new_index 412
# master_index 3442
#
#
# new_index 413
#
# matched pair:
#  ==============
# new_index 413
# master_index 3053
#
#
# new_index 414
#
# matched pair:
#  ==============
# new_index 414
# master_index 911
#
#
# new_index 415
#
# matched pair:
#  ==============
# new_index 415
# master_index 1592
#
#
# new_index 416
#
# matched pair:
#  ==============
# new_index 416
# master_index 1594
#
#
# new_index 417
#
# matched pair:
#  ==============
# new_index 417
# master_index 1593
#
#
# new_index 418
#
# matched pair:
#  ==============
# new_index 418
# master_index 1260
#
#
# new_index 419
#
# matched pair:
#  ==============
# new_index 419
# master_index 1261
#
#
# new_index 420
#
# matched pair:
#  ==============
# new_index 420
# master_index 1262
#
#
# new_index 421
#
# matched pair:
#  ==============
# new_index 421
# master_index 4092
#
#
# new_index 422
#
# matched pair:
#  ==============
# new_index 422
# master_index 2735
#
#
# new_index 423
#
# matched pair:
#  ==============
# new_index 423
# master_index 2738
#
#
# new_index 424
#
# matched pair:
#  ==============
# new_index 424
# master_index 2737
#
#
# new_index 425
#
# matched pair:
#  ==============
# new_index 425
# master_index 2735
#
# 2735 	 new noor_index 	 2735 & 425
#
# new_index 426
#
# matched pair:
#  ==============
# new_index 426
# master_index 1962
#
#
# new_index 427
#
# matched pair:
#  ==============
# new_index 427
# master_index 1960
#
#
# new_index 428
#
# matched pair:
#  ==============
# new_index 428
# master_index 2823
#
#
# new_index 429
#
# matched pair:
#  ==============
# new_index 429
# master_index 2824
#
#
# new_index 430
#
# matched pair:
#  ==============
# new_index 430
# master_index 2827
#
#
# new_index 431
#
# matched pair:
#  ==============
# new_index 431
# master_index 2831
#
#
# new_index 432
#
# matched pair:
#  ==============
# new_index 432
# master_index 2830
#
#
# new_index 433
#
# matched pair:
#  ==============
# new_index 433
# master_index 2828
#
#
# new_index 434
#
# matched pair:
#  ==============
# new_index 434
# master_index 2832
#
#
# new_index 435
#
# matched pair:
#  ==============
# new_index 435
# master_index 2834
#
#
# new_index 436
#
# matched pair:
#  ==============
# new_index 436
# master_index 2840
#
#
# new_index 437
#
# matched pair:
#  ==============
# new_index 437
# master_index 2832
#
# 2832 	 new noor_index 	 2832 & 437
#
# new_index 438
#
# matched pair:
#  ==============
# new_index 438
# master_index 2851
#
#
# new_index 439
#
# matched pair:
#  ==============
# new_index 439
# master_index 2866
#
#
# new_index 440
#
# matched pair:
#  ==============
# new_index 440
# master_index 2867
#
#
# new_index 441
#
# matched pair:
#  ==============
# new_index 441
# master_index 2870
#
#
# new_index 442
#
# matched pair:
#  ==============
# new_index 442
# master_index 2871
#
#
# new_index 443
#
# matched pair:
#  ==============
# new_index 443
# master_index 2870
#
# 2870 	 new noor_index 	 2870 & 443
#
# new_index 444
#
# matched pair:
#  ==============
# new_index 444
# master_index 2873
#
#
# new_index 445
#
# matched pair:
#  ==============
# new_index 445
# master_index 2852
#
# 2852 	 new pmg 	 2.88 = -log[Mg+2]
#
# new_index 446
#
# matched pair:
#  ==============
# new_index 446
# master_index 2854
#
# 2854 	 new pmg 	 2.69 = -log[Mg+2]
#
# new_index 447
#
# matched pair:
#  ==============
# new_index 447
# master_index 2855
#
# 2855 	 new pmg 	 2.58 = -log[Mg+2]
#
# new_index 448
#
# matched pair:
#  ==============
# new_index 448
# master_index 2856
#
# 2856 	 new pmg 	 2.57 = -log[Mg+2]
#
# new_index 449
#
# matched pair:
#  ==============
# new_index 449
# master_index 2856
#
# 2856 	 new noor_index 	 2856 & 449
#
# new_index 450
#
# matched pair:
#  ==============
# new_index 450
# master_index 2857
#
# 2857 	 new pmg 	 2.39 = -log[Mg+2]
#
# new_index 451
#
# matched pair:
#  ==============
# new_index 451
# master_index 2859
#
# 2859 	 new pmg 	 2.28 = -log[Mg+2]
#
# new_index 452
#
# matched pair:
#  ==============
# new_index 452
# master_index 2834
#
# 2834 	 new pmg 	 2.25 = -log[Mg+2]
# 2834 	 new noor_index 	 2834 & 452
#
# new_index 453
#
# matched pair:
#  ==============
# new_index 453
# master_index 2842
#
# 2842 	 new pmg 	 1.95 = -log[Mg+2]
# 2842 	 new ionic strength 	 0.5 & 0.25
#
# new_index 454
#
# matched pair:
#  ==============
# new_index 454
# master_index 2849
#
# 2849 	 new pmg 	 1.96 = -log[Mg+2]
#
# new_index 455
#
# matched pair:
#  ==============
# new_index 455
# master_index 2833
#
# 2833 	 new ionic strength 	 0.25 & 0.07
#
# new_index 456
#
# matched pair:
#  ==============
# new_index 456
# master_index 2838
#
#
# new_index 457
#
# matched pair:
#  ==============
# new_index 457
# master_index 2841
#
#
# new_index 458
#
# matched pair:
#  ==============
# new_index 458
# master_index 2834
#
# 2834 	 new ionic strength 	 0.25 & 0.5
# 2834 	 new noor_index 	 2834 & 458
#
# new_index 459
#
# matched pair:
#  ==============
# new_index 459
# master_index 2847
#
#
# new_index 460
#
# matched pair:
#  ==============
# new_index 460
# master_index 2847
#
# 2847 	 new noor_index 	 2847 & 460
#
# new_index 461
#
# matched pair:
#  ==============
# new_index 461
# master_index 2835
#
#
# new_index 462
#
# matched pair:
#  ==============
# new_index 462
# master_index 2853
#
# 2853 	 new pmg 	 2.69 = -log[Mg+2]
#
# new_index 463
#
# matched pair:
#  ==============
# new_index 463
# master_index 2861
#
# 2861 	 new pmg 	 2.26 = -log[Mg+2]
#
# new_index 464
#
# matched pair:
#  ==============
# new_index 464
# master_index 2845
#
#
# new_index 465
#
# matched pair:
#  ==============
# new_index 465
# master_index 2826
#
#
# new_index 466
#
# matched pair:
#  ==============
# new_index 466
# master_index 2833
#
# 2833 	 new ionic strength 	 0.25 & 0.07 & 0.25
# 2833 	 new noor_index 	 2833 & 466
#
# new_index 467
#
# matched pair:
#  ==============
# new_index 467
# master_index 2868
#
#
# new_index 468
#
# matched pair:
#  ==============
# new_index 468
# master_index 2874
#
#
# new_index 469
#
# matched pair:
#  ==============
# new_index 469
# master_index 2856
#
# 2856 	 new pmg 	 2.57 = -log[Mg+2] or 2.39 (-log[Mg+2])
# 2856 	 new noor_index 	 2856 & 469
#
# new_index 470
#
# matched pair:
#  ==============
# new_index 470
# master_index 2856
#
# 2856 	 new pmg 	 2.57 = -log[Mg+2] or 2.39 (-log[Mg+2]) or 2.39 (-log[Mg+2])
# 2856 	 new noor_index 	 2856 & 470
#
# new_index 471
#
# matched pair:
#  ==============
# new_index 471
# master_index 2833
#
# 2833 	 new ionic strength 	 0.25 & 0.07 & 0.25 & 0.07
# 2833 	 new noor_index 	 2833 & 471
#
# new_index 472
#
# matched pair:
#  ==============
# new_index 472
# master_index 2842
#
# 2842 	 new ionic strength 	 0.5 & 0.25 & 0.5
# 2842 	 new noor_index 	 2842 & 472
#
# new_index 473
#
# matched pair:
# ...
#
#
# new_index 4373
#
# matched pair:
#  ==============
# new_index 4373
# master_index 1541
#
#
# new_index 4374
#
# matched pair:
#  ==============
# new_index 4374
# master_index 1542
#
#
# new_index 4375
#
# matched pair:
#  ==============
# new_index 4375
# master_index 4910
#
#
# new_index 4376
#
# matched pair:
#  ==============
# new_index 4376
# master_index 3830
#
#
# new_index 4377
#
# matched pair:
#  ==============
# new_index 4377
# master_index 3508
#
#
# new_index 4378
#
# matched pair:
#  ==============
# new_index 4378
# master_index 3507
#
#
# new_index 4379
#
# matched pair:
#  ==============
# new_index 4379
# master_index 3509
#
#
# new_index 4380
#
# matched pair:
#  ==============
# new_index 4380
# master_index 3510
#
#
# new_index 4381
#
# matched pair:
#  ==============
# new_index 4381
# master_index 818
#
#
# new_index 4382
#
# matched pair:
#  ==============
# new_index 4382
# master_index 820
#
#
# new_index 4383
#
# matched pair:
#  ==============
# new_index 4383
# master_index 819
#
# 819 	 new pmg 	 2.28 = -log[Mg+2]
#
# new_index 4384
#
# matched pair:
#  ==============
# new_index 4384
# master_index 822
#
#
# new_index 4385
#
# matched pair:
#  ==============
# new_index 4385
# master_index 816
#
#
# new_index 4386
#
# matched pair:
#  ==============
# new_index 4386
# master_index 821
#
# 821 	 new pmg 	 2.28 = -log[Mg+2]
#
# new_index 4387
#
# matched pair:
#  ==============
# new_index 4387
# master_index 815
#
# 815 	 new pmg 	 2.28 = -log[Mg+2]
#
# new_index 4388
#
# matched pair:
#  ==============
# new_index 4388
# master_index 817
#
# 817 	 new pmg 	 2.28 = -log[Mg+2]
#
# new_index 4389
#
# matched pair:
#  ==============
# new_index 4389
# master_index 1969
#
# 1969 	 new pmg 	 3.0 = -log[Mg+2]
#
# new_index 4390
#
# matched pair:
#  ==============
# new_index 4390
# master_index 1971
#
# 1971 	 new pmg 	 2.0 = -log[Mg+2]
#
# new_index 4391
#
# matched pair:
#  ==============
# new_index 4391
# master_index 1968
#
# 1968 	 new pmg 	 3.22 = -log[Mg+2]
#
# new_index 4392
#
# matched pair:
#  ==============
# new_index 4392
# master_index 1970
#
# 1970 	 new pmg 	 2.4 = -log[Mg+2]
#
# new_index 4393
#
# matched pair:
#  ==============
# new_index 4393
# master_index 1967
#
# 1967 	 new pmg 	 3.4 = -log[Mg+2]
#
# new_index 4394
#
# matched pair:
#  ==============
# new_index 4394
# master_index 1966
#
# 1966 	 new pmg 	 3.7 = -log[Mg+2]
#
# new_index 4395
#
# matched pair:
#  ==============
# new_index 4395
# master_index 185
#
#
# new_index 4396
#
# matched pair:
#  ==============
# new_index 4396
# master_index 622
#
#
# new_index 4397
#
# matched pair:
#  ==============
# new_index 4397
# master_index 620
#
#
# new_index 4398
#
# matched pair:
#  ==============
# new_index 4398
# master_index 621
#
#
# new_index 4399
#
# matched pair:
#  ==============
# new_index 4399
# master_index 619
#
#
# new_index 4400
#
# matched pair:
#  ==============
# new_index 4400
# master_index 3374
#
#
# new_index 4401
#
# matched pair:
#  ==============
# new_index 4401
# master_index 3375
#
#
# new_index 4402
#
# matched pair:
#  ==============
# new_index 4402
# master_index 3932
#
#
# new_index 4403
#
# matched pair:
#  ==============
# new_index 4403
# master_index 4911
#
#
# new_index 4404
#
# matched pair:
#  ==============
# new_index 4404
# master_index 1100
#
# 1100 	 new EC 	 2.7.3.2 & 2.7.3.2 & 3.6.1.32 & 3.6.1.32
# 1100 	 new noor_index 	 1100 & 4404
#
# new_index 4405
#
# matched pair:
#  ==============
# new_index 4405
# master_index 1600
#
# 1600 	 new method 	 amino acid analysis, Conway diffusion, and UV absorption
#
# new_index 4406
#
# matched pair:
#  ==============
# new_index 4406
# master_index 1601
#
# 1601 	 new method 	 amino acid analysis, Conway diffusion, and UV absorption
#
# new_index 4407
#
# matched pair:
#  ==============
# new_index 4407
# master_index 1602
#
# 1602 	 new method 	 amino acid analysis, Conway diffusion, and UV absorption
#
# new_index 4408
#
# matched pair:
#  ==============
# new_index 4408
# master_index 1603
#
# 1603 	 new method 	 amino acid analysis, Conway diffusion, and UV absorption
#
# new_index 4409
#
# matched pair:
#  ==============
# new_index 4409
# master_index 1604
#
# 1604 	 new method 	 amino acid analysis, Conway diffusion, and UV absorption
#
# new_index 4410
#
# matched pair:
#  ==============
# new_index 4410
# master_index 1604
#
# 1604 	 new noor_index 	 1604 & 4410
#
# new_index 4411
#
# matched pair:
#  ==============
# new_index 4411
# master_index 1610
#
# 1610 	 new method 	 amino acid analysis, Conway diffusion, and UV absorption
#
# new_index 4412
#
# matched pair:
#  ==============
# new_index 4412
# master_index 1604
#
# 1604 	 new noor_index 	 1604 & 4412
#
# new_index 4413
#
# matched pair:
#  ==============
# new_index 4413
# master_index 1604
#
# 1604 	 new noor_index 	 1604 & 4413
#
# new_index 4414
#
# matched pair:
#  ==============
# new_index 4414
# master_index 1604
#
# 1604 	 new noor_index 	 1604 & 4414
#
# new_index 4415
#
# matched pair:
#  ==============
# new_index 4415
# master_index 1604
#
# 1604 	 new noor_index 	 1604 & 4415
#
# new_index 4416
#
# matched pair:
#  ==============
# new_index 4416
# master_index 870
#
#
# new_index 4417
#
# matched pair:
#  ==============
# new_index 4417
# master_index 1184
#
#
# new_index 4418
#
# matched pair:
#  ==============
# new_index 4418
# master_index 1185
#
#
# new_index 4419
#
# matched pair:
#  ==============
# new_index 4419
# master_index 2753
#
#
# new_index 4420
# --> Failed index to match:  4420 ___ 1-piperidine-2-carboxylate reductase
#
# new_index 4421
# --> Failed index to match:  4421 ___ 1-piperidine-2-carboxylate reductase
#
# new_index 4422
# --> Failed index to match:  4422 ___ 1-piperidine-2-carboxylate reductase
#
# new_index 4423
# --> Failed index to match:  4423 ___ 1-piperidine-2-carboxylate reductase
#
# new_index 4424
# --> Failed index to match:  4424 ___ 1-piperidine-2-carboxylate reductase
#
# new_index 4425
# --> Failed index to match:  4425 ___ 1-piperidine-2-carboxylate reductase
#
# new_index 4426
#
# matched pair:
#  ==============
# new_index 4426
# master_index 809
#
#
# new_index 4427
#
# matched pair:
#  ==============
# new_index 4427
# master_index 1043
#
#
# new_index 4428
#
# matched pair:
#  ==============
# new_index 4428
# master_index 672
#
#
# new_index 4429
#
# matched pair:
#  ==============
# new_index 4429
# master_index 4912
#
#
# new_index 4430
#
# matched pair:
#  ==============
# new_index 4430
# master_index 1245
#
#
# new_index 4431
#
# matched pair:
#  ==============
# new_index 4431
# master_index 2807
#
#
# new_index 4432
#
# matched pair:
#  ==============
# new_index 4432
# master_index 2808
#
#
# new_index 4433
#
# matched pair:
#  ==============
# new_index 4433
# master_index 2810
#
#
# new_index 4434
#
# matched pair:
#  ==============
# new_index 4434
# master_index 2816
#
#
# new_index 4435
#
# matched pair:
#  ==============
# new_index 4435
# master_index 2819
#
#
# new_index 4436
#
# matched pair:
#  ==============
# new_index 4436
# master_index 2820
#
#
# new_index 4437
#
# matched pair:
#  ==============
# new_index 4437
# master_index 2821
#
#
# new_index 4438
#
# matched pair:
#  ==============
# new_index 4438
# master_index 2822
#
#
# new_index 4439
# matched pair:
#  ==============
# new_index 4439
# master_index 2811
#
#
# new_index 4440
#
# matched pair:
#  ==============
# new_index 4440
# master_index 2806
#
#
# new_index 4441
#
# matched pair:
#  ==============
# new_index 4441
# master_index 2805
#
#
# new_index 4442
#
# matched pair:
#  ==============
# new_index 4442
# master_index 2815
#
# 2815 	 new pmg 	 1.7 = -log[Mg+2]
#
# new_index 4443
#
# matched pair:
#  ==============
# new_index 4443
# master_index 2810
#
# 2810 	 new noor_index 	 2810 & 4443
#
# new_index 4444
#
# matched pair:
#  ==============
# new_index 4444
# master_index 2814
#
# 2814 	 new pmg 	 2.3 = -log[Mg+2]
#
# new_index 4445
#
# matched pair:
#  ==============
# new_index 4445
# master_index 2818
#
#
# new_index 4446
#
# matched pair:
#  ==============
# new_index 4446
# master_index 2810
#
# 2810 	 new noor_index 	 2810 & 4446
#
# new_index 4447
#
# matched pair:
#  ==============
# new_index 4447
# master_index 2817
#
#
# new_index 4448
#
# matched pair:
#  ==============
# new_index 4448
# master_index 2809
#
#
# new_index 4449
#
# matched pair:
#  ==============
# new_index 4449
# master_index 300
#
#
# new_index 4450
#
# matched pair:
#  ==============
# new_index 4450
# master_index 3316
#
#
# new_index 4451
#
# matched pair:
#  ==============
# new_index 4451
# master_index 146
#
#
# new_index 4452
#
# matched pair:
#  ==============
# new_index 4452
# master_index 148
#
#
# new_index 4453
#
# matched pair:
#  ==============
# new_index 4453
# master_index 150
#
#
# new_index 4454
#
# matched pair:
#  ==============
# new_index 4454
# master_index 145
#
#
# new_index 4455
#
# matched pair:
#  ==============
# new_index 4455
# master_index 147
#
#
# new_index 4456
#
# matched pair:
#  ==============
# new_index 4456
# master_index 149
#
#
# new_index 4457
#
# matched pair:
#  ==============
# new_index 4457
# master_index 1789
#
#
# new_index 4458
#
# matched pair:
#  ==============
# new_index 4458
# master_index 1796
#
#
# new_index 4459
#
# matched pair:
#  ==============
# new_index 4459
# master_index 1797
#
#
# new_index 4460
#
# matched pair:
#  ==============
# new_index 4460
# master_index 1793
#
#
# new_index 4461
#
# matched pair:
#  ==============
# new_index 4461
# master_index 1794
#
#
# new_index 4462
#
# matched pair:
#  ==============
# new_index 4462
# master_index 1790
#
#
# new_index 4463
#
# matched pair:
#  ==============
# new_index 4463
# master_index 1791
#
#
# new_index 4464
#
# matched pair:
#  ==============
# new_index 4464
# master_index 1795
#
#
# new_index 4465
#
# matched pair:
#  ==============
# new_index 4465
# master_index 1792
#
#
# new_index 4466
#
# matched pair:
#  ==============
# new_index 4466
# master_index 1409
#
#
# new_index 4467
# --> Failed index to match:  4467 ___ aconitate hydratase
#
# new_index 4468
#
# matched pair:
#  ==============
# new_index 4468
# master_index 222
#
#
# new_index 4469
#
# matched pair:
#  ==============
# new_index 4469
# master_index 224
#
#
# new_index 4470
#
# matched pair:
#  ==============
# new_index 4470
# master_index 225
#
#
# new_index 4471
#
# matched pair:
#  ==============
# new_index 4471
# master_index 223
#
#
# new_index 4472
#
# matched pair:
#  ==============
# new_index 4472
# master_index 1615
#
#
# new_index 4473
#
# matched pair:
#  ==============
# new_index 4473
# master_index 1615
#
# 1615 	 new noor_index 	 1615 & 4473
#
# new_index 4474
#
# matched pair:
#  ==============
# new_index 4474
# master_index 1617
#
#
# new_index 4475
#
# matched pair:
#  ==============
# new_index 4475
# master_index 1619
#
#
# new_index 4476
#
# matched pair:
#  ==============
# new_index 4476
# master_index 1622
#
#
# new_index 4477
#
# matched pair:
#  ==============
# new_index 4477
# master_index 1623
#
#
# new_index 4478
#
# matched pair:
#  ==============
# new_index 4478
# master_index 1626
#
#
# new_index 4479
#
# matched pair:
#  ==============
# new_index 4479
# master_index 1627
#
#
# new_index 4480
#
# matched pair:
#  ==============
# new_index 4480
# master_index 1628
#
#
# new_index 4481
#
# matched pair:
#  ==============
# new_index 4481
# master_index 1629
#
#
# new_index 4482
#
# matched pair:
#  ==============
# new_index 4482
# master_index 1631
#
#
# new_index 4483
#
# matched pair:
#  ==============
# new_index 4483
# master_index 1633
#
#
# new_index 4484
#
# matched pair:
#  ==============
# new_index 4484
# master_index 1632
#
#
# new_index 4485
#
# matched pair:
#  ==============
# new_index 4485
# master_index 1635
#
#
# new_index 4486
#
# matched pair:
#  ==============
# new_index 4486
# master_index 1621
#
#
# new_index 4487
#
# matched pair:
#  ==============
# new_index 4487
# master_index 1633
#
# 1633 	 new noor_index 	 1633 & 4487
#
# new_index 4488
#
# matched pair:
#  ==============
# new_index 4488
# master_index 1617
#
# 1617 	 new noor_index 	 1617 & 4488
#
# new_index 4489
#
# matched pair:
#  ==============
# new_index 4489
# master_index 1625
#
#
# new_index 4490
#
# matched pair:
#  ==============
# new_index 4490
# master_index 1623
#
# 1623 	 new noor_index 	 1623 & 4490
#
# new_index 4491
#
# matched pair:
#  ==============
# new_index 4491
# master_index 1635
#
# 1635 	 new noor_index 	 1635 & 4491
#
# new_index 4492
#
# matched pair:
#  ==============
# new_index 4492
# master_index 1619
#
# 1619 	 new noor_index 	 1619 & 4492
#
# new_index 4493
#
# matched pair:
#  ==============
# new_index 4493
# master_index 1619
#
# 1619 	 new noor_index 	 1619 & 4493
#
# new_index 4494
#
# matched pair:
#  ==============
# new_index 4494
# master_index 1629
#
# 1629 	 new noor_index 	 1629 & 4494
#
# new_index 4495
#
# matched pair:
#  ==============
# new_index 4495
# master_index 3872
#
#
# new_index 4496
#
# matched pair:
#  ==============
# new_index 4496
# master_index 4913
#
#
# new_index 4497
#
# matched pair:
#  ==============
# new_index 4497
# master_index 4914
#
#
# new_index 4498
#
# matched pair:
#  ==============
# new_index 4498
# master_index 4915
#
#
# new_index 4499
#
# matched pair:
#  ==============
# new_index 4499
# master_index 4916
#
#
# new_index 4500
#
# matched pair:
#  ==============
# new_index 4500
# master_index 4917
#
#
# new_index 4501
#
# matched pair:
#  ==============
# new_index 4501
# master_index 4918
#
#
# new_index 4502
#
# matched pair:
#  ==============
# new_index 4502
# master_index 4919
#
#
# new_index 4503
#
# matched pair:
#  ==============
# new_index 4503
# master_index 4920
#
#
# new_index 4504
#
# matched pair:
#  ==============
# new_index 4504
# master_index 4921
#
#
# new_index 4505
#
# matched pair:
#  ==============
# new_index 4505
# master_index 4922
#
#
# new_index 4506
#
# matched pair:
#  ==============
# new_index 4506
# master_index 4923
#
#
# new_index 4507
#
# matched pair:
#  ==============
# new_index 4507
# master_index 4924
#
#
# new_index 4508
#
# matched pair:
#  ==============
# new_index 4508
# master_index 4925
#
#
# new_index 4509
#
# matched pair:
#  ==============
# new_index 4509
# master_index 984
#
#
# new_index 4510
#
# matched pair:
#  ==============
# new_index 4510
# master_index 4013
#
#
# new_index 4511
#
# matched pair:
#  ==============
# new_index 4511
# master_index 656
#
#
# new_index 4512
#
# matched pair:
#  ==============
# new_index 4512
# master_index 655
#
#
# new_index 4513
#
# matched pair:
#  ==============
# new_index 4513
# master_index 412
#
#
# new_index 4514
#
# matched pair:
#  ==============
# new_index 4514
# master_index 1819
#
#
# new_index 4515
#
# matched pair:
#  ==============
# new_index 4515
# master_index 691
#
#
# new_index 4516
#
# matched pair:
#  ==============
# new_index 4516
# master_index 382
#
#
# new_index 4517
#
# matched pair:
#  ==============
# new_index 4517
# master_index 3222
#
#
# new_index 4518
#
# matched pair:
#  ==============
# new_index 4518
# master_index 3222
#
# 3222 	 new noor_index 	 3222 & 4518
#
# new_index 4519
#
# matched pair:
#  ==============
# new_index 4519
# master_index 3222
#
# 3222 	 new noor_index 	 3222 & 4519
#
# new_index 4520
#
# matched pair:
#  ==============
# new_index 4520
# master_index 3222
#
# 3222 	 new noor_index 	 3222 & 4520
#
# new_index 4521
#
# matched pair:
#  ==============
# new_index 4521
# master_index 3222
#
# 3222 	 new noor_index 	 3222 & 4521
#
# new_index 4522
#
# matched pair:
#  ==============
# new_index 4522
# master_index 3222
#
# 3222 	 new noor_index 	 3222 & 4522
#
# new_index 4523
#
# matched pair:
#  ==============
# new_index 4523
# master_index 3222
#
# 3222 	 new noor_index 	 3222 & 4523
#
# new_index 4524
#
# matched pair:
#  ==============
# new_index 4524
# master_index 3562
#
#
# new_index 4525
#
# matched pair:
#  ==============
# new_index 4525
# master_index 1946
#
#
# new_index 4526
#
# matched pair:
#  ==============
# new_index 4526
# master_index 1950
#
#
# new_index 4527
#
# matched pair:
#  ==============
# new_index 4527
# master_index 1949
#
#
# new_index 4528
#
# matched pair:
#  ==============
# new_index 4528
# master_index 1951
#
#
# new_index 4529
#
# matched pair:
#  ==============
# new_index 4529
# master_index 1947
#
#
# new_index 4530
#
# matched pair:
#  ==============
# new_index 4530
# master_index 1948
#
#
# new_index 4531
# matched pair:
#  ==============
# new_index 4531
# master_index 1952
#
#
# new_index 4532
#
# matched pair:
#  ==============
# new_index 4532
# master_index 2516
#
#
# new_index 4533
#
# matched pair:
#  ==============
# new_index 4533
# master_index 1452
#
#
# new_index 4534
#
# matched pair:
#  ==============
# new_index 4534
# master_index 1453
#
#
# new_index 4535
#
# matched pair:
#  ==============
# new_index 4535
# master_index 385
#
# 385 	 new EC 	 2.7.7.12 & 5.1.3.2
#
# new_index 4536
#
# matched pair:
#  ==============
# new_index 4536
# master_index 4926
#
#
# new_index 4537
#
# matched pair:
#  ==============
# new_index 4537
# master_index 4927
#
#
# new_index 4538
#
# matched pair:
#  ==============
# new_index 4538
# master_index 4928
#
#
# new_index 4539
#
# matched pair:
#  ==============
# new_index 4539
# master_index 4929
#
#
# new_index 4540
#
# matched pair:
#  ==============
# new_index 4540
# master_index 4930
#
#
# new_index 4541
#
# matched pair:
#  ==============
# new_index 4541
# master_index 4931
#
#
# new_index 4542
#
# matched pair:
#  ==============
# new_index 4542
# master_index 4932
#
#
# new_index 4543
#
# matched pair:
#  ==============
# new_index 4543
# master_index 4933
#
#
# Unique matched indices:  False
# Unmatched indices:  267

# %% [markdown]
# # Contrast the scrapings

# %%
# %run ../comparisons.py

# ecoli_bigg = json.load(open('e_coli_core.json'))

# print(len(freiburger_dataframe))

# comp = comparison({'freiburger':freiburger_dataframe},{'noor': noor_dataframe},{'du': du_dataframe})
# enzyme_diff = comp.three_way_comparison('enzymes')
# reference_diff = comp.three_way_comparison('references')
# print('Enzymes')
# for key, value in enzyme_diff.items():
#     print(key, ': ', len(value))
# print('\nReferences')
# for key, value in reference_diff.items():
#     print(key, ': ', len(value))  

# print('\n')
# comp.bigg_comparison(ecoli_bigg, noor_master_merge)
