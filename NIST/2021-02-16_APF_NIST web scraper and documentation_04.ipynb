# %% [markdown]
# # NIST Web Scraping

# %% [markdown]
# The following code documents the methods of combining and organizing the scraped data.

# %% [markdown]
# ## Scraping code

# %% [markdown]
# The web scraping was conducted through the following code. Increments of 27 reference ID URLs were scraped to maintain accuracy of the scraper while executing a timely web scrape.

# %%
#Import Statements
from bs4 import BeautifulSoup
import requests #Pulling webpages
import pandas 
import numpy
import re
import math

#defining the website
root_url = "https://randr.nist.gov/enzyme/DataDetails.aspx?ID="
end_url = "&finalterm=&data=enzyme"
#===========================================================================================================================

#identify the table and rows of pertinent data
bs = BeautifulSoup(open('Enzyme Thermodynamic Database.html'), 'lxml')
table = bs.find("table", attrs = {'id': 'MainBody_gvSearch'})
body = table.find_all("tr")
#print(body[1])

#defining the initial boundaries of the aggregate dataframe
index_range = 12000
index_count = 0
loop_count = 0 
lower_bound = 1 #math.floor(1*len(body)/50)
upper_bound = math.floor(1*len(body)/50)

#loop through the enzyme id values 
id_values = []
id_refined = ''

for row in range(lower_bound,upper_bound):   #
    id_value = body[row].find("a")
    
    #refining the reference IDs 
    id_refined = re.findall(r"(\d+\w+.\w+.\d+)(?<=)",str(id_value))
    scraped_id = str(id_refined).strip('[]')
    scraped_id2 = re.sub(r'(\')', '', scraped_id)
    total_url = root_url + scraped_id2 + end_url
    
    #defining the soup
    soup = requests.get(total_url).text
    bs = BeautifulSoup(soup, 'lxml')
    
    #identify the table1, body1, and headers
    tables1 = bs.find_all("table", attrs = {"id": "MainBody_extraData"})
    print(scraped_id2, '\t: ', loop_count, '\t, ', len(tables1))
    if len(tables1) != 1:
        continue

    body1 = tables1[0].find_all("tr")
    body_rows1 = body1[1:]
    heads = body1[0]

    headings = []
    for head in heads.find_all("th"):
        head = (head.text).rstrip("\n")
        headings.append(head)


    #identify entries of the body rows
    total_rows = []
    for row_number in range(len(body_rows1)):
        each_row = []
        for row_element in body_rows1[row_number].find_all("td"):
            row_refined = re.sub("(\xa0)|(\n)|,","",row_element.text)
            each_row.append(row_refined)
        total_rows.append(each_row)
    
    #create a dataframe
    index_list_body = range(index_count+lower_bound-1, len(body_rows1)+index_count+lower_bound-1)
    bs_dataframe_table1 = pandas.DataFrame(data = total_rows, columns = headings, index = index_list_body)
    bs_dataframe_table1.drop(bs_dataframe_table1.columns[len(bs_dataframe_table1.columns)-1], axis=1, inplace=True)

    
#===========================================================================================================================

    #identify table2 and body2
    tables = bs.find_all("table", attrs={"id": "MainBody_DataList1"})
    if len(tables) == 0:
        continue
    body2 = tables[0].find_all("tr")
    body_rows2 = body2[1:]

    each_row2 = []
    for row in range(len(body_rows2)):
        for row_element in body_rows2[row].find_all("td"):
            row_refined2 = re.sub("(\xa0)|(\n)|,","",row_element.text)
            each_row2.append(row_refined2)

    information_entries_list = []
    information_values_list = []
    column_count = 0
    for i, element in enumerate(each_row2):
        if i == 0 or i % 2 == 0:
            information_entries_list.append(element)
            column_count += 1
        else:
            information_values_list.append(element)
            column_count += 1
    column_count /= 2


    #create a dataframe
    index_list_reference = range(index_count+lower_bound-1, index_count+1+lower_bound-1)
    bs_dataframe_pretable2 = pandas.DataFrame(data = [information_values_list], columns = information_entries_list, index = index_list_reference)
    bs_dataframe_pretable2.drop(bs_dataframe_pretable2.columns[len(bs_dataframe_pretable2.columns)-2], axis=1, inplace=True)
    
#===========================================================================================================================

    #merge the dataframes of this loop
    this_dataframe = bs_dataframe_table1.join(bs_dataframe_pretable2)
    this_dataframe.index.name = 'index'
    
   #iteratively coalesce the new dataframe into the old dataframe 
    if loop_count == 0:
        old_dataframe = this_dataframe
        old_dataframe.index.name = 'index'
        
    elif loop_count > 0:
        these_columns = []
        for column in this_dataframe:
            these_columns.append(column)
            
        old_columns = []
        for existing_column in old_dataframe:
            old_columns.append(existing_column)
            
        common_columns = list(set(these_columns).intersection(old_columns))
        
        #amalgamate the dataframe with the pre-existing dataframe
        current_dataframe = old_dataframe.merge(this_dataframe, on = common_columns, how = 'outer')
        old_dataframe = current_dataframe  
        

    #amalgamate the dataframe with the pre-existing dataframe
    index_count += len(body_rows1)
    loop_count += 1 


#export total_df to csv 
old_dataframe.to_csv("1.csv")

#print(bs_dataframe_table1)
old_dataframe

# %% [markdown]
# ## CSV data combination

# %% [markdown]
# The following code was combined the individual CSV files. The code was dynamically applied to aggregate CSV files into the segments 1-5, 6-16, 17-36, and 37-50. The code subsequently combined each of the four segments into the complete csv file. The columns were reorganized according to subjective preference with the reference information on the left and the data on the right.

# %%
import pandas as pandas
import datetime
import re 

combined_dataframe = pandas.read_csv('')

#dataframes definition
'''df1 = pandas.read_csv("1-5.csv", encoding='cp1252')
df2 = pandas.read_csv("6-16.csv", encoding='cp1252')
df3 = pandas.read_csv("17-36.csv", encoding='cp1252')
df4 = pandas.read_csv("37-50.csv", encoding='cp1252')

dataframes = [df1,df2,df3,df4]
combined_csv = pandas.concat([f for f in dataframes])'''

#defining the columns 
loop_count = 0
these_columns = []
old_columns = []   
total_columns = []

for df in dataframes:  
    for this_column in df:
        if this_column not in total_columns:
            total_columns.append(this_column)
       
right_dataframe_columns = []
left_dataframe_columns = [] 
for column in total_columns:
    if re.match("(\w+)(?=:)", column) or re.match("(\w+\s\w+)(?=:)", column):
        if column not in left_dataframe_columns:
            left_dataframe_columns.append(column)    
            
    if column == 'T(K)':
        right_dataframe_columns.append(column)
    if column == 'pH ':
        right_dataframe_columns.append(column)
    if column == 'K<sub>c</sub>\' ':
        right_dataframe_columns.append(column)
    if column == 'δ<sub>r</sub>H\'<sup>o</sup>(kJ.mol<sup>-1</sup>)':
        right_dataframe_columns.append(column)
      
defined_columns = left_dataframe_columns + right_dataframe_columns 
remaining_columns = list(set(defined_columns).symmetric_difference(set(total_columns)))

#reorganizing the dataframe
final_dataframe_columns = defined_columns + remaining_columns
final_dataframe = combined_csv.reindex(columns = final_dataframe_columns)

#export total_df to csv 
final_dataframe.to_csv("{}_vetted & complete NIST database.csv".format(datetime.date.today()))

# %% [markdown]
# ## Column combination

# %% [markdown]
# The following code combined columns with akin data in the complete CSV. Suffixes were used to further specify data in columns that combined myriad data sources. The columns were finally renamed with generic conventions.

# %%
import datetime 
import pandas 
import re

# dataframes definition
combined_dataframe = pandas.read_csv("2021-05-06_vetted & complete NIST database.csv")
df = combined_dataframe.astype(str)

empty_cell = ['nan', 'NaN', 'none', 'not given', '0', '', None]

combined_columns = []

for this_column in df:
    for index, row in df.iterrows():       
        # combine the equilibrium constant columns
        if re.search('(?i)(^K)', this_column) and not re.search('(Km\')', this_column):
            if str(df.at[index, this_column]) not in empty_cell: 
                if str(df.at[index, 'K<sub>c</sub>\' ']) in empty_cell:
                    df.at[index, 'K<sub>c</sub>\' '] = str(df.at[index, this_column])

                if str(df.at[index, this_column]) not in empty_cell:
                    if str(df.at[index, 'K<sub>c</sub>\' ']) != str(df.at[index, this_column]):
                        df.at[index, 'K<sub>c</sub>\' '] = str(df.at[index, 'K<sub>c</sub>\' ']) + ' & ' + str(df.at[index, this_column])

            if this_column !=  'K<sub>c</sub>\' ':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)

        # combine the ethalpy columns
        if re.search('ë«', this_column):
            if str(df.at[index, this_column]) not in empty_cell:
                if str(df.at[index, 'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)']) in empty_cell:
                    df.at[index, 'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)'] = str(df.at[index, this_column])

                if str(df.at[index, this_column]) not in empty_cell:
                    if str(df.at[index, 'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)']) != str(df.at[index, this_column]):
                        df.at[index, 'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)'] = str(df.at[index, 'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)']) + ' & ' + str(df.at[index, this_column])

            if this_column !=  'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)


        # combine the concentration ionic strenth columns 
        if re.search('I<sub>c', this_column): 
            if str(df.at[index, this_column]) not in empty_cell:
                if str(df.at[index, 'I<sub>c</sub>(mol dm<sup>-3</sup>)']) in empty_cell:
                    df.at[index, 'I<sub>c</sub>(mol dm<sup>-3</sup>)'] = str(df.at[index, this_column])

                if str(df.at[index, this_column]) not in empty_cell:
                    if str(df.at[index, 'I<sub>c</sub>(mol dm<sup>-3</sup>)']) != str(df.at[index, this_column]):
                        df.at[index, 'I<sub>c</sub>(mol dm<sup>-3</sup>)'] = str(df.at[index, 'δ<sub>r</sub>H\'<sup>o</sup>(kJ.mol<sup>-1</sup>)']) + ' & ' + str(df.at[index, this_column])

            if this_column !=  'I<sub>c</sub>(mol dm<sup>-3</sup>)':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)


        # combine the solute molar concentrations
        if re.search('(?<=c\()(\w+\d?\+?)(?<!,)', this_column):
            if re.search('(?<=c\()(\w+\d?\+?)(?<!,)', this_column):
                solute = str(re.search('(?<=c\()(\w+\d?\+?)(?<!,)', this_column).group(1))
                
            if str(df.at[index, this_column]) not in empty_cell:
                if str(df.at[index, 'c(glycerol,mol dm<sup>-3</sup>)']) in empty_cell:
                    df.at[index, 'c(glycerol,mol dm<sup>-3</sup>)'] = str(df.at[index, this_column]) + ' ' + solute

                if str(df.at[index, this_column]) not in empty_cell:
                    if str(df.at[index, 'c(glycerol,mol dm<sup>-3</sup>)']) != (str(df.at[index, this_column]) or str(df.at[index, this_column]) + ' ' + solute):
                        df.at[index, 'c(glycerol,mol dm<sup>-3</sup>)'] = str(df.at[index, 'c(glycerol,mol dm<sup>-3</sup>)']) + ' & ' + str(df.at[index, this_column]) + ' ' + solute

            if this_column !=  'c(glycerol,mol dm<sup>-3</sup>)':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)


        # combine the solute molality concentrations
        if re.search('(?<=m\()(\w+\d?\+?)(?<!,)', this_column):
            if re.search('(?<=c\()(\w+\d?\+?)(?<!,)', this_column):
                solute = str(re.search('(?<=c\()(\w+\d?\+?)(?<!,)', this_column).group(1))
                
            if str(df.at[index, this_column]) not in empty_cell:
                if str(df.at[index, 'm(MgCl2,mol.kg<sup>-1</sup>)']) in empty_cell:
                    df.at[index, 'm(MgCl2,mol.kg<sup>-1</sup>)'] = str(df.at[index, this_column]) + ' ' + solute

                if str(df.at[index, this_column]) not in empty_cell:
                    if str(df.at[index, 'm(MgCl2,mol.kg<sup>-1</sup>)']) != (str(df.at[index, this_column]) or str(df.at[index, this_column]) + ' ' + solute):
                        df.at[index, 'm(MgCl2,mol.kg<sup>-1</sup>)'] = str(df.at[index, 'm(MgCl2,mol.kg<sup>-1</sup>)']) + ' & ' + str(df.at[index, this_column]) + ' ' + solute

            if this_column !=  'm(MgCl2,mol.kg<sup>-1</sup>)':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)


        #combine buffer and solution details
        buffer_columns = ['buffer(mol dm<sup>-3</sup>)', 'buffer and/or salt ', 'media ', 'buffer ']
        if this_column in buffer_columns:
            if str(df.at[index, this_column]) not in empty_cell:
                if str(df.at[index, 'Buffer:']) in empty_cell:
                    df.at[index, 'Buffer:'] = str(df.at[index, this_column])

                if str(df.at[index, 'Buffer:']) not in empty_cell:
                    if not re.search(re.escape(str(df.at[index, this_column])), str(df.at[index, 'Buffer:'])):
                        df.at[index, 'Buffer:'] = str(df.at[index, 'Buffer:']) + '  +  ' + str(df.at[index, this_column])
                        #print('Buffer: ERROR, index: ', index)             

            if this_column !=  'Buffer:':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)

        # combine environmental conditions
        solution_columns = ['salt ', 'cosolvent ', 'added solute ', 'protein ', 'added solute ', 'percent(dimethyl sulfoxide) ', 'p(MPa)', 'pMg ']
        if this_column in solution_columns:
            if str(df.at[index, this_column]) not in empty_cell:
                if str(df.at[index, 'solvent ']) in empty_cell:
                    if str(this_column) == 'p(MPa)':
                        #print("yes: ", index)
                        df.at[index, 'solvent '] = str(df.at[index, this_column]) + ' megapascals'  

                    elif str(this_column) == 'pMg ':
                        #print('yes: ', index)
                        df.at[index, 'solvent '] = str(df.at[index, this_column]) + ' = -log[Mg+2]'   
                        
                    elif str(this_column) == 'percent(dimethyl sulfoxide) ':
                        df.at[index, 'solvent '] = str(df.at[index, this_column]) + ' % DMSO'   

                    else:
                        df.at[index, 'solvent '] = str(df.at[index, this_column])

                if str(df.at[index, 'solvent ']) not in empty_cell:
                    if not re.search(re.escape(str(df.at[index, this_column])), str(df.at[index, 'solvent '])):
                        df.at[index, 'solvent '] = str(df.at[index, 'solvent ']) + '  +  ' + str(df.at[index, this_column])

            if this_column !=  'solvent ':
                if this_column not in combined_columns:
                    combined_columns.append(this_column)
       
            
# rename the base columns
df.rename(columns = {'c(glycerol,mol dm<sup>-3</sup>)':'solutes [mol / dm^3]', 
                     'I<sub>c</sub>(mol dm<sup>-3</sup>)':'Ionic strength [mol / dm^3]', 
                     'T(K)':'T [K]', 
                     'I<sub>m</sub>(mol.kg<sup>-1</sup>)':'Ionic strength [mol / kg]', 
                     'm(MgCl2,mol.kg<sup>-1</sup>)':'solutes [mol / kg]', 
                     'solvent ':'Experimental conditions', 
                     'K<sub>c</sub>\' ':'Keq', 
                     'ë«<sub>r</sub>H(kJ.mol<sup>-1</sup>)':'Enthalpy [kJ / mol]',
                     'Km\' ':'Km'},
          inplace = True)
            
for column in combined_columns:
    print(column)
    del df[column]
    
#export total_df to csv 
df.to_csv("{}_vetted & reorganized NIST database_01.csv".format(datetime.date.today()))

# %% [markdown]
# ## Enzyme names and reactions

# %% [markdown]
# The enzyme names and corresponding reactions from each reference are added in an adjacent column. The generated file is the final file of the NIST web scraped database.

# %%
#Import Statements
from bs4 import BeautifulSoup
import pandas 
import numpy
import datetime
import os
import re


#import the csv file
total_csv = pandas.read_csv("2021-03-21_APF_vetted and reorganized complete NIST enzyme database_001.csv")
bs = BeautifulSoup(open('Enzyme Thermodynamic Database.html'), 'lxml')
#print(bs.prettify())

#identify the table and rows of pertinent data
table = bs.find("table", attrs = {'id': 'MainBody_gvSearch'})
body = table.find_all("tr")
print(len(body))


# loop through the enzyme id values 
reference_ids = []
enzyme_names = []
reactions = []
name_iteration = 0
id_refined = ''
for row in range(1, len(body)):
    id_value = body[row].find("a").text
    reference_ids.append(id_value)   
    
    enzyme_name = body[row].find('span', attrs = {'id': 'MainBody_gvSearch_lblEnzyme_%s' %(name_iteration)}).text
    enzyme_names.append(enzyme_name)
    
    reaction = body[row].find('span', attrs = {'id': 'MainBody_gvSearch_lblReaction_%s' %(name_iteration)}).text
    reactions.append(reaction)
    
    name_iteration += 1

#print(enzyme_names)
#print('\n\n', reactions)
    
# create the columns of enzyme names and reactions  
enzyme_iteration = 0    
enzyme_column = []
reaction_column = []
for index, row in total_csv.iterrows():
    loop_id = total_csv.at[index, 'Reference ID:']
    print(loop_id)
    try:
        if re.search('(\w+)', loop_id):
            if enzyme_iteration == 1432:
                break 

            enzyme = enzyme_names[enzyme_iteration]
            print(enzyme)
            reaction = reactions[enzyme_iteration]    
            print(reaction)

            enzyme_column.append(enzyme)
            reaction_column.append(reaction)    

            enzyme_iteration += 1

    except:
        #pass
        enzyme_column.append('')
        reaction_column.append('')
        #print('space')
        
# add the enzyme names and reactions to the CSV file
total_csv.insert(1, 'Enzyme', enzyme_column)
total_csv.insert(2, 'Reaction', reaction_column)

#generating the final CSV file
file_number = '1'
while os.path.exists('%s _vetted + reorganized NIST_%s.csv' %(datetime.date.today(), file_number)):
    file_number += 1

total_csv.to_csv("%s_vetted + reorganized NIST_%s.csv" %(datetime.date.today(), file_number))
# Out:
# 1433
# 26QUA/WOO_1205
# ['26QUA/WOO_1205']
# 29WOO_1206
# ['29WOO_1206']
# 31BOR/SCH_1141
# ['31BOR/SCH_1141']
# 34JAC_1142
# ['34JAC_1142']
# 34LOH/MEY_1169
# ['34LOH/MEY_1169']
# 34MEY/LOH_1100
# ['34MEY/LOH_1100']
# 34MEY/LOH_1288
# ['34MEY/LOH_1288']
# 35AKA_1170
# ['35AKA_1170']
# 35JAC/TAP_1207
# ['35JAC/TAP_1207']
# 35MEY/KIE_1385
# ['35MEY/KIE_1385']
# 35MEY/KIE2_1386
# ['35MEY/KIE2_1386']
# 35MEY/LOH_1102
# ['35MEY/LOH_1102']
# 35MEY/LOH_1290
# ['35MEY/LOH_1290']
# 35MEY/SCH_797
# ['35MEY/SCH_797']
# 35MEY/SCH_798
# ['35MEY/SCH_798']
# 35MEY/SCH_802
# ['35MEY/SCH_802']
# 35MEY/SCH_805
# ['35MEY/SCH_805']
# 35MEY_1101
# ['35MEY_1101']
# 35MEY_1289
# ['35MEY_1289']
# 36EUL/ADL_7
# ['36EUL/ADL_7']
# 36LEH_589
# ['36LEH_589']
# 36LEH_614
# ['36LEH_614']
# 36MEY/LOH_1099
# ['36MEY/LOH_1099']
# 36MEY/SCH_1096
# ['36MEY/SCH_1096']
# 36VEI_914
# ['36VEI_914']
# 36VEI_915
# ['36VEI_915']
# 36VEI_917
# ['36VEI_917']
# 36VEI_922
# ['36VEI_922']
# 36VEI_923
# ['36VEI_923']
# 36VEI_924
# ['36VEI_924']
# 36VEI_925
# ['36VEI_925']
# 36VEI_926
# ['36VEI_926']
# 37ADL/SRE_8
# ['37ADL/SRE_8']
# 37EUL/ADL_127
# ['37EUL/ADL_127']
# 37EUL/ADL_95
# ['37EUL/ADL_95']
# 37EUL/ADL2_42
# ['37EUL/ADL2_42']
# 37EUL/ADL3_96
# ['37EUL/ADL3_96']
# 37NEG/WUL_9
# ['37NEG/WUL_9']
# 38EUL/ADL_273
# ['38EUL/ADL_273']
# 38MEY/SCH_1387
# ['38MEY/SCH_1387']
# 38SCH/HEL_10
# ['38SCH/HEL_10']
# 38SCH/HEL_23
# ['38SCH/HEL_23']
# 39COH_504
# ['39COH_504']
# 40COH_495
# ['40COH_495']
# 40HER/GOR_1090
# ['40HER/GOR_1090']
# 40KRE/SMY_1143
# ['40KRE/SMY_1143']
# 41UTT/WER_1103
# ['41UTT/WER_1103']
# 41UTT/WER_1291
# ['41UTT/WER_1291']
# 41WAR/CHR_1171
# ['41WAR/CHR_1171']
# 42COL/SUT_1401
# ['42COL/SUT_1401']
# 42LEN/STR_505
# ['42LEN/STR_505']
# 43BAN_590
# ['43BAN_590']
# 43DOU_415
# ['43DOU_415']
# 43KAL_633
# ['43KAL_633']
# 43KRE/EGG_1156
# ['43KRE/EGG_1156']
# 43KRE/EGG_1159
# ['43KRE/EGG_1159']
# 43KRE/EGG_1162
# ['43KRE/EGG_1162']
# 43KUB/OTT_97
# ['43KUB/OTT_97']
# 43MEY/JUN_1091
# ['43MEY/JUN_1091']
# 43MEY/JUN_1104
# ['43MEY/JUN_1104']
# 43MEY/JUN_1281
# ['43MEY/JUN_1281']
# 43MEY/JUN_1292
# ['43MEY/JUN_1292']
# 44LIP_572
# ['44LIP_572']
# 45DAR_496
# ['45DAR_496']
# 45DAR_506
# ['45DAR_506']
# 45DRA/MEY_250
# ['45DRA/MEY_250']
# 45GRE/LEL_497
# ['45GRE/LEL_497']
# 45GRE/LEL_507
# ['45GRE/LEL_507']
# 45OHL_1144
# ['45OHL_1144']
# 45OHL_816
# ['45OHL_816']
# 45OHL_817
# ['45OHL_817']
# 45OHL_822
# ['45OHL_822']
# 46OHL_823
# ['46OHL_823']
# 47BUC_578
# ['47BUC_578']
# 47MEY/OES_1282
# ['47MEY/OES_1282']
# 47MEY/OES_251
# ['47MEY/OES_251']
# 48KOR_676
# ['48KOR_676']
# 48OCH_152
# ['48OCH_152']
# 48SCO/POW_1145
# ['48SCO/POW_1145']
# 48SOR/DEG_591
# ['48SOR/DEG_591']
# 49BAR_43
# ['49BAR_43']
# 49HES_743
# ['49HES_743']
# 49MEY/GRE_762
# ['49MEY/GRE_762']
# 49MEY/GRE_763
# ['49MEY/GRE_763']
# 49MEY/GRE_764
# ['49MEY/GRE_764']
# 49MEY/GRE_765
# ['49MEY/GRE_765']
# 49MEY/GRE_768
# ['49MEY/GRE_768']
# 49MEY/GRE_770
# ['49MEY/GRE_770']
# 49MEY/GRE_778
# ['49MEY/GRE_778']
# 49MEY/GRE_786
# ['49MEY/GRE_786']
# 49MEY/GRE_818
# ['49MEY/GRE_818']
# 49MEY/GRE_819
# ['49MEY/GRE_819']
# 49MEY/GRE_820
# ['49MEY/GRE_820']
# 49MEY/GRE_821
# ['49MEY/GRE_821']
# 49MEY/GRE_824
# ['49MEY/GRE_824']
# 49MEY/OES_1172
# ['49MEY/OES_1172']
# 49MEY/OES_1388
# ['49MEY/OES_1388']
# 49MEY/OES_563
# ['49MEY/OES_563']
# 49SOR/DVO_615
# ['49SOR/DVO_615']
# 50COR/VEL_252
# ['50COR/VEL_252']
# 50FRI_456
# ['50FRI_456']
# 50HES_744
# ['50HES_744']
# 50HES_748
# ['50HES_748']
# 50KOR_677
# ['50KOR_677']
# 50OES/MEY_1283
# ['50OES/MEY_1283']
# 50PAZ_433
# ['50PAZ_433']
# 50PAZ_435
# ['50PAZ_435']
# 50PAZ_437
# ['50PAZ_437']
# 50RAC_11
# ['50RAC_11']
# 50RAC_98
# ['50RAC_98']
# 50SLE_1345
# ['50SLE_1345']
# 50SLE_1350
# ['50SLE_1350']
# 51BLA_65
# ['51BLA_65']
# 51BLI_35
# ['51BLI_35']
# 51FRU/JOH_971
# ['51FRU/JOH_971']
# 51ROW/KOR_465
# ['51ROW/KOR_465']
# 51THE/BON_12
# ['51THE/BON_12']
# 51WOO/GUN_1233
# ['51WOO/GUN_1233']
# 52ASK_592
# ['52ASK_592']
# 52BAU/GEM_942
# ['52BAU/GEM_942']
# 52BAU/GEM_996
# ['52BAU/GEM_996']
# 52BUR_29
# ['52BUR_29']
# 52DOB/FRU_972
# ['52DOB/FRU_972']
# 52DOB/FRU_973
# ['52DOB/FRU_973']
# 52DOB/STU_956
# ['52DOB/STU_956']
# 52DOB/STU_969
# ['52DOB/STU_969']
# 52EGG/HEM_658
# ['52EGG/HEM_658']
# 52FIT/DOU_419
# ['52FIT/DOU_419']
# 52KOR_574
# ['52KOR_574']
# 52LEL/CAR_1260
# ['52LEL/CAR_1260']
# 52LEL/CAR_698
# ['52LEL/CAR_698']
# 52MEY/SHA_815
# ['52MEY/SHA_815']
# 52NAR/WOO_1237
# ['52NAR/WOO_1237']
# 52NEI_99
# ['52NEI_99']
# 52OHL/SHA_1061
# ['52OHL/SHA_1061']
# 52OHL/SHA_1070
# ['52OHL/SHA_1070']
# 52OHL/SHA_792
# ['52OHL/SHA_792']
# 52STA_394
# ['52STA_394']
# 52STE/OCH_1129
# ['52STE/OCH_1129']
# 52STE/OCH_128
# ['52STE/OCH_128']
# 52STE/OCH_145
# ['52STE/OCH_145']
# 52STR/KOR_158
# ['52STR/KOR_158']
# 53BOC/ALB_1146
# ['53BOC/ALB_1146']
# 53BOD_1351
# ['53BOD_1351']
# 53BRI_159
# ['53BRI_159']
# 53BRO_1399
# ['53BRO_1399']
# 53BUR/STA_240
# ['53BUR/STA_240']
# 53BUR/WIL_129
# ['53BUR/WIL_129']
# 53BUR/WIL_30
# ['53BUR/WIL_30']
# 53BUR/WIL_44
# ['53BUR/WIL_44']
# 53COH_1294
# ['53COH_1294']
# 53GRE/BRO_634
# ['53GRE/BRO_634']
# 53HAR/KOR_147
# ['53HAR/KOR_147']
# 53HOC/WAT_1323
# ['53HOC/WAT_1323']
# 53JON_1432
# ['53JON_1432']
# 53KAP/COL_309
# ['53KAP/COL_309']
# 53KRE_1147
# ['53KRE_1147']
# 53KRE_1157
# ['53KRE_1157']
# 53KRE_1160
# ['53KRE_1160']
# 53KRE_1163
# ['53KRE_1163']
# 53KRE2_498
# ['53KRE2_498']
# 53KRE2_508
# ['53KRE2_508']
# 53LYN/OCH_116
# ['53LYN/OCH_116']
# 53LYN/OCH_404
# ['53LYN/OCH_404']
# 53LYN/OCH_717
# ['53LYN/OCH_717']
# 53MAH/WAK_1436
# ['53MAH/WAK_1436']
# 53MAS_1148
# ['53MAS_1148']
# 53MEY/SHA_1069
# ['53MEY/SHA_1069']
# 53MIT/LAM_1324
# ['53MIT/LAM_1324']
# 53NIS/BAR_499
# ['53NIS/BAR_499']
# 53OLS/ANF_280
# ['53OLS/ANF_280']
# 53OLS/ANF_281
# ['53OLS/ANF_281']
# 53OLS/ANF_282
# ['53OLS/ANF_282']
# 53RAT/ANS_1222
# ['53RAT/ANS_1222']
# 53SIE/POT_635
# ['53SIE/POT_635']
# 53STE/COO_405
# ['53STE/COO_405']
# 53STE/COO_718
# ['53STE/COO_718']
# 53STR_274
# ['53STR_274']
# 53STU_954
# ['53STU_954']
# 53STU_955
# ['53STU_955']
# 53TAL/DOB_178
# ['53TAL/DOB_178']
# 54AXE/JAN_1331
# ['54AXE/JAN_1331']
# 54BER/JOK_665
# ['54BER/JOK_665']
# 54BOW/KER_636
# ['54BOW/KER_636']
# 54CHA_1086
# ['54CHA_1086']
# 54GIN/STU_1062
# ['54GIN/STU_1062']
# 54GIN_771
# ['54GIN_771']
# 54GIN_779
# ['54GIN_779']
# 54GOL_406
# ['54GOL_406']
# 54GRE/MII_264
# ['54GRE/MII_264']
# 54HAN/CRA_1261
# ['54HAN/CRA_1261']
# 54HEL_1433
# ['54HEL_1433']
# 54HEL_1435
# ['54HEL_1435']
# 54LEV/MEI_1439
# ['54LEV/MEI_1439']
# 54LIE/KOR_1036
# ['54LIE/KOR_1036']
# 54LIE/KOR_1039
# ['54LIE/KOR_1039']
# 54MAR/WIL_1234
# ['54MAR/WIL_1234']
# 54MIT/DAV_1168
# ['54MIT/DAV_1168']
# 54NOD/KUB_593
# ['54NOD/KUB_593']
# 54ROS/GRU_573
# ['54ROS/GRU_573']
# 54SIS/STA_1427
# ['54SIS/STA_1427']
# 54SIS/STA_1428
# ['54SIS/STA_1428']
# 54STA_375
# ['54STA_375']
# 54STR/HAR_38
# ['54STR/HAR_38']
# 54UTT/KUR_1082
# ['54UTT/KUR_1082']
# 54WAK/GRE_123
# ['54WAK/GRE_123']
# 54WAK/GRE_126
# ['54WAK/GRE_126']
# 54WIL/BAN_66
# ['54WIL/BAN_66']
# 55BLA/WRI_587
# ['55BLA/WRI_587']
# 55BLA/WRI2_242
# ['55BLA/WRI2_242']
# 55BLA/WRI3_36
# ['55BLA/WRI3_36']
# 55BLA/WRI3_37
# ['55BLA/WRI3_37']
# 55BUR_39
# ['55BUR_39']
# 55CAR/COH_1223
# ['55CAR/COH_1223']
# 55CAR/LEL_423
# ['55CAR/LEL_423']
# 55DAV/GIL_81
# ['55DAV/GIL_81']
# 55DAV/GIL_82
# ['55DAV/GIL_82']
# 55DEC_407
# ['55DEC_407']
# 55DIC/WIL_1332
# ['55DIC/WIL_1332']
# 55GLA/BRO_162
# ['55GLA/BRO_162']
# 55HOR/SMY_371
# ['55HOR/SMY_371']
# 55KAT_112
# ['55KAT_112']
# 55KAU/ALI_1438
# ['55KAU/ALI_1438']
# 55KIT/BEN_1071
# ['55KIT/BEN_1071']
# 55KIT/BEN_1077
# ['55KIT/BEN_1077']
# 55LEH/SIC_1089
# ['55LEH/SIC_1089']
# 55LEH/SIC_1092
# ['55LEH/SIC_1092']
# 55LEH/SIC_1097
# ['55LEH/SIC_1097']
# 55LIE/KOR_480
# ['55LIE/KOR_480']
# 55LIE/KOR2_664
# ['55LIE/KOR2_664']
# 55LYN/WIE_124
# ['55LYN/WIE_124']
# 55MUN_683
# ['55MUN_683']
# 55POD/STU_1072
# ['55POD/STU_1072']
# 55SLE_1325
# ['55SLE_1325']
# 55STA/BUR_241
# ['55STA/BUR_241']
# 55STA_395
# ['55STA_395']
# 55STU_825
# ['55STU_825']
# 55STU2_978
# ['55STU2_978']
# 55THO/GOM_1235
# ['55THO/GOM_1235']
# 55VAR/WEB_1440
# ['55VAR/WEB_1440']
# 55WIL/MCI_1208
# ['55WIL/MCI_1208']
# 55WOL/KAP_75
# ['55WOL/KAP_75']
# 55YAN/GIL_83
# ['55YAN/GIL_83']
# 55ZEL_85
# ['55ZEL_85']
# 55ZEL_88
# ['55ZEL_88']
# 56ALE/GRE_348
# ['56ALE/GRE_348']
# 56AME/HOR_519
# ['56AME/HOR_519']
# 56BEN/HEM_989
# ['56BEN/HEM_989']
# 56BOW/KER_637
# ['56BOW/KER_637']
# 56CAR/COH_1224
# ['56CAR/COH_1224']
# 56COW/PIZ_1389
# ['56COW/PIZ_1389']
# 56DIC/WIL_1262
# ['56DIC/WIL_1262']
# 56DIC/WIL_1333
# ['56DIC/WIL_1333']
# 56ENG_1371
# ['56ENG_1371']
# 56FEU/WOL_557
# ['56FEU/WOL_557']
# 56FOR/GUT_977
# ['56FOR/GUT_977']
# 56GRE/COH_1296
# ['56GRE/COH_1296']
# 56HAK/GLA_100
# ['56HAK/GLA_100']
# 56HAU_265
# ['56HAU_265']
# 56HUB_1279
# ['56HUB_1279']
# 56HUR/HOR_1244
# ['56HUR/HOR_1244']
# 56KAP/CIO_101
# ['56KAP/CIO_101']
# 56KAP/CIO_110
# ['56KAP/CIO_110']
# 56KAP/CIO_13
# ['56KAP/CIO_13']
# 56KAP/CIO_22
# ['56KAP/CIO_22']
# 56KAP/CIO_275
# ['56KAP/CIO_275']
# 56KAP/CIO_278
# ['56KAP/CIO_278']
# 56KIT/HOR_1085
# ['56KIT/HOR_1085']
# 56LAR/JAC_77
# ['56LAR/JAC_77']
# 56LEL/CAR_1366
# ['56LEL/CAR_1366']
# 56PAL/DOU_1340
# ['56PAL/DOU_1340']
# 56PAL/DOU_1341
# ['56PAL/DOU_1341']
# 56PAL/DOU_1344
# ['56PAL/DOU_1344']
# 56POD/MOR_1073
# ['56POD/MOR_1073']
# 56POD/MOR_1078
# ['56POD/MOR_1078']
# 56RAB/PRI_353
# ['56RAB/PRI_353']
# 56RAM/GIR_1352
# ['56RAM/GIR_1352']
# 56RAT/ROC_364
# ['56RAT/ROC_364']
# 56REI_1407
# ['56REI_1407']
# 56SMI/STA_1113
# ['56SMI/STA_1113']
# 56SMI/STA_1124
# ['56SMI/STA_1124']
# 56STE/COO_719
# ['56STE/COO_719']
# 56STE/DEL_1175
# ['56STE/DEL_1175']
# 56STE/DEL_1176
# ['56STE/DEL_1176']
# 56STE/DEL_1177
# ['56STE/DEL_1177']
# 56STE/DEL_1178
# ['56STE/DEL_1178']
# 56STE_720
# ['56STE_720']
# 56STU/HOR_1245
# ['56STU/HOR_1245']
# 56TAL/MAR_166
# ['56TAL/MAR_166']
# 56TAL/MAR_179
# ['56TAL/MAR_179']
# 56TOM_173
# ['56TOM_173']
# 56WOL/KAP_76
# ['56WOL/KAP_76']
# 57ASH/HIC_1246
# ['57ASH/HIC_1246']
# 57BUR/HOR_1263
# ['57BUR/HOR_1263']
# 57CAL_638
# ['57CAL_638']
# 57DUR/STU_339
# ['57DUR/STU_339']
# 57FLA/ERW_476
# ['57FLA/ERW_476']
# 57GRE/LIP_715
# ['57GRE/LIP_715']
# 57GRE/LIP_716
# ['57GRE/LIP_716']
# 57HOH_102
# ['57HOH_102']
# 57HOL/HOL_113
# ['57HOL/HOL_113']
# 57HOL/TOU_56
# ['57HOL/TOU_56']
# 57KAR/GRE_347
# ['57KAR/GRE_347']
# 57MAX_1249
# ['57MAX_1249']
# 57REI_362
# ['57REI_362']
# 57ROB/BOY_544
# ['57ROB/BOY_544']
# 57ROB/COO_122
# ['57ROB/COO_122']
# 57ROD/TOW_1390
# ['57ROD/TOW_1390']
# 57SAN/SEA_323
# ['57SAN/SEA_323']
# 57SMI/GUN_1114
# ['57SMI/GUN_1114']
# 57STE_125
# ['57STE_125']
# 57TAL_167
# ['57TAL_167']
# 57TAL_170
# ['57TAL_170']
# 57TAL_171
# ['57TAL_171']
# 57TAL_174
# ['57TAL_174']
# 57TAL_177
# ['57TAL_177']
# 57TAL_180
# ['57TAL_180']
# 57TAL_182
# ['57TAL_182']
# 57VLA/VLA_545
# ['57VLA/VLA_545']
# 57WOL/BAL_1173
# ['57WOL/BAL_1173']
# 58BAC_14
# ['58BAC_14']
# 58BRU/NOL_1334
# ['58BRU/NOL_1334']
# 58BUR/HOR_1264
# ['58BUR/HOR_1264']
# 58CAB/LEL_432
# ['58CAB/LEL_432']
# 58FRO_1443
# ['58FRO_1443']
# 58FRO2_187
# ['58FRO2_187']
# 58HEA/HOR_1297
# ['58HEA/HOR_1297']
# 58LAN/ENG_194
# ['58LAN/ENG_194']
# 58MAL/OCH_673
# ['58MAL/OCH_673']
# 58NOL/BRU_1346
# ['58NOL/BRU_1346']
# 58NOL/BRU_1353
# ['58NOL/BRU_1353']
# 58ROB/LIP_678
# ['58ROB/LIP_678']
# 58TAB/SRE_1247
# ['58TAB/SRE_1247']
# 58TAB/SRE_1335
# ['58TAB/SRE_1335']
# 58TUR/TUR_684
# ['58TUR/TUR_684']
# 58WIL/BAN_1068
# ['58WIL/BAN_1068']
# 58WIL/BAN_679
# ['58WIL/BAN_679']
# 58WIL/BAN_681
# ['58WIL/BAN_681']
# 58WOL/SIM_1265
# ['58WOL/SIM_1265']
# 58YOU/PAC_45
# ['58YOU/PAC_45']
# 59ALE_443
# ['59ALE_443']
# 59ATK/JOH_1402
# ['59ATK/JOH_1402']
# 59BAR/SMY_1214
# ['59BAR/SMY_1214']
# 59BEN/KIT_990
# ['59BEN/KIT_990']
# 59BON/PON_370
# ['59BON/PON_370']
# 59CAL/WEB_639
# ['59CAL/WEB_639']
# 59CHI/SUG_1391
# ['59CHI/SUG_1391']
# 59DEL/DEF_233
# ['59DEL/DEF_233']
# 59DEN/ROB_190
# ['59DEN/ROB_190']
# 59FRI_283
# ['59FRI_283']
# 59GOL_322
# ['59GOL_322']
# 59HAB/CAN_951
# ['59HAB/CAN_951']
# 59HOL_46
# ['59HOL_46']
# 59HOL_47
# ['59HOL_47']
# 59HOL_48
# ['59HOL_48']
# 59HOL_49
# ['59HOL_49']
# 59HOL_50
# ['59HOL_50']
# 59HOL_51
# ['59HOL_51']
# 59HOL_52
# ['59HOL_52']
# 59HOL_57
# ['59HOL_57']
# 59ITO/GRI_1392
# ['59ITO/GRI_1392']
# 59KIR/TUR_663
# ['59KIR/TUR_663']
# 59KIT/HEM_986
# ['59KIT/HEM_986']
# 59KIT/HEM_991
# ['59KIT/HEM_991']
# 59KRI_564
# ['59KRI_564']
# 59MCC/NAJ_1403
# ['59MCC/NAJ_1403']
# 59MCQ/UTT_565
# ['59MCQ/UTT_565']
# 59MER/TOM_5
# ['59MER/TOM_5']
# 59MIL/LUK_1225
# ['59MIL/LUK_1225']
# 59NOR/FRO_188
# ['59NOR/FRO_188']
# 59SAN/LAN_324
# ['59SAN/LAN_324']
# 59SAN/LAN_326
# ['59SAN/LAN_326']
# 59SCO/JAK_526
# ['59SCO/JAK_526']
# 59SHO/PRI_216
# ['59SHO/PRI_216']
# 59STR/SMI_702
# ['59STR/SMI_702']
# 59TAB/WYN_355
# ['59TAB/WYN_355']
# 59TAL/LEV_172
# ['59TAL/LEV_172']
# 59TAL/LEV_175
# ['59TAL/LEV_175']
# 59TAL/LEV_176
# ['59TAL/LEV_176']
# 59TAL/LEV_181
# ['59TAL/LEV_181']
# 59TAL/LEV_183
# ['59TAL/LEV_183']
# 59TAL/LEV_184
# ['59TAL/LEV_184']
# 59TAL/LEV_185
# ['59TAL/LEV_185']
# 59VAG/EAR_1221
# ['59VAG/EAR_1221']
# 60AGO/ARA_1336
# ['60AGO/ARA_1336']
# 60ASH/WAH_1368
# ['60ASH/WAH_1368']
# 60ASH/WAH_1369
# ['60ASH/WAH_1369']
# 60BLA_349
# ['60BLA_349']
# 60COM/ROS_1117
# ['60COM/ROS_1117']
# 60FEI/NEU_1267
# ['60FEI/NEU_1267']
# 60FEI/NEU_1270
# ['60FEI/NEU_1270']
# 60GEL/STU_1079
# ['60GEL/STU_1079']
# 60GEL/STU_613
# ['60GEL/STU_613']
# 60GUP/ROB_186
# ['60GUP/ROB_186']
# 60ICH/FUR_1238
# ['60ICH/FUR_1238']
# 60ISH_997
# ['60ISH_997']
# 60JON/LIP_576
# ['60JON/LIP_576']
# 60KAH/LOW_1354
# ['60KAH/LOW_1354']
# 60KAY/OSB_1057
# ['60KAY/OSB_1057']
# 60KUR/SUG_696
# ['60KUR/SUG_696']
# 60MAX/ROB_1250
# ['60MAX/ROB_1250']
# 60MEN_429
# ['60MEN_429']
# 60NIR/JAK_193
# ['60NIR/JAK_193']
# 60OCO/HAL_269
# ['60OCO/HAL_269']
# 60PIE/WIA_270
# ['60PIE/WIA_270']
# 60PRI/HOR_1087
# ['60PRI/HOR_1087']
# 60SCH/RAT_1444
# ['60SCH/RAT_1444']
# 60VOL_1370
# ['60VOL_1370']
# 61ALE_444
# ['61ALE_444']
# 61ATK/BUR_550
# ['61ATK/BUR_550']
# 61ATK/BUR_640
# ['61ATK/BUR_640']
# 61ATK/JOH_772
# ['61ATK/JOH_772']
# 61BEN/SCH_1408
# ['61BEN/SCH_1408']
# 61BER/BER_1431
# ['61BER/BER_1431']
# 61DAT/RAC_365
# ['61DAT/RAC_365']
# 61DAT/RAC_367
# ['61DAT/RAC_367']
# 61DAT/RAC_368
# ['61DAT/RAC_368']
# 61DOU/MER_117
# ['61DOU/MER_117']
# 61DOU_416
# ['61DOU_416']
# 61DOU_420
# ['61DOU_420']
# 61GAW/GLA_974
# ['61GAW/GLA_974']
# 61GOT/KOR_191
# ['61GOT/KOR_191']
# 61KLE_685
# ['61KLE_685']
# 61KOR/GLA_703
# ['61KOR/GLA_703']
# 61KRA/VEN_266
# ['61KRA/VEN_266']
# 61KRA/VEN_268
# ['61KRA/VEN_268']
# 61LED_488
# ['61LED_488']
# 61PRA_624
# ['61PRA_624']
# 61RAC2_372
# ['61RAC2_372']
# 61RAW/WAD_953
# ['61RAW/WAD_953']
# 61RAW/WAD_957
# ['61RAW/WAD_957']
# 61RAW/WAD_958
# ['61RAW/WAD_958']
# 61SAN/ZIN_288
# ['61SAN/ZIN_288']
# 61VEN/RAC_373
# ['61VEN/RAC_373']
# 61VLA/KOM_827
# ['61VLA/KOM_827']
# 61WIL/WIL_1209
# ['61WIL/WIL_1209']
# 61WOO/STJ_361
# ['61WOO/STJ_361']
# 61YAM_485
# ['61YAM_485']
# 62AKA/CAM_680
# ['62AKA/CAM_680']
# 62BLA_243
# ['62BLA_243']
# 62BRU/JOU_1118
# ['62BRU/JOU_1118']
# 62BRU/JOU_1122
# ['62BRU/JOU_1122']
# 62CHA/VEI_62
# ['62CHA/VEI_62']
# 62CHA/VEI_64
# ['62CHA/VEI_64']
# 62CHA/VEI_67
# ['62CHA/VEI_67']
# 62CHA/VEI_72
# ['62CHA/VEI_72']
# 62DOU/SHU_1105
# ['62DOU/SHU_1105']
# 62DOU/SHU_1111
# ['62DOU/SHU_1111']
# 62DOU2_160
# ['62DOU2_160']
# 62DUR/RAW_338
# ['62DUR/RAW_338']
# 62DUR/RAW_340
# ['62DUR/RAW_340']
# 62DUR/RAW_343
# ['62DUR/RAW_343']
# 62ESP_704
# ['62ESP_704']
# 62GHA/HEA_1107
# ['62GHA/HEA_1107']
# 62GOL/WAG_1116
# ['62GOL/WAG_1116']
# 62GOL/WAG_289
# ['62GOL/WAG_289']
# 62GRI_1393
# ['62GRI_1393']
# 62HAL/FEN_1446
# ['62HAL/FEN_1446']
# 62HAY/NIS_525
# ['62HAY/NIS_525']
# 62HIM/RAB_1442
# ['62HIM/RAB_1442']
# 62HOR_1266
# ['62HOR_1266']
# 62KRE/MEL_118
# ['62KRE/MEL_118']
# 62MEN_672
# ['62MEN_672']
# 62PET_524
# ['62PET_524']
# 62RAB_561
# ['62RAB_561']
# 62RAV/WOL_130
# ['62RAV/WOL_130']
# 62RAV/WOL2_131
# ['62RAV/WOL2_131']
# 62SEG/BEA_509
# ['62SEG/BEA_509']
# 62SHU/DOU_119
# ['62SHU/DOU_119']
# 62SIL_356
# ['62SIL_356']
# 62UEH_1293
# ['62UEH_1293']
# 62WIL/SNE_357
# ['62WIL/SNE_357']
# 62WIL/SNE_358
# ['62WIL/SNE_358']
# 62WIL/SNE_359
# ['62WIL/SNE_359']
# 62WIL/SNE_360
# ['62WIL/SNE_360']
# 63ALL/KEL_1278
# ['63ALL/KEL_1278']
# 63BEC/LEV_472
# ['63BEC/LEV_472']
# 63BER/HOL_396
# ['63BER/HOL_396']
# 63CHE/RAW_983
# ['63CHE/RAW_983']
# 63DAY/WIL_754
# ['63DAY/WIL_754']
# 63DEV/GOU_457
# ['63DEV/GOU_457']
# 63DEV/GOU_459
# ['63DEV/GOU_459']
# 63DOB/DEM_1337
# ['63DOB/DEM_1337']
# 63DOM/ZEC_1372
# ['63DOM/ZEC_1372']
# 63EDM/WRI_195
# ['63EDM/WRI_195']
# 63EHR/MAR_993
# ['63EHR/MAR_993']
# 63FRI/SCH_389
# ['63FRI/SCH_389']
# 63GRE_1058
# ['63GRE_1058']
# 63HAR/COL_1125
# ['63HAR/COL_1125']
# 63HIN/WOL_1355
# ['63HIN/WOL_1355']
# 63HUE_296
# ['63HUE_296']
# 63JEN/CAP_970
# ['63JEN/CAP_970']
# 63KUR/FUK_1131
# ['63KUR/FUK_1131']
# 63MAP/ISH_312
# ['63MAP/ISH_312']
# 63MAR/BAR_196
# ['63MAR/BAR_196']
# 63MAT/HUE_297
# ['63MAT/HUE_297']
# 63MEI/BUK_1196
# ['63MEI/BUK_1196']
# 63MON/WHI_219
# ['63MON/WHI_219']
# 63OKA_198
# ['63OKA_198']
# 63QUA_260
# ['63QUA_260']
# 63SCO/DUN_313
# ['63SCO/DUN_313']
# 63SLY/STA_397
# ['63SLY/STA_397']
# 63SLY/STA_401
# ['63SLY/STA_401']
# 63VIL/LAR_686
# ['63VIL/LAR_686']
# 64ADA/NOR_1240
# ['64ADA/NOR_1240']
# 64ASP/JAK_215
# ['64ASP/JAK_215']
# 64AVI_424
# ['64AVI_424']
# 64BAR/ROO_1419
# ['64BAR/ROO_1419']
# 64BOJ/GAU_363
# ['64BOJ/GAU_363']
# 64HEN/CLE_500
# ['64HEN/CLE_500']
# 64IMA/MOR_1251
# ['64IMA/MOR_1251']
# 64KEL/ALL_1421
# ['64KEL/ALL_1421']
# 64LOW/PAS_1093
# ['64LOW/PAS_1093']
# 64LOW/PAS_1174
# ['64LOW/PAS_1174']
# 64LOW/PAS_1394
# ['64LOW/PAS_1394']
# 64MAI/DEK_1132
# ['64MAI/DEK_1132']
# 64MCN/DAM_1429
# ['64MCN/DAM_1429']
# 64MEL/WOO_1106
# ['64MEL/WOO_1106']
# 64MIL/AVI_425
# ['64MIL/AVI_425']
# 64MOO/REI_318
# ['64MOO/REI_318']
# 64NOR_408
# ['64NOR_408']
# 64PRE/WOO_699
# ['64PRE/WOO_699']
# 64ROS/RAP_311
# ['64ROS/RAP_311']
# 64SAT/TSU_1298
# ['64SAT/TSU_1298']
# 64TAK/SAW_1373
# ['64TAK/SAW_1373']
# 64WIL/HOG_1252
# ['64WIL/HOG_1252']
# 65AND/ALL_1375
# ['65AND/ALL_1375']
# 65ANN/KOS_1382
# ['65ANN/KOS_1382']
# 65BAH/CAT_853
# ['65BAH/CAT_853']
# 65BAH/CAT_854
# ['65BAH/CAT_854']
# 65BES/HER_671
# ['65BES/HER_671']
# 65BOY/BAR_168
# ['65BOY/BAR_168']
# 65BOY/BAR_169
# ['65BOY/BAR_169']
# 65BUL/HAN_510
# ['65BUL/HAN_510']
# 65CAN/FOC_1420
# ['65CAN/FOC_1420']
# 65CAR/KIR_979
# ['65CAR/KIR_979']
# 65CHI/FEI_1110
# ['65CHI/FEI_1110']
# 65DAW/DIC_103
# ['65DAW/DIC_103']
# 65DAW/DIC_114
# ['65DAW/DIC_114']
# 65EIC/CYN_214
# ['65EIC/CYN_214']
# 65GAU/WOL_1226
# ['65GAU/WOL_1226']
# 65GHO/ROS_1274
# ['65GHO/ROS_1274']
# 65GHO/ROS2_1272
# ['65GHO/ROS2_1272']
# 65ICH/HIR_1299
# ['65ICH/HIR_1299']
# 65KAT/BUC_321
# ['65KAT/BUC_321']
# 65KAZ/GRO_1447
# ['65KAZ/GRO_1447']
# 65LEE/DOB_211
# ['65LEE/DOB_211']
# 65MAR/JEN_527
# ['65MAR/JEN_527']
# 65MAY/GIN_705
# ['65MAY/GIN_705']
# 65MOR/JAM_594
# ['65MOR/JAM_594']
# 65ONO/HIR_892
# ['65ONO/HIR_892']
# 65ONO/HIR_902
# ['65ONO/HIR_902']
# 65PIN_799
# ['65PIN_799']
# 65PIN_804
# ['65PIN_804']
# 65PIN_809
# ['65PIN_809']
# 65SEK/SUN_1210
# ['65SEK/SUN_1210']
# 65SHA/CLE_1383
# ['65SHA/CLE_1383']
# 65STI/DIA_810
# ['65STI/DIA_810']
# 65STR_520
# ['65STR_520']
# 65TAK/HIR_881
# ['65TAK/HIR_881']
# 65TAK/HIR_898
# ['65TAK/HIR_898']
# 65TAK/YOS_883
# ['65TAK/YOS_883']
# 65TAK/YOS_900
# ['65TAK/YOS_900']
# 65TAT/DAT_1126
# ['65TAT/DAT_1126']
# 65TSU/SAT_1300
# ['65TSU/SAT_1300']
# 65UYE/RAB_354
# ['65UYE/RAB_354']
# 65WAL/SAL_202
# ['65WAL/SAL_202']
# 65YOS/FRE_271
# ['65YOS/FRE_271']
# 65YOS_132
# ['65YOS_132']
# 66ALB/BAS_687
# ['66ALB/BAS_687']
# 66ALL_234
# ['66ALL_234']
# 66AVI/ENG_213
# ['66AVI/ENG_213']
# 66BER/MOE_133
# ['66BER/MOE_133']
# 66CAR/HUL_200
# ['66CAR/HUL_200']
# 66CAR/HUL_89
# ['66CAR/HUL_89']
# 66CHA/WIL_327
# ['66CHA/WIL_327']
# 66DED_421
# ['66DED_421']
# 66DOM/ZEC_1374
# ['66DOM/ZEC_1374']
# 66GIB/MOR_534
# ['66GIB/MOR_534']
# 66GOL/MAR_447
# ['66GOL/MAR_447']
# 66GOL/MAR_448
# ['66GOL/MAR_448']
# 66GOL/MAR_449
# ['66GOL/MAR_449']
# 66HAN/ALB_688
# ['66HAN/ALB_688']
# 66HOR/HEN_474
# ['66HOR/HEN_474']
# 66JEN/DAR_502
# ['66JEN/DAR_502']
# 66KIM/SUZ_706
# ['66KIM/SUZ_706']
# 66MAR/COH_577
# ['66MAR/COH_577']
# 66MAR/WAD_641
# ['66MAR/WAD_641']
# 66MAT/STR_533
# ['66MAT/STR_533']
# 66MAT_1275
# ['66MAT_1275']
# 66MUD/KLE_341
# ['66MUD/KLE_341']
# 66MUD/KLE_342
# ['66MUD/KLE_342']
# 66MUD/KLE_344
# ['66MUD/KLE_344']
# 66MUD/KLE_345
# ['66MUD/KLE_345']
# 66MUR/SUG_422
# ['66MUR/SUG_422']
# 66MUR/SUG_426
# ['66MUR/SUG_426']
# 66NAT_1301
# ['66NAT_1301']
# 66REI_1356
# ['66REI_1356']
# 66SCH/HOR_79
# ['66SCH/HOR_79']
# 66SCH_385
# ['66SCH_385']
# 66STA/DEN_410
# ['66STA/DEN_410']
# 66THO/NAN_1158
# ['66THO/NAN_1158']
# 66THO/NAN_1161
# ['66THO/NAN_1161']
# 66THO/NAN_1164
# ['66THO/NAN_1164']
# 66TOO/WAK_207
# ['66TOO/WAK_207']
# 66UHR/MAR_616
# ['66UHR/MAR_616']
# 66VER/ROD_707
# ['66VER/ROD_707']
# 66WIL/WAK_411
# ['66WIL/WAK_411']
# 66WIL/WAK_412
# ['66WIL/WAK_412']
# 66WOO/DAV_1083
# ['66WOO/DAV_1083']
# 66WOO/DAV_1084
# ['66WOO/DAV_1084']
# 66WOO/DAV_1445
# ['66WOO/DAV_1445']
# 67BAR_1134
# ['67BAR_1134']
# 67DAN/YOS_1302
# ['67DAN/YOS_1302']
# 67ENG/DAL_276
# ['67ENG/DAL_276']
# 67ENG/DAL_287
# ['67ENG/DAL_287']
# 67ENG/DEN_1165
# ['67ENG/DEN_1165']
# 67EPP/DAW_595
# ['67EPP/DAW_595']
# 67GRO_1088
# ['67GRO_1088']
# 67HER/JEN_721
# ['67HER/JEN_721']
# 67HIR/GRE_538
# ['67HIR/GRE_538']
# 67KEP/TOV_1280
# ['67KEP/TOV_1280']
# 67LOM/GRE_1059
# ['67LOM/GRE_1059']
# 67MOR/WHI_596
# ['67MOR/WHI_596']
# 67PLO/CLE_1130
# ['67PLO/CLE_1130']
# 67POE/GUT_263
# ['67POE/GUT_263']
# 67POE/GUT_319
# ['67POE/GUT_319']
# 67ROS/ADA_1133
# ['67ROS/ADA_1133']
# 67SAK/YOR_470
# ['67SAK/YOR_470']
# 67SAK/YOR2_454
# ['67SAK/YOR2_454']
# 67SIL/VOE_417
# ['67SIL/VOE_417']
# 67SOD/OSU_1241
# ['67SOD/OSU_1241']
# 67SOD/OSU_1242
# ['67SOD/OSU_1242']
# 67TAK/HIZ_1357
# ['67TAK/HIZ_1357']
# 67TAK_1303
# ['67TAK_1303']
# 67TAK2_1342
# ['67TAK2_1342']
# 67TRI/VOG_1050
# ['67TRI/VOG_1050']
# 67TRI/VOG_1227
# ['67TRI/VOG_1227']
# 67UYE/RAB_301
# ['67UYE/RAB_301']
# 67WIL/HIR_1215
# ['67WIL/HIR_1215']
# 67WIL/LUN_104
# ['67WIL/LUN_104']
# 67WIL/LUN_120
# ['67WIL/LUN_120']
# 67WIL/LUN_134
# ['67WIL/LUN_134']
# 67WOL_1052
# ['67WOL_1052']
# 67WU/WIT_811
# ['67WU/WIT_811']
# 68AUR/KLE_209
# ['68AUR/KLE_209']
# 68AVI/ALR_212
# ['68AVI/ALR_212']
# 68AYL/SNE_532
# ['68AYL/SNE_532']
# 68AYL/SNE2_528
# ['68AYL/SNE2_528']
# 68AYL/SNE2_529
# ['68AYL/SNE2_529']
# 68AYL/SNE2_530
# ['68AYL/SNE2_530']
# 68AYL/SNE2_531
# ['68AYL/SNE2_531']
# 68BAD/MIL_1211
# ['68BAD/MIL_1211']
# 68BEE/DEL_236
# ['68BEE/DEL_236']
# 68BOM/PRA_643
# ['68BOM/PRA_643']
# 68BRO_511
# ['68BRO_511']
# 68BUR/WAL_1284
# ['68BUR/WAL_1284']
# 68DYS/NOL_1358
# ['68DYS/NOL_1358']
# 68ERI_24
# ['68ERI_24']
# 68ERI_25
# ['68ERI_25']
# 68ERI_26
# ['68ERI_26']
# 68ERI_27
# ['68ERI_27']
# 68ERI_3
# ['68ERI_3']
# 68ERI_34
# ['68ERI_34']
# 68HAT/SLA_712
# ['68HAT/SLA_712']
# 68HAV/HAN_1219
# ['68HAV/HAN_1219']
# 68JEA/DEM_210
# ['68JEA/DEM_210']
# 68KOH/JAK_135
# ['68KOH/JAK_135']
# 68KOH/JAK_142
# ['68KOH/JAK_142']
# 68KOH/JAK2_86
# ['68KOH/JAK2_86']
# 68KOH/JAK2_90
# ['68KOH/JAK2_90']
# 68KOH/WAR_87
# ['68KOH/WAR_87']
# 68KOH_192
# ['68KOH_192']
# 68LON/DAL_153
# ['68LON/DAL_153']
# 68MAY/AND_1379
# ['68MAY/AND_1379']
# 68MIZ/WEE_1200
# ['68MIZ/WEE_1200']
# 68NIX/BLA_298
# ['68NIX/BLA_298']
# 68POT/GLO_386
# ['68POT/GLO_386']
# 68REE/MEN_713
# ['68REE/MEN_713']
# 68SAL/NOR_1253
# ['68SAL/NOR_1253']
# 68SAL/NOR_1259
# ['68SAL/NOR_1259']
# 68SAL/NOR_1268
# ['68SAL/NOR_1268']
# 68SU/RUS_642
# ['68SU/RUS_642']
# 68SU/RUS_660
# ['68SU/RUS_660']
# 68SUG/PIZ_203
# ['68SUG/PIZ_203']
# 68TAN/KAN_451
# ['68TAN/KAN_451']
# 68VEE_136
# ['68VEE_136']
# 68VEE_148
# ['68VEE_148']
# 68VEE_154
# ['68VEE_154']
# 68VEE_256
# ['68VEE_256']
# 68VEE_314
# ['68VEE_314']
# 68VEE_583
# ['68VEE_583']
# 69BAR_40
# ['69BAR_40']
# 69BEN_1149
# ['69BEN_1149']
# 69BEN_1150
# ['69BEN_1150']
# 69BLA/FRA_1381
# ['69BLA/FRA_1381']
# 69BLA_1166
# ['69BLA_1166']
# 69BRE/AAS_390
# ['69BRE/AAS_390']
# 69BRE/AAS_392
# ['69BRE/AAS_392']
# 69BRE/AAS_393
# ['69BRE/AAS_393']
# 69DAH/AND_1109
# ['69DAH/AND_1109']
# 69DOL_235
# ['69DOL_235']
# 69FAN/FEI_1254
# ['69FAN/FEI_1254']
# 69FAN/FEI_1269
# ['69FAN/FEI_1269']
# 69GAR/CLE_662
# ['69GAR/CLE_662']
# 69GEO/TRA_1075
# ['69GEO/TRA_1075']
# 69GEO/TRA_756
# ['69GEO/TRA_756']
# 69GEO/TRA_757
# ['69GEO/TRA_757']
# 69GRE/RUD_836
# ['69GRE/RUD_836']
# 69GRE/RUD_840
# ['69GRE/RUD_840']
# 69KLO_398
# ['69KLO_398']
# 69LAN/DEK_105
# ['69LAN/DEK_105']
# 69LAN/DEK_92
# ['69LAN/DEK_92']
# 69LAN/DEK_93
# ['69LAN/DEK_93']
# 69LAN/DEK_94
# ['69LAN/DEK_94']
# 69PAS/LOW_1400
# ['69PAS/LOW_1400']
# 69PET/MCK_337
# ['69PET/MCK_337']
# 69POP_628
# ['69POP_628']
# 69ROS/HAM_859
# ['69ROS/HAM_859']
# 69SHE/ALE_446
# ['69SHE/ALE_446']
# 69SMI/MOR_617
# ['69SMI/MOR_617']
# 69SWI_674
# ['69SWI_674']
# 69TSU/FUK_689
# ['69TSU/FUK_689']
# 69VEE/EGG_149
# ['69VEE/EGG_149']
# 69VEE/EGG_315
# ['69VEE/EGG_315']
# 69VEE/EGG_501
# ['69VEE/EGG_501']
# 69VEE/RAI_1094
# ['69VEE/RAI_1094']
# 69VEE/RAI_1286
# ['69VEE/RAI_1286']
# 69VIL/DAL_157
# ['69VIL/DAL_157']
# 69WAN/BAR_1151
# ['69WAN/BAR_1151']
# 69WAN/BAR_1191
# ['69WAN/BAR_1191']
# 69WHI/LEJ_1239
# ['69WHI/LEJ_1239']
# 70ALB_670
# ['70ALB_670']
# 70BAL/DEN_84
# ['70BAL/DEN_84']
# 70BEN/FRI_1367
# ['70BEN/FRI_1367']
# 70BLA_644
# ['70BLA_644']
# 70BRO/KRE_512
# ['70BRO/KRE_512']
# 70CHI/ZAP_1416
# ['70CHI/ZAP_1416']
# 70GEO/WIT_755
# ['70GEO/WIT_755']
# 70GEO/WIT_758
# ['70GEO/WIT_758']
# 70GEO/WIT_777
# ['70GEO/WIT_777']
# 70GEO/WIT_806
# ['70GEO/WIT_806']
# 70HER_1035
# ['70HER_1035']
# 70HEY/ELB_1343
# ['70HEY/ELB_1343']
# 70JEN/TAY_536
# ['70JEN/TAY_536']
# 70KNO/HAN_690
# ['70KNO/HAN_690']
# 70KOH/WAR_91
# ['70KOH/WAR_91']
# 70KRI/BUC_579
# ['70KRI/BUC_579']
# 70MAN/HOL_708
# ['70MAN/HOL_708']
# 70NAK/FUJ_535
# ['70NAK/FUJ_535']
# 70NAK/TSU_205
# ['70NAK/TSU_205']
# 70TSA/HOL_1255
# ['70TSA/HOL_1255']
# 70TSU/FRI_291
# ['70TSU/FRI_291']
# 70VEE/RAI_257
# ['70VEE/RAI_257']
# 70VEE/RAI_584
# ['70VEE/RAI_584']
# 70WUR/HES_163
# ['70WUR/HES_163']
# 70WUR/SCH_1359
# ['70WUR/SCH_1359']
# 71CHE/ALI_597
# ['71CHE/ALI_597']
# 71COH/WOL_1054
# ['71COH/WOL_1054']
# 71COH/WOL_1055
# ['71COH/WOL_1055']
# 71GLO/POT_387
# ['71GLO/POT_387']
# 71HAY/GRE_1229
# ['71HAY/GRE_1229']
# 71HOR/HUS_645
# ['71HOR/HUS_645']
# 71JOS/WAK_413
# ['71JOS/WAK_413']
# 71KAT_220
# ['71KAT_220']
# 71KUN/STA_1384
# ['71KUN/STA_1384']
# 71KUN/STA_1422
# ['71KUN/STA_1422']
# 71MCC/CHA_959
# ['71MCC/CHA_959']
# 71NOJ/TAN_399
# ['71NOJ/TAN_399']
# 71RAJ/LUM_965
# ['71RAJ/LUM_965']
# 71ROB_710
# ['71ROB_710']
# 71RUD/JOH_833
# ['71RUD/JOH_833']
# 71RUD/JOH_834
# ['71RUD/JOH_834']
# 71RUD/JOH_835
# ['71RUD/JOH_835']
# 71RUD/JOH_851
# ['71RUD/JOH_851']
# 71RUD/JOH_852
# ['71RUD/JOH_852']
# 71RUD/JOH_855
# ['71RUD/JOH_855']
# 71RUD/JOH_858
# ['71RUD/JOH_858']
# 71SHI/SUG_667
# ['71SHI/SUG_667']
# 71SHI/SUG_669
# ['71SHI/SUG_669']
# 71TAK/KUR_1230
# ['71TAK/KUR_1230']
# 71TAN/JOH_402
# ['71TAN/JOH_402']
# 71UNK/GOL_1194
# ['71UNK/GOL_1194']
# 71UNK/GOL_1195
# ['71UNK/GOL_1195']
# 71UNK/GOL_1197
# ['71UNK/GOL_1197']
# 71WIL/ROC_1115
# ['71WIL/ROC_1115']
# 71WOH_709
# ['71WOH_709']
# 72BAK/JEN_290
# ['72BAK/JEN_290']
# 72CAG/FRI_570
# ['72CAG/FRI_570']
# 72COO/MEI_521
# ['72COO/MEI_521']
# 72COO/MEI_522
# ['72COO/MEI_522']
# 72COO/MEI_523
# ['72COO/MEI_523']
# 72DAH/AND_1108
# ['72DAH/AND_1108']
# 72DEL_427
# ['72DEL_427']
# 72FOR/GAU_206
# ['72FOR/GAU_206']
# 72GUS/GAN_691
# ['72GUS/GAN_691']
# 72KHA/ZHE_860
# ['72KHA/ZHE_860']
# 72KHA/ZHE_861
# ['72KHA/ZHE_861']
# 72KHA/ZHE_862
# ['72KHA/ZHE_862']
# 72KHA/ZHE_863
# ['72KHA/ZHE_863']
# 72KHA/ZHE_864
# ['72KHA/ZHE_864']
# 72KHA/ZHE_865
# ['72KHA/ZHE_865']
# 72KHA/ZHE_866
# ['72KHA/ZHE_866']
# 72KHA/ZHE_867
# ['72KHA/ZHE_867']
# 72KHA/ZHE_868
# ['72KHA/ZHE_868']
# 72KHA/ZHE_869
# ['72KHA/ZHE_869']
# 72KOR/HUR_199
# ['72KOR/HUR_199']
# 72LEH/TAN_452
# ['72LEH/TAN_452']
# 72MAR/BEL_450
# ['72MAR/BEL_450']
# 72NAG/JAE_299
# ['72NAG/JAE_299']
# 72NEL/KIE_330
# ['72NEL/KIE_330']
# 72ROS/SLA_1441
# ['72ROS/SLA_1441']
# 72STU_745
# ['72STU_745']
# 72TAK/ONO_439
# ['72TAK/ONO_439']
# 72TAK/ONO_440
# ['72TAK/ONO_440']
# 72TAK/ONO_441
# ['72TAK/ONO_441']
# 72TAK/ONO_870
# ['72TAK/ONO_870']
# 72TAK/ONO_871
# ['72TAK/ONO_871']
# 72TAK/ONO_872
# ['72TAK/ONO_872']
# 72WOL_800
# ['72WOL_800']
# 72WUR/HES_1276
# ['72WUR/HES_1276']
# 73BEE/STE_998
# ['73BEE/STE_998']
# 73DEW/LOW_646
# ['73DEW/LOW_646']
# 73GUY/GEL_1127
# ['73GUY/GEL_1127']
# 73GUY/GEL_1128
# ['73GUY/GEL_1128']
# 73GUY/GEL_137
# ['73GUY/GEL_137']
# 73GUY/VEE_403
# ['73GUY/VEE_403']
# 73HAN/RUD_553
# ['73HAN/RUD_553']
# 73HAV/PIT_1304
# ['73HAV/PIT_1304']
# 73HER_1136
# ['73HER_1136']
# 73LAN_1305
# ['73LAN_1305']
# 73MCC/KOL_1216
# ['73MCC/KOL_1216']
# 73RAD/HOC_400
# ['73RAD/HOC_400']
# 73ROT/KIS_300
# ['73ROT/KIS_300']
# 73ROT/KIS_346
# ['73ROT/KIS_346']
# 73SHE/GUL_155
# ['73SHE/GUL_155']
# 73SOM/COS_1418
# ['73SOM/COS_1418']
# 73STU/GER_841
# ['73STU/GER_841']
# 73STU/GER_843
# ['73STU/GER_843']
# 73STU/GER_847
# ['73STU/GER_847']
# 73STU/GER_849
# ['73STU/GER_849']
# 73SUG_714
# ['73SUG_714']
# 73SUZ/IWA_1060
# ['73SUZ/IWA_1060']
# 73VEL/GUY_1167
# ['73VEL/GUY_1167']
# 73VID/UDE_78
# ['73VID/UDE_78']
# 73WUR/HES_164
# ['73WUR/HES_164']
# 74BEL/MAR_1409
# ['74BEL/MAR_1409']
# 74BOS/YAM_471
# ['74BOS/YAM_471']
# 74BUR_15
# ['74BUR_15']
# 74BUR_31
# ['74BUR_31']
# 74CHE/PAT_837
# ['74CHE/PAT_837']
# 74CLA/BIR_1395
# ['74CLA/BIR_1395']
# 74DAN/CAR_473
# ['74DAN/CAR_473']
# 74FER/STR_1112
# ['74FER/STR_1112']
# 74FER/STR_1380
# ['74FER/STR_1380']
# 74FLO/FLE_1063
# ['74FLO/FLE_1063']
# 74FRA/LEE_1306
# ['74FRA/LEE_1306']
# 74GAU/MAI_1271
# ['74GAU/MAI_1271']
# 74GUY/VEL_1404
# ['74GUY/VEL_1404']
# 74GUY/VEL_692
# ['74GUY/VEL_692']
# 74GUY/WEB_1434
# ['74GUY/WEB_1434']
# 74JEB/TY_647
# ['74JEB/TY_647']
# 74JEB/TY_659
# ['74JEB/TY_659']
# 74KEN_1037
# ['74KEN_1037']
# 74KNA/BLA_414
# ['74KNA/BLA_414']
# 74KUR/TAK_1231
# ['74KUR/TAK_1231']
# 74LAN_575
# ['74LAN_575']
# 74LAN_648
# ['74LAN_648']
# 74MCK_1307
# ['74MCK_1307']
# 74SCA/SHI_1308
# ['74SCA/SHI_1308']
# 74SCH/STU_310
# ['74SCH/STU_310']
# 74TUR/GIL_693
# ['74TUR/GIL_693']
# 74UEB/BLA_161
# ['74UEB/BLA_161']
# 74WON/FRE_697
# ['74WON/FRE_697']
# 75BOH/SCH_551
# ['75BOH/SCH_551']
# 75BOH/SCH_552
# ['75BOH/SCH_552']
# 75BRA/JAR_217
# ['75BRA/JAR_217']
# 75COH/LYN_1198
# ['75COH/LYN_1198']
# 75DON/BAR_106
# ['75DON/BAR_106']
# 75GER/WES_783
# ['75GER/WES_783']
# 75GER/WES_788
# ['75GER/WES_788']
# 75GER/WES_789
# ['75GER/WES_789']
# 75GER/WES_790
# ['75GER/WES_790']
# 75GER/WES_838
# ['75GER/WES_838']
# 75GER/WES_839
# ['75GER/WES_839']
# 75GER/WES_842
# ['75GER/WES_842']
# 75GER/WES_844
# ['75GER/WES_844']
# 75GER/WES_845
# ['75GER/WES_845']
# 75GER/WES_846
# ['75GER/WES_846']
# 75GER/WES_848
# ['75GER/WES_848']
# 75GER/WES_850
# ['75GER/WES_850']
# 75GOL_543
# ['75GOL_543']
# 75GOL_546
# ['75GOL_546']
# 75GOL_549
# ['75GOL_549']
# 75GOR/ESF_316
# ['75GOR/ESF_316']
# 75GRI/CAR_1396
# ['75GRI/CAR_1396']
# 75IZU/REE_1376
# ['75IZU/REE_1376']
# 75JEN/NYG_460
# ['75JEN/NYG_460']
# 75JES_999
# ['75JES_999']
# 75KAP/BAR_980
# ['75KAP/BAR_980']
# 75KAP/BAR_981
# ['75KAP/BAR_981']
# 75KAP/BAR_982
# ['75KAP/BAR_982']
# 75KRI_1285
# ['75KRI_1285']
# 75KUR/KON_1095
# ['75KUR/KON_1095']
# 75KUR/KON_1098
# ['75KUR/KON_1098']
# 75MAN/LAN_336
# ['75MAN/LAN_336']
# 75MCG/JOR_547
# ['75MCG/JOR_547']
# 75MUR/TSU_461
# ['75MUR/TSU_461']
# 75PIE/GUY_388
# ['75PIE/GUY_388']
# 75PIE/GUY_391
# ['75PIE/GUY_391']
# 75SCH/GRE_218
# ['75SCH/GRE_218']
# 75SCH/RIF_138
# ['75SCH/RIF_138']
# 75SCH/RIF_150
# ['75SCH/RIF_150']
# 75SHI/BEA_560
# ['75SHI/BEA_560']
# 75SUN_700
# ['75SUN_700']
# 75WYR/GRI_223
# ['75WYR/GRI_223']
# 76BER/KLY_1009
# ['76BER/KLY_1009']
# 76GOL_548
# ['76GOL_548']
# 76GRE/BRI_328
# ['76GRE/BRI_328']
# 76GUY_807
# ['76GUY_807']
# 76HIL/ATT_1397
# ['76HIL/ATT_1397']
# 76JES_139
# ['76JES_139']
# 76LAW/GUY_649
# ['76LAW/GUY_649']
# 76LAW/GUY_773
# ['76LAW/GUY_773']
# 76LAW/GUY_830
# ['76LAW/GUY_830']
# 76LLO/KHA_1309
# ['76LLO/KHA_1309']
# 76MUR_1413
# ['76MUR_1413']
# 76RAO/BUT_618
# ['76RAO/BUT_618']
# 76RUS/MUL_237
# ['76RUS/MUL_237']
# 76SCH/KRI_1000
# ['76SCH/KRI_1000']
# 76SCH/KRI_107
# ['76SCH/KRI_107']
# 76SCH/KRI_228
# ['76SCH/KRI_228']
# 76SPR/LIM_1310
# ['76SPR/LIM_1310']
# 76TRI/PAR_856
# ['76TRI/PAR_856']
# 76WEI/KIR_1179
# ['76WEI/KIR_1179']
# 77ANN/WAL_608
# ['77ANN/WAL_608']
# 77ANT/GIN_962
# ['77ANT/GIN_962']
# 77ANT/GIN_964
# ['77ANT/GIN_964']
# 77APP/NAI_556
# ['77APP/NAI_556']
# 77GRI/LOC_967
# ['77GRI/LOC_967']
# 77REH/JAN_320
# ['77REH/JAN_320']
# 77SCH/CLE_151
# ['77SCH/CLE_151']
# 77SCH/TAT_350
# ['77SCH/TAT_350']
# 77SRA/FRE_722
# ['77SRA/FRE_722']
# 77TRA/JON_481
# ['77TRA/JON_481']
# 78CHR/MAT_1038
# ['78CHR/MAT_1038']
# 78INF/KIN_701
# ['78INF/KIN_701']
# 78LYN/GUY_1437
# ['78LYN/GUY_1437']
# 78LYN/GUY_666
# ['78LYN/GUY_666']
# 78MCG/BRO_230
# ['78MCG/BRO_230']
# 78MCG/BRO_231
# ['78MCG/BRO_231']
# 78MEE/AKE_258
# ['78MEE/AKE_258']
# 78MEE/AKE_585
# ['78MEE/AKE_585']
# 78OKA/GEN_875
# ['78OKA/GEN_875']
# 78OKA/GEN_893
# ['78OKA/GEN_893']
# 78RAO/COH_650
# ['78RAO/COH_650']
# 78SUB_279
# ['78SUB_279']
# 78SUB_284
# ['78SUB_284']
# 78SUB_285
# ['78SUB_285']
# 79BYE/SHE_244
# ['79BYE/SHE_244']
# 79BYE/SHE_245
# ['79BYE/SHE_245']
# 79BYE/SHE_246
# ['79BYE/SHE_246']
# 79BYE/SHE_247
# ['79BYE/SHE_247']
# 79BYE/SHE_248
# ['79BYE/SHE_248']
# 79BYE/SHE_249
# ['79BYE/SHE_249']
# 79BYE/SHE_253
# ['79BYE/SHE_253']
# 79BYE/SHE_255
# ['79BYE/SHE_255']
# 79COR/CRO_16
# ['79COR/CRO_16']
# 79COR/LEA_254
# ['79COR/LEA_254']
# 79COR/LEA_259
# ['79COR/LEA_259']
# 79COR/LEA_580
# ['79COR/LEA_580']
# 79COR/LEA_586
# ['79COR/LEA_586']
# 79FLE/TAT_984
# ['79FLE/TAT_984']
# 79GRI/TAN_1040
# ['79GRI/TAN_1040']
# 79GRI/TAN_1043
# ['79GRI/TAN_1043']
# 79GRI/TAN_1046
# ['79GRI/TAN_1046']
# 79KIM/PET_143
# ['79KIM/PET_143']
# 79LAB/DEB_795
# ['79LAB/DEB_795']
# 79LAW/VEE_598
# ['79LAW/VEE_598']
# 79LAW/VEE_651
# ['79LAW/VEE_651']
# 79LAW/VEE_774
# ['79LAW/VEE_774']
# 79LAW/VEE_831
# ['79LAW/VEE_831']
# 79MCK/TAV_1311
# ['79MCK/TAV_1311']
# 79PIR/LIL_1137
# ['79PIR/LIL_1137']
# 79RAO/KAY_566
# ['79RAO/KAY_566']
# 79REK/EGO_238
# ['79REK/EGO_238']
# 79REK/EGO_334
# ['79REK/EGO_334']
# 79SCH/HIN_108
# ['79SCH/HIN_108']
# 79VIC/GRE_482
# ['79VIC/GRE_482']
# 80BEY/ROE_886
# ['80BEY/ROE_886']
# 80BEY/ROE_894
# ['80BEY/ROE_894']
# 80CAM/SGA_455
# ['80CAM/SGA_455']
# 80CAM/SGA_950
# ['80CAM/SGA_950']
# 80CHE/HED_567
# ['80CHE/HED_567']
# 80COO/BLA_109
# ['80COO/BLA_109']
# 80COO/BLA_1152
# ['80COO/BLA_1152']
# 80COO/BLA_140
# ['80COO/BLA_140']
# 80COO/BLA_156
# ['80COO/BLA_156']
# 80COO/BLA_17
# ['80COO/BLA_17']
# 80COO/BLA_2
# ['80COO/BLA_2']
# 80COO/BLA_286
# ['80COO/BLA_286']
# 80COO/BLA_32
# ['80COO/BLA_32']
# 80COO/BLA_6
# ['80COO/BLA_6']
# 80ELM/HAS_562
# ['80ELM/HAS_562']
# 80FUK/OBO_1256
# ['80FUK/OBO_1256']
# 80JAF/COH_582
# ['80JAF/COH_582']
# 80LER/COH_599
# ['80LER/COH_599']
# 80LER/COH_606
# ['80LER/COH_606']
# 80LER/COH_619
# ['80LER/COH_619']
# 80LER/COH_623
# ['80LER/COH_623']
# 80PET/AMI_144
# ['80PET/AMI_144']
# 80PET/AMI_503
# ['80PET/AMI_503']
# 80REK/EGO_239
# ['80REK/EGO_239']
# 80REK/EGO_335
# ['80REK/EGO_335']
# 80SLI/BOL_975
# ['80SLI/BOL_975']
# 80SVE/GAL_1023
# ['80SVE/GAL_1023']
# 80SVE/MAR_1005
# ['80SVE/MAR_1005']
# 80SVE/MAR_1006
# ['80SVE/MAR_1006']
# 80SVE/MAR_1007
# ['80SVE/MAR_1007']
# 80SVE/MAR_1008
# ['80SVE/MAR_1008']
# 80SVE/MAR_1010
# ['80SVE/MAR_1010']
# 80SVE/MAR_1014
# ['80SVE/MAR_1014']
# 80SVE/MAR_1016
# ['80SVE/MAR_1016']
# 80SVE/MAR_1017
# ['80SVE/MAR_1017']
# 80TER/RAB_994
# ['80TER/RAB_994']
# 81GON/CHE_1326
# ['81GON/CHE_1326']
# 81GRI/CLE_272
# ['81GRI/CLE_272']
# 81HIN/POL_1076
# ['81HIN/POL_1076']
# 81HIN/POL_769
# ['81HIN/POL_769']
# 81HIN/POL_781
# ['81HIN/POL_781']
# 81HIN/POL_782
# ['81HIN/POL_782']
# 81HIR_225
# ['81HIR_225']
# 81HSI/SU_694
# ['81HSI/SU_694']
# 81MER/MCA_204
# ['81MER/MCA_204']
# 81MER/MCA_539
# ['81MER/MCA_539']
# 81PAH/JAG_294
# ['81PAH/JAG_294']
# 81RAM/PIC_652
# ['81RAM/PIC_652']
# 81RAO/COH_600
# ['81RAO/COH_600']
# 81SUG/VEI_53
# ['81SUG/VEI_53']
# 82BAR/HEB_1277
# ['82BAR/HEB_1277']
# 82DEM_1064
# ['82DEM_1064']
# 82GAL/SVE_1019
# ['82GAL/SVE_1019']
# 82GAL/SVE_1021
# ['82GAL/SVE_1021']
# 82GAL/SVE_1022
# ['82GAL/SVE_1022']
# 82GAL/SVE_1024
# ['82GAL/SVE_1024']
# 82GAL/SVE_1028
# ['82GAL/SVE_1028']
# 82GAL/SVE_1029
# ['82GAL/SVE_1029']
# 82GUY/THA_828
# ['82GUY/THA_828']
# 82GUY_115
# ['82GUY_115']
# 82GUY_1398
# ['82GUY_1398']
# 82GUY_537
# ['82GUY_537']
# 82GUY_803
# ['82GUY_803']
# 82HSI/CHI_1327
# ['82HSI/CHI_1327']
# 82RED_554
# ['82RED_554']
# 82RED_558
# ['82RED_558']
# 82RED_568
# ['82RED_568']
# 82REH/YOU_232
# ['82REH/YOU_232']
# 82SAL/GIA_477
# ['82SAL/GIA_477']
# 82SAL/JOR_462
# ['82SAL/JOR_462']
# 82SUE/KAT_221
# ['82SUE/KAT_221']
# 83BRA_18
# ['83BRA_18']
# 83BRA_28
# ['83BRA_28']
# 83BRA_33
# ['83BRA_33']
# 83BRA_4
# ['83BRA_4']
# 83CRA/BOS_19
# ['83CRA/BOS_19']
# 83HAA/KAR_1013
# ['83HAA/KAR_1013']
# 83HAA/KAR_1015
# ['83HAA/KAR_1015']
# 83HON/HAR_695
# ['83HON/HAR_695']
# 83KAT/SUE_222
# ['83KAT/SUE_222']
# 83KHO/KAR_653
# ['83KHO/KAR_653']
# 83MIL/RYC_607
# ['83MIL/RYC_607']
# 83SEL/MAN_1228
# ['83SEL/MAN_1228']
# 83TIL_1312
# ['83TIL_1312']
# 83WED/BLA_146
# ['83WED/BLA_146']
# 83YAM/SAI_261
# ['83YAM/SAI_261']
# 84ADA/UED_887
# ['84ADA/UED_887']
# 84ADA/UED_895
# ['84ADA/UED_895']
# 84BLA/COC_295
# ['84BLA/COC_295']
# 84DEM_1065
# ['84DEM_1065']
# 84DEY_1257
# ['84DEY_1257']
# 84DIT/KUB_80
# ['84DIT/KUB_80']
# 84DIT/KUB2_54
# ['84DIT/KUB2_54']
# 84KOL/EGG_1201
# ['84KOL/EGG_1201']
# 84LLO/CHA_1313
# ['84LLO/CHA_1313']
# 84OYA/IRI_985
# ['84OYA/IRI_985']
# 84PAU_317
# ['84PAU_317']
# 84PUZ/GOR_486
# ['84PUZ/GOR_486']
# 84PUZ/GOR_487
# ['84PUZ/GOR_487']
# 84RAG/LJU_303
# ['84RAG/LJU_303']
# 84REK/RUM_963
# ['84REK/RUM_963']
# 84TEW/GOL_1314
# ['84TEW/GOL_1314']
# 84TEW/GOL_1315
# ['84TEW/GOL_1315']
# 84UCH/TSU_1119
# ['84UCH/TSU_1119']
# 84WAS/DAU_1236
# ['84WAS/DAU_1236']
# 85ANS/PRI_141
# ['85ANS/PRI_141']
# 85ANS/PRI_277
# ['85ANS/PRI_277']
# 85BAR_430
# ['85BAR_430']
# 85COO/PRA_1203
# ['85COO/PRA_1203']
# 85DAS/BRO_746
# ['85DAS/BRO_746']
# 85DEM/BEH_1066
# ['85DEM/BEH_1066']
# 85FAG/DEW_1080
# ['85FAG/DEW_1080']
# 85GAJ/GOL_1153
# ['85GAJ/GOL_1153']
# 85GAJ/GOL_1154
# ['85GAJ/GOL_1154']
# 85HER/AIY_952
# ['85HER/AIY_952']
# 85LEE/OSU_629
# ['85LEE/OSU_629']
# 85LEE/OSU_630
# ['85LEE/OSU_630']
# 85LEE/OSU_631
# ['85LEE/OSU_631']
# 85LEE/OSU_632
# ['85LEE/OSU_632']
# 85LIE_292
# ['85LIE_292']
# 85LIE_325
# ['85LIE_325']
# 85MAK/KIE_1316
# ['85MAK/KIE_1316']
# 85REK/SLO_987
# ['85REK/SLO_987']
# 85SRI/FIS_293
# ['85SRI/FIS_293']
# 85TEW/GOL2_1295
# ['85TEW/GOL2_1295']
# 85TEW/GOL2_1377
# ['85TEW/GOL2_1377']
# 85TEW/GOL2_1378
# ['85TEW/GOL2_1378']
# 85TEW/STE_1328
# ['85TEW/STE_1328']
# 85TEW/STE_1329
# ['85TEW/STE_1329']
# 85WIE/HIN_1180
# ['85WIE/HIN_1180']
# 85WIE/HIN_1183
# ['85WIE/HIN_1183']
# 85WIE/HIN_1185
# ['85WIE/HIN_1185']
# 85WIE/HIN_1187
# ['85WIE/HIN_1187']
# 86CAS/VEE_366
# ['86CAS/VEE_366']
# 86CAS/VEE_369
# ['86CAS/VEE_369']
# 86CAS/VEE_374
# ['86CAS/VEE_374']
# 86CAS/VEE2_1248
# ['86CAS/VEE2_1248']
# 86CAS/VEE2_1338
# ['86CAS/VEE2_1338']
# 86CAS/VEE2_165
# ['86CAS/VEE2_165']
# 86CAS/VEE2_753
# ['86CAS/VEE2_753']
# 86DAL/REN_1067
# ['86DAL/REN_1067']
# 86DEW/EMI_946
# ['86DEW/EMI_946']
# 86GAJ/STE_1074
# ['86GAJ/STE_1074']
# 86GOL/GAJ_1212
# ['86GOL/GAJ_1212']
# 86GOL/GAJ_1213
# ['86GOL/GAJ_1213']
# 86GRA/ELL_620
# ['86GRA/ELL_620']
# 86HUB/HUR_930
# ['86HUB/HUR_930']
# 86KIM/LEE_601
# ['86KIM/LEE_601']
# 86KON/POL_121
# ['86KON/POL_121']
# 86KUP/FER_661
# ['86KUP/FER_661']
# 86MEI/GAD_111
# ['86MEI/GAD_111']
# 86MEI/GAD_302
# ['86MEI/GAD_302']
# 86MEI/GAD_306
# ['86MEI/GAD_306']
# 86MEI/GAD_307
# ['86MEI/GAD_307']
# 86MEY/BRO_611
# ['86MEY/BRO_611']
# 86NAK/KIM_1081
# ['86NAK/KIM_1081']
# 86OLI/TOI_1317
# ['86OLI/TOI_1317']
# 86OLI/TOI_1330
# ['86OLI/TOI_1330']
# 86POL/MEN_1318
# ['86POL/MEN_1318']
# 86PRU/TEN_333
# ['86PRU/TEN_333']
# 86REK/SKY_1025
# ['86REK/SKY_1025']
# 86REK/SKY_1031
# ['86REK/SKY_1031']
# 86ROH/ETT_1020
# ['86ROH/ETT_1020']
# 86TEW/GOL_1321
# ['86TEW/GOL_1321']
# 86TEW/GOL_1322
# ['86TEW/GOL_1322']
# 87ANT_791
# ['87ANT_791']
# 87ANT_793
# ['87ANT_793']
# 87ANT_796
# ['87ANT_796']
# 87BED/TES_20
# ['87BED/TES_20']
# 87BUC/MIL_1135
# ['87BUC/MIL_1135']
# 87BUC/MIL_224
# ['87BUC/MIL_224']
# 87KUC/MIZ_682
# ['87KUC/MIZ_682']
# 87MOS/FRE_1417
# ['87MOS/FRE_1417']
# 87OWU/TRE_1003
# ['87OWU/TRE_1003']
# 87RAO/HAR_555
# ['87RAO/HAR_555']
# 87REK/EGO_1018
# ['87REK/EGO_1018']
# 87TAV/LEE_483
# ['87TAV/LEE_483']
# 87TAV/LEE_484
# ['87TAV/LEE_484']
# 87TEW/GAJ_1220
# ['87TEW/GAJ_1220']
# 87WOL/REI_801
# ['87WOL/REI_801']
# 88BED/HAD_1430
# ['88BED/HAD_1430']
# 88BEL/BAE_569
# ['88BEL/BAE_569']
# 88LIM/RAI_1287
# ['88LIM/RAI_1287']
# 88MAC/FEW_201
# ['88MAC/FEW_201']
# 88TEW/GOL_1011
# ['88TEW/GOL_1011']
# 88TEW/GOL_1012
# ['88TEW/GOL_1012']
# 88TEW/STE_1339
# ['88TEW/STE_1339']
# 88TEW/STE_1347
# ['88TEW/STE_1347']
# 88TEW/STE_1348
# ['88TEW/STE_1348']
# 88TEW/STE_1360
# ['88TEW/STE_1360']
# 88TEW/STE_1361
# ['88TEW/STE_1361']
# 88TEW/STE2_766
# ['88TEW/STE2_766']
# 88TEW/STE2_767
# ['88TEW/STE2_767']
# 88TEW/STE2_775
# ['88TEW/STE2_775']
# 88TEW/STE2_787
# ['88TEW/STE2_787']
# 88TEW/STE2_813
# ['88TEW/STE2_813']
# 88TEW/STE2_814
# ['88TEW/STE2_814']
# 89AIR_1032
# ['89AIR_1032']
# 89BER/MUD_947
# ['89BER/MUD_947']
# 89ELD/DEG_602
# ['89ELD/DEG_602']
# 89ELL_588
# ['89ELL_588']
# 89ELL_621
# ['89ELL_621']
# 89ELL_625
# ['89ELL_625']
# 89ELL_627
# ['89ELL_627']
# 89GOL/TEW_1405
# ['89GOL/TEW_1405']
# 89GOL/TEW_418
# ['89GOL/TEW_418']
# 89GOL/TEW_931
# ['89GOL/TEW_931']
# 89GOL/TEW_932
# ['89GOL/TEW_932']
# 89GOL/TEW2_943
# ['89GOL/TEW2_943']
# 89IMA_948
# ['89IMA_948']
# 89IMA_949
# ['89IMA_949']
# 89JEE/SHI_21
# ['89JEE/SHI_21']
# 89JOH/HED_937
# ['89JOH/HED_937']
# 89JOH/HED_938
# ['89JOH/HED_938']
# 89JOH/HED_939
# ['89JOH/HED_939']
# 89LOP/COH_603
# ['89LOP/COH_603']
# 89LOP/COH_605
# ['89LOP/COH_605']
# 89LOP/COH_609
# ['89LOP/COH_609']
# 89REK/SIK_1026
# ['89REK/SIK_1026']
# 89RIZ/HAR_55
# ['89RIZ/HAR_55']
# 89ROM/DEM_761
# ['89ROM/DEM_761']
# 89ROM/DEM_776
# ['89ROM/DEM_776']
# 89ROM/DEM_780
# ['89ROM/DEM_780']
# 89ROM/DEM_808
# ['89ROM/DEM_808']
# 89ROM/DEM_812
# ['89ROM/DEM_812']
# 89SAN/SIN_1362
# ['89SAN/SIN_1362']
# 89SCH/GIF_58
# ['89SCH/GIF_58']
# 89SCH/GIF_63
# ['89SCH/GIF_63']
# 89SCH/GIF_68
# ['89SCH/GIF_68']
# 89TEW/GOL_909
# ['89TEW/GOL_909']
# 89TEW/GOL_910
# ['89TEW/GOL_910']
# 89TEW/GOL_912
# ['89TEW/GOL_912']
# 89TEW/GOL_916
# ['89TEW/GOL_916']
# 89TEW/GOL_918
# ['89TEW/GOL_918']
# 89TEW/GOL_919
# ['89TEW/GOL_919']
# 90LIU_1424
# ['90LIU_1424']
# 90LUN/APR_431
# ['90LUN/APR_431']
# 90OCO/BUT_752
# ['90OCO/BUT_752']
# 90SAN/SIN_1363
# ['90SAN/SIN_1363']
# 91AND/KAT_1232
# ['91AND/KAT_1232']
# 91GOL/BEL_882
# ['91GOL/BEL_882']
# 91GOL/BEL_888
# ['91GOL/BEL_888']
# 91GOL/BEL_889
# ['91GOL/BEL_889']
# 91GOL/BEL_890
# ['91GOL/BEL_890']
# 91GOL/BEL_891
# ['91GOL/BEL_891']
# 91GOL/BEL_896
# ['91GOL/BEL_896']
# 91GOL/BEL_897
# ['91GOL/BEL_897']
# 91GOL/BEL_899
# ['91GOL/BEL_899']
# 91GOL/BEL_901
# ['91GOL/BEL_901']
# 91GOL/BEL_940
# ['91GOL/BEL_940']
# 91GOL/BEL_941
# ['91GOL/BEL_941']
# 91HOR/UEH_467
# ['91HOR/UEH_467']
# 91HOR/UEH_469
# ['91HOR/UEH_469']
# 91HOR/WAT_468
# ['91HOR/WAT_468']
# 91KLE/RAN_654
# ['91KLE/RAN_654']
# 91KNI/SEM_1406
# ['91KNI/SEM_1406']
# 91KRA/GYG_1120
# ['91KRA/GYG_1120']
# 91LIU/FRO_832
# ['91LIU/FRO_832']
# 91MOR/FRE_329
# ['91MOR/FRE_329']
# 91SCH/GIF_59
# ['91SCH/GIF_59']
# 91SCH/GIF_69
# ['91SCH/GIF_69']
# 91SEM/CLE_1349
# ['91SEM/CLE_1349']
# 91SEM/CLE_1364
# ['91SEM/CLE_1364']
# 91SEM/CLE_542
# ['91SEM/CLE_542']
# 91SRI/NAM_308
# ['91SRI/NAM_308']
# 91TEW/GOL_876
# ['91TEW/GOL_876']
# 91TEW/GOL_877
# ['91TEW/GOL_877']
# 91TEW/GOL_911
# ['91TEW/GOL_911']
# 91TEW/GOL_913
# ['91TEW/GOL_913']
# 91TEW/GOL_920
# ['91TEW/GOL_920']
# 91TEW/GOL_921
# ['91TEW/GOL_921']
# 91TEW/GOL_928
# ['91TEW/GOL_928']
# 91TEW/GOL_929
# ['91TEW/GOL_929']
# 91TEW/GOL_934
# ['91TEW/GOL_934']
# 91TEW/GOL_935
# ['91TEW/GOL_935']
# 91TEW/GOL2_655
# ['91TEW/GOL2_655']
# 91TEW/GOL2_656
# ['91TEW/GOL2_656']
# 91WOH/DIE_304
# ['91WOH/DIE_304']
# 91WOH/DIE_305
# ['91WOH/DIE_305']
# 92BLA/GUI_966
# ['92BLA/GUI_966']
# 92DEM/ATT_1319
# ['92DEM/ATT_1319']
# 92ELL/SRI_927
# ['92ELL/SRI_927']
# 92ELL/SRI_933
# ['92ELL/SRI_933']
# 92ELL/SRI_936
# ['92ELL/SRI_936']
# 92IBO/OBO_1030
# ['92IBO/OBO_1030']
# 92KAH/SCH_189
# ['92KAH/SCH_189']
# 92KER/KER_1155
# ['92KER/KER_1155']
# 92KIM/KIN_1411
# ['92KIM/KIN_1411']
# 92KIM/KIN_458
# ['92KIM/KIN_458']
# 92KIM/KIN_464
# ['92KIM/KIN_464']
# 92KIM/KIN_466
# ['92KIM/KIN_466']
# 92KIM/KIN_475
# ['92KIM/KIN_475']
# 92KIM/KIN_478
# ['92KIM/KIN_478']
# 92KIM/KIN_479
# ['92KIM/KIN_479']
# 92KIM/KIN_675
# ['92KIM/KIN_675']
# 92KIM/KIN_829
# ['92KIM/KIN_829']
# 92KIT/SAS_445
# ['92KIT/SAS_445']
# 92KRA_1121
# ['92KRA_1121']
# 92KRA_1273
# ['92KRA_1273']
# 92LEE/HAN_945
# ['92LEE/HAN_945']
# 92LOR/TRA_737
# ['92LOR/TRA_737']
# 92LOR/TRA_739
# ['92LOR/TRA_739']
# 92LOR/TRA_741
# ['92LOR/TRA_741']
# 92REK/TIS_794
# ['92REK/TIS_794']
# 92REK/TIS_826
# ['92REK/TIS_826']
# 92TEA/DOB_604
# ['92TEA/DOB_604']
# 92WAN/CHE_747
# ['92WAN/CHE_747']
# 92XIA/XUE_1414
# ['92XIA/XUE_1414']
# 93BES/REB_351
# ['93BES/REB_351']
# 93BES/REB_352
# ['93BES/REB_352']
# 93BLI/MAR_1033
# ['93BLI/MAR_1033']
# 93BLI/MAR_1034
# ['93BLI/MAR_1034']
# 93BOH/HUT_226
# ['93BOH/HUT_226']
# 93HUT/BOH_227
# ['93HUT/BOH_227']
# 93HUT/BOH_229
# ['93HUT/BOH_229']
# 93JAN/PAD_724
# ['93JAN/PAD_724']
# 93JAN/PAD_725
# ['93JAN/PAD_725']
# 93JAN/PAD_726
# ['93JAN/PAD_726']
# 93JAN/PAD_728
# ['93JAN/PAD_728']
# 93JAN/PAD_729
# ['93JAN/PAD_729']
# 93JAN/PAD_730
# ['93JAN/PAD_730']
# 93JAN/PAD_738
# ['93JAN/PAD_738']
# 93JAN/PAD_740
# ['93JAN/PAD_740']
# 93JAN/PAD_742
# ['93JAN/PAD_742']
# 93LAR/TEW_1053
# ['93LAR/TEW_1053']
# 93LAR/TEW_1056
# ['93LAR/TEW_1056']
# 93LAR/TEW_1217
# ['93LAR/TEW_1217']
# 93LAR/TEW_1218
# ['93LAR/TEW_1218']
# 93LAR/TEW_759
# ['93LAR/TEW_759']
# 93LAR/TEW_760
# ['93LAR/TEW_760']
# 93LAR/TEW_784
# ['93LAR/TEW_784']
# 93LAR/TEW_785
# ['93LAR/TEW_785']
# 93MOC/STR_453
# ['93MOC/STR_453']
# 93SHI/CHE_1243
# ['93SHI/CHE_1243']
# 93TEW/KIS_1047
# ['93TEW/KIS_1047']
# 93TEW/KIS_1051
# ['93TEW/KIS_1051']
# 93WER/TWE_1189
# ['93WER/TWE_1189']
# 93WER/TWE_1192
# ['93WER/TWE_1192']
# 93WER/TWE_1202
# ['93WER/TWE_1202']
# 94CHI/KIR_490
# ['94CHI/KIR_490']
# 94CHI/KIR_491
# ['94CHI/KIR_491']
# 94CHI/KIR_492
# ['94CHI/KIR_492']
# 94CHI/KIR_493
# ['94CHI/KIR_493']
# 94KIS/TEW_1041
# ['94KIS/TEW_1041']
# 94KIS/TEW_1042
# ['94KIS/TEW_1042']
# 94KIS/TEW_1044
# ['94KIS/TEW_1044']
# 94KIS/TEW_1045
# ['94KIS/TEW_1045']
# 94LEU/COO_409
# ['94LEU/COO_409']
# 94NOE/COL_197
# ['94NOE/COL_197']
# 94TEW/GOL_1139
# ['94TEW/GOL_1139']
# 94TEW/GOL_1140
# ['94TEW/GOL_1140']
# 95BIS/KRA_1027
# ['95BIS/KRA_1027']
# 95CHE/ARM_494
# ['95CHE/ARM_494']
# 95HUT/BOH_1001
# ['95HUT/BOH_1001']
# 95HUT/BOH_995
# ['95HUT/BOH_995']
# 95JUS/KOT_1002
# ['95JUS/KOT_1002']
# 95KAM/JUR_626
# ['95KAM/JUR_626']
# 95KAM/JUR_657
# ['95KAM/JUR_657']
# 95KOZ/TOM_1425
# ['95KOZ/TOM_1425']
# 95KOZ/TOM_1426
# ['95KOZ/TOM_1426']
# 95LEE/WAL_489
# ['95LEE/WAL_489']
# 95LIA/WAN_331
# ['95LIA/WAN_331']
# 95LIA/WAN2_1048
# ['95LIA/WAN2_1048']
# 95LIU/ZEN_1049
# ['95LIU/ZEN_1049']
# 95LIU/ZEN_968
# ['95LIU/ZEN_968']
# 95LIU/ZEN_976
# ['95LIU/ZEN_976']
# 95SCH/TRA_581
# ['95SCH/TRA_581']
# 95TEW/SCH_960
# ['95TEW/SCH_960']
# 95TEW/SCH_961
# ['95TEW/SCH_961']
# 95WIS/KUS_610
# ['95WIS/KUS_610']
# 95WIS/KUS_612
# ['95WIS/KUS_612']
# 96ARA/RUZ_711
# ['96ARA/RUZ_711']
# 96HIR/MAY_731
# ['96HIR/MAY_731']
# 96HIR/MAY_732
# ['96HIR/MAY_732']
# 96HIR/MAY_733
# ['96HIR/MAY_733']
# 96HIR/MAY_734
# ['96HIR/MAY_734']
# 96HIR/MAY_735
# ['96HIR/MAY_735']
# 96HIR/MAY_736
# ['96HIR/MAY_736']
# 96LI/ZHA_668
# ['96LI/ZHA_668']
# 96OES/SCH_1410
# ['96OES/SCH_1410']
# 96OES/SCH_1412
# ['96OES/SCH_1412']
# 96OES/SCH_1415
# ['96OES/SCH_1415']
# 96PRO/GRO_1258
# ['96PRO/GRO_1258']
# 96TEW/GOL_60
# ['96TEW/GOL_60']
# 96TEW/GOL_61
# ['96TEW/GOL_61']
# 96TEW/GOL_70
# ['96TEW/GOL_70']
# 96TEW/GOL_71
# ['96TEW/GOL_71']
# 96TEW/GOL_73
# ['96TEW/GOL_73']
# 96TEW/GOL_74
# ['96TEW/GOL_74']
# 96TEW/SCH_749
# ['96TEW/SCH_749']
# 96TEW/SCH_750
# ['96TEW/SCH_750']
# 96TEW/SCH_751
# ['96TEW/SCH_751']
# 97CHA_622
# ['97CHA_622']
# 97CON/DEL_1320
# ['97CON/DEL_1320']
# 97DEJ/ROC_428
# ['97DEJ/ROC_428']
# 97HAN/KLE_208
# ['97HAN/KLE_208']
# 97KAS/TEW_1423
# ['97KAS/TEW_1423']
# 97LIA/WU_332
# ['97LIA/WU_332']
# 97PES/PRI_878
# ['97PES/PRI_878']
# 97PES/PRI_879
# ['97PES/PRI_879']
# 97PES/PRI_880
# ['97PES/PRI_880']
# 97PES/PRI_884
# ['97PES/PRI_884']
# 97PES/PRI_885
# ['97PES/PRI_885']
# 97PES/PRI_903
# ['97PES/PRI_903']
# 97PES/PRI_904
# ['97PES/PRI_904']
# 97PES/PRI_905
# ['97PES/PRI_905']
# 97PES/PRI_906
# ['97PES/PRI_906']
# 97PES/PRI_907
# ['97PES/PRI_907']
# 97PES/PRI_908
# ['97PES/PRI_908']
# 97SAL/GOD_1123
# ['97SAL/GOD_1123']
# 97STA/SUA_1365
# ['97STA/SUA_1365']
# 97TEW/GOL_434
# ['97TEW/GOL_434']
# 97TEW/GOL_436
# ['97TEW/GOL_436']
# 97TEW/GOL_438
# ['97TEW/GOL_438']
# 97TEW/GOL_442
# ['97TEW/GOL_442']
# 97TEW/GOL_873
# ['97TEW/GOL_873']
# 97TEW/GOL_874
# ['97TEW/GOL_874']
# 97YOR/ISH_540
# ['97YOR/ISH_540']
# 98DIE/STR_1004
# ['98DIE/STR_1004']
# 98KIM/VOE_559
# ['98KIM/VOE_559']
# 98KIS/TEW_1181
# ['98KIS/TEW_1181']
# 98KIS/TEW_1182
# ['98KIS/TEW_1182']
# 98KIS/TEW_1184
# ['98KIS/TEW_1184']
# 98KIS/TEW_1186
# ['98KIS/TEW_1186']
# 98KIS/TEW_1188
# ['98KIS/TEW_1188']
# 98KIS/TEW2_541
# ['98KIS/TEW2_541']
# 98LAE/EIS_1204
# ['98LAE/EIS_1204']
# 98LOV/LAU_857
# ['98LOV/LAU_857']
# 98TEW/CHE_1138
# ['98TEW/CHE_1138']
# 98TEW/KIS_513
# ['98TEW/KIS_513']
# 98TEW/KIS_514
# ['98TEW/KIS_514']
# 98TEW/KIS_515
# ['98TEW/KIS_515']
# 98TEW/KIS_516
# ['98TEW/KIS_516']
# 98TEW/KIS_517
# ['98TEW/KIS_517']
# 98TEW/KIS_518
# ['98TEW/KIS_518']
# 98TEW_727
# ['98TEW_727']
# 98THO/JOR_267
# ['98THO/JOR_267']
# 99HUT/OEH_944
# ['99HUT/OEH_944']
# 99KIS/HOL_1199
# ['99KIS/HOL_1199']
# 99KIS/HOL_262
# ['99KIS/HOL_262']
# 99KIS/TEW_988
# ['99KIS/TEW_988']
# 99KIS/TEW_992
# ['99KIS/TEW_992']
# 99TEW/SCH_723
# ['99TEW/SCH_723']
# 26QUA/WOO_1205
#  aspartate ammonia-lyase
#  L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 29WOO_1206
#  aspartate ammonia-lyase
#  L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# 31BOR/SCH_1141
#  fumarate hydratase
#  fumarate(aq) + H2O(l) = (S)-malate(aq)
# nan
# 34JAC_1142
#  fumarate hydratase
#  fumarate(aq) + H2O(l) = (S)-malate(aq)
# nan
# nan
# nan
# nan
# 34LOH/MEY_1169
#  phosphopyruvate hydratase
#  2-phospho-D-glycerate(aq) = phosphoenolpyruvate(aq) + H2O(l)
# nan
# nan
# nan
# 34MEY/LOH_1100
#  fructose-biphosphate aldolase and triose-phosphate isomerase
#  D-fructose 1,6-bisphosphate(aq) = 2 glycerone phosphate(aq)
# nan
# nan
# nan
# nan
# 35AKA_1170
#  triose-phosphate isomerase and fructose-bisphosphate aldolase
#  D-fructose 1,6-bisphosphate(aq) = 2 glycerone phosphate(aq)
# 35JAC/TAP_1207
#  phosphopyruvate hydratase
#  2-phospho-D-glycerate(aq) = phosphoenolpyruvate(aq) + H2O(l)
# nan
# 35MEY/KIE_1385
#  aspartate ammonia-lyase
#  L-aspartate(aq) = fumarate(aq) + ammonia(aq)
# nan
# nan
# nan
# 35MEY/KIE2_1386
#  phosphoglycerate mutase
#  2-phospho-D-glycerate(aq) = 3-phospho-D-glycerate(aq)
# 35MEY/LOH_1102
#  phosphoglycerate mutase
#  2-phospho-D-glycerate(aq) = 3-phospho-D-glycerate(aq)
# nan
# 35MEY/SCH_797
#  fructose-biphosphate aldolase and triose-phosphate isomerase
#  D-fructose 1,6-bisphosphate(aq) = 2 glycerone phosphate(aq)
# 35MEY/SCH_798
#  triose-phosphate isomerase and fructose-bisphosphate aldolase
#  D-fructose 1,6-bisphosphate(aq) = 2 glycerone phosphate(aq)
# 35MEY/SCH_802
#  alkaline phosphatase
#  phospho-L-arginine(aq) + H2O(l) = L-arginine(aq) + orthophosphate(aq)
# 35MEY/SCH_805
#  alkaline phosphatase
#  phosphocreatine(aq) + H2O(l) = creatine(aq) + orthophosphate(aq)
# 35MEY_1101
#  alkaline phosphatase
#  (R)-3-phosphoglycerate(aq) + H2O(l) = (R)-glycerate(aq) + orthophosphate(aq)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 36EUL/ADL_7
#  alkaline phosphatase
#  phosphoenolpyruvate(aq) + H2O(l) = pyruvate(aq) + orthophosphate(aq)
# nan
# nan
# 36LEH_589
#  fructose-biphosphate aldolase and triose-phosphate isomerase
#  D-fructose 1,6-bisphosphate(aq) = 2 glycerone phosphate(aq)
# nan
# 36LEH_614
#  triose-phosphate isomerase and fructose-bisphosphate aldolase
#  D-fructose 1,6-bisphosphate(aq) = 2 glycerone phosphate(aq)
# 36MEY/LOH_1099
#  alcohol dehydrogenase
#  ethanol(aq) + NAD(aq) = acetaldehyde(aq) + NADH(aq)
# nan
# nan
# 36MEY/SCH_1096
#  creatine kinase
#  ATP(aq) + creatine(aq) = ADP(aq) + phosphocreatine(aq)
# 36VEI_914
#  arginine kinase
#  ATP(aq) + L-arginine(aq) = ADP(aq) + NÏ‰-phospho-L-arginine(aq)
# nan
# 36VEI_915
#  fructose-biphosphate aldolase
#  methylerythrulose 1-phosphate(aq) = acetaldehyde(aq) + glycerone phosphate(aq)
# nan
# 36VEI_917
#  fructose-biphosphate aldolase
#  D-fructose 1-phosphate(aq) = D-glyceraldehyde(aq) + glycerone phosphate(aq)
# nan
# 36VEI_922
#  _-glucosidase
#  1-butyl Î²-D-glucopyranoside(aq) + H2O(l) = 1-butanol(aq) + D-glucose(aq)
# nan
# 36VEI_923
#  _-glucosidase
#  2-butyl Î²-D-glucopyranoside(aq) + H2O(l) = (1)-2-butanol(aq) + D-glucose(aq)
# nan
# 36VEI_924
#  _-glucosidase
#  ethyl Î²-D-glucopyranoside(aq) + H2O(l) = ethanol(aq) + D-glucose(aq)
# nan
# 36VEI_925
#  _-glucosidase
#  methyl Î²-D-glucopyranoside(aq) + H2O(l) = methanol(aq) + D-glucose(aq)
# nan
# 36VEI_926
#  _-glucosidase
#  2-methyl-1-propyl Î²-D-glucopyranoside(aq) + H2O(l) = 2-methyl-1-propanol(aq) + D-glucose(aq)
# nan
# 37ADL/SRE_8
#  _-glucosidase
# ...
# nan
# nan
# nan
# nan
# nan
# 92KRA_1273
#  _-glucosidase
#  Î±-D-melibiose(aq) + H2O(l) = D-galactose(aq) + D-glucose(aq)
# 92LEE/HAN_945
#  _-galactosidase
#  3-O-Î²-D-galactopyranosyl-D-arabinose(aq) + H2O(l) = D-galactose(aq) + D-arabinose(aq)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 92LOR/TRA_737
#  _-galactosidase
#  3-O-Î²-D-galactopyranosyl-D-arabinose(aq) + H2O(l) = D-galactose(aq) + D-arabinose(aq)
# 92LOR/TRA_739
#  _-galactosidase
#  lactulose(aq) + H2O(l) = D-galactose(aq) + D-fructose(aq)
# 92LOR/TRA_741
#  _-galactosidase
#  lactulose(aq) + H2O(l) = D-galactose(aq) + D-fructose(aq)
# 92REK/TIS_794
#  adenylate kinase
#  2 ADP(aq) = AMP(aq) + ATP(aq)
# 92REK/TIS_826
#  adenylate kinase
#  2 ADP(aq) = AMP(aq) + ATP(aq)
# 92TEA/DOB_604
#  methylenetetrahydrofolate dehydrogenase (NAD+)
#  5,10-methylenetetrahydrofolate(aq) + NAD(aq) = 5,10-methenyltetrahydrofolate(aq) + NADH(aq)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 92WAN/CHE_747
#  methylenetetrahydrofolate dehydrogenase (NAD+)
#  5,10-methylenetetrahydrofolate(aq) + AP-NAD(aq) = 5,10-methenyltetrahydrofolate(aq) + AP-NADH(aq)
# nan
# 92XIA/XUE_1414
#  chymotrypsin
#  N-acetyl-L-tryptophan phenylethyl ester(sln) + H2O(sln) = N-acetyl-L-tryptophan(sln) + 2-phenylethanol(sln)
# 93BES/REB_351
#  xylose isomerase
#  D-glucose(aq) = D-fructose(aq)
# 93BES/REB_352
#  _-galactosidase
#  allolactose(aq) + H2O(l) = D-galactose(aq) + D-glucose(aq)
# 93BLI/MAR_1033
#  _-galactosidase
#  lactose(aq) + H2O(l) = D-galactose(aq) + D-glucose(aq)
# 93BLI/MAR_1034
#  _-galactosidase
#  lactulose(aq) + H2O(l) = D-galactose(aq) + D-fructose(aq)
# 93BOH/HUT_226
#  aminoacylase
#  N-acetyl-L-valine(aq) + H2O(l) = acetate(aq) + L-valine(aq)
# 93HUT/BOH_227
#  ribitol dehydrogenase
#  ribitol(aq) + NAD(aq) = D-ribulose(aq) + NADH(aq)
# 93HUT/BOH_229
#  fumarate hydratase
#  fumarate(aq) + H2O(l) = (S)-malate(aq)
# 93JAN/PAD_724
#  phosphopentomutase
#  D-ribose 1-phosphate(aq) = D-ribose 5-phosphate(aq)
# 93JAN/PAD_725
#  purine-nucleoside phosphorylase
#  guanosine(aq) + orthophosphate(aq) = guanine(aq) + Î±-D-ribose 1-phosphate(aq)
# 93JAN/PAD_726
#  purine-nucleoside phosphorylase
#  inosine(aq) + orthophosphate(aq) = hypoxanthine(aq) + Î±-D-ribose 1-phosphate(aq)
# 93JAN/PAD_728
#  purine-nucleoside phosphorylase
#  xanthosine(aq) + orthophosphate(aq) = xanthine(aq) + Î±-D-ribose 1-phosphate(aq)
# 93JAN/PAD_729
#  adenine phosphoribosyltransferase
#  adenine(aq) + 5-phospho-Î±-D-ribose 1-diphosphate(aq) = AMP(aq) + pyrophosphate(aq)
# 93JAN/PAD_730
#  hypoxanthine phosphoribosyltransferase
#  guanine(aq) + 5-phospho-Î±-D-ribose 1-diphosphate(aq) = GMP(aq) + pyrophosphate(aq)
# 93JAN/PAD_738
#  hypoxanthine phosphoribosyltransferase
#  hypoxanthine(aq) + 5-phospho-Î±-D-ribose 1-diphosphate(aq) = IMP(aq) + pyrophosphate(aq)
# 93JAN/PAD_740
#  ribose-phosphate pyrophosphokinase
#  ATP(aq) + D-ribose 5-phosphate(aq) = AMP(aq) + 5-phospho-Î±-D-ribose 1-diphosphate(aq)
# 93JAN/PAD_742
#  5'-nucleosidase
#  AMP(aq) + H2O(l) = adenosine(aq) + orthophosphate(aq)
# 93LAR/TEW_1217
#  cellobiose phosphorylase
#  cellobiose(aq) + orthophosphate(aq) = D-glucose(aq) + Î±-D-glucose 1-phosphate(aq)
# nan
# 93LAR/TEW_1218
#  N-acetylneuraminate lyase
#  N-acetylneuraminate(aq) = N-acetyl-D-mannosamine(aq) + pyruvate(aq)
# nan
# 93LAR/TEW_759
#  N-acylglucosamine 2-epimerase
#  N-acetyl-D-glucosamine(aq) = N-acetyl-D-mannosamine(aq)
# 93LAR/TEW_760
#  a-dextrin endo-1,6-a-glucosidase
#  maltosyl-Î²-cyclomaltoheptaose(aq) + H2O(l) = cyclomaltoheptaose(aq) + maltose(aq)
# nan
# nan
# nan
# nan
# 93LAR/TEW_784
#  triacylglycerol lipase
#  diolein(aq) + H2O(l) = oleic acid(aq) + monoolein(aq)
# 93LAR/TEW_785
#  triacylglycerol lipase
#  monoolein(aq) + H2O(l) = oleic acid(aq) + glycerol(aq)
# nan
# nan
# nan
# nan
# 93MOC/STR_453
#  triacylglycerol lipase
#  triolein(aq) + H2O(l) = oleic acid(aq) + diolein(aq)
# 93SHI/CHE_1243
#  alkaline phosphatase
#  4-nitrophenyl phosphate(aq) + H2O(l) = 4-nitrophenol(aq) + orthophosphate(aq)
# 93TEW/KIS_1047
#  acid phosphatase
#  4-nitrophenyl phosphate(aq) + H2O(l) = 4-nitrophenol(aq) + orthophosphate(aq)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 93TEW/KIS_1051
#  creatine kinase
#  ATP(aq) + creatine(aq) = ADP(aq) + phosphocreatine(aq)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 93WER/TWE_1189
#  acetylcholinesterase
#  acetylcholine(aq) + H2O(l) = acetate(aq) + choline(aq)
# 93WER/TWE_1192
#  phosphomannomutase
#  D-mannose 1-phosphate(aq) = D-mannose 6-phosphate(aq)
# 93WER/TWE_1202
#  glycine hydroxymethyltransferase
#  5,10-methylenetetrahydrofolate(aq) + glycine(aq) + H2O(l) = tetrahydrofolate(aq) + L-serine(aq)
# 94CHI/KIR_490
#  glycine hydroxymethyltransferase
#  CH2-H4PteGlu4(aq) + glycine(aq) + H2O(l) = H4PteGlu4(aq) + L-serine(aq)
# 94CHI/KIR_491
#  D-(-)-phenylglycyl-_-lactamide amidohydrolase
#  ampicillin(aq) + H2O(l) = 6-aminopenicillanic acid(aq) + D(-)-Î±-aminophenylacetic acid(aq)
# 94CHI/KIR_492
#  D-(-)-phenylglycyl-_-lactamide amidohydrolase
#  cephalexin(aq) + H2O(l) = 7-aminodeacetoxycephalosporanic acid(aq) + D(-)-Î±-aminophenylacetic acid(aq)
# 94CHI/KIR_493
#  glucose oxidase
#  Î²-D-glucose(aq) + O2(aq) = D-glucono-1,5-lactone(aq) + H2O2(aq)
# 94KIS/TEW_1041
#  glucose oxidase
#  Î²-D-glucose(aq) + O2(aq) = D-glucono-1,5-lactone(aq) + H2O2(aq)
# 94KIS/TEW_1042
#  glucose oxidase and catalase
#  Î²-D-glucose(aq) + 1/2 O2(aq) = D-glucono-1,5-lactone(aq) + H2O(liq)
# nan
# nan
# nan
# nan
# 94KIS/TEW_1044
#  triacylglycerol lipase
#  n-decanoic acid glycerol diester(sln) + H2O(sln) = n-decanoic acid(sln) + n-decanoic acid glycerol monoester(sln)
# 94KIS/TEW_1045
#  triacylglycerol lipase
#  n-decanoic acid glycerol monoester(sln) + H2O(sln) = n-decanoic acid(sln) + glycerol(sln)
# nan
# nan
# nan
# nan
# nan
# nan
# 94LEU/COO_409
#  triacylglycerol lipase
#  n-decanoic acid glycerol triester(sln) + H2O(sln) = n-decanoic acid(sln) + n-decanoic acid glycerol diester(sln)
# 94NOE/COL_197
#  triacylglycerol lipase
#  n-octanoic acid glycerol diester(sln) + H2O(sln) = n-octanoic acid(sln) + n-octanoic acid glycerol monoester(sln)
# 94TEW/GOL_1139
#  triacylglycerol lipase
#  n-octanoic acid glycerol monoester(sln) + H2O(sln) = n-octanoic acid(sln) + glycerol(sln)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 94TEW/GOL_1140
#  triacylglycerol lipase
#  n-octanoic acid glycerol triester(sln) + H2O(sln) = n-octanoic acid(sln) + n-octanoic acid glycerol diester(sln)
# 95BIS/KRA_1027
#  triacylglycerol lipase
#  diolein(sln) + H2O(sln) = oleic acid(sln) + monoolein(sln)
# 95CHE/ARM_494
#  triacylglycerol lipase
#  monoolein(sln) + H2O(sln) = oleic acid(sln) + glycerol(sln)
# 95HUT/BOH_1001
#  triacylglycerol lipase
#  triolein(sln) + H2O(sln) = oleic acid(sln) + diolein(sln)
# nan
# nan
# nan
# nan
# nan
# nan
# 95HUT/BOH_995
#  adenosine deaminase
#  adenosine(aq) + H2O(l) = inosine(aq) + ammonia(aq)
# nan
# nan
# nan
# 95JUS/KOT_1002
#  AMP deaminase
#  AMP(aq) + H2O(l) = IMP(aq) + ammonia(aq)
# 95KAM/JUR_626
#  histidine ammonia-lyase
#  L-histidine(aq) = urocanate(aq) + ammonia(aq)
# 95KAM/JUR_657
#  histidine ammonia-lyase
#  L-histidine(aq) = urocanate(aq) + ammonia(aq)
# 95KOZ/TOM_1425
#  alkaline phosphatase
#  AMP(aq) + H2O(l) = adenosine(aq) + orthophosphate(aq)
# 95KOZ/TOM_1426
#  alkaline phosphatase
#  AMP(aq) + H2O(l) = adenosine(aq) + orthophosphate(aq)
# 95LEE/WAL_489
#  alkaline phosphatase
#  IMP(aq) + H2O(l) = inosine(aq) + orthophosphate(aq)
# 95LIA/WAN_331
#  alkaline phosphatase
#  IMP(aq) + H2O(l) = inosine(aq) + orthophosphate(aq)
# 95LIA/WAN2_1048
#  sinapate 1-glucosyltransferase
#  UDPglucose(aq) + sinapate(aq) = UDP(aq) + 1-sinapoyl-D-glucose(aq)
# 95LIU/ZEN_1049
#  2-arylpropionyl-CoA epimerase
#  (S)-2-(4-isobutylphenyl)propionyl-CoA(aq) =  (R)-2-(4-isobutylphenyl)propionyl-CoA(aq)
# 95LIU/ZEN_968
#  arginase
#  L-arginine(aq) + H2O(l) = L-ornithine(aq) + urea(aq)
# 95LIU/ZEN_976
#  arginine deiminase
#  L-arginine(aq) + H2O(l) = L-citrulline(aq) + ammonia(aq)
# 95SCH/TRA_581
#  maleate hydratase
#  (R)-malate(aq) = maleate(aq) + H2O(l)
# nan
# 95TEW/SCH_960
#  (R)-2-methylmalate dehydratase
#  (R)-2-methylmalate(aq) = 2-methylmaleate(aq) + H2O(l)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 95TEW/SCH_961
#  dimethylmaleate hydratase
#  (2R,3S)-2,3-dimethylmalate(aq) = dimethylmaleate(aq) + H2O(l)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 95WIS/KUS_610
#  glutathione transferase
#  glutathione(aq) + ethyl-(E)-2-octenoate(aq)= glutathione derivative of ethyl (E)-2-octenoate(aq)
# 95WIS/KUS_612
#  glutathione transferase
#  glutathione(aq) + methyl-(E)-2-octenoate(aq) = glutathione derivative of methyl (E)-2-octenoate(aq)
# 96ARA/RUZ_711
#  glutathione transferase
#  glutathione(aq) + (E)-3-nonen-2-one(aq) = glutathione derivative of (E)-3-nonen-2-one(aq)
# nan
# 96HIR/MAY_731
#  glutathione transferase
#  glutathione(aq) + (E)-2-octenal(aq) = glutathione derivative of (E)-2-octenal(aq)
# nan
# nan
# nan
# 96HIR/MAY_732
#  _-lactamase
#  ampicillin(aq) + H2O(l) = ampicillinoic acid(aq)
# nan
# nan
# nan
# 96HIR/MAY_733
#  _-lactamase
#  ampicillin(aq) + H2O(l) = ampicillinoic acid(aq)
# nan
# nan
# nan
# 96HIR/MAY_734
#  _-lactamase
#  penicillin G(aq) + H2O(l) = penicillinoic acid(aq)
# nan
# nan
# nan
# 96HIR/MAY_735
#  _-lactamase
#  penicillin G(aq) + H2O(l) = penicillinoic acid(aq)
# nan
# nan
# nan
# 96HIR/MAY_736
#  serine acetyltransferase
#  acetyl-CoA(aq) + L-serine(aq) = CoA(aq) + O-acetyl-L-serine(aq)
# nan
# nan
# nan
# 96LI/ZHA_668
#  mannitol dehydrogenase
#  D-mannitol(aq) + NADP(aq) = D-fructose(aq) + NADPH(aq)
# nan
# nan
# nan
# nan
# 96OES/SCH_1410
#  tryptophanase
#  L-tryptophan(aq) + H2O(l) = indole(aq) + pyruvate(aq) + ammonia(aq)
# 96OES/SCH_1412
#  tryptophanase
#  L-tryptophan(aq) + H2O(l) = indole(aq) + pyruvate(aq) + ammonia(aq)
# 96OES/SCH_1415
#  aminoacylase
#  N-acetyl-L-methionine(aq) + H2O(l) = L-methionine(aq) + acetate(aq)
# 96PRO/GRO_1258
#  glutathione transferase
#  reduced glutathione(aq) + (E)-4-phenyl-3-buten-2-one(aq) = 4-(glutathionyl)-4-phenyl-2-butanone(aq)
# 96TEW/GOL_60
#  urease
#  urea(aq) + 2 H2O(l) = 2 ammonia(aq) + carbon dioxide(aq)
# 96TEW/GOL_61
#  urease
#  ammonium carbamate(aq) + H2O(l) = 2 ammonia(aq) + carbon dioxide(aq)
# 96TEW/GOL_70
#  urease
#  urea(aq) + 2 H2O(l) = 2 ammonia(aq) + carbon dioxide(aq)
# 96TEW/GOL_71
#  taurocyamine kinase
#  ATP(aq) + taurocyamine(aq) = ADP(aq) + NÏ‰-phosphotaurocyamine(aq)
# 96TEW/GOL_73
#  adenylate kinase
#  2 ADP(aq) = AMP(aq) + ATP(aq)
# 96TEW/GOL_74
#  isochorismate synthase
#  chorismate(aq) = isochorismate(aq)
# 96TEW/SCH_749
#  isochorismate synthase
#  chorismate(aq) + ammonia(aq) = 2-amino-2-deoxyisochorismate(aq) + H2O(l)
# nan
# nan
# nan
# 96TEW/SCH_750
#  UDP-N-acetylglucosamine 1-carboxyvinyltransferase
#  (Z)-phosphoenolbutyrate(aq) + UDP-N-acetyl-D-glucosamine(aq) = orthophosphate(aq) + (Z)-enolbutyryl-UDP-N-acetylglucosamine(aq)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 96TEW/SCH_751
#  catalase
#  H2O2(aq) = 1/2 O2(aq) + H2O(l)
# nan
# 97CHA_622
#  arginase
#  L-arginine(aq) + H2O(l) = L-ornithine(aq) + urea(aq)
# 97CON/DEL_1320
#  arginase
#  L-arginine(aq) + H2O(l) = L-ornithine(aq) + urea(aq)
# nan
# nan
# nan
# nan
# 97DEJ/ROC_428
#  chymotrypsin
#  N-acetyl-L-tyrosine ethyl ester(aq) + H2O(l) = N-acetyl-L-tyrosine(aq) + ethanol(aq)
# nan
# 97HAN/KLE_208
#  chymotrypsin
#  2-propylhippurate(aq) + H2O(l) = 2-propanol(aq) + hippurate(aq)
# nan
# 97KAS/TEW_1423
#  phosphoglycerate kinase
#  ATP(aq) + 3-phospho-D-glycerate(aq) = ADP(aq) + 3-phospho-D-glyceroyl phosphate(aq)
# nan
# 97LIA/WU_332
#  a-chymotrypsin
#  N-acetyl-L-phenylalanine ethyl ester(sln) + H2O(sln) =  N-acetyl-L-phenylalanine(sln) + ethanol(sln)
# 97PES/PRI_878
#  chymotrypsin
#  N-acetyl-L-phenylalanine ethyl ester(aq) + H2O(l) =  N-acetyl-L-phenylalanine(aq) + ethanol(aq)
# 97PES/PRI_879
#  creatine kinase
#  phosphocreatine(aq) + cyclocreatine(aq) = creatine(aq) + phosphocyclocreatine(aq)
# 97PES/PRI_880
#  creatine kinase
#  phosphocreatine(aq) + Î²-guanidopropionate(aq) = creatine(aq) + Î²-phosphoguanidopropionate(aq)
# 97PES/PRI_884
#  UDPhexose synthase
# UDPglucose(aq) + imidazole(aq) = glucose 1-phosphate(aq) + UMPimidazole(aq)
# 97PES/PRI_885
#  triacyglycerol lipase
#  tributyrylglycerol(sln) + (R)-2-decanol(sln) = (R)-2-decyl butyrate(sln) + glycerol-1,2-dibutyrate(sln)
# 97PES/PRI_903
#  triacyglycerol lipase
#  tributyrylglycerol(sln) + (R)-2-dodecanol(sln) = (R)-2-dodecyl butyrate(sln) + glycerol-1,2-dibutyrate(sln)
# 97PES/PRI_904
#  triacyglycerol lipase
#  tributyrylglycerol(sln) + (R)-2-heptanol(sln) = (R)-2-heptyl butyrate(sln) + glycerol-1,2-dibutyrate(sln)
# 97PES/PRI_905
#  triacyglycerol lipase
#  tributyrylglycerol(sln) + (R)-2-nonanol(sln) = (R)-2-nonyl butyrate(sln) + glycerol-1,2-dibutyrate(sln)
# 97PES/PRI_906
#  triacyglycerol lipase
#  tributyrylglycerol(sln) + (R)-2-octanol(sln) = (R)-2-octyl butyrate(sln) + glycerol-1,2-dibutyrate(sln)
# 97PES/PRI_907
#  triacyglycerol lipase
#  tributyrylglycerol(sln) + (R)-2-undecanol(sln) = (R)-2-undecyl butyrate(sln) + glycerol-1,2-dibutyrate(sln)
# 97PES/PRI_908
#  guanylate kinase
#  ATP(aq) + GMP(aq) = ADP(aq) + GDP(aq)
# 97SAL/GOD_1123
#  _-phosphoglucomutase
#  Î²-D-glucose 1-phosphate(aq) = Î²-D-glucose 6-phosphate(aq)
# 97STA/SUA_1365
#  phosphomannomutase
#  Î²-D-glucose 1-phosphate(aq) = Î²-D-glucose 6-phosphate(aq)
# nan
# 97TEW/GOL_434
#  phosphomannomutase
#  D-mannose 1-phosphate(aq) = D-mannose 6-phosphate(aq)
# 97TEW/GOL_436
#  UDPglucose 4-epimerase
#  UDPglucose(aq) = UDPgalactose(aq)
# 97TEW/GOL_438
#  L-iditol 2-dehydrogenase
#  L-iditol(aq) + NAD(aq) = L-sorbose(aq) + NADH(aq)
# 97TEW/GOL_442
#  L-iditol 2-dehydrogenase
#  L-iditol(aq) + NAD(aq) = L-sorbose(aq) + NADH(aq)
# 97TEW/GOL_873
#  L-iditol 2-dehydrogenase
#  D-sorbitol(aq) + NAD(aq) = D-fructose(aq) + NADH(aq)
# 97TEW/GOL_874
#  L-iditol 2-dehydrogenase
#  D-sorbitol(aq) + NAD(aq) = D-fructose(aq) + NADH(aq)
# 97YOR/ISH_540
#  L-iditol 2-dehydrogenase
#  xylitol(aq) + NAD(aq) = D-xylulose(aq) + NADH(aq)
# 98DIE/STR_1004
#  L-iditol 2-dehydrogenase
#  xylitol(aq) + NAD(aq) = D-xylulose(aq) + NADH(aq)
# nan
# nan
# 98KIM/VOE_559
#  tannase
#  3,4,5-trihydroxybenzoic acid propyl ester(sln) + H2O(sln) = 3,4,5-trihydroxybenzoate(sln) + propan-1-ol(sln)
# 98KIS/TEW_1181
#  tannase
#  3,4,5-trihydroxybenzoic acid propyl ester(aq) + H2O(l) = 3,4,5-trihydroxybenzoate(aq) + propan-1-ol(aq)
# 98KIS/TEW_1182
#  tannase
#  3,4,5-trihydroxybenzoic acid propyl ester(aq) + H2O(l) = 3,4,5-trihydroxybenzoate(aq) + propan-1-ol(aq)
# 98KIS/TEW_1184
#  arginine kinase
#  ATP(aq) + L-arginine(aq) = ADP(aq) + NÏ‰-phospho-L-arginine(aq)
# 98KIS/TEW_1186
#  xylose isomerase
#  D-glucose(aq) = D-fructose(aq)
# 98KIS/TEW_1188
#  sucrose synthase
#  UDPglucose(aq) + D-fructose(aq) = UDP(aq) + sucrose(aq)
# 98KIS/TEW2_541
#  carnitine dehydrogenase
#  D-carnitine(aq) + NAD(aq) = 3-dehydrocarnitine(aq) + NADH(aq)
# nan
# nan
# nan
# nan
# 98LAE/EIS_1204
#  chorismate mutase
#  chorismate(aq) = prephenate(aq)
# 98LOV/LAU_857
#  catalase
#  H2O2(aq) = 1/2 O2(aq) + H2O(l)
# 98TEW/CHE_1138
#  glucan 1,4-a-glucosidase
#  6-O-Î±-D-galactopyranosyl-D-galactopyranose(aq) + H2O(l) = 2 D-galactose(aq)
# 98TEW/KIS_513
#  glucan 1,4-a-glucosidase
#  4-O-Î±-D-glucopyranosyl-D-fructofuranose(aq) + H2O(l) = D-glucose(aq) + D-fructose(aq)
# nan
# 98TEW/KIS_514
#  glucan 1,4-a-glucosidase
#  3-O-Î±-D-glucopyranosyl-lyxopyranose(aq) + H2O(l) = D-glucose(aq) + lyxose(aq)
# 98TEW/KIS_515
#  glucan 1,4-a-glucosidase
#  Î±-isomaltose(aq) + H2O(l) = 2 D-glucose(aq)
# nan
# 98TEW/KIS_516
#  glucan 1,4-a-glucosidase
#  Î²-isomaltose(aq) + H2O(l) = 2 D-glucose(aq)
# 98TEW/KIS_517
#  glucan 1,4-a-glucosidase
#  Î±-isomaltose(aq) + H2O(l) = 2 D-glucose(aq)
# nan
# 98TEW/KIS_518
#  glucan 1,4-a-glucosidase
#  Î²-isomaltose(aq) + H2O(l) = 2 D-glucose(aq)
# 98TEW_727
#  glucan 1,4-a-glucosidase
#  1-O-Î±-D-mannopyranosyl-D-mannofuranose(aq) + H2O(l) = 2 D-mannose(aq)
# nan
# nan
# nan
# nan
# 98THO/JOR_267
#  glucan 1,4-a-glucosidase
#  6-O-Î±-D-mannopyranose-D-mannopyranose(aq) + H2O(l) = 2 D-mannose(aq)
# 99HUT/OEH_944
#  glucan 1,4-a-glucosidase
#  Î±-D-melibiose(aq) + H2O(l) = D-galactose(aq) + D-glucose(aq)
# 99KIS/HOL_1199
#  glucan 1,4-a-glucosidase
#  Î²-D-melibiose(aq) + H2O(l) = D-galactose(aq) + D-glucose(aq)
# 99KIS/HOL_262
#  N-acetylneuraminate lyase
#  2-keto-3-deoxy-D-glycero-D-galacto-nonopyranulosonate(aq) = D-mannose(aq) + pyruvate(aq)
# 99KIS/TEW_988
#  glucose-6-phosphate isomerase
#  D-glucose 6-phosphate(aq) = D-fructose 6-phosphate(aq)
# 99KIS/TEW_992
#  cyclomaltodextrin glucanotransferase
#  Gu(aq) = cyclomaltohexaose(aq) + G(u-6)(aq)
# 99TEW/SCH_723
#  cyclomaltodextrin glucanotransferase
#  Gv(aq) = cyclomaltoheptaose(aq) + G(v-7)(aq)
# nan
# nan
# nan
# nan
# nan
# nan

# %% [markdown]
# The above scraping protocols were refined and consolidated. The final dataframe consists of the desired columns from all components of the NIST website and the static HTML file. A 30-second time delay was introduced to the end of each scraping loop, which theoretically allows the NIST server to recover and critically improves the accuracy of the scraped values to an acceptable threshold.

# %%
# Import Statements
from bs4 import BeautifulSoup
import requests #Pulling webpages
import pandas
import datetime
import numpy
import os
import re
import time
import math

# defining the website
root_url = "https://randr.nist.gov/enzyme/DataDetails.aspx?ID="
end_url = "&finalterm=&data=enzyme"
#===========================================================================================================================

# identify the table and rows of pertinent data
bs = BeautifulSoup(open('Enzyme Thermodynamic Database.html'), 'lxml')
table = bs.find("table", attrs = {'id': 'MainBody_gvSearch'})
body = table.find_all("tr")
#print(body[1])

# defining the boundaries of the dataframe section
index_range = 12000
index_count = 0
loop_count = 0 
output_loop = 1
lower_bound = 1 #math.floor(1*len(body)/50)
upper_bound = math.floor(1*len(body))

# loop through the enzyme id values 
name_iteration = 0
enzyme_iteration = 0
for row in range(lower_bound,upper_bound):   
    # parsing the reaction names and strings   
    enzyme_name = body[row].find('span', attrs = {'id': 'MainBody_gvSearch_lblEnzyme_%s' %(name_iteration)}).text
    reaction = body[row].find('span', attrs = {'id': 'MainBody_gvSearch_lblReaction_%s' %(name_iteration)}).text
    id_value = body[row].find("a").text
    name_iteration += 1
    
    # defining the soup
    total_url = root_url + id_value + end_url
    soup = requests.get(total_url).text
    bs = BeautifulSoup(soup, 'lxml')
    
    # scrape the table and header information
    tables1 = bs.find_all("table", attrs = {"id": "MainBody_extraData"})
    print(id_value, '\t: ', loop_count, '\t, ', len(tables1))
    if len(tables1) != 1:
        continue

    body1 = tables1[0].find_all("tr")
    body_rows1 = body1[1:]
    heads = body1[0]

    headings = ['Enzyme:', 'Reaction:']
    for head in heads.find_all("th"):
        head = (head.text).rstrip("\n")
        headings.append(head)
        
    #print(headings)

    total_rows = []
    for row_number in range(len(body_rows1)):
        each_row = [enzyme_name, reaction]
        for row_element in body_rows1[row_number].find_all("td"):
            row_refined = re.sub("(\xa0)|(\n)|,","",row_element.text)
            each_row.append(row_refined)
        total_rows.append(each_row)
        
    #print(total_rows)
    
    # create a dataframe
    index_list_body = range(index_count+lower_bound-1, len(body_rows1)+index_count+lower_bound-1)
    bs_dataframe_table1 = pandas.DataFrame(data = total_rows, columns = headings, index = index_list_body)
    bs_dataframe_table1.drop(bs_dataframe_table1.columns[len(bs_dataframe_table1.columns)-1], axis=1, inplace=True)
    '''display(bs_dataframe_table1)'''
    
#===========================================================================================================================

    # scrape additional information 
    tables = bs.find_all("table", attrs={"id": "MainBody_DataList1"})
    if len(tables) == 0:
        continue
    body2 = tables[0].find_all("tr")
    body_rows2 = body2[1:]

    each_row2 = []
    for row in range(len(body_rows2)):
        for row_element in body_rows2[row].find_all("td"):
            #print('row element: ', row_element)
            row_refined2 = re.sub("(\xa0)|(\n)|,","",row_element.text)
            #print('row refined', row_refined2)
            each_row2.append(row_refined2)

    information_entries_list = []
    information_values_list = []
    column_count = 0
    for i, element in enumerate(each_row2):
        if i == 0 or i % 2 == 0:
            information_entries_list.append(element)
            column_count += 1
        else:
            information_values_list.append(element)
            column_count += 1
    column_count /= 2

    # create the dataframe and refine the columns
    index_list_reference = range(index_count+lower_bound-1, index_count+1+lower_bound-1)
    bs_dataframe_pretable2 = pandas.DataFrame(data = [information_values_list], columns = information_entries_list, index = index_list_reference)
    bs_dataframe_pretable2.drop(bs_dataframe_pretable2.columns[len(bs_dataframe_pretable2.columns)-2], axis=1, inplace=True)
    bs_dataframe_pretable2.drop(bs_dataframe_pretable2.columns[len(bs_dataframe_pretable2.columns)-1], axis=1, inplace=True)
    '''display(bs_dataframe_pretable2)'''
    
#===========================================================================================================================

    # merge the dataframes of this loop
    this_dataframe = bs_dataframe_table1.join(bs_dataframe_pretable2)
    this_dataframe.index.name = 'index'
    
    # iteratively coalesce the new dataframe into the old dataframe 
    if loop_count == 0:
        old_dataframe = this_dataframe
        old_dataframe.index.name = 'index'
        
    elif loop_count > 0:
        these_columns = []
        for column in this_dataframe:
            these_columns.append(column)
            
        old_columns = []
        for existing_column in old_dataframe:
            old_columns.append(existing_column)
            
        common_columns = list(set(these_columns).intersection(old_columns))
        
        # amalgamate the dataframe with the pre-existing dataframe
        current_dataframe = old_dataframe.merge(this_dataframe, on = common_columns, how = 'outer')
        old_dataframe = current_dataframe  
        
    # amalgamate the dataframe with the pre-existing dataframe
    index_count += len(body_rows1)
    
    time_delay = 0
    time.sleep(time_delay)
    
    max_referenes_per_csv = 0
    if loop_count == max_referenes_per_csv:
        id_value = re.sub('(/)', '-', id_value)
        output = './individual scraping/{}, {}.csv'.format(datetime.date.today(), id_value, output_loop)
        while os.path.exists(output):
            output_loop += 1
            output = './individual scraping/2021-05-06_{}.csv'.format(datetime.date.today(), id_value, output_loop)
            
        old_dataframe.to_csv(output)
        
        loop_count = 0 
        
    else:        
        loop_count += 1
# Out:
# 26QUA/WOO_1205 	:  0 	,  1
# 29WOO_1206 	:  0 	,  1
# 31BOR/SCH_1141 	:  0 	,  1
# 34JAC_1142 	:  0 	,  1
# 34LOH/MEY_1169 	:  0 	,  1
# 34MEY/LOH_1100 	:  0 	,  1
# 34MEY/LOH_1288 	:  0 	,  1
# 35AKA_1170 	:  0 	,  1
# 35JAC/TAP_1207 	:  0 	,  1
# 35MEY/KIE_1385 	:  0 	,  1
# 35MEY/KIE2_1386 	:  0 	,  1
# 35MEY/LOH_1102 	:  0 	,  1
# 35MEY/LOH_1290 	:  0 	,  1
# 35MEY/SCH_797 	:  0 	,  1
# 35MEY/SCH_798 	:  0 	,  1
# 35MEY/SCH_802 	:  0 	,  1
# 35MEY/SCH_805 	:  0 	,  1
# 35MEY_1101 	:  0 	,  1
# 35MEY_1289 	:  0 	,  1
# 36EUL/ADL_7 	:  0 	,  1
# 36LEH_589 	:  0 	,  1
# 36LEH_614 	:  0 	,  1
# 36MEY/LOH_1099 	:  0 	,  1
# 36MEY/SCH_1096 	:  0 	,  1
# 36VEI_914 	:  0 	,  1
# 36VEI_915 	:  0 	,  1
# 36VEI_917 	:  0 	,  1
# 36VEI_922 	:  0 	,  1
# 36VEI_923 	:  0 	,  1
# 36VEI_924 	:  0 	,  1
# 36VEI_925 	:  0 	,  1
# 36VEI_926 	:  0 	,  1
# 37ADL/SRE_8 	:  0 	,  1
# 37EUL/ADL_127 	:  0 	,  1
# 37EUL/ADL_95 	:  0 	,  1
# 37EUL/ADL2_42 	:  0 	,  1
# 37EUL/ADL3_96 	:  0 	,  1
# 37NEG/WUL_9 	:  0 	,  1
# 38EUL/ADL_273 	:  0 	,  1
# 38MEY/SCH_1387 	:  0 	,  1
# 38SCH/HEL_10 	:  0 	,  1
# 38SCH/HEL_23 	:  0 	,  1
# 39COH_504 	:  0 	,  1
# 40COH_495 	:  0 	,  1
# 40HER/GOR_1090 	:  0 	,  1
# 40KRE/SMY_1143 	:  0 	,  1
# 41UTT/WER_1103 	:  0 	,  1
# 41UTT/WER_1291 	:  0 	,  1
# 41WAR/CHR_1171 	:  0 	,  1
# 42COL/SUT_1401 	:  0 	,  1
# 42LEN/STR_505 	:  0 	,  1
# 43BAN_590 	:  0 	,  1
# 43DOU_415 	:  0 	,  1
# 43KAL_633 	:  0 	,  1
# 43KRE/EGG_1156 	:  0 	,  1
# 43KRE/EGG_1159 	:  0 	,  1
# 43KRE/EGG_1162 	:  0 	,  1
# 43KUB/OTT_97 	:  0 	,  1
# 43MEY/JUN_1091 	:  0 	,  1
# 43MEY/JUN_1104 	:  0 	,  1
# 43MEY/JUN_1281 	:  0 	,  1
# 43MEY/JUN_1292 	:  0 	,  1
# 44LIP_572 	:  0 	,  1
# 45DAR_496 	:  0 	,  1
# 45DAR_506 	:  0 	,  1
# 45DRA/MEY_250 	:  0 	,  1
# 45GRE/LEL_497 	:  0 	,  1
# 45GRE/LEL_507 	:  0 	,  1
# 45OHL_1144 	:  0 	,  1
# 45OHL_816 	:  0 	,  1
# 45OHL_817 	:  0 	,  1
# 45OHL_822 	:  0 	,  1
# 46OHL_823 	:  0 	,  1
# 47BUC_578 	:  0 	,  1
# 47MEY/OES_1282 	:  0 	,  1
# 47MEY/OES_251 	:  0 	,  1
# 48KOR_676 	:  0 	,  1
# 48OCH_152 	:  0 	,  1
# 48SCO/POW_1145 	:  0 	,  1
# 48SOR/DEG_591 	:  0 	,  1
# 49BAR_43 	:  0 	,  1
# 49HES_743 	:  0 	,  1
# 49MEY/GRE_762 	:  0 	,  1
# 49MEY/GRE_763 	:  0 	,  1
# 49MEY/GRE_764 	:  0 	,  1
# 49MEY/GRE_765 	:  0 	,  1
# 49MEY/GRE_768 	:  0 	,  1
# 49MEY/GRE_770 	:  0 	,  1
# 49MEY/GRE_778 	:  0 	,  1
# 49MEY/GRE_786 	:  0 	,  1
# 49MEY/GRE_818 	:  0 	,  1
# 49MEY/GRE_819 	:  0 	,  1
# 49MEY/GRE_820 	:  0 	,  1
# 49MEY/GRE_821 	:  0 	,  1
# 49MEY/GRE_824 	:  0 	,  1
# 49MEY/OES_1172 	:  0 	,  1
# 49MEY/OES_1388 	:  0 	,  1
# 49MEY/OES_563 	:  0 	,  1
# 49SOR/DVO_615 	:  0 	,  1
# 50COR/VEL_252 	:  0 	,  1
# 50FRI_456 	:  0 	,  1
# 50HES_744 	:  0 	,  1
# 50HES_748 	:  0 	,  1
# 50KOR_677 	:  0 	,  1
# 50OES/MEY_1283 	:  0 	,  1
# 50PAZ_433 	:  0 	,  1
# 50PAZ_435 	:  0 	,  1
# 50PAZ_437 	:  0 	,  1
# 50RAC_11 	:  0 	,  1
# 50RAC_98 	:  0 	,  1
# 50SLE_1345 	:  0 	,  1

# %%
# import libraries
import pandas
import numpy
import glob
import os

#path_original = "./sabio_scraped/"
path = './individual scraping/'
files = glob.glob(os.path.join(path, '*.csv'))

# create the total list of dataframes
total_dataframes = []
'''for file in original_files:
    file_name = os.path.splitext(os.path.basename(file))[0]
    dfn = pandas.read_excel(file)
    total_dataframes.append(dfn)'''
for file in files:
    file_name = os.path.splitext(os.path.basename(file))[0]
    dfn = pandas.read_excel(file)
    total_dataframes.append(dfn)
    
# combine the total set of dataframes
combined_df = pandas.DataFrame()
combined_df = pandas.concat(total_dataframes)
display(combined_df)

# replace the NaN values with blank spaces
combined_df = combined_df.fillna(' ')
'''numpy_array = combined_df.to_numpy()
cleaned_array = numpy.nan_to_num(numpy_array, False, '')
display(cleaned_array)'''

# export the dataframe
combined_df.to_csv('{}_concatenated scraped NIST enzymes_03.csv'.format(datetime.date.today()))

'''total_columns = []
for column in combined_df:
    total_columns.append(column)
    print(column)
print(len(total_columns))'''
