# %% [markdown]
# # Consolidating the NIST Keq data

# %% [markdown]
# The Keqs of the NIST CSV file are condensed into a JSON file. The Keq values are complemented in the JSON with the experimental temperatures and pH values that will guide user selection of the appropriate Keq value to describe the system. The values are respectively listed with the references to facilitate verification of the reference source for each provided datum. The JSON may readily be imported to a Python scripted and used in calculations or model development.

# %%
#import libraries
import pandas
import numpy
import math
import json
import re

#import the final CSV file
final_csv = pandas.read_csv('2021-05-06_vetted & reorganized NIST database_01.csv')

#acquire a list of all enzymes
enzyme_list = []
empty_cell = ['nan', 'NaN', 'none', 'not given', '', ' ', None, numpy.nan]
for index, row in final_csv.iterrows():
    if final_csv.at[index, 'Enzyme:'] not in enzyme_list and final_csv.at[index, 'Enzyme:'] not in empty_cell:
        enzyme_list.append(final_csv.at[index, 'Enzyme:'])      
        
enzymes = []
for original_enzyme in enzyme_list:
    enzyme_name = re.search('(\w.*)',original_enzyme)
    enzymes.append(enzyme_name.group())

data_per_enzyme = {}
for enzyme in enzymes:
    # lists of the database varialbes
    keq_values_per_enzyme = []
    km_values_per_enzyme = []
    enthalpy_values_per_enzyme = []
    temperatures_per_enzyme = []
    phs_per_enzyme = []
    
    # lists of identifying whether the reference contains the identified variable 
    references_of_an_enzyme = []
    reaction_of_an_enzyme = []
    km_in_the_reference = []
    enthalpy_in_the_reference = []
    keqs_in_a_reference = []
    for index, row in final_csv.iterrows():
        iteration = 0
        if final_csv.at[index, 'Enzyme:'] == ' %s' %(enzyme):
            reaction_of_an_enzyme.append(final_csv.at[index, 'Reaction:'])
            if final_csv.at[index, 'Reference:'] not in empty_cell:
                references_of_an_enzyme.append(final_csv.at[index, 'Reference:'])
            elif final_csv.at[index, 'Reference:'] in empty_cell:
                references_of_an_enzyme.append('Ibid')
            
            # clean keqs are added to a list
            if final_csv.at[index, 'Keq'] not in empty_cell:
                #print(final_csv.at[index, 'Keq'])
                cleaned_keq = re.search('(\-?\d+\.?\d*)', '%s' %(final_csv.at[index, 'Keq']))
                #print(cleaned_keq.group())
                keq_values_per_enzyme.append(float(cleaned_keq.group())) 
                keqs_in_a_reference.append('True')
                temperatures_per_enzyme.append(final_csv.at[index, 'T [K]'])
                if final_csv.at[index, 'pH '] not in empty_cell:
                    phs_per_enzyme.append(final_csv.at[index, 'pH '])
                elif final_csv.at[index, 'pH '] in empty_cell:
                    phs_per_enzyme.append('nan')
            
            elif final_csv.at[index, 'Keq'] in empty_cell:
                keqs_in_a_reference.append('False')    
                
            # clean kms are added to a list
            if final_csv.at[index, 'Km'] not in empty_cell:
                #print(final_csv.at[index, 'Km\'])
                cleaned_km = re.search('(\-?\d+\.?\d*)', '%s' %(final_csv.at[index, 'Km']))
                #print(cleaned_km.group())
                km_values_per_enzyme.append(float(cleaned_km.group())) 
                if final_csv.at[index, 'Keq'] in empty_cell:
                    temperatures_per_enzyme.append(final_csv.at[index, 'T [K]'])
                    if final_csv.at[index, 'pH '] not in empty_cell:
                        phs_per_enzyme.append(final_csv.at[index, 'pH '])
                    elif final_csv.at[index, 'pH '] in empty_cell:
                        phs_per_enzyme.append('nan')
                    
            elif final_csv.at[index, 'Km'] in empty_cell:
                km_in_the_reference.append('False')
                
            # clean enthalpy values are added to a list
            if final_csv.at[index, 'Enthalpy [kJ / mol]'] not in empty_cell:
                #print(final_csv.at[index, 'Km\'])
                cleaned_enthalpy = re.search('(\-?\d+\.?\d*)', '%s' %(final_csv.at[index, 'Enthalpy [kJ / mol]']))
                #print(cleaned_km.group())
                enthalpy_in_the_reference.append('True')
                enthalpy_values_per_enzyme.append(float(cleaned_enthalpy.group())) 
                if final_csv.at[index, 'Keq'] in empty_cell and final_csv.at[index, 'Km'] in empty_cell:
                    temperatures_per_enzyme.append(final_csv.at[index, 'T [K]'])
                    if final_csv.at[index, 'pH '] not in empty_cell:
                        phs_per_enzyme.append(final_csv.at[index, 'pH '])
                    elif final_csv.at[index, 'pH '] in empty_cell:
                        phs_per_enzyme.append('nan')
                    
            elif final_csv.at[index, 'Enthalpy [kJ / mol]'] in empty_cell:
                enthalpy_in_the_reference.append('False')
                
                
            #loop through the unlabeled rows of each enzyme
            while final_csv.at[index + iteration, 'Enzyme:'] in empty_cell:
                if final_csv.at[index, 'Keq'] not in empty_cell:
                    #clean keqs are added to a list
                    cleaned_keq = re.search('(\-?\d+\.?\d*)', '%s' %(final_csv.at[index, 'Keq']))
                    #print(cleaned_keq)
                    keq_values_per_enzyme.append(float(cleaned_keq.group())) 
                    keqs_in_a_reference.append('True')
                    temperatures_per_enzyme.append(final_csv.at[index, 'T [K]'])
                    if final_csv.at[index, 'pH '] not in empty_cell:
                        phs_per_enzyme.append(final_csv.at[index, 'pH '])
                    elif final_csv.at[index, 'pH '] in empty_cell:
                        phs_per_enzyme.append('nan')

                elif final_csv.at[index, 'Keq'] in empty_cell:
                    keqs_in_a_reference.append('False')  
                    
                #clean kms are added to a list
                if final_csv.at[index, 'Km'] not in empty_cell:
                    #print(final_csv.at[index, 'Km\'])
                    cleaned_km = re.search('(\-?\d+\.?\d*)', '%s' %(final_csv.at[index, 'Km']))
                    #print(cleaned_km.group())
                    km_in_a_reference.append('True')
                    km_values_per_enzyme.append(float(cleaned_km.group())) 
                    if final_csv.at[index, 'Keq'] in empty_cell:
                        temperatures_per_enzyme.append(final_csv.at[index, 'T [K]'])
                        if final_csv.at[index, 'pH '] not in empty_cell:
                            phs_per_enzyme.append(final_csv.at[index, 'pH '])
                        elif final_csv.at[index, 'pH '] in empty_cell:
                            phs_per_enzyme.append('nan')

                elif final_csv.at[index, 'Km'] in empty_cell:
                    km_in_the_reference.append('False')
                    
                # clean enthalpy values are added to a list
                if final_csv.at[index, 'Enthalpy [kJ / mol]'] not in empty_cell:
                    #print(final_csv.at[index, 'Km\'])
                    cleaned_ethalpy = re.search('(\-?\d+\.?\d*)', '%s' %(final_csv.at[index, 'Enthalpy [kJ / mol]']))
                    #print(cleaned_km.group())
                    enthalpy_in_the_reference.append('True')
                    enthalpy_values_per_enzyme.append(float(cleaned_enthalpy.group())) 
                    if final_csv.at[index, 'Keq'] in empty_cell and final_csv.at[index, 'Km'] in empty_cell:
                        temperatures_per_enzyme.append(final_csv.at[index, 'T [K]'])
                        if final_csv.at[index, 'pH '] not in empty_cell:
                            phs_per_enzyme.append(final_csv.at[index, 'pH '])
                        elif final_csv.at[index, 'pH '] in empty_cell:
                            phs_per_enzyme.append('nan')

                elif final_csv.at[index, 'Enthalpy [kJ / mol]'] in empty_cell:
                    enthalpy_in_the_reference.append('False')
                    
                    
                #proceed to the next loop
                if iteration + index < 3979:
                    iteration += 1

    #processing the average and standard deviation Keq values
    if len(keq_values_per_enzyme) != 0:
        average_keq_per_enzyme = sum(keq_values_per_enzyme) / len(keq_values_per_enzyme)
        standard_deviation_keq_per_enzyme = math.sqrt(sum([(x - average_keq_per_enzyme)**2 for x in keq_values_per_enzyme]) / len(keq_values_per_enzyme))

    elif len(keq_values_per_enzyme) == 0:
        average_keq_per_enzyme = 'nan'
        standard_deviation_keq_per_enzyme = 'nan'
        
    #processing the average and standard deviation Km values
    if len(km_values_per_enzyme) != 0:
        average_km_per_enzyme = sum(km_values_per_enzyme) / len(km_values_per_enzyme)
        standard_deviation_km_per_enzyme = math.sqrt(sum([(x - average_km_per_enzyme)**2 for x in km_values_per_enzyme]) / len(km_values_per_enzyme))

    elif len(km_values_per_enzyme) == 0:
        average_km_per_enzyme = 'nan'
        standard_deviation_km_per_enzyme = 'nan' 
        
    #processing the average and standard deviation enthalpy values
    if len(enthalpy_values_per_enzyme) != 0:
        average_enthalpy_per_enzyme = sum(enthalpy_values_per_enzyme) / len(enthalpy_values_per_enzyme)
        standard_deviation_enthalpy_per_enzyme = math.sqrt(sum([(x - average_enthalpy_per_enzyme)**2 for x in enthalpy_values_per_enzyme]) / len(enthalpy_values_per_enzyme))

    elif len(enthalpy_values_per_enzyme) == 0:
        average_enthalpy_per_enzyme = 'nan'
        standard_deviation_enthalpy_per_enzyme = 'nan' 
        
        
    #store the information into a nested dictionary structure
    data_per_enzyme[enzyme] = {'reaction':reaction_of_an_enzyme,
                               'experimental temperatures':temperatures_per_enzyme,
                               'experimental phs':phs_per_enzyme,
                               'keq reference':references_of_an_enzyme,
                               'Keq':{'keq values in the reference':keqs_in_a_reference,
                                       'keqs':keq_values_per_enzyme, 
                                       'keq quantity':len(keq_values_per_enzyme), 
                                       'keq average':average_keq_per_enzyme, 
                                       'keq standard deviation':standard_deviation_keq_per_enzyme},
                               'Km':{'km values in the reference':km_in_the_reference,
                                    'km values':km_values_per_enzyme,
                                    'km average':average_km_per_enzyme,
                                    'km standard deviation':standard_deviation_km_per_enzyme},
                               'Enthalpy':{'enthalpy values in the reference':enthalpy_in_the_reference,
                                         'enthalpy values':enthalpy_values_per_enzyme,
                                         'enthalpy average':average_enthalpy_per_enzyme,
                                         'enthalpy standard deviation':standard_deviation_enthalpy_per_enzyme}
                              }


#export the dictionary as a JSON file
with open('2021-05-06_NIST consolidated.json', 'w') as output:
    json.dump(data_per_enzyme, output, indent = 4)

# %%
import pandas
import numpy

old = pandas.read_csv('2021-03-21_vetted + reorganized NIST_1.csv')
new = pandas.read_csv('2021-05-06_vetted & reorganized NIST database_01.csv')

empty_cell = ['nan', 'NaN', 'none', 'not given', '', ' ', None, numpy.nan]

# match the indexes for the reference IDs
reference_ids = {}
old_ids = old['Reference ID:'].tolist()
new_ids = new['Reference ID:'].tolist()
for id in old_ids:
    if id in empty_cell:
        continue
    old_id = old_ids.index(id)
    new_id = new_ids.index(id)
    reference_ids[id] = {'Old index': old_id,
                         'New index': new_id}

for id in reference_ids:
    print('\n')
    valid = True
    old_index = reference_ids[id]['Old index']
    new_index = reference_ids[id]['New index']
    '''display(old.iloc[old_index])
    display(new.iloc[new_index])'''
    while valid:
        '''if old.at[old_index, 'Enzyme'] != new.at[new_index, 'Enzyme:']:
            if old.at[old_index, 'Enzyme'] not in empty_cell:
                print('Old enzyme, index {}:'.format(old_index), old.at[old_index, 'Enzyme'])
                print('New enzyme, index {}:'.format(new_index), new.at[new_index, 'Enzyme:'])
                valid = False
        
        if old.at[old_index, 'Reaction'] != new.at[new_index, 'Reaction:']:
            if old.at[old_index, 'Reaction'] not in empty_cell:
                print('Old reaction, index {}:'.format(old_index), old.at[old_index, 'Reaction'])
                print('New reaction, index {}:'.format(new_index), new.at[new_index, 'Reaction:'])
                valid = False'''
        
        if old.at[old_index, 'T [K]'] != new.at[new_index, 'T [K]']:
            if old.at[old_index, 'T [K]'] not in empty_cell:
                print('Old temperature, index {}:'.format(old_index), old.at[old_index, 'T [K]'])
                print('New temperature, index {}:'.format(new_index), new.at[new_index, 'T [K]'])
                valid = False
        
        if old.at[old_index, 'Keq'] != new.at[new_index, 'Keq']:
            if old.at[old_index, 'Keq'] not in empty_cell:
                print('Old Keq, index {}:'.format(old_index), old.at[old_index, 'Keq'])
                print('New Keq, index {}:'.format(new_index), new.at[new_index, 'Keq'])
                valid = False
        
        if old.at[old_index, 'Enthalpy [kJ / mol]'] != new.at[new_index, 'Enthalpy [kJ / mol]']:
            if old.at[old_index, 'Enthalpy [kJ / mol]'] not in empty_cell:
                print('Old enthalpy, index {}:'.format(old_index), old.at[old_index, 'Enthalpy [kJ / mol]'])
                print('New enthalpy, index {}:'.format(new_index), new.at[new_index, 'Enthalpy [kJ / mol]'])
                valid = False
        
        if old.at[old_index, 'Km'] != new.at[new_index, 'Km']:
            if old.at[old_index, 'Km'] not in empty_cell:
                print('Old Km, index {}:'.format(old_index), old.at[old_index, 'Km'])
                print('New Km, index {}:'.format(new_index), new.at[new_index, 'Km'])
                valid = False
            
        if old.at[old_index, 'pH '] != new.at[new_index, 'pH ']:
            if old.at[old_index, 'pH '] not in empty_cell:
                print('Old pH, index {}:'.format(old_index), old.at[old_index, 'pH '])
                print('New pH, index {}:'.format(new_index), new.at[new_index, 'pH '])
                valid = False
        
        old_index += 1
        new_index += 1
    
    try:
        if re.search('(\d\d\w+.?\w+)', old.at[old_index, 'Reference ID:']):   
            print('{} is equivalent.'.format(id))
            
        elif not re.search('(\d\d\w+.?\w+)', old.at[old_index, 'Reference ID:']):   
            print('{} is different.'.format(id))
    
    except:
        print('ERROR\n', '='*len('ERROR'))
        print('Old Reference ID {}, index {}:'.format(id, old_index),old.at[old_index, 'Reference ID:'])
        
    '''for index, row in old.iterrows():
        if id == old.at[index, row['Reference ID:']]: 
            for index2, row2 in new.iterrows():
                while old.at[index, row] == new.at[index2, row2]:'''
# Out:
# Old temperature, index 18: 301.15
# New temperature, index 18: 266.15
# Old Keq, index 18: 2.3
# New Keq, index 18: 0.00018
# 26QUA/WOO_1205 is equivalent.
#
#
# Old temperature, index 18: 301.15
# New temperature, index 18: 266.15
# Old Keq, index 18: 2.3
# New Keq, index 18: 0.00018
# 29WOO_1206 is equivalent.
#
#
# Old temperature, index 18: 301.15
# New temperature, index 18: 266.15
# Old Keq, index 18: 2.3
# New Keq, index 18: 0.00018
# 31BOR/SCH_1141 is equivalent.
#
#
# Old temperature, index 18: 301.15
# New temperature, index 18: 266.15
# Old Keq, index 18: 2.3
# New Keq, index 18: 0.00018
# 34JAC_1142 is equivalent.
#
#
# Old temperature, index 18: 301.15
# New temperature, index 18: 266.15
# Old Keq, index 18: 2.3
# New Keq, index 18: 0.00018
# 34LOH/MEY_1169 is equivalent.
#
#
# Old temperature, index 18: 301.15
# New temperature, index 18: 266.15
# Old Keq, index 18: 2.3
# New Keq, index 18: 0.00018
# 34MEY/LOH_1100 is equivalent.
#
#
# Old pH, index 19: 7
# New pH, index 24: 7.0
# ERROR
#  =====
# Old Reference ID 35AKA_1170, index 20: nan
#
#
# Old pH, index 19: 7
# New pH, index 24: 7.0
# ERROR
#  =====
# Old Reference ID 35JAC/TAP_1207, index 20: nan
#
#
# Old temperature, index 25: 301.15
# New temperature, index 31: 293.15
# Old Keq, index 25: 4
# New Keq, index 31:
# 35MEY/KIE_1385 is equivalent.
#
#
# Old Keq, index 25: 4
# New Keq, index 26: 4.0
# 35MEY/KIE2_1386 is equivalent.
#
#
# Old enthalpy, index 28: -31
# New enthalpy, index 33: 58
# 35MEY/LOH_1102 is equivalent.
#
#
# Old enthalpy, index 28: -31
# New enthalpy, index 35: -31.0
# 35MEY/SCH_797 is equivalent.
#
#
# Old Keq, index 33: 0.000071
# New Keq, index 40: 7.1e-05
# ERROR
#  =====
# Old Reference ID 35MEY/SCH_798, index 34: nan
#
#
# Old Keq, index 33: 0.000071
# New Keq, index 40: 7.1e-05
# ERROR
#  =====
# Old Reference ID 35MEY/SCH_802, index 34: nan
#
#
# Old Keq, index 33: 0.000071
# New Keq, index 40: 7.1e-05
# ERROR
#  =====
# Old Reference ID 35MEY/SCH_805, index 34: nan
#
#
# Old Keq, index 33: 0.000071
# New Keq, index 40: 7.1e-05
# ERROR
#  =====
# Old Reference ID 35MEY_1101, index 34: nan
#
#
# Old Keq, index 61: 1.30E-05
# New Keq, index 97: 1.3e-05
# ERROR
#  =====
# Old Reference ID 36EUL/ADL_7, index 62: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36LEH_589, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36LEH_614, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36MEY/LOH_1099, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36MEY/SCH_1096, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36VEI_914, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36VEI_915, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36VEI_917, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36VEI_922, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36VEI_923, index 82: nan
#
#
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# ERROR
#  =====
# Old Reference ID 36VEI_924, index 82: nan
#
#
# Old Keq, index 85: 19
# New Keq, index 121: 19.0
# ERROR
#  =====
# Old Reference ID 36VEI_925, index 86: nan
#
#
# Old Keq, index 85: 19
# New Keq, index 121: 19.0
# ERROR
#  =====
# Old Reference ID 36VEI_926, index 86: nan
#
#
# Old Keq, index 87: 6.00E-06
# New Keq, index 123: 6e-06
# ERROR
#  =====
# Old Reference ID 37ADL/SRE_8, index 88: nan
#
#
# Old Keq, index 90: 2.30E-05
# New Keq, index 138: 2.3e-05
# ERROR
#  =====
# Old Reference ID 37EUL/ADL_127, index 91: nan
#
#
# Old Keq, index 97: 7.70E-05
# New Keq, index 145: 7.7e-05
# ERROR
#  =====
# Old Reference ID 37EUL/ADL_95, index 98: nan
#
#
# Old Keq, index 104: 1.60E-05
# New Keq, index 126: 1.6e-05
# ERROR
#  =====
# Old Reference ID 37EUL/ADL2_42, index 105: nan
#
#
# Old Keq, index 107: 7.10E-06
# New Keq, index 129: 7.1e-06
# ERROR
#  =====
# Old Reference ID 37EUL/ADL3_96, index 108: nan
#
#
# Old Keq, index 117: 3.90E-11
# New Keq, index 152: 3.9e-11
# ERROR
#  =====
# Old Reference ID 37NEG/WUL_9, index 118: nan
#
#
# Old Keq, index 117: 3.90E-11
# New Keq, index 152: 3.9e-11
# ERROR
#  =====
# Old Reference ID 38EUL/ADL_273, index 118: nan
#
#
# Old Keq, index 136: 2.60E-05
# New Keq, index 171: 2.6e-05
# ERROR
#  =====
# Old Reference ID 38MEY/SCH_1387, index 137: nan
#
#
# Old Keq, index 136: 2.60E-05
# New Keq, index 171: 2.6e-05
# ERROR
#  =====
# Old Reference ID 38SCH/HEL_10, index 137: nan
#
#
# Old Keq, index 142: 9.10E-06
# New Keq, index 178: 9.1e-06
# ERROR
#  =====
# Old Reference ID 38SCH/HEL_23, index 143: nan
#
#
# Old Keq, index 151: 6.00E-05
# New Keq, index 187: 6e-05
# ERROR
#  =====
# Old Reference ID 39COH_504, index 152: nan
#
#
# Old Keq, index 151: 6.00E-05
# New Keq, index 187: 6e-05
# ERROR
#  =====
# Old Reference ID 40COH_495, index 152: nan
#
#
# Old Keq, index 151: 6.00E-05
# New Keq, index 187: 6e-05
# ERROR
#  =====
# Old Reference ID 40HER/GOR_1090, index 152: nan
#
#
# Old pH, index 159: 9
# New pH, index 195: 9.0
# ERROR
#  =====
# Old Reference ID 40KRE/SMY_1143, index 160: nan
#
#
# Old pH, index 159: 9
# New pH, index 195: 9.0
# ERROR
#  =====
# Old Reference ID 41UTT/WER_1103, index 160: nan
#
#
# Old pH, index 162: 9
# New pH, index 198: 9.0
# 41UTT/WER_1291 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 41WAR/CHR_1171 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 42COL/SUT_1401 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 42LEN/STR_505 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43BAN_590 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43DOU_415 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43KAL_633 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43KRE/EGG_1156 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43KRE/EGG_1159 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43KRE/EGG_1162 is equivalent.
#
#
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# 43KUB/OTT_97 is equivalent.
#
#
# Old Keq, index 184: 8.00E-05
# New Keq, index 222: 8e-05
# ERROR
#  =====
# Old Reference ID 43MEY/JUN_1091, index 185: nan
#
#
# Old pH, index 192: 7
# New pH, index 230: 7.0
# ERROR
#  =====
# Old Reference ID 43MEY/JUN_1104, index 193: nan
#
#
# Old pH, index 192: 7
# New pH, index 230: 7.0
# ERROR
#  =====
# Old Reference ID 43MEY/JUN_1281, index 193: nan
#
#
# Old Keq, index 195: 5.60E-03
# New Keq, index 237: 0.0056
# 44LIP_572 is equivalent.
#
#
# Old pH, index 200: 8
# New pH, index 242: 8.0
# ERROR
#  =====
# Old Reference ID 45DAR_496, index 201: nan
#
#
# Old pH, index 200: 8
# New pH, index 242: 8.0
# ERROR
#  =====
# Old Reference ID 45DAR_506, index 201: nan
#
#
# Old pH, index 200: 8
# New pH, index 242: 8.0
# ERROR
#  =====
# Old Reference ID 45DRA/MEY_250, index 201: nan
#
#
# Old Keq, index 203: 1
# New Keq, index 245: 1.0
# 45GRE/LEL_497 is equivalent.
#
#
# Old Keq, index 203: 1
# New Keq, index 245: 1.0
# 45GRE/LEL_507 is equivalent.
#
#
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# 45OHL_1144 is equivalent.
#
#
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# 45OHL_816 is equivalent.
#
#
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# 45OHL_817 is equivalent.
#
#
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# 45OHL_822 is equivalent.
#
#
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# 46OHL_823 is equivalent.
#
#
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# 47BUC_578 is equivalent.
#
#
# Old pH, index 213: 8
# New pH, index 255: 8.0
# 47MEY/OES_1282 is equivalent.
#
#
# Old pH, index 214: 6
# New pH, index 256: 6.0
# ERROR
#  =====
# Old Reference ID 47MEY/OES_251, index 215: nan
#
#
# Old temperature, index 224: 303
# New temperature, index 266: 303.0
# ERROR
#  =====
# Old Reference ID 48KOR_676, index 225: nan
#
#
# Old temperature, index 224: 303
# New temperature, index 266: 303.0
# ERROR
#  =====
# Old Reference ID 48OCH_152, index 225: nan
#
#
# Old temperature, index 224: 303
# New temperature, index 266: 303.0
# ERROR
#  =====
# Old Reference ID 48SCO/POW_1145, index 225: nan
#
#
# Old Keq, index 233: 0.15
# New Keq, index 275: 0.29
# ERROR
#  =====
# Old Reference ID 48SOR/DEG_591, index 234: nan
#
#
# Old Keq, index 248: 7.10E-05
# New Keq, index 290: 7.1e-05
# Old pH, index 248: 7
# New pH, index 290: 7.0
# 49BAR_43 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49HES_743 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_762 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_763 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_764 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_765 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_768 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_770 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_778 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_786 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_818 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_819 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_820 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_821 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/GRE_824 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/OES_1172 is equivalent.
#
#
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
# 49MEY/OES_1388 is equivalent.
#
#
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# ERROR
#  =====
# Old Reference ID 49MEY/OES_563, index 276: nan
#
#
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# ERROR
#  =====
# Old Reference ID 49SOR/DVO_615, index 276: nan
#
#
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# ERROR
#  =====
# Old Reference ID 50COR/VEL_252, index 276: nan
#
#
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# ERROR
#  =====
# Old Reference ID 50FRI_456, index 276: nan
#
#
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# ERROR
#  =====
# Old Reference ID 50HES_744, index 276: nan
#
#
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# ERROR
#  =====
# Old Reference ID 50HES_748, index 276: nan
#
#
# Old pH, index 283: 8
# New pH, index 325: 8.0
# ERROR
#  =====
# Old Reference ID 50KOR_677, index 284: nan
#
#
# Old pH, index 283: 8
# New pH, index 325: 8.0
# ERROR
#  =====
# Old Reference ID 50OES/MEY_1283, index 284: nan
#
#
# Old pH, index 283: 8
# New pH, index 325: 8.0
# ERROR
#  =====
# Old Reference ID 50PAZ_433, index 284: nan
#
#
# Old pH, index 283: 8
# New pH, index 325: 8.0
# ERROR
#  =====
# Old Reference ID 50PAZ_435, index 284: nan
#
#
# Old pH, index 283: 8
# New pH, index 325: 8.0
# ERROR
#  =====
# Old Reference ID 50PAZ_437, index 284: nan
#
#
# Old pH, index 283: 8
# New pH, index 325: 8.0
# ERROR
#  =====
# Old Reference ID 50RAC_11, index 284: nan
#
#
# Old pH, index 288: 8
# New pH, index 330: 8.0
# ERROR
#  =====
# Old Reference ID 50RAC_98, index 289: nan
#
#
# Old pH, index 294: 7
# New pH, index 336: 7.0
# ERROR
#  =====
# Old Reference ID 50SLE_1345, index 295: nan
#
#
# Old pH, index 294: 7
# New pH, index 336: 7.0
# ERROR
#  =====
# Old Reference ID 50SLE_1350, index 295: nan
#
#
# Old pH, index 294: 7
# New pH, index 336: 7.0
# ERROR
#  =====
# Old Reference ID 51BLA_65, index 295: nan
#
#
# Old pH, index 294: 7
# New pH, index 336: 7.0
# ERROR
#  =====
# Old Reference ID 51BLI_35, index 295: nan
#
#
# Old pH, index 297: 8
# New pH, index 339: 8.0
# 51FRU/JOH_971 is equivalent.
#
#
# Old pH, index 299: 10
# New pH, index 341: 10.0
# ERROR
#  =====
# Old Reference ID 51ROW/KOR_465, index 300: nan
#
#
# Old pH, index 299: 10
# New pH, index 341: 10.0
# ERROR
#  =====
# Old Reference ID 51THE/BON_12, index 300: nan
#
#
# Old Keq, index 303: 1
# New Keq, index 345: 1.0
# 51WOO/GUN_1233 is equivalent.
#
#
# Old pH, index 308: 7
# New pH, index 350: 7.0
# 52ASK_592 is equivalent.
#
#
# Old pH, index 308: 7
# New pH, index 350: 7.0
# 52BAU/GEM_942 is equivalent.
#
#
# Old pH, index 308: 7
# New pH, index 350: 7.0
# 52BAU/GEM_996 is equivalent.
#
#
# Old pH, index 308: 7
# New pH, index 350: 7.0
# 52BUR_29 is equivalent.
#
#
# Old enthalpy, index 314: -4
# New enthalpy, index 356: -4.0
# ERROR
#  =====
# Old Reference ID 52DOB/FRU_972, index 315: nan
#
#
# Old enthalpy, index 314: -4
# New enthalpy, index 356: -4.0
# ERROR
#  =====
# Old Reference ID 52DOB/FRU_973, index 315: nan
#
#
# Old pH, index 319: 7
# New pH, index 361: 7.0
# ERROR
#  =====
# Old Reference ID 52DOB/STU_956, index 320: nan
#
#
# Old enthalpy, index 332: -21
# New enthalpy, index 374: -21.0
# ERROR
#  =====
# Old Reference ID 52DOB/STU_969, index 333: nan
#
#
# Old pH, index 340: 7
# New pH, index 382: 7.0
# 52EGG/HEM_658 is equivalent.
#
#
# Old pH, index 340: 7
# New pH, index 382: 7.0
# 52FIT/DOU_419 is equivalent.
#
#
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
# 52KOR_574 is equivalent.
#
#
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
# 52LEL/CAR_1260 is equivalent.
#
#
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
# 52LEL/CAR_698 is equivalent.
#
#
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
# 52MEY/SHA_815 is equivalent.
#
#
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
# 52NAR/WOO_1237 is equivalent.
#
#
# Old pH, index 346: 10
# New pH, index 388: 10.0
# ERROR
#  =====
# Old Reference ID 52NEI_99, index 347: nan
#
#
# Old pH, index 351: 7
# New pH, index 393: 7.0
# 52OHL/SHA_1061 is equivalent.
#
#
# Old pH, index 351: 7
# New pH, index 393: 7.0
# 52OHL/SHA_1070 is equivalent.
#
#
# Old enthalpy, index 352: -19
# New enthalpy, index 394: -19.0
# 52OHL/SHA_792 is equivalent.
#
#
# Old Keq, index 356: 101
# New Keq, index 398: 101.0
# ERROR
#  =====
# Old Reference ID 52STA_394, index 357: nan
#
#
# Old Keq, index 356: 101
# New Keq, index 398: 101.0
# ERROR
#  =====
# Old Reference ID 52STE/OCH_1129, index 357: nan
#
#
# Old Keq, index 359: 1.34E-06
# New Keq, index 401: 1.34e-06
# ERROR
#  =====
# Old Reference ID 52STE/OCH_128, index 360: nan
#
#
# Old Keq, index 367: 101
# New Keq, index 409: 101.0
# ERROR
#  =====
# Old Reference ID 52STE/OCH_145, index 368: nan
#
#
# Old pH, index 391: 5
# New pH, index 433: 5.0
# ERROR
#  =====
# Old Reference ID 52STR/KOR_158, index 392: nan
#
#
# Old pH, index 391: 5
# New pH, index 433: 5.0
# ERROR
#  =====
# Old Reference ID 53BOC/ALB_1146, index 392: nan
#
#
# Old pH, index 419: 7
# New pH, index 461: 7.0
# 53BOD_1351 is equivalent.
#
#
# Old pH, index 419: 7
# New pH, index 461: 7.0
# 53BRI_159 is equivalent.
#
#
# Old Keq, index 423: 2000
# New Keq, index 465: 2000.0
# ERROR
#  =====
# Old Reference ID 53BRO_1399, index 424: nan
#
#
# Old Keq, index 423: 2000
# New Keq, index 465: 2000.0
# ERROR
#  =====
# Old Reference ID 53BUR/STA_240, index 424: nan
#
#
# Old Keq, index 426: 2.75E-05
# New Keq, index 468: 2.75e-05
# ERROR
#  =====
# Old Reference ID 53BUR/WIL_129, index 427: nan
#
#
# Old Keq, index 467: 1.74E-04
# New Keq, index 509: 0.000174
# ERROR
#  =====
# Old Reference ID 53BUR/WIL_30, index 468: nan
#
#
# Old Keq, index 467: 1.74E-04
# New Keq, index 509: 0.000174
# ERROR
#  =====
# Old Reference ID 53BUR/WIL_44, index 468: nan
#
#
# Old pH, index 476: 6
# New pH, index 518: 6.0
# ERROR
#  =====
# Old Reference ID 53COH_1294, index 477: nan
#
#
# Old pH, index 476: 6
# New pH, index 518: 6.0
# ERROR
#  =====
# Old Reference ID 53GRE/BRO_634, index 477: nan
#
#
# Old pH, index 476: 6
# New pH, index 518: 6.0
# ERROR
#  =====
# Old Reference ID 53HAR/KOR_147, index 477: nan
#
#
# Old pH, index 476: 6
# New pH, index 518: 6.0
# ERROR
#  =====
# Old Reference ID 53HOC/WAT_1323, index 477: nan
#
#
# Old pH, index 476: 6
# New pH, index 518: 6.0
# ERROR
#  =====
# Old Reference ID 53JON_1432, index 477: nan
#
#
# Old pH, index 476: 6
# New pH, index 518: 6.0
# ERROR
#  =====
# Old Reference ID 53KAP/COL_309, index 477: nan
#
#
# Old Keq, index 483: 0.148
# New Keq, index 527: 0.0019
# Old pH, index 483: 7.4
# New pH, index 527: 7.0
# 53KRE_1147 is equivalent.
#
#
# Old Keq, index 483: 0.148
# New Keq, index 527: 0.0019
# Old pH, index 483: 7.4
# New pH, index 527: 7.0
# 53KRE_1157 is equivalent.
#
#
# Old Keq, index 483: 0.148
# New Keq, index 527: 0.0019
# Old pH, index 483: 7.4
# New pH, index 527: 7.0
# 53KRE_1160 is equivalent.
#
#
# Old Keq, index 483: 0.148
# New Keq, index 527: 0.0019
# Old pH, index 483: 7.4
# New pH, index 527: 7.0
# 53KRE_1163 is equivalent.
#
#
# Old Keq, index 485: 1.90E-03
# New Keq, index 523: 4.43
# Old pH, index 485: 7
# New pH, index 523: 7.4
# 53KRE2_498 is equivalent.
#
#
# Old Keq, index 485: 1.90E-03
# New Keq, index 523: 4.43
# Old pH, index 485: 7
# New pH, index 523: 7.4
# 53KRE2_508 is equivalent.
#
#
# Old Keq, index 485: 1.90E-03
# New Keq, index 527: 0.0019
# Old pH, index 485: 7
# New pH, index 527: 7.0
# 53LYN/OCH_116 is equivalent.
#
#
# Old Keq, index 486: 2.00E-05
# New Keq, index 528: 2e-05
# ERROR
#  =====
# Old Reference ID 53LYN/OCH_404, index 487: nan
#
#
# Old pH, index 489: 8
# New pH, index 531: 8.0
# 53LYN/OCH_717 is equivalent.
#
#
# Old pH, index 489: 8
# New pH, index 531: 8.0
# 53MAH/WAK_1436 is equivalent.
#
#
# Old temperature, index 492: 277
# New temperature, index 534: 277.0
# ERROR
#  =====
# Old Reference ID 53MAS_1148, index 493: nan
#
#
# Old pH, index 515: 7
# New pH, index 557: 7.0
# 53MEY/SHA_1069 is equivalent.
#
#
# Old pH, index 515: 7
# New pH, index 557: 7.0
# 53MIT/LAM_1324 is equivalent.
#
#
# Old Keq, index 517: 4.60E-07
# New Keq, index 559: 4.6e-07
# ERROR
#  =====
# Old Reference ID 53NIS/BAR_499, index 518: nan
#
#
# Old Keq, index 517: 4.60E-07
# New Keq, index 559: 4.6e-07
# ERROR
#  =====
# Old Reference ID 53OLS/ANF_280, index 518: nan
#
#
# Old Keq, index 520: 9.70E-07
# New Keq, index 562: 9.7e-07
# Old pH, index 520: 7
# New pH, index 562: 7.0
# ERROR
#  =====
# Old Reference ID 53OLS/ANF_281, index 521: nan
#
#
# Old Keq, index 523: 3.10E-07
# New Keq, index 565: 3.1e-07
# ERROR
#  =====
# Old Reference ID 53OLS/ANF_282, index 524: nan
#
#
# Old Keq, index 527: 1
# New Keq, index 569: 1.0
# 53RAT/ANS_1222 is equivalent.
#
#
# Old Keq, index 527: 1
# New Keq, index 569: 1.0
# 53SIE/POT_635 is equivalent.
#
#
# Old Keq, index 528: 2.00E-05
# New Keq, index 570: 2e-05
# 53STE/COO_405 is equivalent.
#
#
# Old Keq, index 530: 3.47E-07
# New Keq, index 572: 3.47e-07
# ERROR
#  =====
# Old Reference ID 53STE/COO_718, index 531: nan
#
#
# Old Keq, index 530: 3.47E-07
# New Keq, index 572: 3.47e-07
# ERROR
#  =====
# Old Reference ID 53STR_274, index 531: nan
#
#
# Old Keq, index 556: 4
# New Keq, index 598: 4.0
# ERROR
#  =====
# Old Reference ID 53STU_954, index 557: nan
#
#
# Old Keq, index 556: 4
# New Keq, index 598: 4.0
# ERROR
#  =====
# Old Reference ID 53STU_955, index 557: nan
#
#
# Old Keq, index 556: 4
# New Keq, index 598: 4.0
# ERROR
#  =====
# Old Reference ID 53TAL/DOB_178, index 557: nan
#
#
# Old pH, index 558: 7
# New pH, index 600: 7.0
# ERROR
#  =====
# Old Reference ID 54AXE/JAN_1331, index 559: nan
#
#
# Old pH, index 561: 6
# New pH, index 603: 6.0
# 54BER/JOK_665 is equivalent.
#
#
# Old pH, index 562: 6
# New pH, index 604: 6.0
# ERROR
#  =====
# Old Reference ID 54BOW/KER_636, index 563: nan
#
#
# Old Keq, index 573: 6.00E-05
# New Keq, index 615: 6e-05
# ERROR
#  =====
# Old Reference ID 54CHA_1086, index 574: nan
#
#
# Old Keq, index 573: 6.00E-05
# New Keq, index 615: 6e-05
# ERROR
#  =====
# Old Reference ID 54GIN_771, index 574: nan
#
#
# Old Keq, index 573: 6.00E-05
# New Keq, index 615: 6e-05
# ERROR
#  =====
# Old Reference ID 54GIN_779, index 574: nan
#
#
# Old Keq, index 573: 6.00E-05
# New Keq, index 615: 6e-05
# ERROR
#  =====
# Old Reference ID 54GOL_406, index 574: nan
#
#
# Old Keq, index 575: 10
# New Keq, index 617: 10.0
# Old pH, index 575: 7
# New pH, index 617: 7.0
# 54GRE/MII_264 is equivalent.
#
#
# Old pH, index 578: 8
# New pH, index 620: 8.0
# ERROR
#  =====
# Old Reference ID 54HAN/CRA_1261, index 579: nan
#
#
# Old pH, index 578: 8
# New pH, index 620: 8.0
# ERROR
#  =====
# Old Reference ID 54HEL_1433, index 579: nan
#
#
# Old pH, index 580: 8
# New pH, index 622: 8.0
# 54HEL_1435 is equivalent.
#
#
# Old pH, index 581: 7
# New pH, index 623: 7.0
# ERROR
#  =====
# Old Reference ID 54LEV/MEI_1439, index 582: nan
#
#
# Old Keq, index 587: 1
# New Keq, index 629: 1.0
# Old pH, index 587: 8
# New pH, index 629: 8.0
# 54LIE/KOR_1036 is equivalent.
#
#
# Old Keq, index 587: 1
# New Keq, index 629: 1.0
# Old pH, index 587: 8
# New pH, index 629: 8.0
# 54LIE/KOR_1039 is equivalent.
#
#
# Old Keq, index 587: 1
# New Keq, index 629: 1.0
# Old pH, index 587: 8
# New pH, index 629: 8.0
# 54MAR/WIL_1234 is equivalent.
#
#
# Old Keq, index 589: 8.70E-03
# New Keq, index 631: 0.0087
# 54MIT/DAV_1168 is equivalent.
#
#
# Old Keq, index 589: 8.70E-03
# New Keq, index 631: 0.0087
# 54ROS/GRU_573 is equivalent.
#
#
# Old pH, index 590: 6
# New pH, index 632: 6.0
# ERROR
#  =====
# Old Reference ID 54SIS/STA_1427, index 591: nan
#
#
# Old Keq, index 595: 4
# New Keq, index 637: 4.0
# Old pH, index 595: 8
# New pH, index 637: 8.0
# 54SIS/STA_1428 is equivalent.
#
#
# Old Keq, index 601: 7.23E-03
# New Keq, index 643: 0.00723
# ERROR
#  =====
# Old Reference ID 54STA_375, index 602: nan
#
#
# Old Keq, index 601: 7.23E-03
# New Keq, index 643: 0.00723
# ERROR
#  =====
# Old Reference ID 54STR/HAR_38, index 602: nan
#
#
# Old Keq, index 604: 6.30E-01
# New Keq, index 646: 0.63
# Old pH, index 604: 10
# New pH, index 646: 10.0
# ERROR
#  =====
# Old Reference ID 54UTT/KUR_1082, index 605: nan
#
#
# Old Keq, index 604: 6.30E-01
# New Keq, index 646: 0.63
# Old pH, index 604: 10
# New pH, index 646: 10.0
# ERROR
#  =====
# Old Reference ID 54WAK/GRE_123, index 605: nan
#
#
# Old Keq, index 608: 2.50E-01
# New Keq, index 650: 0.25
# Old pH, index 608: 10
# New pH, index 650: 10.0
# ERROR
#  =====
# Old Reference ID 54WAK/GRE_126, index 609: nan
#
#
# Old Keq, index 612: 2.05E-02
# New Keq, index 654: 0.0205
# Old pH, index 612: 7
# New pH, index 654: 7.0
# 54WIL/BAN_66 is equivalent.
#
#
# Old Keq, index 613: 3.50E-04
# New Keq, index 659: 0.00035
# Old pH, index 613: 7
# New pH, index 659: 7.0
# 55BLA/WRI_587 is equivalent.
#
#
# Old Keq, index 615: 2.00E+02
# New Keq, index 656: 200.0
# 55BLA/WRI2_242 is equivalent.
#
#
# Old Keq, index 616: 8.80E-03
# New Keq, index 657: 0.0088
# 55BLA/WRI3_36 is equivalent.
#
#
# Old Keq, index 617: 6.30E-04
# New Keq, index 658: 0.00063
# 55BLA/WRI3_37 is equivalent.
#
#
# Old Keq, index 618: 6.40E-05
# New Keq, index 660: 6.4e-05
# 55BUR_39 is equivalent.
#
#
# Old pH, index 619: 7
# New pH, index 661: 7.0
# 55CAR/COH_1223 is equivalent.
#
#
# Old Keq, index 621: 4.61E-03
# New Keq, index 663: 0.00461
# 55CAR/LEL_423 is equivalent.
#
#
# Old Keq, index 621: 4.61E-03
# New Keq, index 663: 0.00461
# 55DAV/GIL_81 is equivalent.
#
#
# Old pH, index 622: 7
# New pH, index 664: 7.0
# ERROR
#  =====
# Old Reference ID 55DAV/GIL_82, index 623: nan
#
#
# Old Keq, index 624: 1.48E-05
# New Keq, index 666: 1.48e-05
# Old pH, index 624: 6
# New pH, index 666: 6.0
# ERROR
#  =====
# Old Reference ID 55DEC_407, index 625: nan
#
#
# Old pH, index 630: 7
# New pH, index 672: 7.0
# 55DIC/WIL_1332 is equivalent.
#
#
# Old pH, index 635: 8
# New pH, index 677: 8.0
# ERROR
#  =====
# Old Reference ID 55GLA/BRO_162, index 636: nan
#
#
# Old pH, index 635: 8
# New pH, index 677: 8.0
# ERROR
#  =====
# Old Reference ID 55HOR/SMY_371, index 636: nan
#
#
# Old pH, index 635: 8
# New pH, index 677: 8.0
# ERROR
#  =====
# Old Reference ID 55KAT_112, index 636: nan
#
#
# Old pH, index 635: 8
# New pH, index 677: 8.0
# ERROR
#  =====
# Old Reference ID 55KAU/ALI_1438, index 636: nan
#
#
# Old pH, index 635: 8
# New pH, index 677: 8.0
# ERROR
#  =====
# Old Reference ID 55KIT/BEN_1071, index 636: nan
#
#
# Old pH, index 640: 8
# New pH, index 682: 8.0
# 55KIT/BEN_1077 is equivalent.
#
#
# Old Keq, index 641: 6.90E-04
# New Keq, index 683: 0.00069
# Old pH, index 641: 7
# New pH, index 683: 7.0
# 55LEH/SIC_1089 is equivalent.
#
#
# Old Keq, index 642: 1.18E-04
# New Keq, index 684: 0.000118
# Old pH, index 642: 7
# New pH, index 684: 7.0
# 55LEH/SIC_1092 is equivalent.
#
#
# Old Keq, index 643: 2.80E-06
# New Keq, index 685: 2.8e-06
# Old pH, index 643: 7
# New pH, index 685: 7.0
# 55LEH/SIC_1097 is equivalent.
#
#
# Old pH, index 644: 8
# New pH, index 687: 8.0
# 55LIE/KOR_480 is equivalent.
#
#
# Old temperature, index 646: 298.15
# New temperature, index 687: 303.15
# Old Keq, index 646: 0.012
# New Keq, index 687: 8.3
# Old pH, index 646: 7.8
# New pH, index 687: 8.0
# 55LIE/KOR2_664 is equivalent.
#
#
# Old pH, index 648: 8
# New pH, index 690: 8.0
# 55LYN/WIE_124 is equivalent.
#
#
# Old pH, index 648: 8
# New pH, index 690: 8.0
# 55MUN_683 is equivalent.
#
#
# Old pH, index 648: 8
# New pH, index 690: 8.0
# 55POD/STU_1072 is equivalent.
#
#
# Old Keq, index 650: 1200
# New Keq, index 692: 1200.0
# Old pH, index 650: 7
# New pH, index 692: 7.0
# 55SLE_1325 is equivalent.
#
#
# Old Keq, index 650: 1200
# New Keq, index 692: 1200.0
# Old pH, index 650: 7
# New pH, index 692: 7.0
# 55STA/BUR_241 is equivalent.
#
#
# Old pH, index 651: 8
# New pH, index 693: 8.0
# 55STA_395 is equivalent.
#
#
# Old enthalpy, index 659: -20
# New enthalpy, index 702: -20.0
# ERROR
#  =====
# Old Reference ID 55STU_825, index 660: nan
#
#
# Old temperature, index 662: 310.15
# New temperature, index 695: 298.15
# Old Keq, index 662: 1
# New Keq, index 695:
# Old pH, index 662: 7.4
# New pH, index 695: 3.62
# 55STU2_978 is equivalent.
#
#
# Old Keq, index 662: 1
# New Keq, index 704: 1.0
# 55THO/GOM_1235 is equivalent.
#
#
# Old pH, index 665: 7
# New pH, index 707: 7.0
# 55VAR/WEB_1440 is equivalent.
#
#
# Old pH, index 665: 7
# New pH, index 707: 7.0
# 55WIL/MCI_1208 is equivalent.
#
#
# Old pH, index 665: 7
# New pH, index 707: 7.0
# 55WOL/KAP_75 is equivalent.
#
#
# Old pH, index 666: 7
# New pH, index 708: 7.0
# ERROR
#  =====
# Old Reference ID 55YAN/GIL_83, index 667: nan
#
#
# Old Keq, index 668: 2.71E-06
# New Keq, index 710: 2.71e-06
# Old pH, index 668: 7
# New pH, index 710: 7.0
# ERROR
#  =====
# Old Reference ID 55ZEL_85, index 669: nan
#
#
# Old Keq, index 674: 1.03E-07
# New Keq, index 716: 1.03e-07
# ERROR
#  =====
# Old Reference ID 55ZEL_88, index 675: nan
#
#
# Old pH, index 684: 6
# New pH, index 726: 6.0
# ERROR
#  =====
# Old Reference ID 56ALE/GRE_348, index 685: nan
#
#
# Old pH, index 684: 6
# New pH, index 726: 6.0
# ERROR
#  =====
# Old Reference ID 56AME/HOR_519, index 685: nan
#
#
# Old pH, index 684: 6
# New pH, index 726: 6.0
# ERROR
#  =====
# Old Reference ID 56BEN/HEM_989, index 685: nan
#
#
# Old pH, index 684: 6
# New pH, index 726: 6.0
# ERROR
#  =====
# Old Reference ID 56BOW/KER_637, index 685: nan
#
#
# Old pH, index 693: 6
# New pH, index 735: 6.0
# ERROR
#  =====
# Old Reference ID 56CAR/COH_1224, index 694: nan
#
#
# Old Keq, index 696: 5
# New Keq, index 738: 5.0
# 56COW/PIZ_1389 is equivalent.
#
#
# Old enthalpy, index 714: -26
# New enthalpy, index 756: -26.0
# ERROR
#  =====
# Old Reference ID 56DIC/WIL_1262, index 715: nan
#
#
# Old enthalpy, index 714: -26
# New enthalpy, index 756: -26.0
# ERROR
#  =====
# Old Reference ID 56DIC/WIL_1333, index 715: nan
#
#
# Old enthalpy, index 714: -26
# New enthalpy, index 756: -26.0
# ERROR
#  =====
# Old Reference ID 56ENG_1371, index 715: nan
#
#
# Old enthalpy, index 714: -26
# New enthalpy, index 756: -26.0
# ERROR
#  =====
# Old Reference ID 56FEU/WOL_557, index 715: nan
#
#
# Old enthalpy, index 714: -26
# New enthalpy, index 756: -26.0
# ERROR
#  =====
# Old Reference ID 56FOR/GUT_977, index 715: nan
#
#
# Old pH, index 740: 8
# New pH, index 782: 8.0
# 56GRE/COH_1296 is equivalent.
#
#
# Old Keq, index 741: 9.78E-06
# New Keq, index 783: 9.78e-06
# ERROR
#  =====
# Old Reference ID 56HAK/GLA_100, index 742: nan
#
#
# Old pH, index 745: 7
# New pH, index 787: 7.0
# 56HAU_265 is equivalent.
#
#
# Old pH, index 745: 7
# New pH, index 787: 7.0
# 56HUB_1279 is equivalent.
#
#
# Old Keq, index 747: 1.20E-03
# New Keq, index 789: 0.0012
# Old pH, index 747: 9
# New pH, index 789: 9.0
# 56HUR/HOR_1244 is equivalent.
#
#
# Old Keq, index 747: 1.20E-03
# New Keq, index 789: 0.0012
# Old pH, index 747: 9
# New pH, index 789: 9.0
# 56KAP/CIO_101 is equivalent.
#
#
# Old pH, index 748: 9
# New pH, index 790: 9.0
# 56KAP/CIO_110 is equivalent.
#
#
# Old Keq, index 749: 1.60E-04
# New Keq, index 791: 0.00016
# Old pH, index 749: 7
# New pH, index 791: 7.0
# ERROR
#  =====
# Old Reference ID 56KAP/CIO_13, index 750: nan
#
#
# Old pH, index 751: 7
# New pH, index 793: 7.0
# ERROR
#  =====
# Old Reference ID 56KAP/CIO_22, index 752: nan
#
#
# Old Keq, index 753: 2.43E-06
# New Keq, index 795: 2.43e-06
# 56KAP/CIO_275 is equivalent.
#
#
# Old pH, index 755: 8
# New pH, index 797: 8.0
# ERROR
#  =====
# Old Reference ID 56KAP/CIO_278, index 756: nan
#
#
# Old pH, index 755: 8
# New pH, index 797: 8.0
# ERROR
#  =====
# Old Reference ID 56KIT/HOR_1085, index 756: nan
#
#
# Old Keq, index 757: 6.70E-04
# New Keq, index 799: 0.00067
# ERROR
#  =====
# Old Reference ID 56LAR/JAC_77, index 758: nan
#
#
# Old pH, index 766: 8
# New pH, index 808: 8.0
# 56LEL/CAR_1366 is equivalent.
#
#
# Old pH, index 766: 8
# New pH, index 808: 8.0
# 56PAL/DOU_1340 is equivalent.
#
#
# Old pH, index 766: 8
# New pH, index 808: 8.0
# 56PAL/DOU_1341 is equivalent.
#
#
# Old pH, index 766: 8
# New pH, index 808: 8.0
# 56PAL/DOU_1344 is equivalent.
#
#
# Old pH, index 766: 8
# New pH, index 808: 8.0
# 56POD/MOR_1078 is equivalent.
#
#
# Old pH, index 767: 7
# New pH, index 809: 7.0
# 56RAB/PRI_353 is equivalent.
#
#
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# ERROR
#  =====
# Old Reference ID 56RAM/GIR_1352, index 774: nan
#
#
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# ERROR
#  =====
# Old Reference ID 56RAT/ROC_364, index 774: nan
#
#
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# ERROR
#  =====
# Old Reference ID 56REI_1407, index 774: nan
#
#
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# ERROR
#  =====
# Old Reference ID 56SMI/STA_1113, index 774: nan
#
#
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# ERROR
#  =====
# Old Reference ID 56SMI/STA_1124, index 774: nan
#
#
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# ERROR
#  =====
# Old Reference ID 56STE/COO_719, index 774: nan
#
#
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
# ERROR
#  =====
# Old Reference ID 56STE/DEL_1175, index 786: nan
#
#
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
# ERROR
#  =====
# Old Reference ID 56STE/DEL_1176, index 786: nan
#
#
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
# ERROR
#  =====
# Old Reference ID 56STE/DEL_1177, index 786: nan
#
#
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
# ERROR
#  =====
# Old Reference ID 56STE/DEL_1178, index 786: nan
#
#
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
# ERROR
#  =====
# Old Reference ID 56STE_720, index 786: nan
#
#
# Old Keq, index 794: 5.80E-03
# New Keq, index 836: 0.0058
# Old pH, index 794: 6
# New pH, index 836: 6.0
# ERROR
#  =====
# Old Reference ID 56STU/HOR_1245, index 795: nan
#
#
# Old Keq, index 794: 5.80E-03
# New Keq, index 836: 0.0058
# Old pH, index 794: 6
# New pH, index 836: 6.0
# ERROR
#  =====
# Old Reference ID 56TAL/MAR_166, index 795: nan
#
#
# Old pH, index 798: 6
# New pH, index 840: 6.0
# ERROR
#  =====
# Old Reference ID 56TAL/MAR_179, index 799: nan
#
#
# Old pH, index 802: 7
# New pH, index 844: 7.0
# ERROR
#  =====
# Old Reference ID 56TOM_173, index 803: nan
#
#
# Old Keq, index 804: 4.90E-03
# New Keq, index 846: 0.0049
# Old pH, index 804: 7
# New pH, index 846: 7.0
# 56WOL/KAP_76 is equivalent.
#
#
# Old pH, index 806: 7
# New pH, index 848: 7.0
# 57ASH/HIC_1246 is equivalent.
#
#
# Old pH, index 806: 7
# New pH, index 848: 7.0
# 57BUR/HOR_1263 is equivalent.
#
#
# Old pH, index 812: 8
# New pH, index 854: 8.0
# 57CAL_638 is equivalent.
#
#
# Old pH, index 812: 8
# New pH, index 854: 8.0
# 57DUR/STU_339 is equivalent.
#
#
# Old pH, index 812: 8
# New pH, index 854: 8.0
# 57FLA/ERW_476 is equivalent.
#
#
# Old Keq, index 815: 1.73E-02
# New Keq, index 857: 0.0173
# 57GRE/LIP_715 is equivalent.
#
#
# Old Keq, index 815: 1.73E-02
# New Keq, index 857: 0.0173
# 57GRE/LIP_716 is equivalent.
#
#
# Old Keq, index 815: 1.73E-02
# New Keq, index 857: 0.0173
# 57HOH_102 is equivalent.
#
#
# Old Keq, index 816: 3.70E-06
# New Keq, index 858: 3.7e-06
# Old pH, index 816: 7
# New pH, index 858: 7.0
# ERROR
#  =====
# Old Reference ID 57HOL/HOL_113, index 817: nan
#
#
# Old Keq, index 824: 8.58E-04
# New Keq, index 866: 0.000858
# Old pH, index 824: 7
# New pH, index 866: 7.0
# ERROR
#  =====
# Old Reference ID 57HOL/TOU_56, index 825: nan
#
#
# Old Keq, index 828: 1.00E+05
# New Keq, index 870: 100000.0
# 57KAR/GRE_347 is equivalent.
#
#
# Old Keq, index 828: 1.00E+05
# New Keq, index 870: 100000.0
# 57MAX_1249 is equivalent.
#
#
# Old Keq, index 828: 1.00E+05
# New Keq, index 870: 100000.0
# 57REI_362 is equivalent.
#
#
# Old pH, index 834: 6
# New pH, index 876: 6.0
# ERROR
#  =====
# Old Reference ID 57ROB/BOY_544, index 835: nan
#
#
# Old Keq, index 858: 1.20E-01
# New Keq, index 900: 0.12
# Old pH, index 858: 10
# New pH, index 900: 10.0
# ERROR
#  =====
# Old Reference ID 57ROB/COO_122, index 859: nan
#
#
# Old Keq, index 861: 6
# New Keq, index 903: 6.0
# ERROR
#  =====
# Old Reference ID 57ROD/TOW_1390, index 862: nan
#
#
# Old Keq, index 871: 7.42E-02
# New Keq, index 913: 0.0742
# Old pH, index 871: 7
# New pH, index 913: 7.0
# 57SAN/SEA_323 is equivalent.
#
#
# Old Keq, index 871: 7.42E-02
# New Keq, index 913: 0.0742
# Old pH, index 871: 7
# New pH, index 913: 7.0
# 57SMI/GUN_1114 is equivalent.
#
#
# Old Keq, index 871: 7.42E-02
# New Keq, index 913: 0.0742
# Old pH, index 871: 7
# New pH, index 913: 7.0
# 57STE_125 is equivalent.
#
#
# Old Keq, index 871: 7.42E-02
# New Keq, index 913: 0.0742
# Old pH, index 871: 7
# New pH, index 913: 7.0
# 57TAL_167 is equivalent.
#
#
# Old Keq, index 872: 6.68E-02
# New Keq, index 914: 0.0668
# Old pH, index 872: 7
# New pH, index 914: 7.0
# 57TAL_170 is equivalent.
#
#
# Old Keq, index 873: 1.57E-02
# New Keq, index 915: 0.0157
# Old pH, index 873: 7
# New pH, index 915: 7.0
# 57TAL_171 is equivalent.
#
#
# Old pH, index 874: 7
# New pH, index 916: 7.0
# 57TAL_174 is equivalent.
#
#
# Old pH, index 875: 7
# New pH, index 917: 7.0
# 57TAL_177 is equivalent.
#
#
# Old pH, index 876: 7
# New pH, index 918: 7.0
# 57TAL_180 is equivalent.
#
#
# Old pH, index 877: 7
# New pH, index 919: 7.0
# 57TAL_182 is equivalent.
#
#
# Old Keq, index 879: 6.46E-05
# New Keq, index 921: 6.46e-05
# Old pH, index 879: 7
# New pH, index 921: 7.0
# ERROR
#  =====
# Old Reference ID 57VLA/VLA_545, index 880: nan
#
#
# Old Keq, index 879: 6.46E-05
# New Keq, index 921: 6.46e-05
# Old pH, index 879: 7
# New pH, index 921: 7.0
# ERROR
#  =====
# Old Reference ID 58BAC_14, index 880: nan
#
#
# Old pH, index 907: 7
# New pH, index 949: 7.0
# 58BRU/NOL_1334 is equivalent.
#
#
# Old pH, index 907: 7
# New pH, index 949: 7.0
# 58BUR/HOR_1264 is equivalent.
#
#
# Old Keq, index 909: 2.9
# New Keq, index 951: 0.0031
# Old pH, index 909: 8
# New pH, index 951: 7.4
# 58CAB/LEL_432 is equivalent.
#
#
# Old pH, index 909: 8
# New pH, index 954: 8.0
# 58FRO_1443 is equivalent.
#
#
# Old pH, index 911: 8
# New pH, index 952: 8.0
# ERROR
#  =====
# Old Reference ID 58FRO2_187, index 912: nan
#
#
# Old pH, index 913: 7
# New pH, index 955: 7.0
# ERROR
#  =====
# Old Reference ID 58HEA/HOR_1297, index 914: nan
#
#
# Old Keq, index 916: 180
# New Keq, index 958: 180.0
# Old pH, index 916: 10
# New pH, index 958: 10.0
# ERROR
#  =====
# Old Reference ID 58LAN/ENG_194, index 917: nan
#
#
# Old Keq, index 923: 1.10E-08
# New Keq, index 965: 1.1e-08
# Old pH, index 923: 8
# New pH, index 965: 8.0
# 58MAL/OCH_673 is equivalent.
#
#
# Old Keq, index 923: 1.10E-08
# New Keq, index 965: 1.1e-08
# Old pH, index 923: 8
# New pH, index 965: 8.0
# 58NOL/BRU_1346 is equivalent.
#
#
# Old Keq, index 923: 1.10E-08
# New Keq, index 965: 1.1e-08
# Old pH, index 923: 8
# New pH, index 965: 8.0
# 58NOL/BRU_1353 is equivalent.
#
#
# Old Keq, index 923: 1.10E-08
# New Keq, index 965: 1.1e-08
# Old pH, index 923: 8
# New pH, index 965: 8.0
# 58ROB/LIP_678 is equivalent.
#
#
# Old Keq, index 924: 3
# New Keq, index 966: 3.0
# 58TAB/SRE_1247 is equivalent.
#
#
# Old pH, index 926: 7
# New pH, index 968: 7.0
# ERROR
#  =====
# Old Reference ID 58TAB/SRE_1335, index 927: nan
#
#
# Old pH, index 926: 7
# New pH, index 968: 7.0
# ERROR
#  =====
# Old Reference ID 58TUR/TUR_684, index 927: nan
#
#
# Old Keq, index 930: 6.00E-07
# New Keq, index 972: 6e-07
# 58WIL/BAN_1068 is equivalent.
#
#
# Old Keq, index 931: 4.00E-08
# New Keq, index 973: 4e-08
# 58WIL/BAN_679 is equivalent.
#
#
# Old Keq, index 932: 6.00E-07
# New Keq, index 974: 6e-07
# 58WIL/BAN_681 is equivalent.
#
#
# Old Keq, index 934: 9.62E-05
# New Keq, index 976: 9.62e-05
# Old pH, index 934: 7
# New pH, index 976: 7.0
# ERROR
#  =====
# Old Reference ID 58WOL/SIM_1265, index 935: nan
#
#
# Old Keq, index 934: 9.62E-05
# New Keq, index 976: 9.62e-05
# Old pH, index 934: 7
# New pH, index 976: 7.0
# ERROR
#  =====
# Old Reference ID 58YOU/PAC_45, index 935: nan
#
#
# Old pH, index 941: 7
# New pH, index 983: 7.0
# 59ALE_443 is equivalent.
#
#
# Old pH, index 942: 7
# New pH, index 984: 7.0
# 59ATK/JOH_1402 is equivalent.
#
#
# Old pH, index 948: 5
# New pH, index 990: 5.0
# ERROR
#  =====
# Old Reference ID 59BAR/SMY_1214, index 949: nan
#
#
# Old pH, index 948: 5
# New pH, index 990: 5.0
# ERROR
#  =====
# Old Reference ID 59BEN/KIT_990, index 949: nan
#
#
# Old pH, index 948: 5
# New pH, index 990: 5.0
# ERROR
#  =====
# Old Reference ID 59BON/PON_370, index 949: nan
#
#
# Old pH, index 948: 5
# New pH, index 990: 5.0
# ERROR
#  =====
# Old Reference ID 59CAL/WEB_639, index 949: nan
#
#
# Old pH, index 948: 5
# New pH, index 990: 5.0
# ERROR
#  =====
# Old Reference ID 59CHI/SUG_1391, index 949: nan
#
#
# Old Keq, index 953: 4.74E-04
# New Keq, index 995: 0.000474
# ERROR
#  =====
# Old Reference ID 59DEL/DEF_233, index 954: nan
#
#
# Old Keq, index 964: 9.00E-03
# New Keq, index 1006: 0.009
# Old pH, index 964: 9
# New pH, index 1006: 9.0
# 59DEN/ROB_190 is equivalent.
#
#
# Old Keq, index 965: 4.50E-06
# New Keq, index 1007: 4.5e-06
# Old pH, index 965: 8
# New pH, index 1007: 8.0
# 59FRI_283 is equivalent.
#
#
# Old Keq, index 966: 5.50E-03
# New Keq, index 1008: 0.0055
# Old pH, index 966: 6
# New pH, index 1008: 6.0
# 59GOL_322 is equivalent.
#
#
# Old Keq, index 967: 1.40E-06
# New Keq, index 1009: 1.4e-06
# 59HAB/CAN_951 is equivalent.
#
#
# Old Keq, index 968: 1.44E-04
# New Keq, index 1010: 0.000144
# Old pH, index 968: 7
# New pH, index 1010: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_46, index 969: nan
#
#
# Old Keq, index 970: 5.54E-04
# New Keq, index 1012: 0.000554
# Old pH, index 970: 7
# New pH, index 1012: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_47, index 971: nan
#
#
# Old Keq, index 972: 4.23E-03
# New Keq, index 1014: 0.00423
# Old pH, index 972: 7
# New pH, index 1014: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_48, index 973: nan
#
#
# Old Keq, index 974: 1.75E-04
# New Keq, index 1016: 0.000175
# Old pH, index 974: 7
# New pH, index 1016: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_49, index 975: nan
#
#
# Old Keq, index 976: 4.19E-03
# New Keq, index 1018: 0.00419
# Old pH, index 976: 7
# New pH, index 1018: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_50, index 977: nan
#
#
# Old Keq, index 978: 6.91E-05
# New Keq, index 1020: 6.91e-05
# Old pH, index 978: 7
# New pH, index 1020: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_51, index 979: nan
#
#
# Old Keq, index 980: 4.18E-04
# New Keq, index 1022: 0.000418
# Old pH, index 980: 7
# New pH, index 1022: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_52, index 981: nan
#
#
# Old Keq, index 982: 2.97E-04
# New Keq, index 1024: 0.000297
# Old pH, index 982: 7
# New pH, index 1024: 7.0
# ERROR
#  =====
# Old Reference ID 59HOL_57, index 983: nan
#
#
# Old pH, index 986: 8
# New pH, index 1028: 8.0
# 59ITO/GRI_1392 is equivalent.
#
#
# Old pH, index 986: 8
# New pH, index 1028: 8.0
# 59KIR/TUR_663 is equivalent.
#
#
# Old temperature, index 987: 295
# New temperature, index 1029: 295.0
# 59KIT/HEM_986 is equivalent.
#
#
# Old temperature, index 988: 295
# New temperature, index 1030: 295.0
# Old enthalpy, index 988: -22
# New enthalpy, index 1030: -22.0
# 59KIT/HEM_991 is equivalent.
#
#
# Old Keq, index 989: 3.86E-04
# New Keq, index 1031: 0.000386
# ERROR
#  =====
# Old Reference ID 59KRI_564, index 990: nan
#
#
# Old Keq, index 1002: 1.55E-04
# New Keq, index 1044: 0.000155
# ERROR
#  =====
# Old Reference ID 59MCC/NAJ_1403, index 1003: nan
#
#
# Old Keq, index 1002: 1.55E-04
# New Keq, index 1044: 0.000155
# ERROR
#  =====
# Old Reference ID 59MCQ/UTT_565, index 1003: nan
#
#
# Old Keq, index 1008: 19
# New Keq, index 1050: 19.0
# 59MER/TOM_5 is equivalent.
#
#
# Old Keq, index 1010: 7.17E-03
# New Keq, index 1052: 0.00717
# Old pH, index 1010: 8
# New pH, index 1052: 8.0
# 59MIL/LUK_1225 is equivalent.
#
#
# Old Keq, index 1010: 7.17E-03
# New Keq, index 1052: 0.00717
# Old pH, index 1010: 8
# New pH, index 1052: 8.0
# 59NOR/FRO_188 is equivalent.
#
#
# Old Keq, index 1017: 1
# New Keq, index 1059: 1.0
# ERROR
#  =====
# Old Reference ID 59SAN/LAN_324, index 1018: nan
#
#
# Old Keq, index 1017: 1
# New Keq, index 1059: 1.0
# ERROR
#  =====
# Old Reference ID 59SAN/LAN_326, index 1018: nan
#
#
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
# ERROR
#  =====
# Old Reference ID 59SCO/JAK_526, index 1027: nan
#
#
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
# ERROR
#  =====
# Old Reference ID 59SHO/PRI_216, index 1027: nan
#
#
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
# ERROR
#  =====
# Old Reference ID 59STR/SMI_702, index 1027: nan
#
#
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
# ERROR
#  =====
# Old Reference ID 59TAB/WYN_355, index 1027: nan
#
#
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_172, index 1027: nan
#
#
# Old Keq, index 1029: 1.07E-02
# New Keq, index 1071: 0.0107
# Old pH, index 1029: 7
# New pH, index 1071: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_175, index 1030: nan
#
#
# Old Keq, index 1032: 2.13E-02
# New Keq, index 1074: 0.0213
# Old pH, index 1032: 7
# New pH, index 1074: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_176, index 1033: nan
#
#
# Old Keq, index 1035: 3.78E-01
# New Keq, index 1077: 0.378
# Old pH, index 1035: 7
# New pH, index 1077: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_181, index 1036: nan
#
#
# Old Keq, index 1038: 9.20E-03
# New Keq, index 1080: 0.0092
# Old pH, index 1038: 7
# New pH, index 1080: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_183, index 1039: nan
#
#
# Old Keq, index 1041: 1.88E-02
# New Keq, index 1083: 0.0188
# Old pH, index 1041: 7
# New pH, index 1083: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_184, index 1042: nan
#
#
# Old Keq, index 1044: 9.90E-03
# New Keq, index 1086: 0.0099
# Old pH, index 1044: 7
# New pH, index 1086: 7.0
# ERROR
#  =====
# Old Reference ID 59TAL/LEV_185, index 1045: nan
#
#
# Old Keq, index 1047: 1.22E-06
# New Keq, index 1089: 1.22e-06
# 59VAG/EAR_1221 is equivalent.
#
#
# Old pH, index 1051: 8
# New pH, index 1093: 8.0
# ERROR
#  =====
# Old Reference ID 60AGO/ARA_1336, index 1052: nan
#
#
# Old pH, index 1051: 8
# New pH, index 1093: 8.0
# ERROR
#  =====
# Old Reference ID 60ASH/WAH_1368, index 1052: nan
#
#
# Old pH, index 1053: 8
# New pH, index 1095: 8.0
# 60ASH/WAH_1369 is equivalent.
#
#
# Old Keq, index 1056: 1
# New Keq, index 1098: 1.0
# 60BLA_349 is equivalent.
#
#
# Old Keq, index 1056: 1
# New Keq, index 1098: 1.0
# 60COM/ROS_1117 is equivalent.
#
#
# Old Keq, index 1056: 1
# New Keq, index 1098: 1.0
# 60FEI/NEU_1267 is equivalent.
#
#
# Old pH, index 1058: 8
# New pH, index 1100: 8.0
# 60FEI/NEU_1270 is equivalent.
#
#
# Old pH, index 1058: 8
# New pH, index 1100: 8.0
# 60GEL/STU_1079 is equivalent.
#
#
# Old pH, index 1059: 8
# New pH, index 1101: 8.0
# 60GEL/STU_613 is equivalent.
#
#
# Old Keq, index 1060: 2.40E-03
# New Keq, index 1102: 0.0024
# Old pH, index 1060: 10
# New pH, index 1102: 10.0
# ERROR
#  =====
# Old Reference ID 60GUP/ROB_186, index 1061: nan
#
#
# Old Keq, index 1064: 1
# New Keq, index 1106: 1.0
# Old pH, index 1064: 8
# New pH, index 1106: 8.0
# 60ICH/FUR_1238 is equivalent.
#
#
# Old pH, index 1065: 6.7
# New pH, index 1107: 6.70
# ERROR
#  =====
# Old Reference ID 60ISH_997, index 1066: nan
#
#
# Old pH, index 1068: 8
# New pH, index 1110: 8.0
# ERROR
#  =====
# Old Reference ID 60JON/LIP_576, index 1069: nan
#
#
# Old pH, index 1068: 8
# New pH, index 1110: 8.0
# ERROR
#  =====
# Old Reference ID 60KAH/LOW_1354, index 1069: nan
#
#
# Old Keq, index 1075: 11
# New Keq, index 1117: 11.0
# Old pH, index 1075: 7
# New pH, index 1117: 7.0
# ERROR
#  =====
# Old Reference ID 60KAY/OSB_1057, index 1076: nan
#
#
# Old Keq, index 1082: 25
# New Keq, index 1124: 25.0
# Old pH, index 1082: 8
# New pH, index 1124: 8.0
# 60KUR/SUG_696 is equivalent.
#
#
# Old Keq, index 1082: 25
# New Keq, index 1124: 25.0
# Old pH, index 1082: 8
# New pH, index 1124: 8.0
# 60MAX/ROB_1250 is equivalent.
#
#
# Old Keq, index 1082: 25
# New Keq, index 1124: 25.0
# Old pH, index 1082: 8
# New pH, index 1124: 8.0
# 60MEN_429 is equivalent.
#
#
# Old Keq, index 1082: 25
# New Keq, index 1124: 25.0
# Old pH, index 1082: 8
# New pH, index 1124: 8.0
# 60NIR/JAK_193 is equivalent.
#
#
# Old pH, index 1083: 10
# New pH, index 1125: 10.0
# 60OCO/HAL_269 is equivalent.
#
#
# Old Keq, index 1084: 6.01E-06
# New Keq, index 1126: 6.01e-06
# ERROR
#  =====
# Old Reference ID 60PIE/WIA_270, index 1085: nan
#
#
# Old pH, index 1099: 8
# New pH, index 1141: 8.0
# 60PRI/HOR_1087 is equivalent.
#
#
# Old pH, index 1099: 8
# New pH, index 1141: 8.0
# 60SCH/RAT_1444 is equivalent.
#
#
# Old pH, index 1099: 8
# New pH, index 1141: 8.0
# 60VOL_1370 is equivalent.
#
#
# Old pH, index 1100: 7
# New pH, index 1142: 7.0
# 61ALE_444 is equivalent.
#
#
# Old pH, index 1101: 7
# New pH, index 1143: 7.0
# ERROR
#  =====
# Old Reference ID 61ATK/BUR_550, index 1102: nan
#
#
# Old pH, index 1103: 7
# New pH, index 1145: 7.0
# ERROR
#  =====
# Old Reference ID 61ATK/BUR_640, index 1104: nan
#
#
# Old pH, index 1105: 7
# New pH, index 1147: 7.0
# 61ATK/JOH_772 is equivalent.
#
#
# Old pH, index 1107: 7
# New pH, index 1149: 7.0
# 61BEN/SCH_1408 is equivalent.
#
#
# Old pH, index 1107: 7
# New pH, index 1149: 7.0
# 61BER/BER_1431 is equivalent.
#
#
# Old Keq, index 1108: 8.40E-02
# New Keq, index 1150: 0.084
# 61DAT/RAC_365 is equivalent.
#
#
# Old pH, index 1111: 8
# New pH, index 1153: 8.0
# 61DAT/RAC_367 is equivalent.
#
#
# Old pH, index 1111: 8
# New pH, index 1153: 8.0
# 61DAT/RAC_368 is equivalent.
#
#
# Old pH, index 1111: 8
# New pH, index 1153: 8.0
# 61DOU/MER_117 is equivalent.
#
#
# Old pH, index 1113: 7
# New pH, index 1155: 7.0
# 61DOU_416 is equivalent.
#
#
# Old pH, index 1113: 7
# New pH, index 1155: 7.0
# 61DOU_420 is equivalent.
#
#
# Old Keq, index 1115: 1.90E-06
# New Keq, index 1157: 1.9e-06
# ERROR
#  =====
# Old Reference ID 61GAW/GLA_974, index 1116: nan
#
#
# Old Keq, index 1115: 1.90E-06
# New Keq, index 1157: 1.9e-06
# ERROR
#  =====
# Old Reference ID 61GOT/KOR_191, index 1116: nan
#
#
# Old Keq, index 1117: 1
# New Keq, index 1159: 1.0
# 61KLE_685 is equivalent.
#
#
# Old pH, index 1118: 8
# New pH, index 1160: 8.0
# 61KOR/GLA_703 is equivalent.
#
#
# Old Keq, index 1119: 4.20E-04
# New Keq, index 1161: 0.00042
# ERROR
#  =====
# Old Reference ID 61KRA/VEN_266, index 1120: nan
#
#
# Old pH, index 1129: 8
# New pH, index 1171: 8.0
# ERROR
#  =====
# Old Reference ID 61KRA/VEN_268, index 1130: nan
#
#
# Old pH, index 1129: 8
# New pH, index 1171: 8.0
# ERROR
#  =====
# Old Reference ID 61LED_488, index 1130: nan
#
#
# Old pH, index 1129: 8
# New pH, index 1171: 8.0
# ERROR
#  =====
# Old Reference ID 61PRA_624, index 1130: nan
#
#
# Old pH, index 1129: 8
# New pH, index 1171: 8.0
# ERROR
#  =====
# Old Reference ID 61RAC2_372, index 1130: nan
#
#
# Old pH, index 1129: 8
# New pH, index 1171: 8.0
# ERROR
#  =====
# Old Reference ID 61RAW/WAD_953, index 1130: nan
#
#
# Old enthalpy, index 1137: -5
# New enthalpy, index 1179: -5.0
# Old pH, index 1137: 7
# New pH, index 1179: 7.0
# ERROR
#  =====
# Old Reference ID 61RAW/WAD_957, index 1138: nan
#
#
# Old enthalpy, index 1137: -5
# New enthalpy, index 1179: -5.0
# Old pH, index 1137: 7
# New pH, index 1179: 7.0
# ERROR
#  =====
# Old Reference ID 61RAW/WAD_958, index 1138: nan
#
#
# Old Keq, index 1140: 1.11E-02
# New Keq, index 1182: 0.0111
# 61SAN/ZIN_288 is equivalent.
#
#
# Old pH, index 1144: 7
# New pH, index 1186: 7.0
# ERROR
#  =====
# Old Reference ID 61VEN/RAC_373, index 1145: nan
#
#
# Old pH, index 1144: 7
# New pH, index 1186: 7.0
# ERROR
#  =====
# Old Reference ID 61VLA/KOM_827, index 1145: nan
#
#
# Old pH, index 1144: 7
# New pH, index 1186: 7.0
# ERROR
#  =====
# Old Reference ID 61WIL/WIL_1209, index 1145: nan
#
#
# Old pH, index 1147: 7
# New pH, index 1189: 7.0
# 61WOO/STJ_361 is equivalent.
#
#
# Old pH, index 1147: 7
# New pH, index 1189: 7.0
# 61YAM_485 is equivalent.
#
#
# Old Keq, index 1148: 1.80E-08
# New Keq, index 1190: 1.8e-08
# ERROR
#  =====
# Old Reference ID 62AKA/CAM_680, index 1149: nan
#
#
# Old pH, index 1150: 8
# New pH, index 1192: 8.0
# 62BLA_243 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62BRU/JOU_1118 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62BRU/JOU_1122 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62CHA/VEI_62 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62CHA/VEI_64 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62CHA/VEI_67 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62CHA/VEI_72 is equivalent.
#
#
# Old Keq, index 1157: 1.60E-03
# New Keq, index 1199: 0.0016
# 62DOU/SHU_1105 is equivalent.
#
#
# Old Keq, index 1158: 3.70E-03
# New Keq, index 1200: 0.0037
# 62DOU/SHU_1111 is equivalent.
#
#
# Old Keq, index 1159: 570
# New Keq, index 1201: 570.0
# 62DOU2_160 is equivalent.
#
#
# Old Keq, index 1164: 4.60E-04
# New Keq, index 1206: 0.00046
# 62DUR/RAW_338 is equivalent.
#
#
# Old Keq, index 1164: 4.60E-04
# New Keq, index 1206: 0.00046
# ...
# New Keq, index 3704: 3000.0
# ERROR
#  =====
# Old Reference ID 92KRA_1273, index 3646: nan
#
#
# Old Keq, index 3645: 3000
# New Keq, index 3704: 3000.0
# ERROR
#  =====
# Old Reference ID 92LEE/HAN_945, index 3646: nan
#
#
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
# 92LOR/TRA_737 is equivalent.
#
#
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
# 92LOR/TRA_739 is equivalent.
#
#
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
# 92LOR/TRA_741 is equivalent.
#
#
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
# 92REK/TIS_794 is equivalent.
#
#
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
# 92REK/TIS_826 is equivalent.
#
#
# Old Keq, index 3666: 0.00444
# New Keq, index 3725: 0.00439
# ERROR
#  =====
# Old Reference ID 92TEA/DOB_604, index 3667: nan
#
#
# Old pH, index 3694: 7
# New pH, index 3753: 7.0
# ERROR
#  =====
# Old Reference ID 92WAN/CHE_747, index 3695: nan
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 92XIA/XUE_1414 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93BES/REB_351 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93BES/REB_352 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93BLI/MAR_1033 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93BLI/MAR_1034 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93BOH/HUT_226 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93HUT/BOH_227 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93HUT/BOH_229 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_724 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_725 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_726 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_728 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_729 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_730 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_738 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_740 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93JAN/PAD_742 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93LAR/TEW_1217 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93LAR/TEW_1218 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93LAR/TEW_759 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93LAR/TEW_760 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93LAR/TEW_784 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93LAR/TEW_785 is equivalent.
#
#
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# 93MOC/STR_453 is equivalent.
#
#
# Old pH, index 3730: 7
# New pH, index 3789: 7.0
# 93SHI/CHE_1243 is equivalent.
#
#
# Old pH, index 3749: 7
# New pH, index 3808: 7.0
# 93TEW/KIS_1047 is equivalent.
#
#
# Old pH, index 3749: 7
# New pH, index 3808: 7.0
# 93TEW/KIS_1051 is equivalent.
#
#
# Old pH, index 3749: 7
# New pH, index 3808: 7.0
# 93WER/TWE_1189 is equivalent.
#
#
# Old pH, index 3750: 7
# New pH, index 3809: 7.0
# 93WER/TWE_1192 is equivalent.
#
#
# Old pH, index 3751: 7
# New pH, index 3810: 7.0
# 93WER/TWE_1202 is equivalent.
#
#
# Old Keq, index 3754: 2600
# New Keq, index 3813: 2600.0
# 94CHI/KIR_490 is equivalent.
#
#
# Old Keq, index 3754: 2600
# New Keq, index 3813: 2600.0
# 94CHI/KIR_491 is equivalent.
#
#
# Old Keq, index 3754: 2600
# New Keq, index 3813: 2600.0
# 94CHI/KIR_492 is equivalent.
#
#
# Old Keq, index 3755: 7100
# New Keq, index 3814: 7100.0
# 94CHI/KIR_493 is equivalent.
#
#
# Old enthalpy, index 3760: -84
# New enthalpy, index 3819: -84.0
# ERROR
#  =====
# Old Reference ID 94KIS/TEW_1041, index 3761: nan
#
#
# Old enthalpy, index 3760: -84
# New enthalpy, index 3819: -84.0
# ERROR
#  =====
# Old Reference ID 94KIS/TEW_1042, index 3761: nan
#
#
# Old pH, index 3765: 7
# New pH, index 3824: 7.0
# ERROR
#  =====
# Old Reference ID 94KIS/TEW_1044, index 3766: nan
#
#
# Old pH, index 3765: 7
# New pH, index 3824: 7.0
# ERROR
#  =====
# Old Reference ID 94KIS/TEW_1045, index 3766: nan
#
#
# Old pH, index 3770: 6
# New pH, index 3829: 6.0
# 94LEU/COO_409 is equivalent.
#
#
# Old Km, index 3772: 8.90E-05
# New Km, index 3831: 8.9e-05
# ERROR
#  =====
# Old Reference ID 94NOE/COL_197, index 3773: nan
#
#
# Old Km, index 3772: 8.90E-05
# New Km, index 3831: 8.9e-05
# ERROR
#  =====
# Old Reference ID 94TEW/GOL_1139, index 3773: nan
#
#
# Old pH, index 3791: 7
# New pH, index 3852: 7.0
# 94TEW/GOL_1140 is equivalent.
#
#
# Old pH, index 3791: 7
# New pH, index 3852: 7.0
# 95BIS/KRA_1027 is equivalent.
#
#
# Old pH, index 3792: 8
# New pH, index 3853: 8.0
# 95CHE/ARM_494 is equivalent.
#
#
# Old pH, index 3793: 6
# New pH, index 3854: 6.0
# ERROR
#  =====
# Old Reference ID 95HUT/BOH_1001, index 3794: nan
#
#
# Old pH, index 3802: 7
# New pH, index 3863: 7.0
# ERROR
#  =====
# Old Reference ID 95HUT/BOH_995, index 3803: nan
#
#
# Old pH, index 3804: 7
# New pH, index 3865: 7.0
# 95JUS/KOT_1002 is equivalent.
#
#
# Old Keq, index 3805: 1000000000
# New Keq, index 3866: 1000000000.0
# 95KAM/JUR_626 is equivalent.
#
#
# Old pH, index 3807: 8
# New pH, index 3868: 8.0
# 95KAM/JUR_657 is equivalent.
#
#
# Old pH, index 3807: 8
# New pH, index 3868: 8.0
# 95KOZ/TOM_1425 is equivalent.
#
#
# Old pH, index 3808: 8
# New pH, index 3869: 8.0
# 95KOZ/TOM_1426 is equivalent.
#
#
# Old pH, index 3809: 8
# New pH, index 3870: 8.0
# 95LEE/WAL_489 is equivalent.
#
#
# Old pH, index 3810: 7
# New pH, index 3872: 7.0
# 95LIA/WAN_331 is equivalent.
#
#
# Old enthalpy, index 3812: -18.1
# New enthalpy, index 3872: -83.7
# Old pH, index 3812: 9.5
# New pH, index 3872: 7.0
# 95LIA/WAN2_1048 is equivalent.
#
#
# Old pH, index 3814: 7
# New pH, index 3875: 7.0
# 95LIU/ZEN_1049 is equivalent.
#
#
# Old pH, index 3814: 7
# New pH, index 3875: 7.0
# 95LIU/ZEN_968 is equivalent.
#
#
# Old pH, index 3814: 7
# New pH, index 3875: 7.0
# 95LIU/ZEN_976 is equivalent.
#
#
# Old Keq, index 3815: 8.00E-05
# New Keq, index 3876: 8e-05
# ERROR
#  =====
# Old Reference ID 95SCH/TRA_581, index 3816: nan
#
#
# Old pH, index 3837: 7
# New pH, index 3898: 7.0
# 95TEW/SCH_960 is equivalent.
#
#
# Old pH, index 3837: 7
# New pH, index 3898: 7.0
# 95TEW/SCH_961 is equivalent.
#
#
# Old pH, index 3837: 7
# New pH, index 3898: 7.0
# 95WIS/KUS_610 is equivalent.
#
#
# Old pH, index 3838: 7
# New pH, index 3899: 7.0
# 95WIS/KUS_612 is equivalent.
#
#
# Old pH, index 3839: 7
# New pH, index 3900: 7.0
# ERROR
#  =====
# Old Reference ID 96ARA/RUZ_711, index 3840: nan
#
#
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
# ERROR
#  =====
# Old Reference ID 96HIR/MAY_731, index 3863: nan
#
#
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
# ERROR
#  =====
# Old Reference ID 96HIR/MAY_732, index 3863: nan
#
#
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
# ERROR
#  =====
# Old Reference ID 96HIR/MAY_733, index 3863: nan
#
#
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
# ERROR
#  =====
# Old Reference ID 96HIR/MAY_734, index 3863: nan
#
#
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
# ERROR
#  =====
# Old Reference ID 96HIR/MAY_735, index 3863: nan
#
#
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
# ERROR
#  =====
# Old Reference ID 96HIR/MAY_736, index 3863: nan
#
#
# Old pH, index 3870: 7
# New pH, index 3931: 7.0
# 96LI/ZHA_668 is equivalent.
#
#
# Old pH, index 3870: 7
# New pH, index 3931: 7.0
# 96OES/SCH_1410 is equivalent.
#
#
# Old pH, index 3871: 7
# New pH, index 3932: 7.0
# 96OES/SCH_1412 is equivalent.
#
#
# Old Keq, index 3872: 1
# New Keq, index 3933: 1.0
# Old pH, index 3872: 7
# New pH, index 3933: 7.0
# 96OES/SCH_1415 is equivalent.
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96PRO/GRO_1258, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/GOL_60, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/GOL_61, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/GOL_70, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/GOL_71, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/GOL_73, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/GOL_74, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/SCH_749, index 3885: nan
#
#
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# ERROR
#  =====
# Old Reference ID 96TEW/SCH_750, index 3885: nan
#
#
# Old pH, index 3903: 7
# New pH, index 3964: 7.0
# ERROR
#  =====
# Old Reference ID 96TEW/SCH_751, index 3904: nan
#
#
# Old pH, index 3903: 7
# New pH, index 3964: 7.0
# ERROR
#  =====
# Old Reference ID 97CHA_622, index 3904: nan
#
#
# Old pH, index 3903: 7
# New pH, index 3964: 7.0
# ERROR
#  =====
# Old Reference ID 97CON/DEL_1320, index 3904: nan
#
#
# Old pH, index 3908: 7
# New pH, index 3969: 7.0
# ERROR
#  =====
# Old Reference ID 97DEJ/ROC_428, index 3909: nan
#
#
# Old pH, index 3910: 8
# New pH, index 3971: 8.0
# ERROR
#  =====
# Old Reference ID 97HAN/KLE_208, index 3911: nan
#
#
# Old pH, index 3914: 7
# New pH, index 3975: 7.0
# 97KAS/TEW_1423 is equivalent.
#
#
# Old pH, index 3914: 7
# New pH, index 3975: 7.0
# 97LIA/WU_332 is equivalent.
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_878, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_879, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_880, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_884, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_885, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_903, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_904, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_905, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_906, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_907, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97PES/PRI_908, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97SAL/GOD_1123, index 3928: nan
#
#
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# ERROR
#  =====
# Old Reference ID 97STA/SUA_1365, index 3928: nan
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97TEW/GOL_434 is equivalent.
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97TEW/GOL_436 is equivalent.
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97TEW/GOL_438 is equivalent.
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97TEW/GOL_442 is equivalent.
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97TEW/GOL_873 is equivalent.
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97TEW/GOL_874 is equivalent.
#
#
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# 97YOR/ISH_540 is equivalent.
#
#
# Old pH, index 3936: 5
# New pH, index 3997: 5.0
# ERROR
#  =====
# Old Reference ID 98DIE/STR_1004, index 3937: nan
#
#
# Old temperature, index 3940: 298.15
# New temperature, index 4001: 283.15
# Old Km, index 3940: 1.2?104
# New Km, index 4001:
# Old pH, index 3940: 7.54
# New pH, index 4001: 7.0
# 98KIM/VOE_559 is equivalent.
#
#
# Old temperature, index 3945: 283.15
# New temperature, index 4011: 310.15
# Old Keq, index 3945: 0.133
# New Keq, index 4011: 1.0
# Old pH, index 3945: 7
# New pH, index 4011: 7.4
# ERROR
#  =====
# Old Reference ID 98KIS/TEW_1181, index 3946: nan
#
#
# Old temperature, index 3945: 283.15
# New temperature, index 4011: 310.15
# Old Keq, index 3945: 0.133
# New Keq, index 4011: 1.0
# Old pH, index 3945: 7
# New pH, index 4011: 7.4
# ERROR
#  =====
# Old Reference ID 98KIS/TEW_1182, index 3946: nan
#
#
# Old temperature, index 3945: 283.15
# New temperature, index 4011: 310.15
# Old Keq, index 3945: 0.133
# New Keq, index 4011: 1.0
# Old pH, index 3945: 7
# New pH, index 4011: 7.4
# ERROR
#  =====
# Old Reference ID 98KIS/TEW_1184, index 3946: nan
#
#
# Old temperature, index 3945: 283.15
# New temperature, index 4011: 310.15
# Old Keq, index 3945: 0.133
# New Keq, index 4011: 1.0
# Old pH, index 3945: 7
# New pH, index 4011: 7.4
# ERROR
#  =====
# Old Reference ID 98KIS/TEW_1186, index 3946: nan
#
#
# Old temperature, index 3945: 283.15
# New temperature, index 4011: 310.15
# Old Keq, index 3945: 0.133
# New Keq, index 4011: 1.0
# Old pH, index 3945: 7
# New pH, index 4011: 7.4
# ERROR
#  =====
# Old Reference ID 98KIS/TEW_1188, index 3946: nan
#
#
# Old pH, index 3945: 7
# New pH, index 4001: 7.0
# ERROR
#  =====
# Old Reference ID 98KIS/TEW2_541, index 3946: nan
#
#
# Old Keq, index 3950: 1
# New Keq, index 4011: 1.0
# 98LAE/EIS_1204 is equivalent.
#
#
# Old pH, index 3951: 6
# New pH, index 4012: 6.0
# 98LOV/LAU_857 is equivalent.
#
#
# Old Keq, index 3954: 0.0559 & 0.78
# New Keq, index 4015: 0.78
# 98TEW/CHE_1138 is equivalent.
#
#
# Old Keq, index 3954: 0.0559 & 0.78
# New Keq, index 4015: 0.78
# 98TEW/KIS_513 is equivalent.
#
#
# Old Keq, index 3957: 0.0559 & 1.069
# New Keq, index 4018: 1.069
# 98TEW/KIS_514 is equivalent.
#
#
# Old Keq, index 3957: 0.0559 & 1.069
# New Keq, index 4018: 1.069
# 98TEW/KIS_515 is equivalent.
#
#
# Old Keq, index 3960: 0.0559 & 0.876
# New Keq, index 4021: 0.876
# 98TEW/KIS_516 is equivalent.
#
#
# Old Keq, index 3960: 0.0559 & 0.876
# New Keq, index 4021: 0.876
# 98TEW/KIS_517 is equivalent.
#
#
# Old pH, index 3967: 7
# New pH, index 4028: 7.0
# 98TEW/KIS_518 is equivalent.
#
#
# Old pH, index 3967: 7
# New pH, index 4028: 7.0
# 98TEW_727 is equivalent.
#
#
# Old pH, index 3967: 7
# New pH, index 4028: 7.0
# 98THO/JOR_267 is equivalent.
#
#
# Old enthalpy, index 3969: -127
# New enthalpy, index 4030: -127.0
# 99HUT/OEH_944 is equivalent.
#
#
# Old enthalpy, index 3969: -127
# New enthalpy, index 4030: -127.0
# 99KIS/HOL_1199 is equivalent.
#
#
# Old enthalpy, index 3970: -79
# New enthalpy, index 4031: -79.0
# 99KIS/HOL_262 is equivalent.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 3980 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1cc933907bcf> in <module>
#      39                 valid = False'''
#      40
# ---> 41         if old.at[old_index, 'T [K]'] != new.at[new_index, 'T [K]']:
#      42             if old.at[old_index, 'T [K]'] not in empty_cell:
#      43                 print('Old temperature, index {}:'.format(old_index), old.at[old_index, 'T [K]'])
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2151             return self.obj.loc[key]
#    2152
# -> 2153         return super().__getitem__(key)
#    2154
#    2155     def __setitem__(self, key, value):
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2098
#    2099         key = self._convert_key(key)
# -> 2100         return self.obj._get_value(*key, takeable=self._takeable)
#    2101
#    2102     def __setitem__(self, key, value):
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3142         # use positional
#    3143         col = self.columns.get_loc(col)
# -> 3144         index = self.index.get_loc(index)
#    3145         return self._get_value(index, col, takeable=True)
#    3146
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351                     return self._range.index(new_key)
#     352                 except ValueError as err:
# --> 353                     raise KeyError(key) from err
#     354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 3980

# %%
import pandas
import numpy

old = pandas.read_csv('2021-03-21_vetted + reorganized NIST_1.csv')
old = old.fillna(' ')
#display(old)
new = pandas.read_csv('2021-05-06_vetted & reorganized NIST database_01.csv')
#display(new)

empty_cell = ['nan', 'NaN', 'none', 'not given', '', ' ', None, numpy.nan]

# match the indexes for the reference IDs
reference_ids = {}
old_ids = old['Reference ID:'].tolist()
new_ids = new['Reference ID:'].tolist()
for id in old_ids:
    if id in empty_cell:
        continue
        
    old_id = old_ids.index(id)
    new_id = new_ids.index(id)
    reference_ids[id] = {'Old index': old_id,
                         'New index': new_id}

for id in reference_ids:
    print('\n')
    problem = False
    valid = True
    old_index = reference_ids[id]['Old index']
    new_index = reference_ids[id]['New index']
    '''display(old.iloc[old_index])
    display(new.iloc[new_index])'''
    error_string = []
    while valid:
        '''if old.at[old_index, 'Enzyme'] != new.at[new_index, 'Enzyme:']:
            if old.at[old_index, 'Enzyme'] not in empty_cell:
                print('Old {}, index {}:'.format(old_index), old.at[old_index, 'Enzyme'])
                print('New {}, index {}:'.format(new_index), new.at[new_index, 'Enzyme:'])
                valid = False
        
        if old.at[old_index, 'Reaction'] != new.at[new_index, 'Reaction:']:
            if old.at[old_index, 'Reaction'] not in empty_cell:
                print('Old reaction, index {}:'.format(old_index), old.at[old_index, 'Reaction'])
                print('New reaction, index {}:'.format(new_index), new.at[new_index, 'Reaction:'])
                valid = False'''
        
        if old.at[old_index, 'T [K]'] != new.at[new_index, 'T [K]']:
            if old.at[old_index, 'T [K]'] not in empty_cell:
                error_string.extend(['Old temperature, index {}: {}'.format(old_index, old.at[old_index, 'T [K]']),
                                    'New temperature, index {}: {}'.format(new_index, new.at[new_index, 'T [K]'])]
                                 )
                
                #valid = False
                problem = True
        
        if old.at[old_index, 'Keq'] != new.at[new_index, 'Keq']:
            if old.at[old_index, 'Keq'] not in empty_cell:
                error_string.extend(['Old Keq, index {}: {}'.format(old_index, old.at[old_index, 'Keq']),
                                    'New Keq, index {}: {}'.format(new_index, new.at[new_index, 'Keq'])]
                                 )
                
                #valid = False
                problem = True
        
        if old.at[old_index, 'Enthalpy [kJ / mol]'] != new.at[new_index, 'Enthalpy [kJ / mol]']:
            if old.at[old_index, 'Enthalpy [kJ / mol]'] not in empty_cell:
                error_string.extend(['Old enthalpy, index {}: {}'.format(old_index, old.at[old_index, 'Enthalpy [kJ / mol]']),
                                    'New enthalpy, index {}: {}'.format(new_index, new.at[new_index, 'Enthalpy [kJ / mol]'])]
                                 )

                #valid = False
                problem = True
        
        if old.at[old_index, 'Km'] != new.at[new_index, 'Km']:
            if old.at[old_index, 'Km'] not in empty_cell:
                error_string.extend(['Old Km, index {}: {}'.format(old_index, old.at[old_index, 'Km']),
                                    'New Km, index {}: {}'.format(new_index, new.at[new_index, 'Km'])]
                                 )

                #valid = False
                problem = True
            
        if old.at[old_index, 'pH '] != new.at[new_index, 'pH ']:
            if old.at[old_index, 'pH '] not in empty_cell:
                error_string.extend(['Old pH, index {}: {}'.format(old_index, old.at[old_index, 'pH ']),
                                    'New pH, index {}: {}'.format(new_index, new.at[new_index, 'pH '])]
                                 )

                #valid = False
                problem = True
        
        if old.at[old_index, 'Reference ID:'] != (id or ' '):
            print('{} is equivalent.'.format(id))
            valid = False
        
        old_index += 1
        new_index += 1
        
    if problem:
        print('ERROR: {}\n'.format(id), '='*len('{} ERROR'.format(id)))
        print('\n'.join(error_string))
        
    '''for index, row in old.iterrows():
        if id == old.at[index, row['Reference ID:']]: 
            for index2, row2 in new.iterrows():
                while old.at[index, row] == new.at[index2, row2]:'''
# Out:
# 26QUA/WOO_1205 is equivalent.
#
#
# 29WOO_1206 is equivalent.
#
#
# 31BOR/SCH_1141 is equivalent.
#
#
# 34JAC_1142 is equivalent.
#
#
# 34LOH/MEY_1169 is equivalent.
#
#
# 34MEY/LOH_1100 is equivalent.
#
#
# 35AKA_1170 is equivalent.
# ERROR: 35AKA_1170
#  ================
# Old pH, index 19: 7
# New pH, index 24: 7.0
#
#
# 35JAC/TAP_1207 is equivalent.
# ERROR: 35JAC/TAP_1207
#  ====================
# Old pH, index 19: 7
# New pH, index 24: 7.0
# Old pH, index 20: 7
# New pH, index 25: 7.0
#
#
# 35MEY/KIE_1385 is equivalent.
#
#
# 35MEY/KIE2_1386 is equivalent.
# ERROR: 35MEY/KIE2_1386
#  =====================
# Old Keq, index 25: 4
# New Keq, index 26: 4.0
# Old temperature, index 26: 293.15
# New temperature, index 27: 273.15
# Old enthalpy, index 26: 58
# New enthalpy, index 27:
#
#
# 35MEY/LOH_1102 is equivalent.
#
#
# 35MEY/SCH_797 is equivalent.
# ERROR: 35MEY/SCH_797
#  ===================
# Old enthalpy, index 28: -31
# New enthalpy, index 35: -31.0
#
#
# 35MEY/SCH_798 is equivalent.
#
#
# 35MEY/SCH_802 is equivalent.
#
#
# 35MEY/SCH_805 is equivalent.
#
#
# 35MEY_1101 is equivalent.
# ERROR: 35MEY_1101
#  ================
# Old Keq, index 33: 0.000071
# New Keq, index 40: 7.1e-05
#
#
# 36EUL/ADL_7 is equivalent.
# ERROR: 36EUL/ADL_7
#  =================
# Old Keq, index 61: 1.30E-05
# New Keq, index 97: 1.3e-05
# Old Keq, index 62: 5.30E-05
# New Keq, index 98: 5.3e-05
# Old pH, index 62: 7
# New pH, index 98: 7.0
#
#
# 36LEH_589 is equivalent.
#
#
# 36LEH_614 is equivalent.
#
#
# 36MEY/LOH_1099 is equivalent.
#
#
# 36MEY/SCH_1096 is equivalent.
#
#
# 36VEI_914 is equivalent.
#
#
# 36VEI_915 is equivalent.
#
#
# 36VEI_917 is equivalent.
#
#
# 36VEI_922 is equivalent.
#
#
# 36VEI_923 is equivalent.
#
#
# 36VEI_924 is equivalent.
# ERROR: 36VEI_924
#  ===============
# Old Keq, index 81: 45
# New Keq, index 117: 45.0
# Old Keq, index 82: 57
# New Keq, index 118: 57.0
#
#
# 36VEI_925 is equivalent.
#
#
# 36VEI_926 is equivalent.
# ERROR: 36VEI_926
#  ===============
# Old Keq, index 85: 19
# New Keq, index 121: 19.0
#
#
# 37ADL/SRE_8 is equivalent.
# ERROR: 37ADL/SRE_8
#  =================
# Old Keq, index 87: 6.00E-06
# New Keq, index 123: 6e-06
# Old Keq, index 88: 7.70E-05
# New Keq, index 124: 7.7e-05
#
#
# 37EUL/ADL_127 is equivalent.
# ERROR: 37EUL/ADL_127
#  ===================
# Old Keq, index 90: 2.30E-05
# New Keq, index 138: 2.3e-05
# Old Keq, index 91: 3.50E-05
# New Keq, index 139: 3.5e-05
#
#
# 37EUL/ADL_95 is equivalent.
# ERROR: 37EUL/ADL_95
#  ==================
# Old Keq, index 97: 7.70E-05
# New Keq, index 145: 7.7e-05
# Old Keq, index 98: 8.30E-05
# New Keq, index 146: 8.3e-05
#
#
# 37EUL/ADL2_42 is equivalent.
# ERROR: 37EUL/ADL2_42
#  ===================
# Old Keq, index 104: 1.60E-05
# New Keq, index 126: 1.6e-05
# Old Keq, index 105: 0.00059
# New Keq, index 127: 0.0003
# Old pH, index 105: 8.1
# New pH, index 127: 7.6
#
#
# 37EUL/ADL3_96 is equivalent.
# ERROR: 37EUL/ADL3_96
#  ===================
# Old Keq, index 107: 7.10E-06
# New Keq, index 129: 7.1e-06
# Old Keq, index 108: 9.60E-06
# New Keq, index 130: 9.6e-06
#
#
# 37NEG/WUL_9 is equivalent.
# ERROR: 37NEG/WUL_9
#  =================
# Old Keq, index 117: 3.90E-11
# New Keq, index 152: 3.9e-11
#
#
# 38EUL/ADL_273 is equivalent.
# ERROR: 38EUL/ADL_273
#  ===================
# Old Keq, index 117: 3.90E-11
# New Keq, index 152: 3.9e-11
# Old Keq, index 118: 1.30E-09
# New Keq, index 153: 1.3e-09
#
#
# 38MEY/SCH_1387 is equivalent.
#
#
# 38SCH/HEL_10 is equivalent.
# ERROR: 38SCH/HEL_10
#  ==================
# Old Keq, index 136: 2.60E-05
# New Keq, index 171: 2.6e-05
# Old Keq, index 137: 8.80E-05
# New Keq, index 172: 8.8e-05
#
#
# 38SCH/HEL_23 is equivalent.
# ERROR: 38SCH/HEL_23
#  ==================
# Old Keq, index 142: 9.10E-06
# New Keq, index 178: 9.1e-06
# Old Keq, index 143: 3.00E-05
# New Keq, index 179: 3e-05
#
#
# 39COH_504 is equivalent.
#
#
# 40COH_495 is equivalent.
# ERROR: 40COH_495
#  ===============
# Old Keq, index 151: 6.00E-05
# New Keq, index 187: 6e-05
#
#
# 40HER/GOR_1090 is equivalent.
# ERROR: 40HER/GOR_1090
#  ====================
# Old Keq, index 151: 6.00E-05
# New Keq, index 187: 6e-05
#
#
# 40KRE/SMY_1143 is equivalent.
#
#
# 41UTT/WER_1103 is equivalent.
# ERROR: 41UTT/WER_1103
#  ====================
# Old pH, index 159: 9
# New pH, index 195: 9.0
# Old pH, index 160: 9
# New pH, index 196: 9.0
#
#
# 41UTT/WER_1291 is equivalent.
# ERROR: 41UTT/WER_1291
#  ====================
# Old pH, index 162: 9
# New pH, index 198: 9.0
# Old temperature, index 163: 293.15
# New temperature, index 199: 298.15
# Old Keq, index 163: 1.43
# New Keq, index 199: 0.00182
# Old pH, index 163: 7.34
# New pH, index 199: 9.0
#
#
# 41WAR/CHR_1171 is equivalent.
#
#
# 42COL/SUT_1401 is equivalent.
#
#
# 42LEN/STR_505 is equivalent.
#
#
# 43BAN_590 is equivalent.
#
#
# 43DOU_415 is equivalent.
#
#
# 43KAL_633 is equivalent.
#
#
# 43KRE/EGG_1156 is equivalent.
#
#
# 43KRE/EGG_1159 is equivalent.
#
#
# 43KRE/EGG_1162 is equivalent.
# ERROR: 43KRE/EGG_1162
#  ====================
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
#
#
# 43KUB/OTT_97 is equivalent.
# ERROR: 43KUB/OTT_97
#  ==================
# Old Keq, index 183: 6.00E-05
# New Keq, index 221: 6e-05
# Old Keq, index 184: 8.00E-05
# New Keq, index 222: 8e-05
#
#
# 43MEY/JUN_1091 is equivalent.
# ERROR: 43MEY/JUN_1091
#  ====================
# Old Keq, index 184: 8.00E-05
# New Keq, index 222: 8e-05
# Old Keq, index 185: 1.50E-04
# New Keq, index 223: 0.00015
#
#
# 43MEY/JUN_1104 is equivalent.
#
#
# 43MEY/JUN_1281 is equivalent.
# ERROR: 43MEY/JUN_1281
#  ====================
# Old pH, index 192: 7
# New pH, index 230: 7.0
# Old pH, index 193: 7
# New pH, index 231: 7.0
#
#
# 44LIP_572 is equivalent.
# ERROR: 44LIP_572
#  ===============
# Old Keq, index 195: 5.60E-03
# New Keq, index 237: 0.0056
#
#
# 45DAR_496 is equivalent.
#
#
# 45DAR_506 is equivalent.
#
#
# 45DRA/MEY_250 is equivalent.
# ERROR: 45DRA/MEY_250
#  ===================
# Old pH, index 200: 8
# New pH, index 242: 8.0
#
#
# 45GRE/LEL_497 is equivalent.
# ERROR: 45GRE/LEL_497
#  ===================
# Old Keq, index 203: 1
# New Keq, index 245: 1.0
#
#
# 45GRE/LEL_507 is equivalent.
# ERROR: 45GRE/LEL_507
#  ===================
# Old Keq, index 203: 1
# New Keq, index 245: 1.0
#
#
# 45OHL_1144 is equivalent.
#
#
# 45OHL_816 is equivalent.
#
#
# 45OHL_817 is equivalent.
#
#
# 45OHL_822 is equivalent.
#
#
# 46OHL_823 is equivalent.
#
#
# 47BUC_578 is equivalent.
# ERROR: 47BUC_578
#  ===============
# Old Keq, index 212: 3.10E-04
# New Keq, index 254: 0.00031
# Old pH, index 213: 8
# New pH, index 255: 8.0
#
#
# 47MEY/OES_1282 is equivalent.
# ERROR: 47MEY/OES_1282
#  ====================
# Old pH, index 213: 8
# New pH, index 255: 8.0
# Old pH, index 214: 6
# New pH, index 256: 6.0
#
#
# 47MEY/OES_251 is equivalent.
# ERROR: 47MEY/OES_251
#  ===================
# Old pH, index 214: 6
# New pH, index 256: 6.0
#
#
# 48KOR_676 is equivalent.
#
#
# 48OCH_152 is equivalent.
#
#
# 48SCO/POW_1145 is equivalent.
#
#
# 48SOR/DEG_591 is equivalent.
#
#
# 49BAR_43 is equivalent.
# ERROR: 49BAR_43
#  ==============
# Old Keq, index 248: 7.10E-05
# New Keq, index 290: 7.1e-05
# Old pH, index 248: 7
# New pH, index 290: 7.0
#
#
# 49HES_743 is equivalent.
#
#
# 49MEY/GRE_762 is equivalent.
#
#
# 49MEY/GRE_763 is equivalent.
#
#
# 49MEY/GRE_764 is equivalent.
#
#
# 49MEY/GRE_765 is equivalent.
#
#
# 49MEY/GRE_768 is equivalent.
#
#
# 49MEY/GRE_770 is equivalent.
#
#
# 49MEY/GRE_778 is equivalent.
#
#
# 49MEY/GRE_786 is equivalent.
#
#
# 49MEY/GRE_818 is equivalent.
#
#
# 49MEY/GRE_819 is equivalent.
#
#
# 49MEY/GRE_820 is equivalent.
#
#
# 49MEY/GRE_821 is equivalent.
#
#
# 49MEY/GRE_824 is equivalent.
#
#
# 49MEY/OES_1172 is equivalent.
# ERROR: 49MEY/OES_1172
#  ====================
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
#
#
# 49MEY/OES_1388 is equivalent.
# ERROR: 49MEY/OES_1388
#  ====================
# Old Keq, index 264: 6
# New Keq, index 306: 6.0
#
#
# 49MEY/OES_563 is equivalent.
#
#
# 49SOR/DVO_615 is equivalent.
#
#
# 50COR/VEL_252 is equivalent.
#
#
# 50FRI_456 is equivalent.
#
#
# 50HES_744 is equivalent.
#
#
# 50HES_748 is equivalent.
# ERROR: 50HES_748
#  ===============
# Old Keq, index 275: 4.80E+02
# New Keq, index 317: 480.0
# Old pH, index 275: 5
# New pH, index 317: 5.0
# Old Keq, index 276: 1.73E+03
# New Keq, index 318: 1730.0
#
#
# 50KOR_677 is equivalent.
#
#
# 50OES/MEY_1283 is equivalent.
#
#
# 50PAZ_433 is equivalent.
#
#
# 50PAZ_435 is equivalent.
#
#
# 50PAZ_437 is equivalent.
#
#
# 50RAC_11 is equivalent.
# ERROR: 50RAC_11
#  ==============
# Old pH, index 283: 8
# New pH, index 325: 8.0
#
#
# 50RAC_98 is equivalent.
# ERROR: 50RAC_98
#  ==============
# Old pH, index 288: 8
# New pH, index 330: 8.0
#
#
# 50SLE_1345 is equivalent.
#
#
# 50SLE_1350 is equivalent.
#
#
# 51BLA_65 is equivalent.
# ERROR: 51BLA_65
#  ==============
# Old pH, index 294: 7
# New pH, index 336: 7.0
#
#
# 51BLI_35 is equivalent.
# ERROR: 51BLI_35
#  ==============
# Old pH, index 294: 7
# New pH, index 336: 7.0
# Old pH, index 295: 8
# New pH, index 337: 8.0
#
#
# 51FRU/JOH_971 is equivalent.
# ERROR: 51FRU/JOH_971
#  ===================
# Old pH, index 297: 8
# New pH, index 339: 8.0
#
#
# 51ROW/KOR_465 is equivalent.
# ERROR: 51ROW/KOR_465
#  ===================
# Old pH, index 299: 10
# New pH, index 341: 10.0
#
#
# 51THE/BON_12 is equivalent.
# ERROR: 51THE/BON_12
#  ==================
# Old pH, index 299: 10
# New pH, index 341: 10.0
# Old pH, index 300: 7
# New pH, index 342: 7.0
#
#
# 51WOO/GUN_1233 is equivalent.
# ERROR: 51WOO/GUN_1233
#  ====================
# Old Keq, index 303: 1
# New Keq, index 345: 1.0
#
#
# 52ASK_592 is equivalent.
#
#
# 52BAU/GEM_942 is equivalent.
#
#
# 52BAU/GEM_996 is equivalent.
# ERROR: 52BAU/GEM_996
#  ===================
# Old pH, index 308: 7
# New pH, index 350: 7.0
#
#
# 52BUR_29 is equivalent.
# ERROR: 52BUR_29
#  ==============
# Old pH, index 308: 7
# New pH, index 350: 7.0
#
#
# 52DOB/FRU_972 is equivalent.
#
#
# 52DOB/FRU_973 is equivalent.
#
#
# 52DOB/STU_956 is equivalent.
#
#
# 52DOB/STU_969 is equivalent.
#
#
# 52EGG/HEM_658 is equivalent.
# ERROR: 52EGG/HEM_658
#  ===================
# Old pH, index 340: 7
# New pH, index 382: 7.0
#
#
# 52FIT/DOU_419 is equivalent.
# ERROR: 52FIT/DOU_419
#  ===================
# Old pH, index 340: 7
# New pH, index 382: 7.0
#
#
# 52KOR_574 is equivalent.
#
#
# 52LEL/CAR_1260 is equivalent.
#
#
# 52LEL/CAR_698 is equivalent.
#
#
# 52MEY/SHA_815 is equivalent.
# ERROR: 52MEY/SHA_815
#  ===================
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
#
#
# 52NAR/WOO_1237 is equivalent.
# ERROR: 52NAR/WOO_1237
#  ====================
# Old Keq, index 345: 1
# New Keq, index 387: 1.0
# Old pH, index 346: 10
# New pH, index 388: 10.0
#
#
# 52NEI_99 is equivalent.
# ERROR: 52NEI_99
#  ==============
# Old pH, index 346: 10
# New pH, index 388: 10.0
# Old Keq, index 347: 2.30E-05
# New Keq, index 389: 2.3e-05
# Old pH, index 347: 7
# New pH, index 389: 7.0
#
#
# 52OHL/SHA_1061 is equivalent.
# ERROR: 52OHL/SHA_1061
#  ====================
# Old pH, index 351: 7
# New pH, index 393: 7.0
#
#
# 52OHL/SHA_1070 is equivalent.
# ERROR: 52OHL/SHA_1070
#  ====================
# Old pH, index 351: 7
# New pH, index 393: 7.0
# Old enthalpy, index 352: -19
# New enthalpy, index 394: -19.0
#
#
# 52OHL/SHA_792 is equivalent.
# ERROR: 52OHL/SHA_792
#  ===================
# Old enthalpy, index 352: -19
# New enthalpy, index 394: -19.0
#
#
# 52STA_394 is equivalent.
#
#
# 52STE/OCH_1129 is equivalent.
#
#
# 52STE/OCH_128 is equivalent.
# ERROR: 52STE/OCH_128
#  ===================
# Old Keq, index 359: 1.34E-06
# New Keq, index 401: 1.34e-06
# Old Keq, index 360: 5.55E-06
# New Keq, index 402: 5.55e-06
#
#
# 52STE/OCH_145 is equivalent.
#
#
# 52STR/KOR_158 is equivalent.
#
#
# 53BOC/ALB_1146 is equivalent.
#
#
# 53BOD_1351 is equivalent.
# ERROR: 53BOD_1351
#  ================
# Old pH, index 419: 7
# New pH, index 461: 7.0
#
#
# 53BRI_159 is equivalent.
# ERROR: 53BRI_159
#  ===============
# Old pH, index 419: 7
# New pH, index 461: 7.0
#
#
# 53BRO_1399 is equivalent.
#
#
# 53BUR/STA_240 is equivalent.
# ERROR: 53BUR/STA_240
#  ===================
# Old Keq, index 423: 2000
# New Keq, index 465: 2000.0
# Old Keq, index 424: 8200
# New Keq, index 466: 8200.0
#
#
# 53BUR/WIL_129 is equivalent.
# ERROR: 53BUR/WIL_129
#  ===================
# Old Keq, index 426: 2.75E-05
# New Keq, index 468: 2.75e-05
# Old Keq, index 427: 8.18E-05
# New Keq, index 469: 8.18e-05
#
#
# 53BUR/WIL_30 is equivalent.
#
#
# 53BUR/WIL_44 is equivalent.
# ERROR: 53BUR/WIL_44
#  ==================
# Old Keq, index 467: 1.74E-04
# New Keq, index 509: 0.000174
# Old Keq, index 468: 5.50E-04
# New Keq, index 510: 0.00055
# Old pH, index 468: 8
# New pH, index 510: 8.0
#
#
# 53COH_1294 is equivalent.
#
#
# 53GRE/BRO_634 is equivalent.
#
#
# 53HAR/KOR_147 is equivalent.
#
#
# 53HOC/WAT_1323 is equivalent.
#
#
# 53JON_1432 is equivalent.
# ERROR: 53JON_1432
#  ================
# Old pH, index 476: 6
# New pH, index 518: 6.0
#
#
# 53KAP/COL_309 is equivalent.
# ERROR: 53KAP/COL_309
#  ===================
# Old pH, index 476: 6
# New pH, index 518: 6.0
#
#
# 53KRE_1147 is equivalent.
#
#
# 53KRE_1157 is equivalent.
#
#
# 53KRE_1160 is equivalent.
#
#
# 53KRE_1163 is equivalent.
# ERROR: 53KRE_1163
#  ================
# Old Keq, index 483: 0.148
# New Keq, index 527: 0.0019
# Old pH, index 483: 7.4
# New pH, index 527: 7.0
#
#
# 53KRE2_498 is equivalent.
#
#
# 53KRE2_508 is equivalent.
# ERROR: 53KRE2_508
#  ================
# Old Keq, index 485: 1.90E-03
# New Keq, index 523: 4.43
# Old pH, index 485: 7
# New pH, index 523: 7.4
#
#
# 53LYN/OCH_116 is equivalent.
# ERROR: 53LYN/OCH_116
#  ===================
# Old Keq, index 485: 1.90E-03
# New Keq, index 527: 0.0019
# Old pH, index 485: 7
# New pH, index 527: 7.0
# Old Keq, index 486: 2.00E-05
# New Keq, index 528: 2e-05
#
#
# 53LYN/OCH_404 is equivalent.
# ERROR: 53LYN/OCH_404
#  ===================
# Old Keq, index 486: 2.00E-05
# New Keq, index 528: 2e-05
# Old Keq, index 487: 1.00E-04
# New Keq, index 529: 0.0001
# Old pH, index 487: 9
# New pH, index 529: 9.0
#
#
# 53LYN/OCH_717 is equivalent.
# ERROR: 53LYN/OCH_717
#  ===================
# Old pH, index 489: 8
# New pH, index 531: 8.0
#
#
# 53MAH/WAK_1436 is equivalent.
# ERROR: 53MAH/WAK_1436
#  ====================
# Old pH, index 489: 8
# New pH, index 531: 8.0
#
#
# 53MAS_1148 is equivalent.
#
#
# 53MEY/SHA_1069 is equivalent.
# ERROR: 53MEY/SHA_1069
#  ====================
# Old pH, index 515: 7
# New pH, index 557: 7.0
#
#
# 53MIT/LAM_1324 is equivalent.
# ERROR: 53MIT/LAM_1324
#  ====================
# Old pH, index 515: 7
# New pH, index 557: 7.0
#
#
# 53NIS/BAR_499 is equivalent.
# ERROR: 53NIS/BAR_499
#  ===================
# Old Keq, index 517: 4.60E-07
# New Keq, index 559: 4.6e-07
#
#
# 53OLS/ANF_280 is equivalent.
# ERROR: 53OLS/ANF_280
#  ===================
# Old Keq, index 517: 4.60E-07
# New Keq, index 559: 4.6e-07
# Old Keq, index 518: 1.50E-06
# New Keq, index 560: 1.5e-06
# Old pH, index 518: 7
# New pH, index 560: 7.0
#
#
# 53OLS/ANF_281 is equivalent.
# ERROR: 53OLS/ANF_281
#  ===================
# Old Keq, index 520: 9.70E-07
# New Keq, index 562: 9.7e-07
# Old pH, index 520: 7
# New pH, index 562: 7.0
# Old Keq, index 521: 3.10E-06
# New Keq, index 563: 3.1e-06
#
#
# 53OLS/ANF_282 is equivalent.
# ERROR: 53OLS/ANF_282
#  ===================
# Old Keq, index 523: 3.10E-07
# New Keq, index 565: 3.1e-07
# Old Keq, index 524: 9.90E-07
# New Keq, index 566: 9.9e-07
# Old pH, index 524: 7
# New pH, index 566: 7.0
#
#
# 53RAT/ANS_1222 is equivalent.
# ERROR: 53RAT/ANS_1222
#  ====================
# Old Keq, index 527: 1
# New Keq, index 569: 1.0
#
#
# 53SIE/POT_635 is equivalent.
# ERROR: 53SIE/POT_635
#  ===================
# Old Keq, index 527: 1
# New Keq, index 569: 1.0
# Old Keq, index 528: 2.00E-05
# New Keq, index 570: 2e-05
#
#
# 53STE/COO_405 is equivalent.
# ERROR: 53STE/COO_405
#  ===================
# Old Keq, index 528: 2.00E-05
# New Keq, index 570: 2e-05
#
#
# 53STE/COO_718 is equivalent.
# ERROR: 53STE/COO_718
#  ===================
# Old Keq, index 530: 3.47E-07
# New Keq, index 572: 3.47e-07
#
#
# 53STR_274 is equivalent.
# ERROR: 53STR_274
#  ===============
# Old Keq, index 530: 3.47E-07
# New Keq, index 572: 3.47e-07
# Old Keq, index 531: 1.09E-06
# New Keq, index 573: 1.09e-06
#
#
# 53STU_954 is equivalent.
#
#
# 53STU_955 is equivalent.
#
#
# 53TAL/DOB_178 is equivalent.
#
#
# 54AXE/JAN_1331 is equivalent.
# ERROR: 54AXE/JAN_1331
#  ====================
# Old pH, index 558: 7
# New pH, index 600: 7.0
# Old pH, index 559: 7
# New pH, index 601: 7.0
#
#
# 54BER/JOK_665 is equivalent.
# ERROR: 54BER/JOK_665
#  ===================
# Old pH, index 561: 6
# New pH, index 603: 6.0
# Old pH, index 562: 6
# New pH, index 604: 6.0
#
#
# 54BOW/KER_636 is equivalent.
# ERROR: 54BOW/KER_636
#  ===================
# Old pH, index 562: 6
# New pH, index 604: 6.0
# Old pH, index 563: 6
# New pH, index 605: 6.0
#
#
# 54CHA_1086 is equivalent.
#
#
# 54GIN_771 is equivalent.
#
#
# 54GIN_779 is equivalent.
#
#
# 54GOL_406 is equivalent.
# ERROR: 54GOL_406
#  ===============
# Old Keq, index 573: 6.00E-05
# New Keq, index 615: 6e-05
# Old Keq, index 574: 8.70E-05
# New Keq, index 616: 8.7e-05
#
#
# 54GRE/MII_264 is equivalent.
# ERROR: 54GRE/MII_264
#  ===================
# Old Keq, index 575: 10
# New Keq, index 617: 10.0
# Old pH, index 575: 7
# New pH, index 617: 7.0
#
#
# 54HAN/CRA_1261 is equivalent.
#
#
# 54HEL_1433 is equivalent.
# ERROR: 54HEL_1433
#  ================
# Old pH, index 578: 8
# New pH, index 620: 8.0
#
#
# 54HEL_1435 is equivalent.
# ERROR: 54HEL_1435
#  ================
# Old pH, index 580: 8
# New pH, index 622: 8.0
# Old pH, index 581: 7
# New pH, index 623: 7.0
#
#
# 54LEV/MEI_1439 is equivalent.
# ERROR: 54LEV/MEI_1439
#  ====================
# Old pH, index 581: 7
# New pH, index 623: 7.0
# Old pH, index 582: 6
# New pH, index 624: 6.0
#
#
# 54LIE/KOR_1036 is equivalent.
#
#
# 54LIE/KOR_1039 is equivalent.
# ERROR: 54LIE/KOR_1039
#  ====================
# Old Keq, index 587: 1
# New Keq, index 629: 1.0
# Old pH, index 587: 8
# New pH, index 629: 8.0
#
#
# 54MAR/WIL_1234 is equivalent.
# ERROR: 54MAR/WIL_1234
#  ====================
# Old Keq, index 587: 1
# New Keq, index 629: 1.0
# Old pH, index 587: 8
# New pH, index 629: 8.0
#
#
# 54MIT/DAV_1168 is equivalent.
# ERROR: 54MIT/DAV_1168
#  ====================
# Old Keq, index 589: 8.70E-03
# New Keq, index 631: 0.0087
#
#
# 54ROS/GRU_573 is equivalent.
# ERROR: 54ROS/GRU_573
#  ===================
# Old Keq, index 589: 8.70E-03
# New Keq, index 631: 0.0087
# Old pH, index 590: 6
# New pH, index 632: 6.0
#
#
# 54SIS/STA_1427 is equivalent.
# ERROR: 54SIS/STA_1427
#  ====================
# Old pH, index 590: 6
# New pH, index 632: 6.0
#
#
# 54SIS/STA_1428 is equivalent.
# ERROR: 54SIS/STA_1428
#  ====================
# Old Keq, index 595: 4
# New Keq, index 637: 4.0
# Old pH, index 595: 8
# New pH, index 637: 8.0
#
#
# 54STA_375 is equivalent.
#
#
# 54STR/HAR_38 is equivalent.
# ERROR: 54STR/HAR_38
#  ==================
# Old Keq, index 601: 7.23E-03
# New Keq, index 643: 0.00723
# Old Keq, index 602: 6.68E-02
# New Keq, index 644: 0.0668
#
#
# 54UTT/KUR_1082 is equivalent.
# ERROR: 54UTT/KUR_1082
#  ====================
# Old Keq, index 604: 6.30E-01
# New Keq, index 646: 0.63
# Old pH, index 604: 10
# New pH, index 646: 10.0
#
#
# 54WAK/GRE_123 is equivalent.
# ERROR: 54WAK/GRE_123
#  ===================
# Old Keq, index 604: 6.30E-01
# New Keq, index 646: 0.63
# Old pH, index 604: 10
# New pH, index 646: 10.0
# Old Keq, index 605: 6.30E-04
# New Keq, index 647: 0.00063
# Old pH, index 605: 7
# New pH, index 647: 7.0
#
#
# 54WAK/GRE_126 is equivalent.
# ERROR: 54WAK/GRE_126
#  ===================
# Old Keq, index 608: 2.50E-01
# New Keq, index 650: 0.25
# Old pH, index 608: 10
# New pH, index 650: 10.0
# Old Keq, index 609: 2.50E-04
# New Keq, index 651: 0.00025
# Old pH, index 609: 7
# New pH, index 651: 7.0
#
#
# 54WIL/BAN_66 is equivalent.
# ERROR: 54WIL/BAN_66
#  ==================
# Old Keq, index 612: 2.05E-02
# New Keq, index 654: 0.0205
# Old pH, index 612: 7
# New pH, index 654: 7.0
# Old temperature, index 613: 288.15
# New temperature, index 655: 298.15
# Old Keq, index 613: 3.50E-04
# New Keq, index 655: 7.4
# Old pH, index 613: 7
# New pH, index 655: 4.4
#
#
# 55BLA/WRI_587 is equivalent.
# ERROR: 55BLA/WRI_587
#  ===================
# Old Keq, index 613: 3.50E-04
# New Keq, index 659: 0.00035
# Old pH, index 613: 7
# New pH, index 659: 7.0
# Old Keq, index 614: 7.4
# New Keq, index 660: 6.4e-05
# Old pH, index 614: 4.4
# New pH, index 660: 7.1
#
#
# 55BLA/WRI2_242 is equivalent.
# ERROR: 55BLA/WRI2_242
#  ====================
# Old Keq, index 615: 2.00E+02
# New Keq, index 656: 200.0
#
#
# 55BLA/WRI3_36 is equivalent.
# ERROR: 55BLA/WRI3_36
#  ===================
# Old Keq, index 616: 8.80E-03
# New Keq, index 657: 0.0088
# Old Keq, index 617: 6.30E-04
# New Keq, index 658: 0.00063
#
#
# 55BLA/WRI3_37 is equivalent.
# ERROR: 55BLA/WRI3_37
#  ===================
# Old Keq, index 617: 6.30E-04
# New Keq, index 658: 0.00063
# Old temperature, index 618: 298.15
# New temperature, index 659: 288.15
# Old Keq, index 618: 6.40E-05
# New Keq, index 659: 0.00035
# Old pH, index 618: 7.1
# New pH, index 659: 7.0
#
#
# 55BUR_39 is equivalent.
# ERROR: 55BUR_39
#  ==============
# Old Keq, index 618: 6.40E-05
# New Keq, index 660: 6.4e-05
# Old pH, index 619: 7
# New pH, index 661: 7.0
#
#
# 55CAR/COH_1223 is equivalent.
# ERROR: 55CAR/COH_1223
#  ====================
# Old pH, index 619: 7
# New pH, index 661: 7.0
#
#
# 55CAR/LEL_423 is equivalent.
# ERROR: 55CAR/LEL_423
#  ===================
# Old Keq, index 621: 4.61E-03
# New Keq, index 663: 0.00461
#
#
# 55DAV/GIL_81 is equivalent.
# ERROR: 55DAV/GIL_81
#  ==================
# Old Keq, index 621: 4.61E-03
# New Keq, index 663: 0.00461
# Old pH, index 622: 7
# New pH, index 664: 7.0
#
#
# 55DAV/GIL_82 is equivalent.
# ERROR: 55DAV/GIL_82
#  ==================
# Old pH, index 622: 7
# New pH, index 664: 7.0
#
#
# 55DEC_407 is equivalent.
# ERROR: 55DEC_407
#  ===============
# Old Keq, index 624: 1.48E-05
# New Keq, index 666: 1.48e-05
# Old pH, index 624: 6
# New pH, index 666: 6.0
# Old Keq, index 625: 1.56E-05
# New Keq, index 667: 1.56e-05
# Old pH, index 625: 7
# New pH, index 667: 7.0
#
#
# 55DIC/WIL_1332 is equivalent.
# ERROR: 55DIC/WIL_1332
#  ====================
# Old pH, index 630: 7
# New pH, index 672: 7.0
#
#
# 55GLA/BRO_162 is equivalent.
#
#
# 55HOR/SMY_371 is equivalent.
#
#
# 55KAT_112 is equivalent.
#
#
# 55KAU/ALI_1438 is equivalent.
# ERROR: 55KAU/ALI_1438
#  ====================
# Old pH, index 635: 8
# New pH, index 677: 8.0
#
#
# 55KIT/BEN_1071 is equivalent.
# ERROR: 55KIT/BEN_1071
#  ====================
# Old pH, index 635: 8
# New pH, index 677: 8.0
# Old pH, index 636: 8
# New pH, index 678: 8.0
#
#
# 55KIT/BEN_1077 is equivalent.
# ERROR: 55KIT/BEN_1077
#  ====================
# Old pH, index 640: 8
# New pH, index 682: 8.0
# Old Keq, index 641: 6.90E-04
# New Keq, index 683: 0.00069
# Old pH, index 641: 7
# New pH, index 683: 7.0
#
#
# 55LEH/SIC_1089 is equivalent.
# ERROR: 55LEH/SIC_1089
#  ====================
# Old Keq, index 641: 6.90E-04
# New Keq, index 683: 0.00069
# Old pH, index 641: 7
# New pH, index 683: 7.0
# Old Keq, index 642: 1.18E-04
# New Keq, index 684: 0.000118
# Old pH, index 642: 7
# New pH, index 684: 7.0
#
#
# 55LEH/SIC_1092 is equivalent.
# ERROR: 55LEH/SIC_1092
#  ====================
# Old Keq, index 642: 1.18E-04
# New Keq, index 684: 0.000118
# Old pH, index 642: 7
# New pH, index 684: 7.0
# Old Keq, index 643: 2.80E-06
# New Keq, index 685: 2.8e-06
# Old pH, index 643: 7
# New pH, index 685: 7.0
#
#
# 55LEH/SIC_1097 is equivalent.
# ERROR: 55LEH/SIC_1097
#  ====================
# Old Keq, index 643: 2.80E-06
# New Keq, index 685: 2.8e-06
# Old pH, index 643: 7
# New pH, index 685: 7.0
# Old temperature, index 644: 303.15
# New temperature, index 686: 309.15
# Old Keq, index 644: 8.3
# New Keq, index 686: 0.94
# Old pH, index 644: 8
# New pH, index 686: 7.5
#
#
# 55LIE/KOR_480 is equivalent.
# ERROR: 55LIE/KOR_480
#  ===================
# Old pH, index 644: 8
# New pH, index 687: 8.0
# Old temperature, index 645: 309.15
# New temperature, index 688: 298.15
# Old Keq, index 645: 0.94
# New Keq, index 688: 0.012
# Old pH, index 645: 7.5
# New pH, index 688: 7.8
#
#
# 55LIE/KOR2_664 is equivalent.
# ERROR: 55LIE/KOR2_664
#  ====================
# Old temperature, index 646: 298.15
# New temperature, index 687: 303.15
# Old Keq, index 646: 0.012
# New Keq, index 687: 8.3
# Old pH, index 646: 7.8
# New pH, index 687: 8.0
#
#
# 55LYN/WIE_124 is equivalent.
#
#
# 55MUN_683 is equivalent.
# ERROR: 55MUN_683
#  ===============
# Old pH, index 648: 8
# New pH, index 690: 8.0
#
#
# 55POD/STU_1072 is equivalent.
# ERROR: 55POD/STU_1072
#  ====================
# Old pH, index 648: 8
# New pH, index 690: 8.0
#
#
# 55SLE_1325 is equivalent.
# ERROR: 55SLE_1325
#  ================
# Old Keq, index 650: 1200
# New Keq, index 692: 1200.0
# Old pH, index 650: 7
# New pH, index 692: 7.0
#
#
# 55STA/BUR_241 is equivalent.
# ERROR: 55STA/BUR_241
#  ===================
# Old Keq, index 650: 1200
# New Keq, index 692: 1200.0
# Old pH, index 650: 7
# New pH, index 692: 7.0
# Old pH, index 651: 8
# New pH, index 693: 8.0
#
#
# 55STA_395 is equivalent.
# ERROR: 55STA_395
#  ===============
# Old pH, index 651: 8
# New pH, index 693: 8.0
# Old enthalpy, index 652: -26.4
# New enthalpy, index 694: -1.34
# Old pH, index 652: 3.62
# New pH, index 694: 7.6
#
#
# 55STU_825 is equivalent.
#
#
# 55STU2_978 is equivalent.
# ERROR: 55STU2_978
#  ================
# Old temperature, index 662: 310.15
# New temperature, index 695: 298.15
# Old Keq, index 662: 1
# New Keq, index 695:
# Old pH, index 662: 7.4
# New pH, index 695: 3.62
#
#
# 55THO/GOM_1235 is equivalent.
# ERROR: 55THO/GOM_1235
#  ====================
# Old Keq, index 662: 1
# New Keq, index 704: 1.0
#
#
# 55VAR/WEB_1440 is equivalent.
#
#
# 55WIL/MCI_1208 is equivalent.
# ERROR: 55WIL/MCI_1208
#  ====================
# Old pH, index 665: 7
# New pH, index 707: 7.0
#
#
# 55WOL/KAP_75 is equivalent.
# ERROR: 55WOL/KAP_75
#  ==================
# Old pH, index 665: 7
# New pH, index 707: 7.0
# Old pH, index 666: 7
# New pH, index 708: 7.0
#
#
# 55YAN/GIL_83 is equivalent.
# ERROR: 55YAN/GIL_83
#  ==================
# Old pH, index 666: 7
# New pH, index 708: 7.0
#
#
# 55ZEL_85 is equivalent.
# ERROR: 55ZEL_85
#  ==============
# Old Keq, index 668: 2.71E-06
# New Keq, index 710: 2.71e-06
# Old pH, index 668: 7
# New pH, index 710: 7.0
# Old Keq, index 669: 1.31E-05
# New Keq, index 711: 1.31e-05
#
#
# 55ZEL_88 is equivalent.
# ERROR: 55ZEL_88
#  ==============
# Old Keq, index 674: 1.03E-07
# New Keq, index 716: 1.03e-07
# Old Keq, index 675: 9.29E-08
# New Keq, index 717: 9.29e-08
#
#
# 56ALE/GRE_348 is equivalent.
#
#
# 56AME/HOR_519 is equivalent.
#
#
# 56BEN/HEM_989 is equivalent.
# ERROR: 56BEN/HEM_989
#  ===================
# Old pH, index 684: 6
# New pH, index 726: 6.0
#
#
# 56BOW/KER_637 is equivalent.
# ERROR: 56BOW/KER_637
#  ===================
# Old pH, index 684: 6
# New pH, index 726: 6.0
# Old pH, index 685: 6
# New pH, index 727: 6.0
#
#
# 56CAR/COH_1224 is equivalent.
# ERROR: 56CAR/COH_1224
#  ====================
# Old pH, index 693: 6
# New pH, index 735: 6.0
#
#
# 56COW/PIZ_1389 is equivalent.
# ERROR: 56COW/PIZ_1389
#  ====================
# Old Keq, index 696: 5
# New Keq, index 738: 5.0
#
#
# 56DIC/WIL_1262 is equivalent.
#
#
# 56DIC/WIL_1333 is equivalent.
#
#
# 56ENG_1371 is equivalent.
#
#
# 56FEU/WOL_557 is equivalent.
#
#
# 56FOR/GUT_977 is equivalent.
#
#
# 56GRE/COH_1296 is equivalent.
# ERROR: 56GRE/COH_1296
#  ====================
# Old pH, index 740: 8
# New pH, index 782: 8.0
# Old Keq, index 741: 9.78E-06
# New Keq, index 783: 9.78e-06
#
#
# 56HAK/GLA_100 is equivalent.
# ERROR: 56HAK/GLA_100
#  ===================
# Old Keq, index 741: 9.78E-06
# New Keq, index 783: 9.78e-06
# Old Keq, index 742: 1.74E-05
# New Keq, index 784: 1.74e-05
#
#
# 56HAU_265 is equivalent.
# ERROR: 56HAU_265
#  ===============
# Old pH, index 745: 7
# New pH, index 787: 7.0
#
#
# 56HUB_1279 is equivalent.
# ERROR: 56HUB_1279
#  ================
# Old pH, index 745: 7
# New pH, index 787: 7.0
#
#
# 56HUR/HOR_1244 is equivalent.
# ERROR: 56HUR/HOR_1244
#  ====================
# Old Keq, index 747: 1.20E-03
# New Keq, index 789: 0.0012
# Old pH, index 747: 9
# New pH, index 789: 9.0
#
#
# 56KAP/CIO_101 is equivalent.
# ERROR: 56KAP/CIO_101
#  ===================
# Old Keq, index 747: 1.20E-03
# New Keq, index 789: 0.0012
# Old pH, index 747: 9
# New pH, index 789: 9.0
# Old pH, index 748: 9
# New pH, index 790: 9.0
#
#
# 56KAP/CIO_110 is equivalent.
# ERROR: 56KAP/CIO_110
#  ===================
# Old pH, index 748: 9
# New pH, index 790: 9.0
# Old Keq, index 749: 1.60E-04
# New Keq, index 791: 0.00016
# Old pH, index 749: 7
# New pH, index 791: 7.0
#
#
# 56KAP/CIO_13 is equivalent.
# ERROR: 56KAP/CIO_13
#  ==================
# Old Keq, index 749: 1.60E-04
# New Keq, index 791: 0.00016
# Old pH, index 749: 7
# New pH, index 791: 7.0
# Old Keq, index 750: 1.60E-03
# New Keq, index 792: 0.0016
# Old pH, index 750: 8
# New pH, index 792: 8.0
#
#
# 56KAP/CIO_22 is equivalent.
# ERROR: 56KAP/CIO_22
#  ==================
# Old pH, index 751: 7
# New pH, index 793: 7.0
# Old pH, index 752: 8
# New pH, index 794: 8.0
#
#
# 56KAP/CIO_275 is equivalent.
# ERROR: 56KAP/CIO_275
#  ===================
# Old Keq, index 753: 2.43E-06
# New Keq, index 795: 2.43e-06
#
#
# 56KAP/CIO_278 is equivalent.
# ERROR: 56KAP/CIO_278
#  ===================
# Old pH, index 755: 8
# New pH, index 797: 8.0
#
#
# 56KIT/HOR_1085 is equivalent.
# ERROR: 56KIT/HOR_1085
#  ====================
# Old pH, index 755: 8
# New pH, index 797: 8.0
# Old pH, index 756: 8
# New pH, index 798: 8.0
#
#
# 56LAR/JAC_77 is equivalent.
# ERROR: 56LAR/JAC_77
#  ==================
# Old Keq, index 757: 6.70E-04
# New Keq, index 799: 0.00067
# Old Keq, index 758: 3.70E-04
# New Keq, index 800: 0.00037
#
#
# 56LEL/CAR_1366 is equivalent.
#
#
# 56PAL/DOU_1340 is equivalent.
#
#
# 56PAL/DOU_1341 is equivalent.
#
#
# 56PAL/DOU_1344 is equivalent.
# ERROR: 56PAL/DOU_1344
#  ====================
# Old pH, index 766: 8
# New pH, index 808: 8.0
#
#
# 56POD/MOR_1078 is equivalent.
# ERROR: 56POD/MOR_1078
#  ====================
# Old pH, index 766: 8
# New pH, index 808: 8.0
# Old pH, index 767: 7
# New pH, index 809: 7.0
#
#
# 56RAB/PRI_353 is equivalent.
# ERROR: 56RAB/PRI_353
#  ===================
# Old pH, index 767: 7
# New pH, index 809: 7.0
#
#
# 56RAM/GIR_1352 is equivalent.
#
#
# 56RAT/ROC_364 is equivalent.
#
#
# 56REI_1407 is equivalent.
#
#
# 56SMI/STA_1113 is equivalent.
#
#
# 56SMI/STA_1124 is equivalent.
# ERROR: 56SMI/STA_1124
#  ====================
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
#
#
# 56STE/COO_719 is equivalent.
# ERROR: 56STE/COO_719
#  ===================
# Old Keq, index 773: 4.90E-03
# New Keq, index 815: 0.0049
# Old pH, index 773: 7
# New pH, index 815: 7.0
# Old Keq, index 774: 2.80E-03
# New Keq, index 816: 0.0028
# Old pH, index 774: 7
# New pH, index 816: 7.0
#
#
# 56STE/DEL_1175 is equivalent.
#
#
# 56STE/DEL_1176 is equivalent.
#
#
# 56STE/DEL_1177 is equivalent.
#
#
# 56STE/DEL_1178 is equivalent.
# ERROR: 56STE/DEL_1178
#  ====================
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
#
#
# 56STE_720 is equivalent.
# ERROR: 56STE_720
#  ===============
# Old Keq, index 785: 4.60E-03
# New Keq, index 827: 0.0046
# Old pH, index 785: 7
# New pH, index 827: 7.0
# Old Keq, index 786: 2.80E-03
# New Keq, index 828: 0.0028
# Old pH, index 786: 7
# New pH, index 828: 7.0
#
#
# 56STU/HOR_1245 is equivalent.
# ERROR: 56STU/HOR_1245
#  ====================
# Old Keq, index 794: 5.80E-03
# New Keq, index 836: 0.0058
# Old pH, index 794: 6
# New pH, index 836: 6.0
#
#
# 56TAL/MAR_166 is equivalent.
# ERROR: 56TAL/MAR_166
#  ===================
# Old Keq, index 794: 5.80E-03
# New Keq, index 836: 0.0058
# Old pH, index 794: 6
# New pH, index 836: 6.0
# Old Keq, index 795: 5.80E-02
# New Keq, index 837: 0.058
# Old pH, index 795: 7
# New pH, index 837: 7.0
#
#
# 56TAL/MAR_179 is equivalent.
# ERROR: 56TAL/MAR_179
#  ===================
# Old pH, index 798: 6
# New pH, index 840: 6.0
# Old pH, index 799: 7
# New pH, index 841: 7.0
#
#
# 56TOM_173 is equivalent.
# ERROR: 56TOM_173
#  ===============
# Old pH, index 802: 7
# New pH, index 844: 7.0
#
#
# 56WOL/KAP_76 is equivalent.
# ERROR: 56WOL/KAP_76
#  ==================
# Old Keq, index 804: 4.90E-03
# New Keq, index 846: 0.0049
# Old pH, index 804: 7
# New pH, index 846: 7.0
#
#
# 57ASH/HIC_1246 is equivalent.
# ERROR: 57ASH/HIC_1246
#  ====================
# Old pH, index 806: 7
# New pH, index 848: 7.0
#
#
# 57BUR/HOR_1263 is equivalent.
# ERROR: 57BUR/HOR_1263
#  ====================
# Old pH, index 806: 7
# New pH, index 848: 7.0
#
#
# 57CAL_638 is equivalent.
#
#
# 57DUR/STU_339 is equivalent.
# ERROR: 57DUR/STU_339
#  ===================
# Old pH, index 812: 8
# New pH, index 854: 8.0
#
#
# 57FLA/ERW_476 is equivalent.
# ERROR: 57FLA/ERW_476
#  ===================
# Old pH, index 812: 8
# New pH, index 854: 8.0
#
#
# 57GRE/LIP_715 is equivalent.
#
#
# 57GRE/LIP_716 is equivalent.
# ERROR: 57GRE/LIP_716
#  ===================
# Old Keq, index 815: 1.73E-02
# New Keq, index 857: 0.0173
#
#
# 57HOH_102 is equivalent.
# ERROR: 57HOH_102
#  ===============
# Old Keq, index 815: 1.73E-02
# New Keq, index 857: 0.0173
# Old Keq, index 816: 3.70E-06
# New Keq, index 858: 3.7e-06
# Old pH, index 816: 7
# New pH, index 858: 7.0
#
#
# 57HOL/HOL_113 is equivalent.
# ERROR: 57HOL/HOL_113
#  ===================
# Old Keq, index 816: 3.70E-06
# New Keq, index 858: 3.7e-06
# Old pH, index 816: 7
# New pH, index 858: 7.0
# Old Keq, index 817: 8.57E-06
# New Keq, index 859: 8.57e-06
#
#
# 57HOL/TOU_56 is equivalent.
# ERROR: 57HOL/TOU_56
#  ==================
# Old Keq, index 824: 8.58E-04
# New Keq, index 866: 0.000858
# Old pH, index 824: 7
# New pH, index 866: 7.0
# Old Keq, index 825: 8.58E-03
# New Keq, index 867: 0.00858
# Old pH, index 825: 8
# New pH, index 867: 8.0
#
#
# 57KAR/GRE_347 is equivalent.
#
#
# 57MAX_1249 is equivalent.
# ERROR: 57MAX_1249
#  ================
# Old Keq, index 828: 1.00E+05
# New Keq, index 870: 100000.0
#
#
# 57REI_362 is equivalent.
# ERROR: 57REI_362
#  ===============
# Old Keq, index 828: 1.00E+05
# New Keq, index 870: 100000.0
#
#
# 57ROB/BOY_544 is equivalent.
#
#
# 57ROB/COO_122 is equivalent.
# ERROR: 57ROB/COO_122
#  ===================
# Old Keq, index 858: 1.20E-01
# New Keq, index 900: 0.12
# Old pH, index 858: 10
# New pH, index 900: 10.0
# Old Keq, index 859: 3.60E-02
# New Keq, index 901: 0.0031
# Old pH, index 859: 9
# New pH, index 901: 8.0
#
#
# 57ROD/TOW_1390 is equivalent.
# ERROR: 57ROD/TOW_1390
#  ====================
# Old Keq, index 861: 6
# New Keq, index 903: 6.0
#
#
# 57SAN/SEA_323 is equivalent.
#
#
# 57SMI/GUN_1114 is equivalent.
#
#
# 57STE_125 is equivalent.
# ERROR: 57STE_125
#  ===============
# Old Keq, index 871: 7.42E-02
# New Keq, index 913: 0.0742
# Old pH, index 871: 7
# New pH, index 913: 7.0
#
#
# 57TAL_167 is equivalent.
# ERROR: 57TAL_167
#  ===============
# Old Keq, index 871: 7.42E-02
# New Keq, index 913: 0.0742
# Old pH, index 871: 7
# New pH, index 913: 7.0
# Old Keq, index 872: 6.68E-02
# New Keq, index 914: 0.0668
# Old pH, index 872: 7
# New pH, index 914: 7.0
#
#
# 57TAL_170 is equivalent.
# ERROR: 57TAL_170
#  ===============
# Old Keq, index 872: 6.68E-02
# New Keq, index 914: 0.0668
# Old pH, index 872: 7
# New pH, index 914: 7.0
# Old Keq, index 873: 1.57E-02
# New Keq, index 915: 0.0157
# Old pH, index 873: 7
# New pH, index 915: 7.0
#
#
# 57TAL_171 is equivalent.
# ERROR: 57TAL_171
#  ===============
# Old Keq, index 873: 1.57E-02
# New Keq, index 915: 0.0157
# Old pH, index 873: 7
# New pH, index 915: 7.0
# Old pH, index 874: 7
# New pH, index 916: 7.0
#
#
# 57TAL_174 is equivalent.
# ERROR: 57TAL_174
#  ===============
# Old pH, index 874: 7
# New pH, index 916: 7.0
# Old pH, index 875: 7
# New pH, index 917: 7.0
#
#
# 57TAL_177 is equivalent.
# ERROR: 57TAL_177
#  ===============
# Old pH, index 875: 7
# New pH, index 917: 7.0
# Old pH, index 876: 7
# New pH, index 918: 7.0
#
#
# 57TAL_180 is equivalent.
# ERROR: 57TAL_180
#  ===============
# Old pH, index 876: 7
# New pH, index 918: 7.0
# Old pH, index 877: 7
# New pH, index 919: 7.0
#
#
# 57TAL_182 is equivalent.
# ERROR: 57TAL_182
#  ===============
# Old pH, index 877: 7
# New pH, index 919: 7.0
#
#
# 57VLA/VLA_545 is equivalent.
# ERROR: 57VLA/VLA_545
#  ===================
# Old Keq, index 879: 6.46E-05
# New Keq, index 921: 6.46e-05
# Old pH, index 879: 7
# New pH, index 921: 7.0
#
#
# 58BAC_14 is equivalent.
# ERROR: 58BAC_14
#  ==============
# Old Keq, index 879: 6.46E-05
# New Keq, index 921: 6.46e-05
# Old pH, index 879: 7
# New pH, index 921: 7.0
# Old pH, index 880: 8
# New pH, index 922: 8.0
#
#
# 58BRU/NOL_1334 is equivalent.
#
#
# 58BUR/HOR_1264 is equivalent.
# ERROR: 58BUR/HOR_1264
#  ====================
# Old pH, index 907: 7
# New pH, index 949: 7.0
#
#
# 58CAB/LEL_432 is equivalent.
# ERROR: 58CAB/LEL_432
#  ===================
# Old Keq, index 909: 2.9
# New Keq, index 951: 0.0031
# Old pH, index 909: 8
# New pH, index 951: 7.4
#
#
# 58FRO_1443 is equivalent.
# ERROR: 58FRO_1443
#  ================
# Old pH, index 909: 8
# New pH, index 954: 8.0
# Old temperature, index 910: 310.15
# New temperature, index 955: 298.15
# Old Keq, index 910: 0.0031
# New Keq, index 955: 0.11
# Old pH, index 910: 7.4
# New pH, index 955: 7.0
#
#
# 58FRO2_187 is equivalent.
# ERROR: 58FRO2_187
#  ================
# Old pH, index 911: 8
# New pH, index 952: 8.0
#
#
# 58HEA/HOR_1297 is equivalent.
# ERROR: 58HEA/HOR_1297
#  ====================
# Old pH, index 913: 7
# New pH, index 955: 7.0
# Old pH, index 914: 7
# New pH, index 956: 7.0
#
#
# 58LAN/ENG_194 is equivalent.
# ERROR: 58LAN/ENG_194
#  ===================
# Old Keq, index 916: 180
# New Keq, index 958: 180.0
# Old pH, index 916: 10
# New pH, index 958: 10.0
# Old pH, index 917: 7
# New pH, index 959: 7.0
#
#
# 58MAL/OCH_673 is equivalent.
#
#
# 58NOL/BRU_1346 is equivalent.
#
#
# 58NOL/BRU_1353 is equivalent.
# ERROR: 58NOL/BRU_1353
#  ====================
# Old Keq, index 923: 1.10E-08
# New Keq, index 965: 1.1e-08
# Old pH, index 923: 8
# New pH, index 965: 8.0
#
#
# 58ROB/LIP_678 is equivalent.
# ERROR: 58ROB/LIP_678
#  ===================
# Old Keq, index 923: 1.10E-08
# New Keq, index 965: 1.1e-08
# Old pH, index 923: 8
# New pH, index 965: 8.0
# Old Keq, index 924: 3
# New Keq, index 966: 3.0
#
#
# 58TAB/SRE_1247 is equivalent.
# ERROR: 58TAB/SRE_1247
#  ====================
# Old Keq, index 924: 3
# New Keq, index 966: 3.0
#
#
# 58TAB/SRE_1335 is equivalent.
# ERROR: 58TAB/SRE_1335
#  ====================
# Old pH, index 926: 7
# New pH, index 968: 7.0
#
#
# 58TUR/TUR_684 is equivalent.
# ERROR: 58TUR/TUR_684
#  ===================
# Old pH, index 926: 7
# New pH, index 968: 7.0
#
#
# 58WIL/BAN_1068 is equivalent.
# ERROR: 58WIL/BAN_1068
#  ====================
# Old Keq, index 930: 6.00E-07
# New Keq, index 972: 6e-07
# Old Keq, index 931: 4.00E-08
# New Keq, index 973: 4e-08
#
#
# 58WIL/BAN_679 is equivalent.
# ERROR: 58WIL/BAN_679
#  ===================
# Old Keq, index 931: 4.00E-08
# New Keq, index 973: 4e-08
# Old Keq, index 932: 6.00E-07
# New Keq, index 974: 6e-07
#
#
# 58WIL/BAN_681 is equivalent.
# ERROR: 58WIL/BAN_681
#  ===================
# Old Keq, index 932: 6.00E-07
# New Keq, index 974: 6e-07
#
#
# 58WOL/SIM_1265 is equivalent.
# ERROR: 58WOL/SIM_1265
#  ====================
# Old Keq, index 934: 9.62E-05
# New Keq, index 976: 9.62e-05
# Old pH, index 934: 7
# New pH, index 976: 7.0
#
#
# 58YOU/PAC_45 is equivalent.
# ERROR: 58YOU/PAC_45
#  ==================
# Old Keq, index 934: 9.62E-05
# New Keq, index 976: 9.62e-05
# Old pH, index 934: 7
# New pH, index 976: 7.0
# Old Keq, index 935: 7.15E-05
# New Keq, index 977: 7.15e-05
# Old pH, index 935: 7
# New pH, index 977: 7.0
#
#
# 59ALE_443 is equivalent.
# ERROR: 59ALE_443
#  ===============
# Old pH, index 941: 7
# New pH, index 983: 7.0
# Old pH, index 942: 7
# New pH, index 984: 7.0
#
#
# 59ATK/JOH_1402 is equivalent.
# ERROR: 59ATK/JOH_1402
#  ====================
# Old pH, index 942: 7
# New pH, index 984: 7.0
#
#
# 59BAR/SMY_1214 is equivalent.
#
#
# 59BEN/KIT_990 is equivalent.
#
#
# 59BON/PON_370 is equivalent.
#
#
# 59CAL/WEB_639 is equivalent.
# ERROR: 59CAL/WEB_639
#  ===================
# Old pH, index 948: 5
# New pH, index 990: 5.0
#
#
# 59CHI/SUG_1391 is equivalent.
# ERROR: 59CHI/SUG_1391
#  ====================
# Old pH, index 948: 5
# New pH, index 990: 5.0
#
#
# 59DEL/DEF_233 is equivalent.
# ERROR: 59DEL/DEF_233
#  ===================
# Old Keq, index 953: 4.74E-04
# New Keq, index 995: 0.000474
# Old Keq, index 954: 7.23E-04
# New Keq, index 996: 0.000723
#
#
# 59DEN/ROB_190 is equivalent.
# ERROR: 59DEN/ROB_190
#  ===================
# Old Keq, index 964: 9.00E-03
# New Keq, index 1006: 0.009
# Old pH, index 964: 9
# New pH, index 1006: 9.0
# Old Keq, index 965: 4.50E-06
# New Keq, index 1007: 4.5e-06
# Old pH, index 965: 8
# New pH, index 1007: 8.0
#
#
# 59FRI_283 is equivalent.
# ERROR: 59FRI_283
#  ===============
# Old Keq, index 965: 4.50E-06
# New Keq, index 1007: 4.5e-06
# Old pH, index 965: 8
# New pH, index 1007: 8.0
# Old Keq, index 966: 5.50E-03
# New Keq, index 1008: 0.0055
# Old pH, index 966: 6
# New pH, index 1008: 6.0
#
#
# 59GOL_322 is equivalent.
# ERROR: 59GOL_322
#  ===============
# Old Keq, index 966: 5.50E-03
# New Keq, index 1008: 0.0055
# Old pH, index 966: 6
# New pH, index 1008: 6.0
# Old Keq, index 967: 1.40E-06
# New Keq, index 1009: 1.4e-06
#
#
# 59HAB/CAN_951 is equivalent.
# ERROR: 59HAB/CAN_951
#  ===================
# Old Keq, index 967: 1.40E-06
# New Keq, index 1009: 1.4e-06
# Old Keq, index 968: 1.44E-04
# New Keq, index 1010: 0.000144
# Old pH, index 968: 7
# New pH, index 1010: 7.0
#
#
# 59HOL_46 is equivalent.
# ERROR: 59HOL_46
#  ==============
# Old Keq, index 968: 1.44E-04
# New Keq, index 1010: 0.000144
# Old pH, index 968: 7
# New pH, index 1010: 7.0
# Old Keq, index 969: 1.44E-03
# New Keq, index 1011: 0.00144
# Old pH, index 969: 8
# New pH, index 1011: 8.0
#
#
# 59HOL_47 is equivalent.
# ERROR: 59HOL_47
#  ==============
# Old Keq, index 970: 5.54E-04
# New Keq, index 1012: 0.000554
# Old pH, index 970: 7
# New pH, index 1012: 7.0
# Old Keq, index 971: 5.54E-03
# New Keq, index 1013: 0.00554
# Old pH, index 971: 8
# New pH, index 1013: 8.0
#
#
# 59HOL_48 is equivalent.
# ERROR: 59HOL_48
#  ==============
# Old Keq, index 972: 4.23E-03
# New Keq, index 1014: 0.00423
# Old pH, index 972: 7
# New pH, index 1014: 7.0
# Old Keq, index 973: 4.23E-02
# New Keq, index 1015: 0.0423
# Old pH, index 973: 8
# New pH, index 1015: 8.0
#
#
# 59HOL_49 is equivalent.
# ERROR: 59HOL_49
#  ==============
# Old Keq, index 974: 1.75E-04
# New Keq, index 1016: 0.000175
# Old pH, index 974: 7
# New pH, index 1016: 7.0
# Old Keq, index 975: 1.75E-03
# New Keq, index 1017: 0.00175
# Old pH, index 975: 8
# New pH, index 1017: 8.0
#
#
# 59HOL_50 is equivalent.
# ERROR: 59HOL_50
#  ==============
# Old Keq, index 976: 4.19E-03
# New Keq, index 1018: 0.00419
# Old pH, index 976: 7
# New pH, index 1018: 7.0
# Old Keq, index 977: 4.19E-02
# New Keq, index 1019: 0.0419
# Old pH, index 977: 8
# New pH, index 1019: 8.0
#
#
# 59HOL_51 is equivalent.
# ERROR: 59HOL_51
#  ==============
# Old Keq, index 978: 6.91E-05
# New Keq, index 1020: 6.91e-05
# Old pH, index 978: 7
# New pH, index 1020: 7.0
# Old Keq, index 979: 6.91E-04
# New Keq, index 1021: 0.000691
# Old pH, index 979: 8
# New pH, index 1021: 8.0
#
#
# 59HOL_52 is equivalent.
# ERROR: 59HOL_52
#  ==============
# Old Keq, index 980: 4.18E-04
# New Keq, index 1022: 0.000418
# Old pH, index 980: 7
# New pH, index 1022: 7.0
# Old Keq, index 981: 4.18E-03
# New Keq, index 1023: 0.00418
# Old pH, index 981: 8
# New pH, index 1023: 8.0
#
#
# 59HOL_57 is equivalent.
# ERROR: 59HOL_57
#  ==============
# Old Keq, index 982: 2.97E-04
# New Keq, index 1024: 0.000297
# Old pH, index 982: 7
# New pH, index 1024: 7.0
# Old Keq, index 983: 2.97E-03
# New Keq, index 1025: 0.00297
# Old pH, index 983: 8
# New pH, index 1025: 8.0
#
#
# 59ITO/GRI_1392 is equivalent.
# ERROR: 59ITO/GRI_1392
#  ====================
# Old pH, index 986: 8
# New pH, index 1028: 8.0
#
#
# 59KIR/TUR_663 is equivalent.
# ERROR: 59KIR/TUR_663
#  ===================
# Old pH, index 986: 8
# New pH, index 1028: 8.0
# Old temperature, index 987: 295
# New temperature, index 1029: 295.0
#
#
# 59KIT/HEM_986 is equivalent.
# ERROR: 59KIT/HEM_986
#  ===================
# Old temperature, index 987: 295
# New temperature, index 1029: 295.0
# Old temperature, index 988: 295
# New temperature, index 1030: 295.0
# Old enthalpy, index 988: -22
# New enthalpy, index 1030: -22.0
#
#
# 59KIT/HEM_991 is equivalent.
# ERROR: 59KIT/HEM_991
#  ===================
# Old temperature, index 988: 295
# New temperature, index 1030: 295.0
# Old enthalpy, index 988: -22
# New enthalpy, index 1030: -22.0
# Old Keq, index 989: 3.86E-04
# New Keq, index 1031: 0.000386
#
#
# 59KRI_564 is equivalent.
# ERROR: 59KRI_564
#  ===============
# Old Keq, index 989: 3.86E-04
# New Keq, index 1031: 0.000386
# Old Keq, index 990: 4.50E-04
# New Keq, index 1032: 0.00045
#
#
# 59MCC/NAJ_1403 is equivalent.
# ERROR: 59MCC/NAJ_1403
#  ====================
# Old Keq, index 1002: 1.55E-04
# New Keq, index 1044: 0.000155
#
#
# 59MCQ/UTT_565 is equivalent.
# ERROR: 59MCQ/UTT_565
#  ===================
# Old Keq, index 1002: 1.55E-04
# New Keq, index 1044: 0.000155
# Old Keq, index 1003: 4.51E-04
# New Keq, index 1045: 0.000451
# Old pH, index 1003: 8
# New pH, index 1045: 8.0
#
#
# 59MER/TOM_5 is equivalent.
#
#
# 59MIL/LUK_1225 is equivalent.
# ERROR: 59MIL/LUK_1225
#  ====================
# Old Keq, index 1010: 7.17E-03
# New Keq, index 1052: 0.00717
# Old pH, index 1010: 8
# New pH, index 1052: 8.0
#
#
# 59NOR/FRO_188 is equivalent.
# ERROR: 59NOR/FRO_188
#  ===================
# Old Keq, index 1010: 7.17E-03
# New Keq, index 1052: 0.00717
# Old pH, index 1010: 8
# New pH, index 1052: 8.0
#
#
# 59SAN/LAN_324 is equivalent.
#
#
# 59SAN/LAN_326 is equivalent.
#
#
# 59SCO/JAK_526 is equivalent.
#
#
# 59SHO/PRI_216 is equivalent.
#
#
# 59STR/SMI_702 is equivalent.
#
#
# 59TAB/WYN_355 is equivalent.
# ERROR: 59TAB/WYN_355
#  ===================
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
#
#
# 59TAL/LEV_172 is equivalent.
# ERROR: 59TAL/LEV_172
#  ===================
# Old Keq, index 1026: 1.13E-02
# New Keq, index 1068: 0.0113
# Old pH, index 1026: 7
# New pH, index 1068: 7.0
# Old Keq, index 1027: 1.13E-01
# New Keq, index 1069: 0.113
# Old pH, index 1027: 8
# New pH, index 1069: 8.0
#
#
# 59TAL/LEV_175 is equivalent.
# ERROR: 59TAL/LEV_175
#  ===================
# Old Keq, index 1029: 1.07E-02
# New Keq, index 1071: 0.0107
# Old pH, index 1029: 7
# New pH, index 1071: 7.0
# Old Keq, index 1030: 1.07E-01
# New Keq, index 1072: 0.107
# Old pH, index 1030: 8
# New pH, index 1072: 8.0
#
#
# 59TAL/LEV_176 is equivalent.
# ERROR: 59TAL/LEV_176
#  ===================
# Old Keq, index 1032: 2.13E-02
# New Keq, index 1074: 0.0213
# Old pH, index 1032: 7
# New pH, index 1074: 7.0
# Old Keq, index 1033: 2.13E-01
# New Keq, index 1075: 0.213
# Old pH, index 1033: 8
# New pH, index 1075: 8.0
#
#
# 59TAL/LEV_181 is equivalent.
# ERROR: 59TAL/LEV_181
#  ===================
# Old Keq, index 1035: 3.78E-01
# New Keq, index 1077: 0.378
# Old pH, index 1035: 7
# New pH, index 1077: 7.0
# Old pH, index 1036: 8
# New pH, index 1078: 8.0
#
#
# 59TAL/LEV_183 is equivalent.
# ERROR: 59TAL/LEV_183
#  ===================
# Old Keq, index 1038: 9.20E-03
# New Keq, index 1080: 0.0092
# Old pH, index 1038: 7
# New pH, index 1080: 7.0
# Old Keq, index 1039: 9.20E-02
# New Keq, index 1081: 0.092
# Old pH, index 1039: 8
# New pH, index 1081: 8.0
#
#
# 59TAL/LEV_184 is equivalent.
# ERROR: 59TAL/LEV_184
#  ===================
# Old Keq, index 1041: 1.88E-02
# New Keq, index 1083: 0.0188
# Old pH, index 1041: 7
# New pH, index 1083: 7.0
# Old Keq, index 1042: 1.88E-01
# New Keq, index 1084: 0.188
# Old pH, index 1042: 8
# New pH, index 1084: 8.0
#
#
# 59TAL/LEV_185 is equivalent.
# ERROR: 59TAL/LEV_185
#  ===================
# Old Keq, index 1044: 9.90E-03
# New Keq, index 1086: 0.0099
# Old pH, index 1044: 7
# New pH, index 1086: 7.0
# Old Keq, index 1045: 9.90E-02
# New Keq, index 1087: 0.099
# Old pH, index 1045: 8
# New pH, index 1087: 8.0
#
#
# 59VAG/EAR_1221 is equivalent.
# ERROR: 59VAG/EAR_1221
#  ====================
# Old Keq, index 1047: 1.22E-06
# New Keq, index 1089: 1.22e-06
#
#
# 60AGO/ARA_1336 is equivalent.
#
#
# 60ASH/WAH_1368 is equivalent.
# ERROR: 60ASH/WAH_1368
#  ====================
# Old pH, index 1051: 8
# New pH, index 1093: 8.0
# Old pH, index 1052: 8
# New pH, index 1094: 8.0
#
#
# 60ASH/WAH_1369 is equivalent.
# ERROR: 60ASH/WAH_1369
#  ====================
# Old pH, index 1053: 8
# New pH, index 1095: 8.0
#
#
# 60BLA_349 is equivalent.
#
#
# 60COM/ROS_1117 is equivalent.
# ERROR: 60COM/ROS_1117
#  ====================
# Old Keq, index 1056: 1
# New Keq, index 1098: 1.0
#
#
# 60FEI/NEU_1267 is equivalent.
# ERROR: 60FEI/NEU_1267
#  ====================
# Old Keq, index 1056: 1
# New Keq, index 1098: 1.0
#
#
# 60FEI/NEU_1270 is equivalent.
# ERROR: 60FEI/NEU_1270
#  ====================
# Old pH, index 1058: 8
# New pH, index 1100: 8.0
#
#
# 60GEL/STU_1079 is equivalent.
# ERROR: 60GEL/STU_1079
#  ====================
# Old pH, index 1058: 8
# New pH, index 1100: 8.0
# Old pH, index 1059: 8
# New pH, index 1101: 8.0
#
#
# 60GEL/STU_613 is equivalent.
# ERROR: 60GEL/STU_613
#  ===================
# Old pH, index 1059: 8
# New pH, index 1101: 8.0
# Old Keq, index 1060: 2.40E-03
# New Keq, index 1102: 0.0024
# Old pH, index 1060: 10
# New pH, index 1102: 10.0
#
#
# 60GUP/ROB_186 is equivalent.
# ERROR: 60GUP/ROB_186
#  ===================
# Old Keq, index 1060: 2.40E-03
# New Keq, index 1102: 0.0024
# Old pH, index 1060: 10
# New pH, index 1102: 10.0
# Old Keq, index 1061: 6.00E-05
# New Keq, index 1103: 6e-05
#
#
# 60ICH/FUR_1238 is equivalent.
# ERROR: 60ICH/FUR_1238
#  ====================
# Old Keq, index 1064: 1
# New Keq, index 1106: 1.0
# Old pH, index 1064: 8
# New pH, index 1106: 8.0
# Old pH, index 1065: 6.7
# New pH, index 1107: 6.70
#
#
# 60ISH_997 is equivalent.
# ERROR: 60ISH_997
#  ===============
# Old pH, index 1065: 6.7
# New pH, index 1107: 6.70
#
#
# 60JON/LIP_576 is equivalent.
# ERROR: 60JON/LIP_576
#  ===================
# Old pH, index 1068: 8
# New pH, index 1110: 8.0
#
#
# 60KAH/LOW_1354 is equivalent.
# ERROR: 60KAH/LOW_1354
#  ====================
# Old pH, index 1068: 8
# New pH, index 1110: 8.0
# Old pH, index 1069: 8
# New pH, index 1111: 8.0
#
#
# 60KAY/OSB_1057 is equivalent.
#
#
# 60KUR/SUG_696 is equivalent.
#
#
# 60MAX/ROB_1250 is equivalent.
#
#
# 60MEN_429 is equivalent.
#
#
# 60NIR/JAK_193 is equivalent.
# ERROR: 60NIR/JAK_193
#  ===================
# Old Keq, index 1082: 25
# New Keq, index 1124: 25.0
# Old pH, index 1082: 8
# New pH, index 1124: 8.0
#
#
# 60OCO/HAL_269 is equivalent.
# ERROR: 60OCO/HAL_269
#  ===================
# Old pH, index 1083: 10
# New pH, index 1125: 10.0
# Old Keq, index 1084: 6.01E-06
# New Keq, index 1126: 6.01e-06
#
#
# 60PIE/WIA_270 is equivalent.
# ERROR: 60PIE/WIA_270
#  ===================
# Old Keq, index 1084: 6.01E-06
# New Keq, index 1126: 6.01e-06
# Old Keq, index 1085: 7.68E-06
# New Keq, index 1127: 7.68e-06
#
#
# 60PRI/HOR_1087 is equivalent.
#
#
# 60SCH/RAT_1444 is equivalent.
#
#
# 60VOL_1370 is equivalent.
# ERROR: 60VOL_1370
#  ================
# Old pH, index 1099: 8
# New pH, index 1141: 8.0
# Old pH, index 1100: 7
# New pH, index 1142: 7.0
#
#
# 61ALE_444 is equivalent.
# ERROR: 61ALE_444
#  ===============
# Old pH, index 1100: 7
# New pH, index 1142: 7.0
# Old pH, index 1101: 7
# New pH, index 1143: 7.0
#
#
# 61ATK/BUR_550 is equivalent.
# ...
# New pH, index 3614: 8.0
#
#
# 91KLE/RAN_654 is equivalent.
# ERROR: 91KLE/RAN_654
#  ===================
# Old pH, index 3555: 8
# New pH, index 3614: 8.0
# Old pH, index 3556: 8
# New pH, index 3615: 8.0
#
#
# 91KNI/SEM_1406 is equivalent.
#
#
# 91KRA/GYG_1120 is equivalent.
#
#
# 91LIU/FRO_832 is equivalent.
#
#
# 91MOR/FRE_329 is equivalent.
# ERROR: 91MOR/FRE_329
#  ===================
# Old pH, index 3574: 7
# New pH, index 3633: 7.0
#
#
# 91SCH/GIF_59 is equivalent.
# ERROR: 91SCH/GIF_59
#  ==================
# Old pH, index 3574: 7
# New pH, index 3633: 7.0
# Old pH, index 3575: 7
# New pH, index 3634: 7.0
#
#
# 91SCH/GIF_69 is equivalent.
# ERROR: 91SCH/GIF_69
#  ==================
# Old pH, index 3575: 7
# New pH, index 3634: 7.0
#
#
# 91SEM/CLE_1349 is equivalent.
#
#
# 91SEM/CLE_1364 is equivalent.
#
#
# 91SEM/CLE_542 is equivalent.
#
#
# 91SRI/NAM_308 is equivalent.
#
#
# 91TEW/GOL_876 is equivalent.
#
#
# 91TEW/GOL_877 is equivalent.
#
#
# 91TEW/GOL_911 is equivalent.
#
#
# 91TEW/GOL_913 is equivalent.
#
#
# 91TEW/GOL_920 is equivalent.
#
#
# 91TEW/GOL_921 is equivalent.
#
#
# 91TEW/GOL_928 is equivalent.
#
#
# 91TEW/GOL_929 is equivalent.
#
#
# 91TEW/GOL_934 is equivalent.
#
#
# 91TEW/GOL_935 is equivalent.
#
#
# 91WOH/DIE_304 is equivalent.
#
#
# 91WOH/DIE_305 is equivalent.
#
#
# 92BLA/GUI_966 is equivalent.
# ERROR: 92BLA/GUI_966
#  ===================
# Old Keq, index 3606: 2
# New Keq, index 3665: 2.0
#
#
# 92DEM/ATT_1319 is equivalent.
# ERROR: 92DEM/ATT_1319
#  ====================
# Old pH, index 3617: 7
# New pH, index 3676: 7.0
#
#
# 92ELL/SRI_927 is equivalent.
# ERROR: 92ELL/SRI_927
#  ===================
# Old pH, index 3617: 7
# New pH, index 3676: 7.0
# Old pH, index 3618: 7
# New pH, index 3677: 7.0
#
#
# 92ELL/SRI_933 is equivalent.
# ERROR: 92ELL/SRI_933
#  ===================
# Old pH, index 3618: 7
# New pH, index 3677: 7.0
# Old pH, index 3619: 7
# New pH, index 3678: 7.0
#
#
# 92ELL/SRI_936 is equivalent.
# ERROR: 92ELL/SRI_936
#  ===================
# Old pH, index 3619: 7
# New pH, index 3678: 7.0
# Old pH, index 3620: 7
# New pH, index 3679: 7.0
#
#
# 92IBO/OBO_1030 is equivalent.
# ERROR: 92IBO/OBO_1030
#  ====================
# Old pH, index 3620: 7
# New pH, index 3679: 7.0
#
#
# 92KAH/SCH_189 is equivalent.
# ERROR: 92KAH/SCH_189
#  ===================
# Old pH, index 3626: 7
# New pH, index 3685: 7.0
#
#
# 92KER/KER_1155 is equivalent.
# ERROR: 92KER/KER_1155
#  ====================
# Old Keq, index 3628: 26
# New Keq, index 3687: 26.0
# Old pH, index 3628: 7
# New pH, index 3687: 7.0
#
#
# 92KIM/KIN_1411 is equivalent.
# ERROR: 92KIM/KIN_1411
#  ====================
# Old Keq, index 3628: 26
# New Keq, index 3687: 26.0
# Old pH, index 3628: 7
# New pH, index 3687: 7.0
# Old pH, index 3629: 7
# New pH, index 3688: 7.0
#
#
# 92KIM/KIN_458 is equivalent.
# ERROR: 92KIM/KIN_458
#  ===================
# Old pH, index 3629: 7
# New pH, index 3688: 7.0
# Old pH, index 3630: 7
# New pH, index 3689: 7.0
#
#
# 92KIM/KIN_464 is equivalent.
# ERROR: 92KIM/KIN_464
#  ===================
# Old pH, index 3630: 7
# New pH, index 3689: 7.0
# Old pH, index 3631: 7
# New pH, index 3690: 7.0
#
#
# 92KIM/KIN_466 is equivalent.
# ERROR: 92KIM/KIN_466
#  ===================
# Old pH, index 3631: 7
# New pH, index 3690: 7.0
# Old Keq, index 3632: 2000
# New Keq, index 3691: 2000.0
#
#
# 92KIM/KIN_475 is equivalent.
# ERROR: 92KIM/KIN_475
#  ===================
# Old Keq, index 3632: 2000
# New Keq, index 3691: 2000.0
# Old Keq, index 3633: 100000
# New Keq, index 3692: 100000.0
#
#
# 92KIM/KIN_478 is equivalent.
# ERROR: 92KIM/KIN_478
#  ===================
# Old Keq, index 3633: 100000
# New Keq, index 3692: 100000.0
# Old Keq, index 3634: 100000
# New Keq, index 3693: 100000.0
#
#
# 92KIM/KIN_479 is equivalent.
# ERROR: 92KIM/KIN_479
#  ===================
# Old Keq, index 3634: 100000
# New Keq, index 3693: 100000.0
#
#
# 92KIM/KIN_675 is equivalent.
# ERROR: 92KIM/KIN_675
#  ===================
# Old pH, index 3636: 7
# New pH, index 3695: 7.0
#
#
# 92KIM/KIN_829 is equivalent.
# ERROR: 92KIM/KIN_829
#  ===================
# Old pH, index 3636: 7
# New pH, index 3695: 7.0
# Old pH, index 3637: 7
# New pH, index 3696: 7.0
#
#
# 92KIT/SAS_445 is equivalent.
# ERROR: 92KIT/SAS_445
#  ===================
# Old pH, index 3637: 7
# New pH, index 3696: 7.0
#
#
# 92KRA_1121 is equivalent.
#
#
# 92KRA_1273 is equivalent.
# ERROR: 92KRA_1273
#  ================
# Old Keq, index 3645: 3000
# New Keq, index 3704: 3000.0
#
#
# 92LEE/HAN_945 is equivalent.
# ERROR: 92LEE/HAN_945
#  ===================
# Old Keq, index 3645: 3000
# New Keq, index 3704: 3000.0
# Old Keq, index 3646: 860
# New Keq, index 3705: 860.0
#
#
# 92LOR/TRA_737 is equivalent.
#
#
# 92LOR/TRA_739 is equivalent.
#
#
# 92LOR/TRA_741 is equivalent.
#
#
# 92REK/TIS_794 is equivalent.
# ERROR: 92REK/TIS_794
#  ===================
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
#
#
# 92REK/TIS_826 is equivalent.
# ERROR: 92REK/TIS_826
#  ===================
# Old pH, index 3661: 3
# New pH, index 3720: 3.0
#
#
# 92TEA/DOB_604 is equivalent.
#
#
# 92WAN/CHE_747 is equivalent.
# ERROR: 92WAN/CHE_747
#  ===================
# Old pH, index 3694: 7
# New pH, index 3753: 7.0
# Old pH, index 3695: 7
# New pH, index 3754: 7.0
#
#
# 92XIA/XUE_1414 is equivalent.
#
#
# 93BES/REB_351 is equivalent.
#
#
# 93BES/REB_352 is equivalent.
#
#
# 93BLI/MAR_1033 is equivalent.
#
#
# 93BLI/MAR_1034 is equivalent.
#
#
# 93BOH/HUT_226 is equivalent.
#
#
# 93HUT/BOH_227 is equivalent.
#
#
# 93HUT/BOH_229 is equivalent.
#
#
# 93JAN/PAD_724 is equivalent.
#
#
# 93JAN/PAD_725 is equivalent.
#
#
# 93JAN/PAD_726 is equivalent.
#
#
# 93JAN/PAD_728 is equivalent.
#
#
# 93JAN/PAD_729 is equivalent.
#
#
# 93JAN/PAD_730 is equivalent.
#
#
# 93JAN/PAD_738 is equivalent.
#
#
# 93JAN/PAD_740 is equivalent.
#
#
# 93JAN/PAD_742 is equivalent.
#
#
# 93LAR/TEW_1217 is equivalent.
#
#
# 93LAR/TEW_1218 is equivalent.
#
#
# 93LAR/TEW_759 is equivalent.
#
#
# 93LAR/TEW_760 is equivalent.
#
#
# 93LAR/TEW_784 is equivalent.
#
#
# 93LAR/TEW_785 is equivalent.
#
#
# 93MOC/STR_453 is equivalent.
# ERROR: 93MOC/STR_453
#  ===================
# Old pH, index 3729: 6
# New pH, index 3788: 6.0
# Old pH, index 3730: 7
# New pH, index 3789: 7.0
#
#
# 93SHI/CHE_1243 is equivalent.
# ERROR: 93SHI/CHE_1243
#  ====================
# Old pH, index 3730: 7
# New pH, index 3789: 7.0
#
#
# 93TEW/KIS_1047 is equivalent.
#
#
# 93TEW/KIS_1051 is equivalent.
#
#
# 93WER/TWE_1189 is equivalent.
# ERROR: 93WER/TWE_1189
#  ====================
# Old pH, index 3749: 7
# New pH, index 3808: 7.0
# Old pH, index 3750: 7
# New pH, index 3809: 7.0
#
#
# 93WER/TWE_1192 is equivalent.
# ERROR: 93WER/TWE_1192
#  ====================
# Old pH, index 3750: 7
# New pH, index 3809: 7.0
# Old pH, index 3751: 7
# New pH, index 3810: 7.0
#
#
# 93WER/TWE_1202 is equivalent.
# ERROR: 93WER/TWE_1202
#  ====================
# Old pH, index 3751: 7
# New pH, index 3810: 7.0
#
#
# 94CHI/KIR_490 is equivalent.
#
#
# 94CHI/KIR_491 is equivalent.
# ERROR: 94CHI/KIR_491
#  ===================
# Old Keq, index 3754: 2600
# New Keq, index 3813: 2600.0
#
#
# 94CHI/KIR_492 is equivalent.
# ERROR: 94CHI/KIR_492
#  ===================
# Old Keq, index 3754: 2600
# New Keq, index 3813: 2600.0
# Old Keq, index 3755: 7100
# New Keq, index 3814: 7100.0
#
#
# 94CHI/KIR_493 is equivalent.
# ERROR: 94CHI/KIR_493
#  ===================
# Old Keq, index 3755: 7100
# New Keq, index 3814: 7100.0
#
#
# 94KIS/TEW_1041 is equivalent.
#
#
# 94KIS/TEW_1042 is equivalent.
#
#
# 94KIS/TEW_1044 is equivalent.
#
#
# 94KIS/TEW_1045 is equivalent.
#
#
# 94LEU/COO_409 is equivalent.
# ERROR: 94LEU/COO_409
#  ===================
# Old pH, index 3770: 6
# New pH, index 3829: 6.0
#
#
# 94NOE/COL_197 is equivalent.
# ERROR: 94NOE/COL_197
#  ===================
# Old Km, index 3772: 8.90E-05
# New Km, index 3831: 8.9e-05
#
#
# 94TEW/GOL_1139 is equivalent.
# ERROR: 94TEW/GOL_1139
#  ====================
# Old Km, index 3772: 8.90E-05
# New Km, index 3831: 8.9e-05
# Old Km, index 3773: 8.30E-05
# New Km, index 3832: 8.3e-05
#
#
# 94TEW/GOL_1140 is equivalent.
# ERROR: 94TEW/GOL_1140
#  ====================
# Old pH, index 3791: 7
# New pH, index 3852: 7.0
#
#
# 95BIS/KRA_1027 is equivalent.
# ERROR: 95BIS/KRA_1027
#  ====================
# Old pH, index 3791: 7
# New pH, index 3852: 7.0
# Old pH, index 3792: 8
# New pH, index 3853: 8.0
#
#
# 95CHE/ARM_494 is equivalent.
# ERROR: 95CHE/ARM_494
#  ===================
# Old pH, index 3792: 8
# New pH, index 3853: 8.0
# Old pH, index 3793: 6
# New pH, index 3854: 6.0
#
#
# 95HUT/BOH_1001 is equivalent.
# ERROR: 95HUT/BOH_1001
#  ====================
# Old pH, index 3793: 6
# New pH, index 3854: 6.0
# Old enthalpy, index 3794: -46
# New enthalpy, index 3855: -46.0
#
#
# 95HUT/BOH_995 is equivalent.
#
#
# 95JUS/KOT_1002 is equivalent.
# ERROR: 95JUS/KOT_1002
#  ====================
# Old pH, index 3804: 7
# New pH, index 3865: 7.0
# Old Keq, index 3805: 1000000000
# New Keq, index 3866: 1000000000.0
#
#
# 95KAM/JUR_626 is equivalent.
# ERROR: 95KAM/JUR_626
#  ===================
# Old Keq, index 3805: 1000000000
# New Keq, index 3866: 1000000000.0
#
#
# 95KAM/JUR_657 is equivalent.
# ERROR: 95KAM/JUR_657
#  ===================
# Old pH, index 3807: 8
# New pH, index 3868: 8.0
#
#
# 95KOZ/TOM_1425 is equivalent.
# ERROR: 95KOZ/TOM_1425
#  ====================
# Old pH, index 3807: 8
# New pH, index 3868: 8.0
# Old pH, index 3808: 8
# New pH, index 3869: 8.0
#
#
# 95KOZ/TOM_1426 is equivalent.
# ERROR: 95KOZ/TOM_1426
#  ====================
# Old pH, index 3808: 8
# New pH, index 3869: 8.0
# Old pH, index 3809: 8
# New pH, index 3870: 8.0
#
#
# 95LEE/WAL_489 is equivalent.
# ERROR: 95LEE/WAL_489
#  ===================
# Old pH, index 3809: 8
# New pH, index 3870: 8.0
# Old enthalpy, index 3810: -83.7
# New enthalpy, index 3871: -17.8
# Old pH, index 3810: 7
# New pH, index 3871: 9.4
#
#
# 95LIA/WAN_331 is equivalent.
# ERROR: 95LIA/WAN_331
#  ===================
# Old pH, index 3810: 7
# New pH, index 3872: 7.0
# Old enthalpy, index 3811: -17.8
# New enthalpy, index 3873: -18.1
# Old pH, index 3811: 9.4
# New pH, index 3873: 9.5
#
#
# 95LIA/WAN2_1048 is equivalent.
# ERROR: 95LIA/WAN2_1048
#  =====================
# Old enthalpy, index 3812: -18.1
# New enthalpy, index 3872: -83.7
# Old pH, index 3812: 9.5
# New pH, index 3872: 7.0
#
#
# 95LIU/ZEN_1049 is equivalent.
#
#
# 95LIU/ZEN_968 is equivalent.
# ERROR: 95LIU/ZEN_968
#  ===================
# Old pH, index 3814: 7
# New pH, index 3875: 7.0
#
#
# 95LIU/ZEN_976 is equivalent.
# ERROR: 95LIU/ZEN_976
#  ===================
# Old pH, index 3814: 7
# New pH, index 3875: 7.0
# Old Keq, index 3815: 8.00E-05
# New Keq, index 3876: 8e-05
#
#
# 95SCH/TRA_581 is equivalent.
# ERROR: 95SCH/TRA_581
#  ===================
# Old Keq, index 3815: 8.00E-05
# New Keq, index 3876: 8e-05
#
#
# 95TEW/SCH_960 is equivalent.
#
#
# 95TEW/SCH_961 is equivalent.
#
#
# 95WIS/KUS_610 is equivalent.
# ERROR: 95WIS/KUS_610
#  ===================
# Old pH, index 3837: 7
# New pH, index 3898: 7.0
# Old pH, index 3838: 7
# New pH, index 3899: 7.0
#
#
# 95WIS/KUS_612 is equivalent.
# ERROR: 95WIS/KUS_612
#  ===================
# Old pH, index 3838: 7
# New pH, index 3899: 7.0
# Old pH, index 3839: 7
# New pH, index 3900: 7.0
#
#
# 96ARA/RUZ_711 is equivalent.
# ERROR: 96ARA/RUZ_711
#  ===================
# Old pH, index 3839: 7
# New pH, index 3900: 7.0
#
#
# 96HIR/MAY_731 is equivalent.
#
#
# 96HIR/MAY_732 is equivalent.
#
#
# 96HIR/MAY_733 is equivalent.
#
#
# 96HIR/MAY_734 is equivalent.
#
#
# 96HIR/MAY_735 is equivalent.
#
#
# 96HIR/MAY_736 is equivalent.
# ERROR: 96HIR/MAY_736
#  ===================
# Old Keq, index 3862: 0.022
# New Keq, index 3923: 0.017
#
#
# 96LI/ZHA_668 is equivalent.
#
#
# 96OES/SCH_1410 is equivalent.
# ERROR: 96OES/SCH_1410
#  ====================
# Old pH, index 3870: 7
# New pH, index 3931: 7.0
# Old pH, index 3871: 7
# New pH, index 3932: 7.0
#
#
# 96OES/SCH_1412 is equivalent.
# ERROR: 96OES/SCH_1412
#  ====================
# Old pH, index 3871: 7
# New pH, index 3932: 7.0
# Old Keq, index 3872: 1
# New Keq, index 3933: 1.0
# Old pH, index 3872: 7
# New pH, index 3933: 7.0
#
#
# 96OES/SCH_1415 is equivalent.
# ERROR: 96OES/SCH_1415
#  ====================
# Old Keq, index 3872: 1
# New Keq, index 3933: 1.0
# Old pH, index 3872: 7
# New pH, index 3933: 7.0
#
#
# 96PRO/GRO_1258 is equivalent.
#
#
# 96TEW/GOL_60 is equivalent.
#
#
# 96TEW/GOL_61 is equivalent.
#
#
# 96TEW/GOL_70 is equivalent.
#
#
# 96TEW/GOL_71 is equivalent.
#
#
# 96TEW/GOL_73 is equivalent.
#
#
# 96TEW/GOL_74 is equivalent.
#
#
# 96TEW/SCH_749 is equivalent.
#
#
# 96TEW/SCH_750 is equivalent.
# ERROR: 96TEW/SCH_750
#  ===================
# Old Km, index 3884: 119
# New Km, index 3945: 119.0
# Old Km, index 3885: 126
# New Km, index 3946: 126.0
#
#
# 96TEW/SCH_751 is equivalent.
#
#
# 97CHA_622 is equivalent.
# ERROR: 97CHA_622
#  ===============
# Old pH, index 3903: 7
# New pH, index 3964: 7.0
#
#
# 97CON/DEL_1320 is equivalent.
# ERROR: 97CON/DEL_1320
#  ====================
# Old pH, index 3903: 7
# New pH, index 3964: 7.0
# Old pH, index 3904: 7
# New pH, index 3965: 7.0
#
#
# 97DEJ/ROC_428 is equivalent.
# ERROR: 97DEJ/ROC_428
#  ===================
# Old pH, index 3908: 7
# New pH, index 3969: 7.0
# Old Keq, index 3909: 250
# New Keq, index 3970: 250.0
#
#
# 97HAN/KLE_208 is equivalent.
# ERROR: 97HAN/KLE_208
#  ===================
# Old pH, index 3910: 8
# New pH, index 3971: 8.0
# Old pH, index 3911: 9
# New pH, index 3972: 9.0
#
#
# 97KAS/TEW_1423 is equivalent.
#
#
# 97LIA/WU_332 is equivalent.
# ERROR: 97LIA/WU_332
#  ==================
# Old pH, index 3914: 7
# New pH, index 3975: 7.0
#
#
# 97PES/PRI_878 is equivalent.
#
#
# 97PES/PRI_879 is equivalent.
#
#
# 97PES/PRI_880 is equivalent.
#
#
# 97PES/PRI_884 is equivalent.
#
#
# 97PES/PRI_885 is equivalent.
#
#
# 97PES/PRI_903 is equivalent.
#
#
# 97PES/PRI_904 is equivalent.
#
#
# 97PES/PRI_905 is equivalent.
#
#
# 97PES/PRI_906 is equivalent.
#
#
# 97PES/PRI_907 is equivalent.
#
#
# 97PES/PRI_908 is equivalent.
#
#
# 97SAL/GOD_1123 is equivalent.
# ERROR: 97SAL/GOD_1123
#  ====================
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
#
#
# 97STA/SUA_1365 is equivalent.
# ERROR: 97STA/SUA_1365
#  ====================
# Old pH, index 3927: 7
# New pH, index 3988: 7.0
# Old pH, index 3928: 8
# New pH, index 3989: 8.0
#
#
# 97TEW/GOL_434 is equivalent.
#
#
# 97TEW/GOL_436 is equivalent.
#
#
# 97TEW/GOL_438 is equivalent.
#
#
# 97TEW/GOL_442 is equivalent.
#
#
# 97TEW/GOL_873 is equivalent.
#
#
# 97TEW/GOL_874 is equivalent.
# ERROR: 97TEW/GOL_874
#  ===================
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
#
#
# 97YOR/ISH_540 is equivalent.
# ERROR: 97YOR/ISH_540
#  ===================
# Old pH, index 3935: 9
# New pH, index 3996: 9.0
# Old pH, index 3936: 5
# New pH, index 3997: 5.0
#
#
# 98DIE/STR_1004 is equivalent.
# ERROR: 98DIE/STR_1004
#  ====================
# Old pH, index 3936: 5
# New pH, index 3997: 5.0
#
#
# 98KIM/VOE_559 is equivalent.
# ERROR: 98KIM/VOE_559
#  ===================
# Old temperature, index 3940: 298.15
# New temperature, index 4001: 283.15
# Old Km, index 3940: 1.2?104
# New Km, index 4001:
# Old pH, index 3940: 7.54
# New pH, index 4001: 7.0
#
#
# 98KIS/TEW_1181 is equivalent.
#
#
# 98KIS/TEW_1182 is equivalent.
#
#
# 98KIS/TEW_1184 is equivalent.
#
#
# 98KIS/TEW_1186 is equivalent.
#
#
# 98KIS/TEW_1188 is equivalent.
# ERROR: 98KIS/TEW_1188
#  ====================
# Old temperature, index 3945: 283.15
# New temperature, index 4011: 310.15
# Old Keq, index 3945: 0.133
# New Keq, index 4011: 1.0
# Old pH, index 3945: 7
# New pH, index 4011: 7.4
#
#
# 98KIS/TEW2_541 is equivalent.
# ERROR: 98KIS/TEW2_541
#  ====================
# Old pH, index 3945: 7
# New pH, index 4001: 7.0
#
#
# 98LAE/EIS_1204 is equivalent.
# ERROR: 98LAE/EIS_1204
#  ====================
# Old Keq, index 3950: 1
# New Keq, index 4011: 1.0
# Old pH, index 3951: 6
# New pH, index 4012: 6.0
#
#
# 98LOV/LAU_857 is equivalent.
# ERROR: 98LOV/LAU_857
#  ===================
# Old pH, index 3951: 6
# New pH, index 4012: 6.0
#
#
# 98TEW/CHE_1138 is equivalent.
#
#
# 98TEW/KIS_513 is equivalent.
# ERROR: 98TEW/KIS_513
#  ===================
# Old Keq, index 3954: 0.0559 & 0.78
# New Keq, index 4015: 0.78
#
#
# 98TEW/KIS_514 is equivalent.
#
#
# 98TEW/KIS_515 is equivalent.
# ERROR: 98TEW/KIS_515
#  ===================
# Old Keq, index 3957: 0.0559 & 1.069
# New Keq, index 4018: 1.069
#
#
# 98TEW/KIS_516 is equivalent.
#
#
# 98TEW/KIS_517 is equivalent.
# ERROR: 98TEW/KIS_517
#  ===================
# Old Keq, index 3960: 0.0559 & 0.876
# New Keq, index 4021: 0.876
#
#
# 98TEW/KIS_518 is equivalent.
#
#
# 98TEW_727 is equivalent.
#
#
# 98THO/JOR_267 is equivalent.
# ERROR: 98THO/JOR_267
#  ===================
# Old pH, index 3967: 7
# New pH, index 4028: 7.0
#
#
# 99HUT/OEH_944 is equivalent.
# ERROR: 99HUT/OEH_944
#  ===================
# Old enthalpy, index 3969: -127
# New enthalpy, index 4030: -127.0
#
#
# 99KIS/HOL_1199 is equivalent.
# ERROR: 99KIS/HOL_1199
#  ====================
# Old enthalpy, index 3969: -127
# New enthalpy, index 4030: -127.0
# Old enthalpy, index 3970: -79
# New enthalpy, index 4031: -79.0
#
#
# 99KIS/HOL_262 is equivalent.
# ERROR: 99KIS/HOL_262
#  ===================
# Old enthalpy, index 3970: -79
# New enthalpy, index 4031: -79.0
#
#
# 99KIS/TEW_988 is equivalent.
#
#
# 99KIS/TEW_992 is equivalent.
#
#
# 99TEW/SCH_723 is equivalent.

# %%
list = ['q', 's', 'e']

string = ''

string = string.join(list)

print(string)
# Out:
# qse
