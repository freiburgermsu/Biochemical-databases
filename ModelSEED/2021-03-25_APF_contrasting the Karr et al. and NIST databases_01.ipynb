# %% [markdown]
# # Combining the Kar et al. and NIST databases

# %% [markdown]
# Shambles of code

# %%
# import the libraries
import json

# import the databases
nist = json.load(open('2021-03-29_APF_NIST consolidated_01.json'))
wckb = json.load(open('2021-03-25_APF_WCKB reactions + references.json'))


# loop through the enzymes in both databases
for enzyme, value in nist.items():
    # lists of the database varialbes
    keq_values_per_enzyme = []
    km_values_per_enzyme = []
    enthalpy_values_per_enzyme = []
    temperatures_per_enzyme = []
    phs_per_enzyme = []
    
    # lists of identifying whether the reference contains the identified variable 
    references_of_an_enzyme = []
    reaction_of_an_enzyme = []
    km_in_the_reference = []
    enthalpy_in_the_reference = []
    keqs_in_a_reference = []
    for enzyme2, value2 in wckb.items():
        if enzyme == enzyme2:
            
            
            
            
    #store the information into a nested dictionary structure
    data_per_enzyme[enzyme] = {'reaction':reaction_of_an_enzyme,
                               'experimental temperatures':temperatures_per_enzyme,
                               'experimental phs':phs_per_enzyme,
                               'keq reference':references_of_an_enzyme,
                               'Keq':{'keq values in the reference':keqs_in_a_reference,
                                       'keqs':keq_values_per_enzyme, 
                                       'keq quantity':len(keq_values_per_enzyme), 
                                       'keq average':average_keq_per_enzyme, 
                                       'keq standard deviation':standard_deviation_keq_per_enzyme},
                               'Km':{'km values in the reference':km_in_the_reference,
                                    'km values':km_values_per_enzyme,
                                    'km average':average_km_per_enzyme,
                                    'km standard deviation':standard_deviation_km_per_enzyme},
                               'Enthalpy':{'enthalpy values in the reference':enthalpy_in_the_reference,
                                         'enthalpy values':enthalpy_values_per_enzyme,
                                         'enthalpy average':average_enthalpy_per_enzyme,
                                         'enthalpy standard deviation':standard_deviation_enthalpy_per_enzyme}}

# %% [markdown]
# ## Comparing the data with the BiGG model

# %% [markdown]
# The code is illogical in a few parts, and is inefficient -- The aforementioned reactions data is compared with the BiGG model for the core E. coli metabolism. The missing enzymes will be identified elsewhere to provide a working dataset for our simulation model.

# %%
#import the libraries and JSON files
import collections
import json
import re

metabolites = json.load(open('2021-03-17_APF_Karr et al. metabolite data.json'))
reactions = json.load(open('2021-03-17_APF_Karr et al. kinetic data.json'))
nist = json.load(open('2021-03-21_APF_NIST consolidated_01.json'))
bigg = json.load(open('BiGG model of E_coli core metabolism_indented.json'))


bigg_model_ecoli_ids = ['ACALD', 'ACALDt', 'ACKr','ACONTa','ACONTb','ACt2r','ADK1','AKGDH','AKGt2r','ALCD2x',
                        'ATPM','ATPS4r','BIOMASS_Ecoli_core_w_GAM','CO2t','CS','CYTBD','D_LACt2','ENO','ETOHt2r',
                        'EX_acald_e','EX_ac_e','EX_akg_e','EX_co2_e','EX_etoh_e','EX_for_e','EX_fru_e',
                        'EX_fum_e','EX_glc__D_e','EX_gln__L_e','EX_glu__L_e','EX_h2o_e','EX_h_e','EX_lac__D_e',
                        'EX_mal__L_e','EX_nh4_e','EX_o2_e','EX_pi_e','EX_pyr_e','EX_succ_e','FBA','FBP',
                        'FORt','FORt2','FRD7','FRUpts2','FUM','FUMt2_2','G6PDH2r','GAPD','GLCpts',
                        'GLNabc','GLNS','GLUDy','GLUN','GLUSy','GLUt2r','GND','H2Ot','ICDHyr','ICL',
                        'LDH_D','MALS','MALt2_2','MDH','ME1','ME2','NADH16','NADTRHD','NH4t','O2t','PDH',
                        'PFK','PFL','PGI','PGK','PGL','PGM','PIt2r','PPC','PPCK','PPS','PTAr','PYK','PYRt2','RPE',
                        'RPI','SUCCt2_2','SUCCt3','SUCDi','SUCOAS','TALA','THD2','TKT1','TKT2','TPI']



bigg_model_ecoli_names = ['Acetaldehyde dehydrogenase (acetylating)', 'Acetaldehyde reversible transport',
                         'Acetate kinase','Aconitase (half-reaction A, Citrate hydro-lyase)',
                         'Aconitase (half-reaction B, Isocitrate hydro-lyase)',
                         'Acetate reversible transport via proton symport', 'Adenylate kinase',
                         '2-Oxogluterate dehydrogenase', '2 oxoglutarate reversible transport via symport',
                         'Alcohol dehydrogenase (ethanol)', 'ATP maintenance requirement', 
                         'ATP synthase (four protons for one ATP)', 'Biomass Objective Function with GAM',
                         'CO2 transporter via diffusion', 'Citrate synthase', 
                         'Cytochrome oxidase bd (ubiquinol-8: 2 protons)','D lactate transport via proton symport',
                         'Enolase','Ethanol reversible transport via proton symport','Acetaldehyde exchange',
                         'Acetate exchange', '2-Oxoglutarate exchange', 'CO2 exchange', 'Ethanol exchange',
                         'Formate exchange', 'D-Fructose exchange', 'Fumarate exchange', 'D-Glucose exchange',
                         'L-Glutamine exchange', 'L-Glutamate exchange', 'H2O exchange','H+ exchange','D-lactate exchange',
                         'L-Malate exchange','Ammonia exchange','O2 exchange','Phosphate exchange','Pyruvate exchange',
                         'Succinate exchange','Fructose-bisphosphate aldolase','Fructose-bisphosphatase',
                         'Formate transport via diffusion','Formate transport in via proton symport','Fumarate reductase',
                         'Fructose transport via PEP:Pyr PTS (f6p generating)','Fumarase',
                         'Fumarate transport via proton symport (2 H)','Glucose 6-phosphate dehydrogenase',
                         'Glyceraldehyde-3-phosphate dehydrogenase','D-glucose transport via PEP:Pyr PTS',
                         'L-glutamine transport via ABC system','Glutamine synthetase','Glutamate dehydrogenase (NADP)',
                         'Glutaminase','Glutamate synthase (NADPH)','L glutamate transport via proton symport reversible',
                         'Phosphogluconate dehydrogenase', 'H2O transport via diffusion','Isocitrate dehydrogenase (NADP)',
                         'Isocitrate lyase','D-lactate dehydrogenase','Malate synthase',
                         'Malate transport via proton symport (2 H)','Malate dehydrogenase','Malic enzyme (NAD)',
                         'Malic enzyme (NADP)','NADH dehydrogenase (ubiquinone-8 & 3 protons)',
                         'NAD transhydrogenase','Ammonia reversible transport','O2 transport diffusion',
                         'Pyruvate dehydrogenase','Phosphofructokinase','Pyruvate formate lyase',
                         'Glucose-6-phosphate isomerase','Phosphoglycerate kinase','6-phosphogluconolactonase',
                         'Phosphoglycerate mutase','Phosphate reversible transport via symport',
                         'Phosphoenolpyruvate carboxylase','Phosphoenolpyruvate carboxykinase',
                         'Phosphoenolpyruvate synthase','Phosphotransacetylase','Pyruvate kinase',
                         'Pyruvate transport in via proton symport','Ribulose 5-phosphate 3-epimerase',
                         'Ribose-5-phosphate isomerase','Succinate transport via proton symport (2 H)',
                         'Succinate transport out via proton antiport','Succinate dehydrogenase (irreversible)',
                         'Succinyl-CoA synthetase (ADP-forming)','Transaldolase','NAD(P) transhydrogenase',
                         'Transketolase','Transketolase','Triose-phosphate isomerase']


#creating a complete list of enzymatic reaction names in the BiGG model
enzyme_names = []
metabolite_names = []
for keys in bigg:
    for key, values in  keys.items():
        if key == 'reactions':
            for key, value in values.items():
                enzyme_names.append(value['name'])
                
                
                #creating a list of metabolite names in the BiGG model
                for entry in value['metabolites']:
                    for key, val in entry.items():
                        if key == 'bigg_id':
                            if val not in metabolite_names:
                                metabolite_names.append(val)


#establish the complete set of reaction names
karr_reaction_names = []
nist_enzyme_name = []
for id, values in reactions.items():
    karr_reaction_names.append(values['Enzyme Name'])
for id, value in nist.items():
    nist_enzyme_name.append(id)

                                
#combine the NIST and Karr datasets while respecting the case sensitivity of the enzyme names
union_reactions = []
intersection_reactions = []
for enzyme in karr_reaction_names:
    for enzyme2 in nist_enzyme_name:
        if enzyme.lower() == enzyme2.lower(): 
            if enzyme not in intersection_reactions:
                intersection_reactions.append(enzyme)
        if enzyme not in union_reactions:
            union_reactions.append(enzyme)
        if enzyme2 not in union_reactions:
            union_reactions.append(enzyme2)
            
            
#determine the set of BiGG reactions that are described or undescribed by the set of scraped values 
described_from_union = []
described_from_intersection = []
described_in_karr = []
described_in_karr_by_karr = []
for enzyme in enzyme_names:
    for enzyme2 in union_reactions:
        if enzyme.lower() == enzyme2.lower() and enzyme not in described_from_union:
            described_from_union.append(enzyme)
            break
    for enzyme3 in intersection_reactions:
        if enzyme.lower() == enzyme3.lower() and enzyme not in described_from_intersection:
            described_from_intersection.append(enzyme)
            break
    for enzyme4 in karr_reaction_names:
        if enzyme.lower() == enzyme4.lower() and enzyme not in described_in_karr:
            described_in_karr.append(enzyme)
            if enzyme4 not in described_in_karr_by_karr:
                described_in_karr_by_karr.append(enzyme4)
            break
            
            
# determining the set fo reactions that are not described by the scraped data
undescribed_from_union = []
undescribed_from_intersection = []          
for enzyme in enzyme_names:
    if enzyme not in described_from_union:
        undescribed_from_union.append(enzyme)
for enzyme in enzyme_names:    
    if enzyme not in described_from_intersection:
        undescribed_from_intersection.append(enzyme)
        
both_enzymes_intersection = []
both_enzymes_union = []
for enzyme in undescribed_from_intersection:
    if enzyme in described_from_intersection:
        both_enzymes_intersection.append(enzyme)
for enzyme in undescribed_from_union:
    if enzyme in described_from_union:
        both_enzymes_union.append(enzyme)
    
    
'''#create the michaelis-menten equations for each of the enzymes
described_kinetic_information = {}
for id, values in reactions.items():
    #print(values['Enzyme Name'])
    if values['Enzyme Name'] in described_in_karr or values['Enzyme Name'] in described_in_karr_by_karr:
        print(reactions[id])'''
    
    
'''
#identify the complete set of metabolite names 
karr_metabolite_names = []
for id, list in metabolites.items():
    karr_metabolite_names.append(list['Name'])   

    
#identify the complete set of metabolite ids
metabolite_ids = []
for key in metabolites:
    metabolite_ids.append(key) '''

    

#identifying the differences between the captured enzyme list and the original BiGG list
combined_union = described_from_union + undescribed_from_union
combined_intersection = described_from_intersection + undescribed_from_intersection
for enzyme in combined_intersection:
    if enzyme not in enzyme_names:
        print(enzyme)
for enzyme in combined_union:
    if enzyme not in enzyme_names:
        print(enzyme)
intersection_difference = collections.Counter(enzyme_names) - collections.Counter(combined_intersection)
union_difference = collections.Counter(enzyme_names) - collections.Counter(combined_union)
print('intersection difference\n',intersection_difference)
print('union difference\n',union_difference)
    
    

print('\nIntersection reactions', len(intersection_reactions))
print('Union reactions', len(union_reactions))

print('\nTotal BiGG enzymes:', len(enzyme_names))
print('Described from union enzymes:', len(described_from_union))
print('Undescribed from union reactions', len(undescribed_from_union))
print('Described from intersection enzymes', len(described_from_intersection))
print('Undescribed from intersection enzymes', len(undescribed_from_intersection))

print('\nDescribed in Karr: %s\n' %(len(described_in_karr)), described_in_karr)


union_reactions.sort()
#print(union_reactions)
intersection_reactions.sort()
print('\nInersection reactions\n', '%s'%('='*len('Inersection reactions')),'\n',intersection_reactions)
print('\nBiGG & intersection reactions\n', '%s'%('='*len('BiGG & intersection reactions')), '\n',described_from_intersection)


'''print('\nDescribed and undescribed intersection reactions\n', 
       '%s'%('='*len('nDescribed and undescribed intersection reactions')), 
       '\n%s' %(both_enzymes_intersection))
print('\nDescribed and undescribed union reactions\n', 
       '%s'%('='*len('nDescribed and undescribed union reactions')), 
       '\n%s' %(both_enzymes_union))'''


'''keys.sort()
for key in keys:
    print(key)'''

# %% [markdown]
# The representation of the BiGG model from the NIST database is determined. The set of reactions that are represented and unrepresented are furthermore separately stored as lists.

# %%
#import the libraries and JSON files
import collections
import numpy
import json
import re

nist = json.load(open('2021-03-21_APF_NIST consolidated_01.json'))
bigg = json.load(open('BiGG model of S. aureus.json'))
empty_cell = ['nan', None, numpy.nan, '', ' ']

# creating a complete list of enzymatic reaction names in the BiGG model
saureus_enzymes = []
for key, value in bigg.items():
    #print(key)
    if key == 'reactions':
        for enzyme in value:
            for key2, value2 in enzyme.items():
                if key2 == 'name':
                    saureus_enzymes.append(value2)

# compiling the set of reaction names from the NIST database
nist_enzyme_name = []
parenthesized_nist_enzymes = []
for id, value in nist.items():
    #print(id)
    nist_enzyme_name.append(id)
    if re.search('(\s\(.*\))', id):
        striped_value = re.sub('(\s\(.*\))', '', id)
        #print(striped_value)
        parenthesized_nist_enzymes.append(striped_value)

#print(parenthesized_nist_enzymes)
        
# identifying the BiGG model enzymes that are represented by the NIST database 
represented_enzymes = []
represented_nist_enzymes = []
for enzyme in saureus_enzymes:
    for enzyme2 in nist_enzyme_name:
        if enzyme.lower() == enzyme2.lower(): 
            if enzyme not in represented_enzymes:
                represented_enzymes.append(enzyme)
                represented_nist_enzymes.append(enzyme2)
    for enzyme3 in parenthesized_nist_enzymes:
        if re.search(enzyme3, enzyme):
            #print(enzyme)
            if enzyme not in represented_enzymes:
                represented_enzymes.append(enzyme)
                represented_nist_enzymes.append(enzyme2)
                
unexpressed_enzymes = (set(nist_enzyme_name) - set(represented_nist_enzymes))
unexpressed_nist_enzymes_counted = len(nist_enzyme_name) - len(represented_enzymes)
    
print('\nTotal BiGG enzymes:', len(saureus_enzymes))
print('\nTotal unexpressed NIST enzymes:', unexpressed_nist_enzymes_counted)
print('\nUnexpressed enzymes from the NIST database: %s\n' %(len(unexpressed_enzymes)), unexpressed_enzymes)

print('\nRepresented by the NIST database: %s\n' %(len(represented_enzymes)), represented_enzymes)
# Out:
# Total BiGG enzymes: 1455
#
# Total unexpressed NIST enzymes: 343
#
# Unexpressed enzymes from the NIST database: 345
#  {'_-alanyl-CoA ammonia lyase', 'leucyl aminopeptidase', 'alanine aminotransferase', 'papain', 'pyrimidine-nucleoside phosphorylase', 'acetate CoA-transferase', '2,3-dimethylmalate lyase', 'myosin ATPase', 'L-rhamnose isomerase', '2-aminoadipate transaminase', 'glutamine-pyruvate aminotransaminase', 'uridine phosphorylase', 'S)-2-methylmalate dehydratase', 'glucose-6-phosphate 1-epimerase', 'acetylcholinesterase', 'thiamine pyridinylase', 'aryl sulfotransferase', 'N-methyl-2-oxoglutaramate hydrolase', 'cyclomaltodextrin glucanotransferase and a-amylase', 'a-glucosidase', 'lysine 2,3-aminomutase', 'quinate dehydrogenase', 'malate dehydrogenase', 'glycine formiminotransferase', '2-dehydro-3-deoxyphosphogluconate aldolase', '3-oxoacyl-[acyl-carrier-protein] reductase', 'formate dehydrogenase (NADP+)', 'allantoicase', '2-dehydro-3-deoxy-6-phosphogalactonate aldolase', 'D-xylulose reductase', '2-arylpropionyl-CoA epimerase', 'phosphoserine phosphatase', 'oligo-1,6-glucosidase', 'triacylglycerol lipase', '3-dehydroquinate dehydratase', 'glycerol dehydrogenase (NADP+)', "3',5'-cyclic-nucleotide phosphodiesterase", 'butyryl-CoA dehydrogenase', 'methylaspartate ammonia-lyase', 'carnitine O-acetyltransferase', 'branched-chain-amino-acid transaminase', 'glyceraldehyde-3-phocphate dehydrogenase and phosphoglycerate kinase', '2,4-diaminopentanoate dehydrogenase', 'deoxy)nucleoside-phosphate kinase', '2-deoxy-D-gluconate dehydrogenase', 'alanopine dehydrogenase', 'glucose-1-phosphate guanylyltransferase', '2-methyleneglutarate mutase', 'rhamnulose-1-phosphate aldolase', 'ketotetraose-phosphate aldolase', 'nucleoside-diphosphate kinase', '3-hydroxyacyl-CoA dehydrogenase', '3(or 17)_-hydroxysteroid dehydrogenase', 'glutathione-CoA-glutathione transhydrogenase', '_-lactamase', 'serine-pyruvate transaminase', 'pyrroline-5-carboxylate reductase', 'asparaginase', 'galactinol-raffinose galactosyltransferase', '1-phosphatidylinositol kinase', 'phenylpyruvate tautomerase', 'NADH dehydrogenase', 'citrate (si)-synthase and malate dehydrogenase', 'NAD(P)+ transhydrogenase', 'glu-X carboxypeptidase', 'hypoxanthine phosphoribosyltransferase', 'serine acetyltransferase', 'L-threonate dehydrogenase', 'estradiol 17_-dehydrogenase', 'cellobiose phosphorylase', 'glutamate N-acetyltransferase', 'choline O-acetyltransferase', 'glyoxylate dehydrogenase (acylating)', 'D-glutamate cyclase', 'sepiapterin reductase', 'chymosin', 'UDPglucose 4-epimerase and UDPglucose-hexose 1-phosphate uridylyltransferase', 'glutathione transferase', 'aspartate ammonia-lyase', 'triacyglycerol lipase', 'D-arabino-3-hexulose phosphate formaldehyde lyase', 'sucrose-phosphate synthase', 'ribose isomerase', 'sorbitol-6-phosphate dehydrogenase (NADP+)', 'malate dehydrogenase and aspartate aminotransferase', 'succinate-CoA ligase (ADP forming)', 'D-ornithine 4,5-aminomutase', 'R,R)-butanediol dehydrogenase', 'laminaribiose phosphorylase', '5,10-methylenetetrahydrofolate reductase (FADH2)', 'gly-X carboxypeptidase', 'pyridoxamine-pyruvate transaminase', 'phosphodiesterase I', 'phosphohydrolase (unclassified)', 'fructose-biphosphate aldolase', '15-hydroxyprostaglandin dehydrogenase (NAD+)', 'enoyl-CoA hydratase', 'peroxidase', 'guanosine phosphorylase', 'UDPglucose-hexose 1-phosphate uridylyltransferase and UDPglucose 4-epimerase', 'alanine transaminase', 'cholesterol oxidase and catalase', 'dTDP-4-amino-4,6-dideoxy-D-glucose transaminase', 'malate synthase', 'sucrose phosphorylase', 'pancreatic ribonuclease', 'alcohol dehydrogenase', 'L-fuculose-phosphate aldolase', 'UDPglucuronate 4-epimerase', '_-fructofuranosidase', '3-oxoacid CoA-transferase', 'glucose-6-phosphate dehydrogenase', 'triose-phosphate isomerase and fructose-bisphosphate aldolase', 'adenosylhomocysteinase', 'hydrogen dehydrogenase', 'fructose-biphosphate aldolase and triose-phosphate isomerase', 'methylmalonyl-CoA carboxyltransferase', 'phosphate acetyltransferase and formate C-acetyltransferase', 'glycine-oxaloacetate trans ...
#
# Represented by the NIST database: 74
#  ['Acetaldehyde dehydrogenase (acetylating)', 'Acetate kinase', '4-aminobutyrate transaminase', 'Acetyl-CoA C-acetyltransferase', 'N-Acetylneuraminate lyase', 'Alanine racemase', 'D-alanine transaminase', 'Adenosine deaminase', '4-aminobenzoate synthase', 'Arginine deiminase', 'Adenylate kinase', 'Alkaline phosphatase', 'Arginase', 'Aspartate-semialdehyde dehydrogenase', 'Aspartate kinase', 'Adenylate cyclase', 'Aspartate transaminase', 'Adenine phosphoribosyltransferase', 'Adenylosuccinate lyase', 'Adenylosuccinate synthase', 'Catalase', 'Carbamate kinase', 'Cytidine deaminase', 'Chorismate mutase', 'Diaminopimelate epimerase', 'Dihydroorotase', 'Dihydrofolate reductase', 'Dephospho-CoA kinase', 'Deoxyribose-phosphate aldolase', 'Formate dehydrogenase', 'UDPglucose 4-epimerase', 'Glyceraldehyde-3-phosphate dehydrogenase', 'Glutamate racemase', 'Formate-tetrahydrofolate ligase', 'Glucose-1-phosphate adenylyltransferase', 'Glutaminase', '3-isopropylmalate dehydrogenase', 'D-lactate dehydrogenase', 'L-lactate dehydrogenase', 'Histidinol-phosphate transaminase', 'Isochorismate synthase', 'Lactoylglutathione lyase', 'Methenyltetrahydrofolate cyclohydrolase', 'Mannose-6-phosphate isomerase', 'Nicotinamide ribonucleotide phosphohydrolase', 'Pyruvate carboxylase', 'Phosphoglycerate dehydrogenase', 'Glucose-6-phosphate isomerase', 'Phosphoglycerate kinase', 'Phosphoglycerate mutase', 'Phosphoglucomutase', 'Ornithine carbamoyltransferase', 'D-octopine dehydrogenase', 'Orotate phosphoribosyltransferase', 'Phosphomannomutase', 'Phosphomevalonate kinase', 'Pyruvate kinase', 'Purine-nucleoside phosphorylase', 'Phosphopentomutase', 'Succinyldiaminopimelate transaminase', 'Ribose-5-phosphate isomerase', 'Phosphoserine transaminase', 'Shikimate dehydrogenase', 'Transketolase', 'Thymidylate synthase', 'Triose-phosphate isomerase', 'Thioredoxin reductase (NADPH)', 'Urease', 'UDP-N-acetylglucosamine 1-carboxyvinyltransferase', 'Xylose isomerase', 'Transaldolase', 'Galactokinase', 'L-ribulose-phosphate 4-epimerase', 'L-arabinose isomerase']

# %% [markdown]
# The thermodynamically described enzymes are parsed from the NIST database data. The enzymes which are conjoined with "and" were separated and individually analyzed. The sets of separately described enzymes and conjoined enzymes are each applied as columns of a dataframe, which is exported.

# %%
#import the libraries and JSON files
from ftfy import fix_encoding
import pandas
import numpy
import json
import re

nist = json.load(open('2021-03-29_APF_NIST consolidated_01.json'))
bigg = json.load(open('BiGG model of S. aureus.json'))
empty_cell = ['nan', None, numpy.nan, '', ' ', 'NaN', '[]']


# creating a complete list of enzymatic reaction names in the BiGG model
saureus_enzymes = []
for key, value in bigg.items():
    #print(key)
    if key == 'reactions':
        for enzyme in value:
            for key2, value2 in enzyme.items():
                if key2 == 'name':
                    saureus_enzymes.append(value2)
                    

# compiling the set of reaction names from the NIST database
nist_enzyme_name = []
parenthesized_nist_enzymes = []
parenthesized_nist_ennzymes_original = []
and_conjoined_enzymes = []
and_conjoined_enzyme_original = []
thermodynamic_enzyme_names = []
kinetic_enzymes = []
for name, value in nist.items():
    nist_enzyme_name.append(name)
    for detail, information in value.items():
        #print(detail, '\t', information)
        if detail == 'Keq':
            for detail2, information2 in information.items():
                if detail2 == 'keqs':
                    for information3 in information2:
                        #print(id, '\t', information3)
                        if information3 not in empty_cell: 
                            #print('keqs', id)
                            if re.search('(\sand\s)', name):
                                left_enzyme_striped_value = re.sub('(.*and\s)', '', name)
                                right_enzyme_striped_value = re.sub('(\sand.*)', '', name)
                                if left_enzyme_striped_value not in thermodynamic_enzyme_names:
                                    thermodynamic_enzyme_names.append(left_enzyme_striped_value)
                                if right_enzyme_striped_value not in thermodynamic_enzyme_names:
                                    thermodynamic_enzyme_names.append(right_enzyme_striped_value)
                                if left_enzyme_striped_value not in and_conjoined_enzymes:
                                    and_conjoined_enzymes.append(left_enzyme_striped_value)
                                if right_enzyme_striped_value not in and_conjoined_enzymes:
                                    and_conjoined_enzymes.append(right_enzyme_striped_value)
                                if name not in and_conjoined_enzyme_original:
                                    and_conjoined_enzyme_original.append(name)
                            else:
                                if name not in thermodynamic_enzyme_names:
                                    thermodynamic_enzyme_names.append(name)
                        else:
                            print(information3)

        if detail == 'Enthalpy':
            for detail2, information2 in information.items():
                #print('yay')
                #print('information:\t', detail2, '\t', information2)
                if detail2 == 'enthalpy values':
                    #print('yes')
                    for information3 in information2:
                        if information3 not in empty_cell:
                            if re.search('(\sand\s)', name):
                                left_enzyme_striped_value = re.sub('(.*and\s)', '', name)
                                right_enzyme_striped_value = re.sub('(\sand.*)', '', name)
                                if left_enzyme_striped_value not in thermodynamic_enzyme_names:
                                    thermodynamic_enzyme_names.append(left_enzyme_striped_value)
                                if right_enzyme_striped_value not in thermodynamic_enzyme_names:
                                    thermodynamic_enzyme_names.append(right_enzyme_striped_value)    
                                if left_enzyme_striped_value not in and_conjoined_enzymes:
                                    and_conjoined_enzymes.append(left_enzyme_striped_value)
                                if right_enzyme_striped_value not in and_conjoined_enzymes:
                                    and_conjoined_enzymes.append(right_enzyme_striped_value)
                                if name not in and_conjoined_enzyme_original:
                                    and_conjoined_enzyme_original.append(name)
                            else:
                                if name not in thermodynamic_enzyme_names:
                                    thermodynamic_enzyme_names.append(name)
                        else:
                             print(information3)   
     
        if detail == 'Km':
            for detail2, information2 in information.items():
                #print('yay')
                #print('information:\t', detail2, '\t', information2)
                if detail2 == 'km values':
                    #print('yes')
                    for information3 in information2:
                        if information3 not in empty_cell:
                            if name not in kinetic_enzymes:
                                kinetic_enzymes.append(name)
                                #print('kinetics', name)
                        else:
                             print(information3)           
                                
        
        if re.search('(\s\(.*\))', name):
            striped_value = re.sub('(\s\(.*\))', '', name)
            #print(striped_value)
            parenthesized_nist_enzymes.append(striped_value)
            parenthesized_nist_ennzymes_original.append(name)
            
                
'''for enzyme in and_conjoined_enzyme_original:
    index = and_conjoined_enzyme_original.index(enzyme)
    for entry in nist[enzyme]['Keq']['keqs']:
        if entry not in empty_cell and and_conjoined_enzymes[index] not in thermodynamic_enzyme_names:
            thermodynamic_enzyme_names.append(enzyme)
    for entry in nist[enzyme]['Enthalpy']['enthalpy values']:
        if entry not in empty_cell and and_conjoined_enzymes[index] not in thermodynamic_enzyme_names:
            thermodynamic_enzyme_names.append(enzyme)'''
            
                
'''print('separated enzymes: %s\n' %(len(and_conjoined_enzymes)), set(and_conjoined_enzymes))   
print('\noriginal enzymes: %s\n' %(len(and_conjoined_enzyme_original)), set(and_conjoined_enzyme_original))     '''       

'''print(parenthesized_nist_enzymes)
nist_enzyme_name += and_conjoined_enzymes
thermodynamic_enzyme_names.append('test')'''
        
    
# comparing the NIST and BiGG databases 
represented_enzymes = []
represented_nist_enzymes = []
for enzyme in saureus_enzymes:
    for enzyme2 in thermodynamic_enzyme_names:
        if enzyme.lower() == enzyme2.lower():
            represented_enzymes.append(enzyme)
            represented_nist_enzymes.append(enzyme2)
    
    
'''    for enzyme2 in nist_enzyme_name:
        if enzyme.lower() == enzyme2.lower(): 
            if enzyme not in represented_enzymes:
                represented_enzymes.append(enzyme)
                represented_nist_enzymes.append(enzyme2)
    for enzyme3 in parenthesized_nist_enzymes:
        if re.search(enzyme3, enzyme):
            #print(enzyme)
            if enzyme not in represented_enzymes:
                index = parenthesized_nist_enzymes.index(enzyme3)
                represented_enzymes.append(enzyme)
                represented_nist_enzymes.append(parenthesized_nist_ennzymes_original[index])
    for enzyme3 in and_conjoined_enzymes:
        if re.search(enzyme3, enzyme):
            #print(enzyme)
            if enzyme not in represented_enzymes:
                print(enzyme, '\t', enzyme3)
                index = and_conjoined_enzymes.index(enzyme3)
                represented_enzymes.append(enzyme)
                represented_nist_enzymes.append(and_conjoined_enzyme_original[index])'''
                
                
'''unexpressed_enzymes = (set(nist_enzyme_name) - set(represented_nist_enzymes))
unexpressed_nist_enzymes_counted = len(nist_enzyme_name) - len(represented_enzymes)
not_thermodynamic_enzymes = set(nist_enzyme_name) - set(thermodynamic_enzyme_names)
    
print('\nTotal BiGG enzymes:', len(saureus_enzymes))
print('\nNot thermodynamic enzymes:', len(not_thermodynamic_enzymes))
print('\nTotal unexpressed NIST enzymes:', unexpressed_nist_enzymes_counted)
print('\nUnexpressed enzymes from the NIST database: %s\n' %(len(unexpressed_enzymes)), unexpressed_enzymes)
print('\nThermodynamic enzymes in the NIST database: %s\n' %(len(thermodynamic_enzyme_names)), 
      thermodynamic_enzyme_names)
print('\nS. aureus represented by the NIST database: %s\n' %(len(represented_enzymes)), represented_enzymes)
print('\nKinetics in the NIST database: %s\n' %(len(kinetic_enzymes)), kinetic_enzymes)'''

'''thermodynamic_dictionary = {}
for enzyme in thermodynamic_enzyme_names:
    thermodynamic_dictionary[enzyme] = '''


# export the parsed reaction names to a CSV file
'''dataframe = pandas.DataFrame.from_dict({'separated enzymes':thermodynamic_enzyme_names,
                                     'conjoined enzymes':and_conjoined_enzyme_original},
                            orient = 'index')
dataframe = dataframe.transpose()
dataframe.to_csv('2021-04-29_APF_thermodynamically described enzymes_01.csv')'''



# determine the set of metabolites in the thermodynamically described reactions
'''described_compounds = []
for enzyme in nist:
    for enzyme2 in thermodynamic_enzyme_names:
        if re.search('(-)', enzyme2):
            enzyme2 = re.sub('(-)', '(\-)', enzyme2)
        if re.search(enzyme2, enzyme):
            #print(enzyme,'\n', enzyme2)
            reactants_list = []
            products_list = []
            for reaction in nist[enzyme]['reaction']:
                #print(reaction)
                reaction = fix_encoding(reaction)
                #print(reaction)
                if re.search('(=)', reaction):
                    reaction = reaction.split('=')
                    #print('reaction:\t', reaction)
                    reactants = reaction[0]
                    products = reaction[1] 
                    #print('reactants:\t', reactants)
                    #print('products:\t', products)
                    reactants_list = reactants.split('+')
                    products_list = products.split('+')
                    #print('reactants list:\t', reactants_list)
                    #print('products list:\t', products_list)
                    for element in reactants_list:
                        #print(element)
                        element = element.strip()
                        element = re.sub('(\(aq\)|\(l\)|\(sln\)|\(liq\))', '', element)
                        element = re.sub('(\d\s|\d\/\d\s)', '', element)
                        if element not in described_compounds:
                            #print(element)
                            described_compounds.append(element)
                    for element in products_list:
                        #print(element)
                        element = element.strip()
                        element = re.sub('(\(aq\)|\(l\)|\(sln\)|\(liq\))', '', element)
                        element = re.sub('(\d\s|\d\/\d\s)', '', element)
                        if element not in described_compounds:
                            #print(element)
                            described_compounds.append(element)
                else:
                    print('abnormal reaction:\t', reaction)

export_comopunds_yes_no = {}
for compound in described_compounds:
    export_comopunds_yes_no[compound] = {'logical name': 'yes',
                                        'present in KEGG': ''}

with open('2021-04-29_APF_nist thermodynamically described compounds for ModelSEED_02.json', 'w') as output:
    json.dump(export_comopunds_yes_no, output, indent = 4)'''
    

# create the clean set of reactions for the ModelSEED repository code
rearranged_reactions_for_modelseed = []
to_be_rearranged = []
export_reactions_for_modelseed = {}
for enzyme in nist:
    for enzyme2 in thermodynamic_enzyme_names:
        if re.search('(-)', enzyme2):
            enzyme2 = re.sub('(\-)', '\-', enzyme2)
        if re.search(enzyme2, enzyme):
            for reaction in nist[enzyme]['reaction']:
                reaction = fix_encoding(reaction)
                #print(reaction)
                if reaction not in to_be_rearranged:
                    to_be_rearranged.append(reaction)
                    #print(reaction)
                    
                    # replace the phase identifiers
                    if re.search('(\(aq\)|\(l\)|\(sln\)|\(liq\))', reaction):
                        reaction = re.sub('(\(aq\)|\(l\)|\(sln\)|\(liq\))', '', reaction)
                    #print(reaction)
                    
                    # arrange the reaction equilibrium arrow and stoichiometric coefficients for ModelSEED
                    if re.search('(\s?=\s?)', reaction):
                        reaction = re.sub('(\s?=\s?)', ' <=> ', reaction)
                    if re.search('((?<!\w)\d\s|\d\/\d\s)', reaction):
                        reaction = re.sub('((?<!\w)\d\s|\d\/\d\s)', r'(\1) ', reaction)
                        reaction = re.sub('(?<=\d)(\s)(?=\))', '', reaction)
                    else:
                        reaction = re.sub('(?<=\+)(\s)(?=\w)', ' (1) ', reaction)
                        reaction = re.sub('(?<=>)(\s)(?=\w)', ' (1) ', reaction)
                    if reaction[0] == ' ':
                        reaction = re.sub('\s', '(1) ', reaction, 1)
                    else:
                        reaction = '(1) ' + reaction
                    reaction = re.sub('(?<=\w)(\s)(?=<|\+)', '[0] ', reaction)
                    reaction += '[0]'
                    #print(reaction)
                    if reaction not in rearranged_reactions_for_modelseed:
                        enzyme2 = re.sub(r'(\\)', '', enzyme2)
                        export_reactions_for_modelseed[enzyme2] = {'reaction expression':reaction,
                                                                   'yes_no':''}
                        rearranged_reactions_for_modelseed.append(reaction)
                    else:
                        print('repeated reactions:\t', reaction)


'''print('\nFinal reactions:')
for reaction in rearranged_reactions_for_modelseed:
    print(reaction)
'''
    
with open('2021-04-29_APF_nist thermodynamically described reactions for ModelSEED_02.json', 'w') as output:
    json.dump(export_reactions_for_modelseed, output, indent = 4)
# Out:
# repeated reactions:	 (1) α-D-glucose 1-phosphate[0] <=> (1) α-D-glucose 6-phosphate[0]
# repeated reactions:	 (1) α-D-galactose 1-phosphate[0] <=> (1) α-D-glucose 1-phosphate[0]
# repeated reactions:	 (1) sedoheptulose 7-phosphate[0] + (1) D-glyceraldehyde 3-phosphate[0] <=> (1) D-erythrose 4-phosphate[0] + (1) D-fructose 6-phosphate[0]
# repeated reactions:	 (1) diolein[0] + (1) H2O[0] <=> (1) oleic acid[0] + (1) monoolein[0]
# repeated reactions:	 (1) monoolein[0] + (1) H2O[0] <=> (1) oleic acid[0] + (1) glycerol[0]
# repeated reactions:	 (1) triolein[0] + (1) H2O[0] <=> (1) oleic acid[0] + (1) diolein[0]
# repeated reactions:	 (1) N-acetyl-L-phenylalanine ethyl ester[0] + (1) H2O[0] <=>  N-acetyl-L-phenylalanine[0] + (1) ethanol[0]
# repeated reactions:	 (1) 3,4,5-trihydroxybenzoic acid propyl ester[0] + (1) H2O[0] <=> (1) 3,4,5-trihydroxybenzoate[0] + (1) propan-1-ol[0]

# %%
import re 
from ftfy import fix_encoding

j = 'ATP-\u00ce\u00b1-S(aq) + (R)-5-phosphomevalonate(aq) = ADP-\u00ce\u00b1-S(aq) + (R)-5-diphosphomevalonate(aq)'
p = fix_encoding(j)
print(p)



def decodeu (match):
    u = '%c%c' % (int(match.group(1), 16), int(match.group(2), 16))
    return repr(u.decode('utf-8'))[2:8]




j = re.sub(r'\\u00([cd][0-9a-f])\\u00([89ab][0-9a-f])',decodeu, j)

print(j)
# Out:
# ATP-α-S(aq) + (R)-5-phosphomevalonate(aq) = ADP-α-S(aq) + (R)-5-diphosphomevalonate(aq)
# ATP-Î±-S(aq) + (R)-5-phosphomevalonate(aq) = ADP-Î±-S(aq) + (R)-5-diphosphomevalonate(aq)

# %%
import json
import re

wckb = json.load(open('2021-03-25_APF_WCKB reactions + references.json'))
wckb_metabolites = json.load(open('2021-03-17_APF_Karr et al. metabolite data.json'))

empty_cells = ['NaN', None, numpy.nan, '', ' ', 'null', 'None', 'nan', '[None]', '[\'None\']']    

# determine the set of thermodynamically described reactions from the WCKB downloaded json data
thermodynamically_described_enzymes_wckb = []
wckb_enzymes = []
wckb_keqs = []
wckb_kinetics = []
wckb_gibbs = []
for enzyme, value in wckb.items():
    if enzyme not in wckb_enzymes:
        #print(enzyme)
        wckb_enzymes.append(enzyme)
        for keq in value['keq']:
            if keq not in empty_cells and enzyme not in wckb_gibbs:
                thermodynamically_described_enzymes_wckb.append(enzyme)
                wckb_keqs.append(enzyme)
        for gibbs in value['Gibbs free energy']:
            if gibbs not in empty_cells and enzyme not in wckb_gibbs:
                thermodynamically_described_enzymes_wckb.append(enzyme)
                wckb_gibbs.append(enzyme)
        for forward_kinetics in value['forward kinetics']:
            if forward_kinetics not in empty_cells and enzyme not in wckb_gibbs:
                wckb_kinetics.append(enzyme)
        for backward_kinetics in value['backward kinetics']:
            if backward_kinetics not in empty_cells and enzyme not in wckb_gibbs:
                wckb_kinetics.append(enzyme)
                
print('\n\nWCKB enzymes:\t\t', len(wckb_enzymes)) 
print('Thermodynamically described enzymes: ', len(thermodynamically_described_enzymes)) 
print('WCKB Keqs:\t\t', len(wckb_keqs))   
print('WCKB Kinetics:\t\t', len(wckb_kinetics))
print('WCKB gibbs:\t\t', len(wckb_gibbs))     
                            
thermodynamically_described_enzymes = set(wckb_gibbs).union(set(wckb_keqs))
wckb_reactions = []
export_reactions_wckb_for_modelseed = {}
for enzyme in thermodynamically_described_enzymes:
    for entry in wckb[enzyme]['stoichiometry']:
        compound_loop = 0
        product_loop = 0
        for molecule in entry:
            if molecule['compartment'] == 'c':
                compartment_value = 0
            elif molecule['compartment'] == 'e':
                compartment_value = 1
            elif molecule['compartment'] == 'm':
                compartment_value = 2
                
            if compound_loop == 0:
                reaction_string = '(%s) %s[%d]'  %(abs(int(float(molecule['coefficient']))), molecule['molecule'], compartment_value)
                compound_loop += 1
            elif product_loop == 0 and float(molecule['coefficient']) > 0: 
                reaction_string += ' <=> (%s) %s[%d]'  %(int(float(molecule['coefficient'])), molecule['molecule'], compartment_value)            
                product_loop += 1
            else:
                reaction_string += ' + (%s) %s[%d]'  %(abs(int(float(molecule['coefficient']))), molecule['molecule'], compartment_value)
        print(reaction_string)
        wckb_reactions.append(reaction_string)       
        export_reactions_wckb_for_modelseed[enzyme] = {'reaction expression':reaction_string,
                                                       'yes_no':''}
                    
          
                
with open('2021-04-29_APF_wckb thermodynamically described reactions for ModelSEED_01.json', 'w') as output:
    json.dump(export_reactions_wckb_for_modelseed, output, indent = 4)
    
    
# determine the set of thermodynamically described compounds from the aforementioned reactions
'''described_compounds = []
for enzyme in thermodynamically_described_enzymes:
    for entry in wckb[enzyme]['stoichiometry']:
        for molecule in entry:
            if molecule['molecule'] not in described_compounds:
                described_compounds.append(molecule['molecule'])
            try:
                proper_molecule = wckb_metabolites[molecule['molecule']]['Name']
                #print(molecule['molecule'])
                #print(proper_molecule)
            except:
                print('abbreviation-only compound:\t', molecule['molecule'])
                proper_molecule = molecule['molecule']
                proper_molecule = re.sub('(MG_287_MONOMER.)', '', proper_molecule)
                proper_molecule = re.sub('(MG_287_MONOMER|NA)', 'unknown', proper_molecule)
            if proper_molecule not in described_compounds:
                described_compounds.append(proper_molecule)
            
print('\n\nThermodynamically described compounds: ', len(described_compounds))
export_wckb_compounds_yes_no = {}
for compound in described_compounds:
    export_wckb_compounds_yes_no[compound] = ''
    print(compound)
    
with open('2021-04-29_APF_wckb thermodynamically described compounds for ModelSEED_01.json', 'w') as output:
    json.dump(export_wckb_compounds_yes_no, output, indent = 4)'''
# Out:
# WCKB enzymes:		 1635
# Thermodynamically described enzymes:  208
# WCKB Keqs:		 197
# WCKB Kinetics:		 204
# WCKB gibbs:		 208
# (2) H[0] + (1) PI[0] + (1) URI[0] <=> (1) R1P[0] + (1) URA[0]
# (1) CO2[1] <=> (1) CO2[0]
# (1) ATP[0] + (1) DCMP[0] <=> (1) ADP[0] + (1) DCDP[0]
# (1) ATP[0] + (1) MG_287_MONOMER_ACP[0] + (1) OCDCA[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_ocdcaACP[0] + (1) PPI[0]
# (1) GN[0] + (1) PRPP[0] <=> (1) GMP[0] + (1) PPI[0]
# (1) O2[1] <=> (1) O2[0]
# (1) R5P[0] + (1) X5P[0] <=> (1) S7P[0] + (1) T3P1[0]
# (1) E4P[0] + (1) X5P[0] <=> (1) F6P[0] + (1) T3P1[0]
# (1) CTP[0] + (1) H[0] + (1) PA141[2] <=> (1) CDPDG141[2] + (1) PPI[0]
# (1) ATP[0] + (1) H2O[0] + (1) MN[1] <=> (1) ADP[0] + (1) H[0] + (1) MN[0] + (1) PI[0]
# (1) GTP[0] + (1) URI[0] <=> (1) GDP[0] + (1) H[0] + (1) UMP[0]
# (1) AMP[0] + (1) GTP[0] <=> (1) ADP[0] + (1) GDP[0]
# (1) FOR[1] <=> (1) FOR[0]
# (1) ATP[0] + (1) DAMP[0] <=> (1) ADP[0] + (1) DADP[0]
# (1) H[0] + (1) NADPH[0] + (1) RIBFLV[0] <=> (1) NADP[0] + (1) RBFLVRD[0]
# (1) HCYS[0] + (1) MTHF[0] <=> (1) H[0] + (1) MET[0] + (1) THF[0]
# (1) CTP[0] + (1) H[0] + (1) PA120[2] <=> (1) CDPDG120[2] + (1) PPI[0]
# (1) RL5P[0] <=> (1) R5P[0]
# (1) H[1] + (1) URA[1] <=> (1) H[0] + (1) URA[0]
# (1) DALA[0] + (1) PL5P[0] <=> (1) PDLA5P[0] + (1) PYR[0]
# (1) GL3P[0] + (1) MG_287_MONOMER_palmACP[0] <=> (3) H[0] + (1) HDECG3P[0] + (1) MG_287_MONOMER_ACP[0]
# (1) H[1] + (1) TRP[1] <=> (1) H[0] + (1) TRP[0]
# (1) ATP[0] + (1) CHOL[0] <=> (1) ADP[0] + (1) H[0] + (1) pCHOL[0]
# (1) AMP[0] + (1) ATP[0] <=> (2) ADP[0]
# (1) CYTD[1] + (1) H[1] <=> (1) CYTD[0] + (1) H[0]
# (1) ATP[0] + (1) CO2[0] + (1) NH3[0] <=> (1) ADP[0] + (1) CAP[0] + (1) H[0]
# (1) HYXN[0] + (1) R1P[0] <=> (2) H[0] + (1) INS[0] + (1) PI[0]
# (1) METTHF[0] + (1) NADH[0] <=> (1) MTHF[0] + (1) NAD[0]
# (1) ATP[0] + (1) FMN[0] + (1) H[0] <=> (1) FAD[0] + (1) PPI[0]
# (1) DU[0] + (1) PI[0] <=> (1) DR1P[0] + (1) URA[0]
# (1) AD[1] + (1) H[1] <=> (1) AD[0] + (1) H[0]
# (2) H[0] + (1) HDECG3P[0] + (1) MG_287_MONOMER_palmACP[0] <=> (1) MG_287_MONOMER_ACP[0] + (1) PA160[2]
# (1) GL[1] <=> (1) GL[0]
# (1) ATP[0] + (1) THM[0] <=> (1) AMP[0] + (1) H[0] + (1) TPP[0]
# (1) ATP[0] + (1) UMP[0] <=> (1) ADP[0] + (1) UDP[0]
# (1) G1P[0] <=> (1) G6P[0]
# (1) H[0] + (1) NADH[0] + (1) RIBFLV[0] <=> (1) NAD[0] + (1) RBFLVRD[0]
# (1) AMP[0] + (1) H2O[0] <=> (1) ADN[0] + (1) PI[0]
# (1) ACTP[0] + (1) ADP[0] <=> (1) AC[0] + (1) ATP[0]
# (1) H[0] + (1) H2O[0] + (1) METHF[0] <=> (1) FTHF5[0]
# (1) ATP[0] + (1) MG_287_MONOMER_ACP[0] + (1) TTDCEA[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_tdeACP[0] + (1) PPI[0]
# (1) CTP[0] + (1) H[0] + (1) PA180[2] <=> (1) CDPDG180[2] + (1) PPI[0]
# (1) DC[0] + (1) H2O[0] <=> (1) DU[0] + (1) NH3[0]
# (1) G23CMP[0] + (1) H2O[0] <=> (1) G3MP[0] + (1) H[0]
# (1) ARG[0] + (1) H2O[0] <=> (1) CITR[0] + (1) H[0] + (1) NH3[0]
# (1) ATP[0] + (1) H[0] + (1) NMN[0] <=> (1) NAD[0] + (1) PPI[0]
# (1) ATP[0] + (1) H2O[0] + (1) SPMD[1] <=> (1) ADP[0] + (1) H[0] + (1) PI[0] + (1) SPMD[0]
# (1) H2O[0] + (1) IMP[0] <=> (1) INS[0] + (1) PI[0]
# (1) H[0] + (1) NADH[0] + (1) O2[0] <=> (1) H2O2[0] + (1) NAD[0]
# (1) ATP[0] + (1) H2O[0] + (1) PTRC[1] <=> (1) ADP[0] + (1) H[0] + (1) PI[0] + (1) PTRC[0]
# (1) MAL[0] + (1) NAD[0] <=> (1) H[0] + (1) NADH[0] + (1) OA[0]
# (1) FDP[0] <=> (1) T3P1[0] + (1) T3P2[0]
# (1) ATP[0] + (1) H2O[0] + (1) MOBD[1] <=> (1) ADP[0] + (1) H[0] + (1) MOBD[0] + (1) PI[0]
# (1) GPG[0] + (1) H2O[0] <=> (1) GL[0] + (1) GL3P[0]
# (1) GL3P[0] + (1) MG_287_MONOMER_ocdcaACP[0] <=> (1) H[0] + (1) MG_287_MONOMER_ACP[0] + (1) ODECG3P[0]
# (1) GL3P[0] + (1) MG_287_MONOMER_octeACP[0] <=> (1) H[0] + (1) MG_287_MONOMER_ACP[0] + (1) ODEC11GP[0]
# (1) ALA[0] + (1) PL5P[0] <=> (1) PDLA5P[0] + (1) PYR[0]
# (1) CTP[0] + (1) H[0] + (1) PA140[2] <=> (1) CDPDG140[2] + (1) PPI[0]
# (1) ATP[0] + (1) MG_287_MONOMER_ACP[0] + (1) OCDCEA[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_octeACP[0] + (1) PPI[0]
# (1) ATP[0] + (1) H2O[0] + (1) ZN[1] <=> (1) ADP[0] + (1) H[0] + (1) PI[0] + (1) ZN[0]
# (1) DA[0] + (1) PI[0] <=> (1) AD[0] + (1) DR1P[0]
# (1) H2O[0] + (1) PPI[0] <=> (1) H[0] + (2) PI[0]
# (1) ATP[0] + (1) GDP[0] <=> (1) AMP[0] + (1) H[0] + (1) PPGPP[0]
# (1) G6P[0] <=> (1) F6P[0]
# (1) DUMP[0] + (1) METTHF[0] <=> (1) DHF[0] + (1) DTMP[0] + (2) H[0]
# (1) G2P[0] <=> (1) H2O[0] + (1) PEP[0]
# (1) GLU[0] + (1) HPHPYR[0] <=> (1) AKG[0] + (1) TYR[0]
# (1) GN[0] + (1) R1P[0] <=> (1) GSN[0] + (2) H[0] + (1) PI[0]
# (1) MG_287_MONOMER_ocdcaACP[0] + (1) ODECG3P[0] <=> (1) MG_287_MONOMER_ACP[0] + (1) PA180[2]
# (1) ACAL[0] <=> (1) ACAL[1]
# (1) CAP[0] + (1) ORN[0] <=> (1) CITR[0] + (1) H[0] + (1) PI[0]
# (1) AD[0] + (1) R1P[0] <=> (1) ADN[0] + (2) H[0] + (1) PI[0]
# (1) ACCOA[0] + (1) PI[0] <=> (1) ACTP[0] + (1) COA[0]
# (1) ATP[0] + (1) H2O[0] + (1) PI[1] <=> (1) ADP[0] + (1) H[0] + (2) PI[0]
# (1) H2O[1] <=> (1) H2O[0]
# (1) GPCH[0] + (1) H2O[0] <=> (1) CHOL[0] + (1) GL3P[0]
# (1) CTP[0] + (1) H[0] + (1) PA160[2] <=> (1) CDPDG160[2] + (1) PPI[0]
# (1) ATP[0] + (1) NAD[0] <=> (1) ADP[0] + (1) NADP[0]
# (1) ADP[0] + (1) DPG[0] <=> (1) ATP[0] + (1) G3P[0]
# (1) DPG[0] + (1) GDP[0] <=> (1) G3P[0] + (1) GTP[0]
# (1) DADP[0] + (1) DPG[0] <=> (1) DATP[0] + (1) G3P[0]
# (1) DPG[0] + (1) IDP[0] <=> (1) G3P[0] + (1) ITP[0]
# (1) DGDP[0] + (1) DPG[0] <=> (1) DGTP[0] + (1) G3P[0]
# (1) ATP[0] + (1) GTP[0] <=> (1) AMP[0] + (1) GDPTP[0] + (1) H[0]
# (1) CTP[0] + (1) H[0] + (1) PA161[2] <=> (1) CDPDG161[2] + (1) PPI[0]
# (1) GPE[0] + (1) H2O[0] <=> (1) ETN[0] + (1) GL3P[0] + (1) H[0]
# (1) A23CMP[0] + (1) H2O[0] <=> (1) A3MP[0] + (1) H[0]
# (1) AD[0] + (1) PRPP[0] <=> (1) AMP[0] + (1) PPI[0]
# (1) G1P[0] + (1) H[0] + (1) UTP[0] <=> (1) PPI[0] + (1) UDPG[0]
# (1) GPI[0] + (1) H2O[0] <=> (1) GL3P[0] + (1) INOS[0]
# (1) GL3P[0] + (1) H[0] + (1) MG_287_MONOMER_hdeACP[0] <=> (1) HDECEG3P[0] + (1) MG_287_MONOMER_ACP[0]
# (1) FRU[1] + (1) PEP[0] <=> (1) F1P[0] + (1) PYR[0]
# (1) G3P[0] <=> (1) G2P[0]
# (1) GMP[0] + (1) H2O[0] <=> (1) GSN[0] + (1) PI[0]
# (1) CYTD[0] + (1) H2O[0] <=> (1) NH3[0] + (1) URI[0]
# (1) H[1] + (1) PHE[1] <=> (1) H[0] + (1) PHE[0]
# (1) T3P2[0] <=> (1) T3P1[0]
# (1) ATP[0] + (1) DC[0] <=> (1) ADP[0] + (1) DCMP[0] + (1) H[0]
# (1) DCMP[0] + (1) H2O[0] <=> (1) DC[0] + (1) PI[0]
# (1) ATP[0] + (1) DTMP[0] <=> (1) ADP[0] + (1) DTDP[0]
# (1) AMP[0] + (1) ITP[0] <=> (1) ADP[0] + (1) IDP[0]
# (1) NAD[0] + (1) PI[0] + (1) T3P1[0] <=> (1) DPG[0] + (1) H[0] + (1) NADH[0]
# (1) ATP[0] + (1) HDCA[0] + (1) MG_287_MONOMER_ACP[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_palmACP[0] + (1) PPI[0]
# (2) PG161[2] <=> (1) CL161[2] + (1) GL[0]
# (1) MG_287_MONOMER_myrsACP[0] + (1) TDECG3P[0] <=> (1) MG_287_MONOMER_ACP[0] + (1) PA140[2]
# (1) H2O[0] + (1) PGP160[2] <=> (1) PG160[2] + (1) PI[0]
# (1) ADP[0] + (1) H[0] + (1) PEP[0] <=> (1) ATP[0] + (1) PYR[0]
# (1) CDP[0] + (1) H[0] + (1) PEP[0] <=> (1) CTP[0] + (1) PYR[0]
# (1) DADP[0] + (1) H[0] + (1) PEP[0] <=> (1) DATP[0] + (1) PYR[0]
# (1) DCDP[0] + (1) H[0] + (1) PEP[0] <=> (1) DCTP[0] + (1) PYR[0]
# (1) DGDP[0] + (1) H[0] + (1) PEP[0] <=> (1) DGTP[0] + (1) PYR[0]
# (1) DTDP[0] + (1) H[0] + (1) PEP[0] <=> (1) DTTP[0] + (1) PYR[0]
# (1) DUDP[0] + (1) H[0] + (1) PEP[0] <=> (1) DUTP[0] + (1) PYR[0]
# (1) GDP[0] + (1) H[0] + (1) PEP[0] <=> (1) GTP[0] + (1) PYR[0]
# (1) H[0] + (1) IDP[0] + (1) PEP[0] <=> (1) ITP[0] + (1) PYR[0]
# (1) H[0] + (1) PEP[0] + (1) TDP[0] <=> (1) PYR[0] + (1) TTP[0]
# (1) H[0] + (1) PEP[0] + (1) UDP[0] <=> (1) PYR[0] + (1) UTP[0]
# (1) ATP[0] + (1) GL[0] <=> (1) ADP[0] + (1) GL3P[0]
# (2) PG160[2] <=> (1) CL160[2] + (1) GL[0]
# (1) UDPGAL[0] <=> (1) UDPG[0]
# (1) CDPDG161[2] + (1) GL3P[0] <=> (1) CMP[0] + (2) H[0] + (1) PGP161[2]
# (1) ATP[0] + (1) MG_287_MONOMER_ACP[0] + (1) TTDCA[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_myrsACP[0] + (1) PPI[0]
# (1) GLN[0] + (1) H2O[0] <=> (1) GLU[0] + (1) H[0] + (1) NH3[0]
# (1) CDPDG181[2] + (1) GL3P[0] <=> (1) CMP[0] + (2) H[0] + (1) PGP181[2]
# (2) H[0] + (1) SER[0] + (1) THF[0] <=> (1) GLY[0] + (1) H2O[0] + (1) METTHF[0]
# (1) MG_287_MONOMER_octeACP[0] + (1) ODEC11GP[0] <=> (1) MG_287_MONOMER_ACP[0] + (1) PA181[2]
# (1) H2O[0] + (1) PGP161[2] <=> (1) PG161[2] + (1) PI[0]
# (1) AHCYS[0] + (1) H2O[0] <=> (1) ADN[0] + (1) HCYS[0]
# (1) ATP[0] + (1) RIBFLV[0] <=> (1) ADP[0] + (1) FMN[0] + (1) H[0]
# (1) ATP[0] + (1) DGMP[0] <=> (1) ADP[0] + (1) DGDP[0]
# (1) COA[0] + (1) NAD[0] + (1) PYR[0] <=> (1) ACCOA[0] + (1) CO2[0] + (1) NADH[0]
# (1) HDECEG3P[0] + (1) MG_287_MONOMER_hdeACP[0] <=> (2) H[0] + (1) MG_287_MONOMER_ACP[0] + (1) PA161[2]
# (1) FADH2[0] + (2) FE3[0] <=> (1) FAD[0] + (2) FE2[0] + (2) H[0]
# (1) ATP[0] + (1) NH3[0] + (1) NR[0] <=> (1) ADP[0] + (1) NMN[0] + (1) PI[0]
# (1) DTMP[0] + (1) H2O[0] <=> (1) DT[0] + (1) PI[0]
# (1) ATP[0] + (1) PYDX[0] <=> (1) ADP[0] + (1) H[0] + (1) PL5P[0]
# (1) MG_287_MONOMER_tdeACP[0] + (1) TDECEG3P[0] <=> (1) MG_287_MONOMER_ACP[0] + (1) PA141[2]
# (1) ATP[0] + (1) CMP[0] <=> (1) ADP[0] + (1) CDP[0]
# (1) ATP[0] + (1) DG[0] <=> (1) ADP[0] + (1) DGMP[0] + (1) H[0]
# (1) ATP[0] + (1) THMP[0] <=> (1) ADP[0] + (1) TPP[0]
# (1) ATP[0] + (1) F1P[0] <=> (1) ADP[0] + (1) FDP[0] + (1) H[0]
# (1) GLC[1] + (1) PEP[0] <=> (1) G6P[0] + (1) PYR[0]
# (1) ATP[0] + (1) FE2[1] + (1) H2O[0] <=> (1) ADP[0] + (1) FE2[0] + (1) H[0] + (1) PI[0]
# (1) GL3P[0] + (1) MG_287_MONOMER_myrsACP[0] <=> (1) H[0] + (1) MG_287_MONOMER_ACP[0] + (1) TDECG3P[0]
# (1) ATP[0] + (1) FTHF10[0] + (3) H[0] <=> (1) ADP[0] + (1) METTHF[0] + (1) PI[0]
# (1) CDPDG160[2] + (1) GL3P[0] <=> (1) CMP[0] + (2) H[0] + (1) PGP160[2]
# (1) ATP[0] + (1) GMP[0] <=> (1) ADP[0] + (1) GDP[0]
# (1) DHA[0] + (1) PEP[0] <=> (1) PYR[0] + (1) T3P2[0]
# (1) ATP[0] + (1) H2O[0] + (1) MET[0] <=> (1) AMET[0] + (1) PI[0] + (1) PPI[0]
# (1) CTP[0] + (1) H[0] + (1) PA181[2] <=> (1) CDPDG181[2] + (1) PPI[0]
# (1) DHF[0] + (1) H[0] + (1) NADPH[0] <=> (1) NADP[0] + (1) THF[0]
# (1) FMN[0] + (1) H[0] + (1) NADH[0] <=> (1) FMNH2[0] + (1) NAD[0]
# (1) FMN[0] + (1) H[0] + (1) NADPH[0] <=> (1) FMNH2[0] + (1) NADP[0]
# (1) DDECG3P[0] + (1) MG_287_MONOMER_ddcaACP[0] <=> (1) MG_287_MONOMER_ACP[0] + (1) PA120[2]
# (1) H2O[0] + (1) U23CMP[0] <=> (1) H[0] + (1) U3MP[0]
# (1) C23CMP[0] + (1) H2O[0] <=> (1) C3MP[0] + (1) H[0]
# (1) G6P[1] + (2) PI[0] <=> (1) G6P[0] + (2) PI[1]
# (1) ATP[0] + (1) DU[0] <=> (1) ADP[0] + (1) DUMP[0] + (1) H[0]
# (1) ATP[0] + (1) DA[0] <=> (1) ADP[0] + (1) DAMP[0] + (1) H[0]
# (1) DA[1] + (1) H[1] <=> (1) DA[0] + (1) H[0]
# (1) H2O[0] + (1) PGP181[2] <=> (1) PG181[2] + (1) PI[0]
# (1) NAC[1] <=> (1) NAC[0]
# (1) COA[0] + (1) MG_287_MONOMER[0] <=> (1) H[0] + (1) MG_287_MONOMER_ACP[0] + (1) PAP[0]
# (1) GPS[0] + (1) H2O[0] <=> (1) GL3P[0] + (1) SER[0]
# (1) H2O[0] + (1) PAP[0] <=> (1) AMP[0] + (1) PI[0]
# (1) NH4[1] <=> (1) NH4[0]
# (1) AD[0] + (1) H2O[0] <=> (1) HYXN[0] + (1) NH3[0]
# (1) GN[1] + (1) H[1] <=> (1) GN[0] + (1) H[0]
# (1) THR[0] <=> (1) ACAL[0] + (1) GLY[0]
# (1) MAN6P[1] + (2) PI[0] <=> (1) MAN6P[0] + (2) PI[1]
# (1) ATP[0] + (1) H2O[0] + (1) MG[1] <=> (1) ADP[0] + (1) H[0] + (1) MG[0] + (1) PI[0]
# (1) FADH2[0] + (1) H[0] + (1) T3P2[0] <=> (1) FAD[0] + (1) GL3P[0]
# (1) dINS[0] + (1) PI[0] <=> (1) DR1P[0] + (1) HYXN[0]
# (1) ATP[0] + (1) GLN[1] + (1) H2O[0] <=> (1) ADP[0] + (1) GLN[0] + (1) H[0] + (1) PI[0]
# (1) S7P[0] + (1) T3P1[0] <=> (1) E4P[0] + (1) F6P[0]
# (1) ATP[0] + (1) F6P[0] <=> (1) ADP[0] + (1) FDP[0] + (1) H[0]
# (1) F6P[0] + (1) GTP[0] <=> (1) FDP[0] + (1) GDP[0] + (1) H[0]
# (1) DATP[0] + (1) F6P[0] <=> (1) DADP[0] + (1) FDP[0] + (1) H[0]
# (1) F6P[0] + (1) ITP[0] <=> (1) FDP[0] + (1) H[0] + (1) IDP[0]
# (1) F6P[0] + (1) UTP[0] <=> (1) FDP[0] + (1) H[0] + (1) UDP[0]
# (1) HYXN[0] + (1) PRPP[0] <=> (1) IMP[0] + (1) PPI[0]
# (1) ATP[0] + (3) H[0] + (1) H2O[0] + (1) NAC[0] + (1) PRPP[0] <=> (1) ADP[0] + (1) NAMN[0] + (1) PI[0] + (1) PPI[0]
# (1) PRPP[0] + (1) URA[0] <=> (1) PPI[0] + (1) UMP[0]
# (1) ATP[0] + (1) NAAD[0] + (1) NH3[0] <=> (1) AMP[0] + (3) H[0] + (1) NAD[0] + (1) PPI[0]
# (1) H[1] + (1) K[1] <=> (1) H[0] + (1) K[0]
# (1) ATP[0] + (1) TAG6P[0] <=> (1) ADP[0] + (1) H[0] + (1) TAG16P[0]
# (1) ATP[0] + (1) CU[1] + (1) H2O[0] <=> (1) ADP[0] + (1) CU[0] + (1) H[0] + (1) PI[0]
# (1) CYTD[0] + (1) GTP[0] <=> (1) CMP[0] + (1) GDP[0] + (1) H[0]
# (1) ATP[0] + (1) FE3[1] + (1) H2O[0] <=> (1) ADP[0] + (1) FE3[0] + (1) H[0] + (1) PI[0]
# (1) DATP[0] + (1) GMP[0] <=> (1) DADP[0] + (1) GDP[0]
# (1) DG[0] + (1) PI[0] <=> (1) DR1P[0] + (1) GN[0]
# (1) ATP[0] + (1) H2O[0] + (1) SO4[1] <=> (1) ADP[0] + (1) H[0] + (1) PI[0] + (1) SO4[0]
# (1) METTHF[0] + (1) NADP[0] <=> (2) H[0] + (1) METHF[0] + (1) NADPH[0]
# (1) NADP[0] + (1) SNGLYP[0] <=> (1) H[0] + (1) NADPH[0] + (1) T3P2[0]
# (1) GLU[0] + (1) PHPYR[0] <=> (1) AKG[0] + (1) PHE[0]
# (1) MAN6P[0] <=> (1) MAN1P[0]
# (1) AC[1] + (1) H[1] <=> (1) AC[0] + (1) H[0]
# (1) RL5P[0] <=> (1) X5P[0]
# (1) DATP[0] + (1) DGMP[0] <=> (1) DADP[0] + (1) DGDP[0]
# (1) ATP[0] + (1) R5P[0] <=> (1) AMP[0] + (1) H[0] + (1) PRPP[0]
# (1) FMET[0] + (1) H2O[0] <=> (1) FOR[0] + (1) H[0] + (1) MET[0]
# (1) DUMP[0] + (1) H2O[0] <=> (1) DU[0] + (1) PI[0]
# (1) ATP[0] + (1) FOR[0] + (1) THF[0] <=> (1) ADP[0] + (1) FTHF10[0] + (1) PI[0]
# (1) H[0] + (1) NADH[0] + (1) PYR[0] <=> (1) LAC[0] + (1) NAD[0]
# (1) CL[1] + (2) H[0] <=> (1) CL[0] + (2) H[1]
# (1) DR5P[0] <=> (1) ACAL[0] + (1) T3P1[0]
# (1) ATP[0] + (1) DT[0] <=> (1) ADP[0] + (1) DTMP[0] + (1) H[0]
# (1) R1P[0] + (1) XAN[0] <=> (2) H[0] + (1) PI[0] + (1) XTSN[0]
# (1) H[1] + (1) TYR[1] <=> (1) H[0] + (1) TYR[0]
# (1) AKG[1] + (1) H[1] <=> (1) AKG[0] + (1) H[0]
# (1) DT[0] + (1) PI[0] <=> (1) DR1P[0] + (1) THY[0]
# (1) H2O[0] + (1) METHF[0] <=> (1) FTHF10[0] + (1) H[0]
# (1) FAD[0] + (1) H[0] + (1) NADH[0] <=> (1) FADH2[0] + (1) NAD[0]
# (1) UDPGAL[0] <=> (1) UDPGALF[0]
# (1) ADP[0] + (4) H[1] + (1) H[0] + (1) PI[0] <=> (1) ATP[0] + (4) H[0] + (1) H2O[0]
# (1) ATP[0] + (1) DPCOA[0] <=> (1) ADP[0] + (1) COA[0] + (1) H[0]
# (1) GL3P[0] + (1) MG_287_MONOMER_ddcaACP[0] <=> (1) DDECG3P[0] + (1) H[0] + (1) MG_287_MONOMER_ACP[0]
# (1) FUC1P[1] + (2) PI[0] <=> (1) FUC1P[0] + (2) PI[1]
# (1) H[0] + (1) NA[1] <=> (1) H[1] + (1) NA[0]
# (1) AMET[0] + (1) HCYS[0] <=> (1) AHCYS[0] + (1) H[0] + (1) MET[0]
# (2) PG181[2] <=> (1) CL181[2] + (1) GL[0]
# (1) ATP[0] + (1) CO2[0] + (1) H2O[0] + (1) PYR[0] <=> (1) ADP[0] + (2) H[0] + (1) OA[0] + (1) PI[0]
# (1) ATP[0] + (1) H2O[0] + (1) RIB[1] <=> (1) ADP[0] + (1) H[0] + (1) PI[0] + (1) RIB[0]
# (1) ATP[0] + (1) HDCEA[0] + (1) MG_287_MONOMER_ACP[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_hdeACP[0] + (1) PPI[0]
# (1) GL3P[0] + (1) MG_287_MONOMER_tdeACP[0] <=> (1) H[0] + (1) MG_287_MONOMER_ACP[0] + (1) TDECEG3P[0]
# (1) DU[0] + (1) PI[0] <=> (1) DR1P[0] + (1) URA[0]
# (1) ATP[0] + (1) DDCA[0] + (1) MG_287_MONOMER_ACP[0] <=> (1) AMP[0] + (1) MG_287_MONOMER_ddcaACP[0] + (1) PPI[0]
# (1) H2O[0] + (1) pSER[0] <=> (1) PI[0] + (1) SER[0]
# (1) CO2[0] + (1) H2O[0] + (1) PEP[0] <=> (1) H[0] + (1) OA[0] + (1) PI[0]
# (1) H[0] + (1) THY[1] <=> (1) H[1] + (1) THY[0]
# "described_compounds = []\nfor enzyme in thermodynamically_described_enzymes:\n    for entry in wckb[enzyme]['stoichiometry']:\n        for molecule in entry:\n            if molecule['molecule'] not in described_compounds:\n                described_compounds.append(molecule['molecule'])\n            try:\n                proper_molecule = wckb_metabolites[molecule['molecule']]['Name']\n                #print(molecule['molecule'])\n                #print(proper_molecule)\n            except:\n                print('abbreviation-only compound:\t', molecule['molecule'])\n                proper_molecule = molecule['molecule']\n                proper_molecule = re.sub('(MG_287_MONOMER.)', '', proper_molecule)\n                proper_molecule = re.sub('(MG_287_MONOMER|NA)', 'unknown', proper_molecule)\n            if proper_molecule not in described_compounds:\n                described_compounds.append(proper_molecule)\n            \nprint('\n\nThermodynamically described compounds: ', len(described_compounds))\nexport_wckb_compounds_yes_no = {}\nfor compound in described_compounds:\n    export_wckb_compounds_yes_no[compound] = ''\n    print(compound)\n    \nwith open('2021-04-29_APF_wckb thermodynamically described compounds for ModelSEED_01.json', 'w') as output:\n    json.dump(export_wckb_compounds_yes_no, output, indent = 4)"

# %% [markdown]
# The WCKB and NIST thermodynamically described datasets are combined. The exported JSON files will be used to investigate the KEGG IDs for the compounds, and the JSON files will be the subsequent basis for the TSV files that are passed throguh the ModelSEED contribution codes.

# %%
import json
import re

wckb = json.load(open('2021-04-29_APF_nist thermodynamically described compounds for ModelSEED_02.json'))
nist = json.load(open('2021-04-29_APF_wckb thermodynamically described compounds for ModelSEED_01.json'))
wckb_2 = json.load(open('2021-04-29_APF_wckb thermodynamically described reactions for ModelSEED_01.json'))
nist_2 = json.load(open('2021-04-29_APF_nist thermodynamically described reactions for ModelSEED_02.json'))
    
    
# combine the thermodynamically described compounds from the NIST and WCKB sources
'''export_union_compounds = {}
union_compounds = []
excluded_compounds = []
nist_compounds = []
wckb_compounds = []
for compound in nist:
    nist_compounds.append(compound)
    for compound2 in wckb:
        wckb_compounds.append(compound2)
        if compound.lower() == compound2.lower():
            if compound not in union_compounds:
                union_compounds.append(compound)
                export_union_compounds[compound] = ""

print('union compounds:\t', len(union_compounds))
for compound in union_compounds:
    print(compound)
    
complete_compounds_set = set(nist_compounds).union(set(wckb_compounds))
sorted_set_compounds = sorted(complete_compounds_set)
complete_thermodynamic_compounds = {}
print('\n\ncomplete compounds set:\t', len(complete_compounds_set))
for compound in sorted_set_compounds:
    complete_thermodynamic_compounds[compound] = ''
    print(compound)
    
    
with open('2021-04-29_APF_complete thermodynamically described compounds for KEGG_01.json', 'w') as output:
    json.dump(complete_thermodynamic_compounds, output, indent = 4)
    
with open('2021-04-30_APF_ModelSEED formatted compounds.tsv', 'w') as output:
    #output.write("id" + "name" + "abbreviation" + "aliases" + "formula" + "mass" + "charge" + "deltag" + "deltagerr" + "pka" + "pkb" + "inchikey" + "smiles" + "is_cofactor" + "is_core" + "is_obsolete" + "abstract_compound" + "comprised_of" + "linked_compound" + "notes" + "source" + '\n')
    output.write('\t'.join(['NAMES','ID', '\n']))
    for compound in complete_thermodynamic_compounds:
        output.write('\t'.join([compound, ]) + '\n')'''
    
    
# combine the thermodynamically described reactions from the NIST and WCKB sources
'''export_union_reactions = {}
union_reactions = []
nist_reactions = []
wckb_reactions = []
for reaction in nist_2:
    nist_reactions.append(reaction)
    for reaction2 in wckb_2:
        wckb_reactions.append(reaction2)
        if reaction.lower() == reaction2.lower():
            if reaction not in union_reactions:
                union_reactions.append(reaction)
                export_union_reactions[reaction] =''
                
print('union reactions:\t', len(union_reactions))
for reaction in union_reactions:
    print(reaction)
    
complete_reactions_set = set(nist_reactions).union(set(wckb_reactions))
sorted_set_reactions = sorted(complete_reactions_set)
complete_thermodynamic_reactions = {}
print('\n\ncomplete compounds set:\t', len(sorted_set_reactions))
for reaction in sorted_set_reactions:
    #reaction = re.sub('(\))', '\)', reaction)
    #print(reaction)
    try:
        complete_thermodynamic_reactions[reaction] = {'reaction expression':nist_2[reaction]['reaction expression'],
                                                      'yes_no':''}
    except:
        complete_thermodynamic_reactions[reaction] = {'reaction expression':wckb_2[reaction]['reaction expression'],
                                                      'yes_no':''}
    
    
with open('2021-04-30_APF_complete thermodynamically described reactions for KEGG_01.json', 'w') as output:
    json.dump(complete_thermodynamic_reactions, output, indent = 4)
    
with open('2021-04-30_APF_ModelSEED formatted reactions.tsv', 'w') as output:
    output.write('\t'.join(['NAMES','reaction', '\n']))
    for reaction in complete_thermodynamic_reactions:
        output.write('\t'.join([reaction, 
                                complete_thermodynamic_reactions[reaction]['reaction expression']]) + '\n')'''
# Out:
# union compounds:	 94
# phosphate
# uridine
# uracil
# carbon dioxide
# ATP
# dCMP
# ADP
# dCDP
# AMP
# diphosphate
# guanine
# GMP
# D-Xylulose 5-phosphate
# D-Erythrose 4-phosphate
# D-Fructose 6-phosphate
# CTP
# GTP
# GDP
# UMP
# Formate
# dAMP
# dADP
# L-homocysteine
# L-Methionine
# 5,6,7,8-Tetrahydrofolate
# D-Ribulose 5-phosphate
# D-alanine
# pyruvate
# L-tryptophan
# choline
# cytidine
# ammonia
# carbamoyl phosphate
# hypoxanthine
# inosine
# 5,10-Methylenetetrahydrofolate
# adenine
# glycerol
# thiamine
# UDP
# D-Glucose 1-phosphate
# D-Glucose 6-phosphate
# adenosine
# Acetyl phosphate
# acetate
# L-Arginine
# L-citrulline
# IMP
# oxaloacetate
# D-Fructose 1,6-bisphosphate
# L-alanine
# dUMP
# dihydrofolate
# dTMP
# phosphoenolpyruvate
# L-Glutamate
# 2-Oxoglutarate
# L-tyrosine
# guanosine
# acetaldehyde
# Acetyl-CoA
# 3-Phospho-D-glyceroyl phosphate
# 3-Phospho-D-glycerate
# dATP
# IDP
# ITP
# dGDP
# UTP
# myo-inositol
# D-Fructose
# D-Fructose 1-phosphate
# L-phenylalanine
# CDP
# dTTP
# CMP
# L-glutamine
# L-Serine
# glycine
# S-Adenosyl-L-homocysteine
# dGMP
# thymidine
# Pyridoxal
# D-Glucose
# Dihydroxyacetone
# S-Adenosyl-L-methionine
# L-Threonine
# D-Mannose 6-phosphate
# 2'-deoxyinosine
# D-Mannose 1-phosphate
# 2-Deoxy-D-ribose 5-phosphate
# xanthine
# xanthosine
# thymine
# D-ribose
#
#
# complete compounds set:	 1055
#
# (
# (-)-4-carboxymethyl-Δ-α--but-2-en-4-olide
# (-)-ureidoglycolate
# (1)-2-butanol
# (2,6-β-D-fructosyl)n
# (2R,3S)-2,3-dimethylmalate
# (2S)-4',7-dihydroxyflavanone
# (3-phospho-D-glycerol-aminomethyl)phosphonate
# (3-phospho-D-glycerol-chloroethyl)phosphonate
# (3-phospho-D-glycerol-chloromethyl)phosphonate
# (3-phospho-D-glycerol-ethyl)phosphonate
# (3-phospho-D-glycerol-methoxy)phosphonate
# (3-phospho-D-glycerol-methyl)phosphonate
# (3-phospho-D-glyceroyl)phosphonate
# (3R)-3-hydroxybutanoyl-CoA
# (3R)-3-hydroxyhexanoyl-CoA
# (3S)-3,6-diaminohexanoate
# (3S)-3-hydroxybutanoyl-CoA
# (3S)-3-hydroxyhexanoyl-CoA
# (E)-2-octenal
# (E)-3-nonen-2-one
# (E)-4-phenyl-3-buten-2-one
# (E)-dihydroxyfumarate
# (L-lysine)n
# (R)-2-(4-isobutylphenyl)propionyl-CoA
# (R)-2-decanol
# (R)-2-decyl butyrate
# (R)-2-dodecanol
# (R)-2-dodecyl butyrate
# (R)-2-heptanol
# (R)-2-heptyl butyrate
# (R)-2-nonanol
# (R)-2-nonyl butyrate
# (R)-2-octanol
# (R)-2-octyl butyrate
# (R)-2-undecanol
# (R)-2-undecyl butyrate
# (R)-3-hydroxybutanoate
# (R)-3-phosphoglycerate
# (R)-5-diphosphomevalonate
# (R)-5-phosphomevalonate
# (R)-S-lactoylglutathione
# (R)-glyceraldehyde
# (R)-glycerate
# (R)-lactate
# (R)-malate
# (R)-methylmalonyl-CoA
# (R,S)-malyl-CoA
# (S)-2-(4-isobutylphenyl)propionyl-CoA
# (S)-2-methylmalate
# (S)-3-hydroxybutanoyl-CoA
# (S)-3-hydroxyhexanoyl-CoA
# (S)-5-amino-3-oxohexanoate
# (S)-dihydroorotate
# (S)-lactaldehyde
# (S)-lactate
# (S)-malate
# (S)-methylmalonyl-CoA
# (S)-proline
# (aminomethyl)phosphonate
# (chloroethyl)phosphonate
# (chloromethyl)phosphonate
# (ethyl)phosphonate
# (methoxy)phosphonate
# (methyl)phosphonate
# (n-1) H2O
# )-5-exo-hydroxycamphor
# )-camphor
# 1
# 1,2-didodecanoyl-sn-glycerol 3-phosphate
# 1,2-dihexadec-9-enoyl-sn-glycerol 3-phosphate
# 1,2-dihexadecanoyl-sn-glycerol 3-phosphate
# 1,2-dioctadec-11-enoyl-sn-glycerol 3-phosphate
# 1,2-dioctadecanoyl-sn-glycerol 3-phosphate
# 1,2-ditetradec-7-enoyl-sn-glycerol 3-phosphate
# 1,2-ditetradecanoyl-sn-glycerol 3-phosphate
# 1,2-propanediol
# 1,3-propanediol
# 1-(indol-3-yl)glycerol 3-phosphate
# 1-O-α-D-mannopyranosyl-D-mannofuranose
# 1-butanol
# 1-butyl β-D-glucopyranoside
# 1-dodecanoyl-sn-glycerol 3-phosphate
# 1-hexadec-9-enoyl-sn-glycerol 3-phosphate
# 1-hexadecanoyl-sn-glycerol 3-phosphate
# 1-hexanol
# 1-naphthol
# 1-naphthyl phosphate
# 1-nonanol
# 1-octadec-11-enoyl-sn-glycerol 3-phosphate
# 1-octadecanoyl-sn-glycerol 3-phosphate
# 1-octanol
# 1-phosphatidyl-1D-myo-inositol
# 1-phosphatidyl-1D-myo-inositol 4-phosphate
# 1-phospho-α-D-glucuronate
# 1-propanol
# 1-propyl β-D-glucopyranoside
# 1-sinapoyl-D-glucose
# 1-tetradec-7-enoyl-sn-glycerol 3-phosphate
# 1-tetradecanoyl-sn-glycerol 3-phosphate
# 1-α-D-galactosyl-myo-inositol
# 10-formyl-tetrahydrofolate
# 10-formyltetrahydrofolate
# 10/20-DNA oligomer
# 11-cis-retinal
# 2',3'-Cyclic AMP
# 2',3'-Cyclic CMP
# 2',3'-Cyclic GMP
# 2',3'-Cyclic UMP
# 2',4,4'-trihydroxychalcone
# 2'-deoxyadenosine
# 2'-deoxyadenosine 3':5'-(cyclic)phosphate
# 2'-deoxyadenosine 5'-monophosphate
# 2'-deoxyinosine
# 2,2'-iminodipropanoate
# 2,3-dimethylmalate
# 2,4-diaminopentanoate
# 2,4-dihydroxybutanoate
# 2,5-dihydro-5-oxofuran-2-acetate
# 2-Deoxy-D-ribose 1-phosphate
# 2-Deoxy-D-ribose 5-phosphate
# 2-Oxoglutarate
# 2-amino-2-deoxyisochorismate
# 2-amino-4-oxopentanoate
# 2-butenoyl-CoA
# 2-butyl β-D-glucopyranoside
# 2-dehydro-3-deoxy-D-fuconate
# 2-dehydro-3-deoxy-D-galactonate 6-phosphate
# 2-dehydro-3-deoxy-L-pentonate
# 2-deoxy-3-dehydro-D-gluconate
# 2-deoxy-D-gluconate
# 2-deoxy-D-ribose 5-phosphate
# 2-deoxy-α-D-ribose 1-phosphate
# 2-hydroxy-3-oxopropanoate
# 2-hydroxybutanoate
# 2-hydroxymethylserine
# 2-keto-3-deoxy-D-glycero-D-galacto-nonopyranulosonate
# 2-methyl-1-propanol
# 2-methyl-1-propyl β-D-glucopyranoside
# 2-methyl-2-propanol
# 2-methyl-2-propyl β-D-glucopyranoside
# 2-methyl-3-oxopropanoate
# 2-methyl-4-amino-5-hydroxymethylpyrimidine diphosphate
# 2-methyleneglutarate
# 2-methylfumarate
# 2-methyliminodiacetate
# 2-methylserine
# 2-oxo-3-hydroxybutanedioic acid
# 2-oxo-3-hydroxysuccinate
# 2-oxo-4-hydroxybutanoate
# 2-oxo-4-methiolbutyrate
# 2-oxo-D-gluconate
# 2-oxo-myo-inositol
# 2-oxoadipate
# 2-oxobutanoate
# 2-oxoglutaramate
# 2-oxoglutarate
# 2-phenylethanol
# 2-phospho-D-glycerate
# 2-propanol
# 2-propyl β-D-glucopyranoside
# 2-propylhippurate
# 2-thienylacetic acid
# 2-thio-5-diphosphomevalonate
# 3'-AMP
# 3'-CMP
# 3'-GMP
# 3'-UMP
# 3'-dephospho-CoA
# 3'-phosphoadenylylsulfate
# 3,4,5-trihydroxybenzoate
# 3,4,5-trihydroxybenzoic acid propyl ester
# 3,5-dinitrophenol
# 3,5-dinitrophenolsulfate
# 3-(2-furyl)acryloylimidazole
# 3-(4-Hydroxyphenyl)pyruvate
# 3-(imidazol-4-yl)-2-oxopropyl phosphate
# 3-O-α-D-glucopyranosyl-lyxopyranose
# 3-O-β-D-galactopyranosyl-D-arabinose
# 3-Phospho-D-glycerate
# 3-Phospho-D-glyceroyl phosphate
# 3-dehydrocarnitine
# 3-dehydroquinate
# 3-dehydroshikimate
# 3-hydroxy-2-methylpropanoate
# 3-hydroxy-4-aminomethylpyridine
# 3-hydroxybenzaldehyde
# 3-hydroxybenzyl alcohol
# 3-hydroxypropanoate
# 3-hydroxypropyl phosphate
# 3-hydroxypyridine-4-aldehyde
# 3-oxo-L-threonate
# 3-oxobutanoate
# 3-oxobutanoyl-CoA
# 3-oxohexanoyl-CoA
# 3-oxolactose
# 3-oxopropanoate
# 3-phospho-D-glycerate
# 3-phospho-D-glyceroyl phosphate
# 3-phosphohydroxypyruvate
# 3-phosphonooxypyruvate
# 4',5'-anhydroadenosine
# 4,5-dihydro-4-oxo-5-imidazolepropanoate
# 4-(glutathionyl)-4-phenyl-2-butanone
# 4-O-α-D-glucopyranosyl-D-fructofuranose
# 4-aminobutanoate
# 4-hydroxy-2-oxoglutarate
# 4-hydroxybutanoate
# 4-methyl-2-oxopentanoate
# 4-methyl-2-oxopentanooate
# 4-methyl-5-(2'-hydroxyethyl)-thiazole
# 4-methyl-5-(2-phosphonoxyethyl)-thiazole
# 4-nitrophenol
# 4-nitrophenol sulfate
# 4-nitrophenyl phenylphosphonate
# 4-nitrophenyl phosphate
# 4-oxobutanoate
# 4-phospho-L-aspartate
# 5,10-Methylenetetrahydrofolate
# 5,10-methenyltetrahydrofolate
# 5,10-methylenetetrahydrofolate
# 5,10-methyltetrahydrofolate
# 5,6,7,8-Tetrahydrofolate
# 5,6,7,8-tetrahydrofolate
# 5,6-dideoxyfructose 1-phosphate
# 5-Methyltetrahydrofolate
# 5-Phospho-alpha-D-ribose 1-diphosphate
# 5-amino-1-β-D-ribosyl-4-imidazolecarboxamide 5'-phosphate
# 5-amino-4-imidazolecarboxamide
# 5-dehydroquinate
# 5-dehydroshikimate
# 5-deoxypyridoxal
# 5-deoxypyridoxamine
# 5-formiminotetrahydrofolate
# 5-formyltetrahydrofolate
# 5-hydroxy-N-methylpyroglutamate
# 5-methyluridine
# 5-oxo-D-gluconate
# 5-oxo-D-proline
# 5-phospho-α-D-ribose 1-diphosphate
# 5α-androstane-17β-ol-3-one
# 5α-androstane-3,17-dione
# 5α-androstane-3α,17β-diol
# 5α-androstane-3α-ol-17-one
# 5α-pregnane-17α,21-diol-3,20-dione
# 5α-pregnane-3α,17α,21-triol-20-one
# 5β-androstane-3,17-dione
# 5β-androstane-3α-ol-17-one
# 5β-pregnane-17α,21-diol-3,11,20-trione
# 5β-pregnane-17α,21-diol-3,20-dione
# 5β-pregnane-3α,17α,21-triol-11,20-dione
# 5β-pregnane-3α,17α,21-triol-20-one
# 6-O-α-D-galactopyranosyl-D-galactopyranose
# 6-O-α-D-mannopyranose-D-mannopyranose
# 6-amino-D-fructose 6-phosphate
# 6-amino-D-glucose
# 6-amino-D-glucose 6-phosphate
# 6-aminopenicillanate-
# 6-aminopenicillanic acid
# 6-aminopenicillanic acid-
# 6-phospho-2-dehydro-3-deoxy-D-gluconate
# 6-phospho-D-gluconate
# 6-thioglucose 1-phosphate
# 6-thioglucose 6-phosphate
# 7,8-dihydrobiopterin
# 7,8-dihydrofolate
# 7-amino-3-(1-pyridyl-methyl)-3-cephem-4-carboxylic acid
# 7-aminocephalosporanic acid
# 7-aminodeacetoxycephalosporanic acid
# 7-phenylacetamidodeacetoxycephalosporanic acid
# 9-cis,11-trans-octadecadienoate
# 9-cis,12-cis-octadecadienoate
# 9/20-DNA oligomer
# ACP
# ADP
# ADP-N1-oxide
# ADP-α-S
# ADP-β-S
# ADP3-
# ADPglucose
# AMP
# AMP2--
# AP-NAD
# AP-NADH
# ATP
# ATP-N1-oxide
# ATP-α-S
# ATP-β-S
# ATP-γ-S
# ATP4-
# Acetyl phosphate
# Acetyl-CoA
# Adenosine 3',5'-bisphosphate
# CDP
# CDP-1,2-didodecanoylglycerol
# CDP-1,2-dihexadec-9-enoylglycerol
# CDP-1,2-dihexadecanoylglycerol
# CDP-1,2-dioctadec-11-enoylglycerol
# CDP-1,2-dioctadecanoylglycerol
# CDP-1,2-ditetradec-7-enoylglycerol
# CDP-1,2-ditetradecanoylglycerol
# CDP-3,6-dideoxy-D-glucose
# CDP-3,6-dideoxy-D-mannose
# CDPcholine
# CDPethanolamine
# CDPglucose
# CH2-H4PteGlu4
# CMP
# CTP
# CoA
# CoA-glutathione
# D(-)-α-aminophenylacetic acid
# D-Erythrose 4-phosphate
# D-Fructose
# D-Fructose 1,6-bisphosphate
# D-Fructose 1-phosphate
# D-Fructose 6-phosphate
# D-Glucose
# D-Glucose 1-phosphate
# D-Glucose 6-phosphate
# D-Glycerate 2-phosphate
# D-Mannose 1-phosphate
# D-Mannose 6-phosphate
# D-Ribulose 5-phosphate
# D-Tagatose 1,6-biphosphate
# D-Tagatose 6-phosphate
# D-Xylulose 5-phosphate
# D-alanine
# D-altrose
# D-arabino-3-hexulose 6-phosphate
# D-arabinose
# D-arabinose 5-phosphate
# D-arabitol
# D-carnitine
# D-erythrose
# D-erythrose 4-phospahte
# D-erythrose 4-phosphate
# D-erythrulose
# D-fructose
# D-fructose 1,6-bisphosphate
# D-fructose 1-phosphate
# D-fructose 6-phosphate
# D-fructuronate
# D-galactono-1,4-lactone
# D-galactose
# D-galactose 6-phosphate
# D-galacturonate
# D-gluconate
# D-glucono-1,5-lactone
# D-glucono-1,5-lactone 6-phosphate
# D-glucosamine 1-phosphate
# D-glucosamine 6-phosphate
# D-glucose
# D-glucose 1-phosphate
# D-glucose 6-phosphate
# D-glucose 6-phosphate2-
# D-glucuronate
# D-glutamate
# D-glyceraldehdye-3-phosphate
# D-glyceraldehyde
# D-glyceraldehyde 3-phosphate
# D-glyceraldehyde-3-phosphate
# D-glycero-D-glucoheptitol
# D-lactate
# D-leucine
# D-lysine
# D-lyxose
# D-mannitol
# D-mannitol 1-phosphate
# D-mannose
# D-mannose 1-phosphate
# D-mannose 6-phosphate
# D-ornithine
# D-psicose
# D-rhamnose
# D-rhamnulose
# D-ribose
# D-ribose 1-phosphate
# D-ribose 5-phosphate
# D-ribulose
# D-ribulose 1,5-biphosphate
# D-ribulose 5-phosphate
# D-sedoheptulose
# D-sedoheptulose-7-phosphate
# D-serine
# D-sorbitol
# D-sorbitol 6-phosphate
# D-tagatose
# D-tagaturonate
# D-threo-2,4-diaminopentanoate
# D-turanose
# D-xylose
# D-xylulose
# D-xylulose 5-phosphate
# D-α-amino-n-butyrate
# DL-3-hydroxybutanoyl-CoA
# DL-Δ1-pyrroline-5-carboxylate
# Dihydroxyacetone
# Dihydroxyacetone phosphate
# Dodecanoate (n-C12:0)
# Formate
# G(u-6)
# G(v-7)
# G(w-8)
# GDP
# GDP-L-galactose
# GDPglucose
# GDPmannose
# GMP
# GTP
# Glycerol 3-phosphate
# Glycerophosphoglycerol
# Glycerophosphoserine
# Gu
# Guanosine 3',5'-bis(diphosphate)
# Guanosine 3'-diphosphate 5'-triphosphate
# Gv
# Gw
# H
# H2
# H2O
# H2O(1)
# H2O2
# H4PteGlu4
# HPO42-
# Hexadecanoate (n-C16:0)
# Hexadecenoate (n-C16:1)
# IDP
# IMP
# ITP
# L,L-2,6-diaminoheptanedioate
# L-2-aminoadipate
# L-4-aspartyl phosphate
# L-5-carboxymethylhydantoin
# L-Arginine
# L-Glutamate
# L-Malate
# L-Methionine
# L-O-phosphoserine
# L-Serine
# L-Threonine
# L-acetylcarnitine
# L-alanine
# L-arabinose
# L-arginine
# L-arginosuccinate
# L-asparagine
# L-aspartate
# L-aspartate 4-semialdehyde
# L-aspartate-4-semialdehyde
# L-butyrylcarnitine
# L-carnitine
# L-citrulline
# L-dibromotyrosine ethyl ester
# L-erythro-3,5-diaminohexanoate
# L-erythrulose
# L-fructose
# L-fucose
# L-fucose 1-phosphate
# L-fuculose
# L-fuculose 1-phosphate
# L-glutamate
# L-glutamine
# L-histidine
# L-histidinol phosphate
# L-homocysteine
# L-homoserine
# L-iditol
# L-lactaldehyde
# L-leucine
# L-lysine
# L-mannose
# L-methionine
# L-norleucine
# L-norvaline
# L-ornithine
# L-palmitoylcarnitine
# L-phenylalaninamide
# L-phenylalanine
# L-phenylalanine methyl ester
# L-phenylalanylglycine
# L-phenylalanylglycine methyl ester
# L-phenylglycine
# L-propionylcarnitine
# L-rhamnose
# L-rhamnulose
# L-rhamnulose 1-phosphate
# L-ribulose
# L-ribulose 5-phosphate
# L-serine
# L-sorbose
# L-threitol
# L-threo-3-methylaspartate
# L-threonate
# L-threonine
# L-tryptophan
# L-tyrosine
# L-tyrosylglycinamide
# L-valine
# L-valyl-tRNAval
# L-xylulose
# L-α-amino-n-butyrate
# L-α-glycerophosphate
# Molybdate
# N,N-dimethylglycine
# N-(5-amino-1-β-D-ribosyl-4-imidazoyl-carbonyl)-L-aspartic acid 5'-phosphate
# N-(L-argino)succinate
# N-(benzyloxycarbonyl)-L-aspartic acid
# N-(benzyloxycarbonyl)-L-aspartyl-L-phenylalanine methyl ester
# N-Formyl-L-methionine
# N-acetyl-D-glucosamine
# N-acetyl-D-glucosamine 1-phosphate
# N-acetyl-D-glucosamine 6-phosphate
# N-acetyl-D-mannosamine
# N-acetyl-D-mannosamine 6-phosphate
# N-acetyl-L-alanine
# N-acetyl-L-glutamate
# N-acetyl-L-glycine
# N-acetyl-L-methionine
# N-acetyl-L-norleucine
# N-acetyl-L-norvaline
# N-acetyl-L-phenylalanine
# N-acetyl-L-phenylalanine ethyl ester
# N-acetyl-L-phenylalanine methyl ester
# N-acetyl-L-phenylalanine-L-dibromidetyrosine ethyl ester
# N-acetyl-L-phenylalanyl-L-phenylalanylglycine
# N-acetyl-L-phenylalanyl-L-phenylalanylglycine methyl ester
# N-acetyl-L-phenylalanylglycinamide
# N-acetyl-L-tryptophan
# N-acetyl-L-tryptophan ethyl ester
# N-acetyl-L-tryptophan phenylethyl ester
# N-acetyl-L-tyrosine
# N-acetyl-L-tyrosine ethyl ester
# N-acetyl-L-tyrosine hydroxamic acid
# N-acetyl-L-valine
# N-acetyl-L-α-amino-n-butyrate
# N-acetyl-α-D-glucosamine 1-phosphate
# N-acetylethanolamine
# N-acetylethanolamine phosphate
# N-acetylimidazole
# N-acetylneuraminate
# N-benzoyl-L-tyrosinamide
# N-benzoyl-L-tyrosine
# N-benzoyl-L-tyrosylglycinamide
# N-benzoyl-L-tyrosylglycinanilide
# N-benzoyl-L-tyrosylglycine
# N-carbamoyl-L-aspartate
# N-formimino-L-glutamate
# N-formiminoglycine
# N-glycolyl-D-mannosamine
# N-glycolylneuraminate
# N-succinyl-2-L-amino-6-oxoheptanedioate
# N-succinyl-L-2,6-diaminoheptanedioate
# N2-(D-1-carboxyethyl)-L-arginine
# N2-acetyl-L-ornithine
# N4-methylcytidine
# NAD
# NADH
# NADP
# NADPH
# Nicotinate D-ribonucleotide
# Nα-benzoyl-L-argininamide
# Nα-benzoyl-L-arginine
# Nω-phospho-L-arginine
# Nω-phospholombricine
# Nω-phosphotaurocyamine
# O-acetyl-L-serine
# O-acetylcholine
# O-phospho-L-serine
# O-phosphorylethanolamine
# O-α-D-galactopyranosyl-(1->6)-O-α-D-galactopyranosyl-(1->6)-α-D-glucopyranose
# O-α-D-glucopyranosyl-(1->4)n
# O2
# Phosphatidylglycerol (dihexadec-9-enoyl, n-C16:1)
# Phosphatidylglycerol (dihexadecanoyl, n-C16:0)
# Phosphatidylglycerol (dioctadec-11-enoyl, n-C18:1)
# Phosphatidylglycerophosphate (dihexadec-9-enoyl, n-C16:1)
# Phosphatidylglycerophosphate (dihexadecanoyl, n-C16:0)
# Phosphatidylglycerophosphate (dioctadec-11-enoyl, n-C18:1)
# Pyridoxal
# Pyridoxal 5'-phosphate
# Pyridoxamine 5'-phosphate
# S-Adenosyl-L-homocysteine
# S-Adenosyl-L-methionine
# S-adenosyl-L-homocysteine
# S-adenosyl-L-methionine
# S-aminomethyldihydro-α-lipoate
# S-methylmethionine
# S-methylpropiothetin
# S-methylthioglycolate
# TDP
# TNAD
# TNADH
# TTP
# Thiamin monophosphate
# UDP
# UDP-D-fucose
# UDP-D-galacto-1,4-furanose
# UDP-D-galacturonate
# UDP-D-glucuronate
# UDP-D-quinovose
# UDP-D-xylose
# UDP-L-arabinose
# UDP-N-acetyl-D-glucosamine
# UDP-galactose
# UDP-glucose
# UDPgalactose
# UDPglucose
# UMP
# UMPimidazole
# UTP
# acetaldehyde
# acetate
# acetate-
# acetoacetate
# acetoacetyl-CoA
# acetone
# acetyl phosphate
# acetyl phosphate2-
# acetyl-CoA
# acetylcholine
# acrylylpantetheine
# adenine
# adenosine
# adenosine 2':3'-(cyclic)phosphate
# adenosine 3',5'-biphosphate
# adenosine 3'-monophosphate
# adenosine 3':5'-(cyclic)phosphate
# adenosine 5'-(α,β-methylene)diphosphate
# adenosine 5'-(α,β-methylene)triphosphate
# adenosine 5'-phosphosulfate
# adenosine 5'-tetraphosphate
# adenylosuccinate
# adenylyl sulfate
# all-trans-retinal
# allantoate
# allantoin
# allitol
# allolactose
# alpha-D-Ribose 1-phosphate
# alpha-D-Ribose 5-phosphate
# ammonia
# ammonium
# ammonium carbamate
# ampicillin
# ampicillinoic acid
# aniline
# benzaldehyde
# benzoic acid
# benzyl alcohol
# benzyloxycarbonylglycine
# benzyloxycarbonylglycyl-L-leucine
# benzyloxycarbonylglycyl-L-phenylalaninamide
# benzyloxycarbonylglycyl-L-phenylalanine
# betaine
# butanal
# butanoyl-CoA
# butyryl-CoA
# carbamoyl oxamate
# carbamoyl phosphate
# carbon dioxide
# cardiolipin (tetrahexadec-9-enoyl, n-C16:1)
# cardiolipin (tetrahexadecanoyl, n-C16:0)
# cardiolipin (tetraoctadec-11-enoyl, n-C18:1)
# cellobiose
# cellotriose
# cephalexin
# cephaloridine
# cephalothin
# chloride ion
# cholest-4-en-3-one
# cholesterol
# choline
# chorismate
# cis-3-hexenal
# cis-3-hexene-1-ol
# cis-4-hydroxy-D-proline
# cis-D-3-fluoro-2-pyrrolidone-5-carboxylate
# cis-aconitate
# cis-but-2-enoyl-CoA
# cis-cis-hexadienedioate
# cis-hex-2-enoyl-CoA
# cis-trans-hexadienedioate
# citrate
# coenzyme A
# coniferyl alcohol
# coniferyl aldehyde
# creatine
# cupric ion
# cyclocreatine
# cyclohexanol
# cyclohexanone
# cyclomaltoheptaose
# cyclomaltohexaose
# cyclomaltooctaose
# cytidine
# cytidine 2':3'-(cyclic)phosphate
# cytidine 3'-monophosphate
# cytochrome c
# dADP
# dAMP
# dATP
# dCDP
# dCMP
# dCTP
# dGDP
# dGMP
# dGTP
# dTDP
# dTDP-4-amino-4,6-dideoxy-D-glucose
# dTDP-4-dehydro-6-deoxy-D-glucose
# dTDPglucose
# dTMP
# dTTP
# dUDP
# dUMP
# dUTP
# ddcaACP
# deoxyadenosine
# deoxycytidine
# deoxyguanosine
# deoxyuridine
# dephospho-CoA
# dephosvitin
# desamino NAD
# desamino NADH
# dihydro-α-lipoate
# dihydrofolate
# dihydrolipoamide
# dihydroxyacetone
# dimethylacetothetin
# dimethylmaleate
# dimethylpropiothetin
# dimethylsulfide
# diolein
# diphosphate
# disaccharide
# enol-oxaloacetate
# enol-phenylpyruvate
# erythro-3-hydroxyaspartate
# erythrulose 1-phosphate
# estradiol-17β
# estrone
# ethanol
# ethanolamine
# ethyl β-D-glucopyranoside
# ethyl-(E)-2-octenoate
# ethylene glycol
# ethylene glycol phosphate
# ferric iron
# ferrous iron
# flavin adenine dinucleotide, oxidized
# flavin adenine dinucleotide, reduced
# flavin mononucleotide, oxidized
# flavin mononucleotide, reduced
# folate
# formaldehyde
# formate
# formyl phosphate
# formyl-CoA
# fumarate
# furylacrylic acid
# galactitol
# glucose 1-phosphate
# glutathione
# glutathione (reduced)
# glutathione derivative of (E)-2-octenal
# glutathione derivative of (E)-3-nonen-2-one
# glutathione derivative of ethyl (E)-2-octenoate
# glutathione derivative of methyl (E)-2-octenoate
# glycerol
# glycerol-1,2-dibutyrate
# glycerone phosphate
# glycinamide
# glycine
# glycolaldehyde
# glycolate
# glycyl-L-phenylalaninamide
# glycyl-L-phenylalanine
# glycylanalide
# glyoxylate
# guanidinoacetate
# guanine
# guanosine
# guanosine 2':3'-(cyclic)phosphate
# guanosine 3'-monophosphate
# guanosine 3':5'-(cyclic)phosphate
# hdeACP
# heptanoate
# heteroanilithiamine
# heteronicotinathiamine
# hexanal
# hippurate
# hippuric acid
# hippurylanilide
# hydrogen ion
# hydrogen peroxide
# hydroxylamine
# hydroxypyruvate
# hypoxanthine
# imidazole
# indole
# indole-3-lactate
# indole-3-pyruvate
# indophenol
# inosine
# inosine 3':5'-(cyclic)phosphate
# inosine 5'-diphosphate
# inosine 5'-triphosphate
# isochorismate
# isocitrate
# isomaltose
# isomaltotriose
# keto-oxaloacetate
# keto-phenylpyruvate
# lactose
# lactulose
# laminaribiose
# laminaritetraose
# laminaritriose
# lipoamide
# lombricine
# lysozyme
# lyxose
# magnesium ion
# maleate
# maltoheptaose
# maltohexaose
# maltopentaose
# maltose
# maltosyl-β-cyclomaltoheptaose
# maltotetraose
# maltotriose
# manganese ion
# meso-diaminoheptanedioate
# meso-tartrate
# methanol
# methyl α-D-glucopyranose
# methyl α-D-glucopyranoside 6-phosphate
# methyl β-D-glucopyranoside
# methyl β-D-ribofuranose
# methyl β-D-ribofuranoside 5-phosphate
# methyl-(E)-2-octenoate
# methylamine
# methylerythrulose 1-phosphate
# methylglyoxal
# methylitaconate
# methylmalonyl-CoA
# monoethyl phosphate
# monoolein
# myo-inositol
# myrsACP
# n-decanoic acid
# n-decanoic acid glycerol diester
# n-decanoic acid glycerol monoester
# n-decanoic acid glycerol triester
# n-heptanoyl-CoA
# n-octanoic acid
# n-octanoic acid glycerol diester
# n-octanoic acid glycerol monoester
# n-octanoic acid glycerol triester
# nicotinamide
# nicotinamide adenine dinucleotide phosphate, oxidized
# nicotinamide adenine dinucleotide phosphate, reduced
# nicotinamide adenine dinucleotide, oxidized
# nicotinamide adenine dinucleotide, reduced
# nicotinamide mononucleotide
# nicotinamide riboside
# nicotinate
# nicotinate/nicotinic acid mononucleotide
# nicotinic acid adenine dinucleotide
# nonanal
# norpyridoxal
# norpyridoxamine
# ocdcaACP
# octadecanoate (n-C18:0)
# octadecenoate (n-C18:1)
# octanal
# octeACP
# oleic acid
# ornithine
# orotate
# orotidine 5'-phosphate
# orthophospate
# orthophosphate
# oxaloacetate
# oxamate
# oxidized glutathione
# oxidized thiocyanate
# oxygen
# palatinose
# palmACP
# palmitate
# palmitoyl-CoA
# panose
# pantoic acid
# pantothenate
# penicic acid
# penicillin G
# penicillin G-
# penicillinoic acid
# phenol
# phenoxyacetate
# phenoxymethylpenicillin
# phenoxymethylpenicillin-
# phenoxymethylpenicillinoic acid
# phenyl phosphate
# phenyl α-D-glucopyranoside
# phenyl α-maltoside
# phenylacetic acid
# phenylacetyl-L-phenylglycine
# phenylacetylglycine
# phenylphosphonate
# phenylpyruvate
# phosphate
# phospho-L-arginine
# phospho-β-guanadinopropionate
# phosphocreatine
# phosphocyclocreatine
# phosphoenolpyruvate
# phosphoenolpyruvate kinase
# phosphoenolpyruvate3-
# phosphoguanidinoacetate
# phospholysozyme
# phosphonate
# phosphoribosyl-1-O-(2-thiodiphosphate)
# phosphoryl-choline
# phosphorylcholine
# phosphoserine
# phosphotaurocyamine
# phosvitin
# potassium ion
# prephenate
# propan-1-ol
# propanal
# propanoate
# propanonyl-CoA
# propanoyl-CoA
# propionaldehyde
# propionate
# propionyl-CoA
# propionylcholine
# putrescine
# pyocyanine
# pyridoxal
# pyridoxamine
# pyrophosphate
# pyrophosphate  This is an approximate result.
# pyruvate
# pyruvate kinase
# pyruvate-
# quinate
# raffinose
# reduced cytochrome c
# reduced glutathione
# reduced indophenol
# reduced pyocyanine
# retinol
# retinyl palmitate
# ribitol
# riboflavin, oxidized
# riboflavin, reduced
# sedoheptulose 7-phosphate
# sepiapterin
# shikimate
# sinapate
# sn-Glycero-3-phospho-1-inositol
# sn-Glycero-3-phosphocholine
# sn-Glycero-3-phosphoethanolamine
# sn-glycerol 3-phosphate
# sn-glycerol-1-phosphate
# spermidine
# stachyose
# succinate
# succinyl-CoA
# sucrose
# sucrose 6-phosphate
# sulfate
# sulphate
# tRNAval
# taurocyamine
# tdeACP
# tetradecanoate (n-C14:0)
# tetradecenoate (n-C14:1)
# tetrahydrofolate
# tetrahydroxypteridine
# tetrasaccharide
# thiamine
# thiamine diphosphate
# thiamine monophosphate
# thiocyanate
# thiopyrophosphate
# thymidine
# thymine
# trans-2-hexenal
# trans-2-hexene-1-ol
# trans-4-hydroxy-L-proline
# trans-D-3-fluoro-2-pyrrolidone-5-carboxylate
# trans-but-2-enoyl-CoA
# trans-cinnamate
# trans-hex-2-enoyl-CoA
# tributyrylglycerol
# trimetaphosphate
# trimethylsulfonium
# triolein
# triphosphate
# trisaccharide
# unknown
# uracil
# urate
# urea
# uridine
# uridine 2':3'-(cyclic)phosphate
# uridine 3'-monophosphate
# uridine 3':5'-(cyclic)phosphate
# urocanate
# vitamin A alcohol
# vitamin A aldehyde
# water
# xanthine
# xanthine-8-carboxylate
# xanthosine
# xylitol
# zinc ion
# Î¿-methylpyridoxal
# Î¿-methylpyridoxamine
# Δ1-pyrroline-2-carboxylate
# α,α-trehalose
# α-D-galactose 1-phosphate
# α-D-glucose 1,6-diphosphate
# α-D-glucose 1-phosphate
# α-D-glucose 6-phosphate
# α-D-mannose 1-phosphate
# α-D-melibiose
# α-D-ribose 1-phosphate
# α-isomaltose
# α-lipoate
# β-(3,5-diiodo-4-hydroxyphenyl)lactate
# β-(3,5-diiodo-4-hydroxyphenyl)pyruvate
# β-D-allose
# β-D-glucose
# β-D-glucose 1-phosphate
# β-D-glucose 6-phosphate
# β-D-melibiose
# β-alanine
# β-alanylpantetheine
# β-gentiobiose
# β-guanadinopropionate
# β-guanidopropionate
# β-isomaltose
# β-nicotinamide mononucleotide
# β-phosphoguanidopropionate
# γ-/glutamohydroxamic acid
# γ-fluoroglutamate
# union reactions:	 31
# triose-phosphate isomerase
# phosphoglycerate mutase
# malate dehydrogenase
# phosphoglucomutase
# acetate kinase
# glyceraldehyde-3-phosphate dehydrogenase
# phosphoglycerate kinase
# nicotinamide-nucleotide adenylyltransferase
# pyruvate kinase
# glucose-6-phosphate isomerase
# ribose-5-phosphate isomerase
# transaldolase
# D-lactate dehydrogenase
# dephospho-CoA kinase
# adenine phosphoribosyltransferase
# UDPglucose 4-epimerase
# ornithine carbamoyltransferase
# adenosylhomocysteinase
# carbamate kinase
# methenyltetrahydrofolate cyclohydrolase
# deoxyribose-phosphate aldolase
# transketolase
# formate-tetrahydrofolate ligase
# dihydrofolate reductase
# homocysteine S-methyltransferase
# NADH dehydrogenase
# cytidine deaminase
# thymidylate synthase
# phosphomannomutase
# glycerol kinase
# arginine deiminase
#
#
# complete compounds set:	 496
# "with open('2021-04-30_APF_ModelSEED formatted reactions.tsv', 'w') as output:\n    output.write('\t'.join(['NAMES','reaction', '\n']))\n    for reaction in complete_thermodynamic_reactions:\n        output.write('\t'.join([reaction, ]) + '\n')"
